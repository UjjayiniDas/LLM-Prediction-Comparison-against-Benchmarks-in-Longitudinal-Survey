# %% [markdown]
# ### Import Libraries and Reproducibility

# %%
import sys, os, re, json, pandas as pd, numpy as np
from datetime import datetime
from collections import Counter
from tqdm.auto import tqdm
import transformers

SEED = 22
transformers.set_seed(SEED)
rng = np.random.default_rng(SEED)

# %% [markdown]
# ### Configuration and Instructions

# %%
TRAIN_PATH = "train_w4.csv"
TEST_PATH  = "test_w4.csv"
LABEL      = "SNAP"
OUTPUT_DIR = "./results_wave4"
os.makedirs(OUTPUT_DIR, exist_ok=True)

MODEL_ID = "mlx-community/Qwen2.5-1.5B-Instruct-4bit"

# ── Feature sets ────────────────────────────────────────────────────────
# SNAP_wave1, SNAP_wave2 and SNAP_wave3 are LONGITUDINAL predictors: self-reported Wave 1, 2 and 3 SNAP
# participation carried forward into the Wave 4 feature set.

DEMO_FEATURES     = [
    "marital.status", "sex", "hispanic.origin", "race",
    "education", "citizenship", "employment", "state", "age",
]
INCOME_FEATURES   = DEMO_FEATURES + ["income"]
LONGITUDINAL_FEATURES = ["SNAP_wave1"] + ["SNAP_wave2"] + ["SNAP_wave3"]
FULL_FEATURES     = INCOME_FEATURES + LONGITUDINAL_FEATURES          # canonical Wave 4 full model
MINIMAL_FEATURES  = ["income", "employment", "education", "SNAP_wave1", "SNAP_wave2", "SNAP_wave3"]

COL_MAP = {
    "marital.status":  "Marital Status",
    "sex":             "Sex",
    "hispanic.origin": "Hispanic Origin",
    "race":            "Race",
    "education":       "Educational Attainment",
    "citizenship":     "Citizenship",
    "employment":      "Employment Status",
    "state":           "State of Residence",
    "age":             "Age",
    "income":          "Income (Wave 3)",
    "SNAP_wave1":      "SNAP Coverage in Wave 1 (Prior Wave)",
    "SNAP_wave2":      "SNAP Coverage in Wave 2 (Prior Wave)",
    "SNAP_wave3":      "SNAP Coverage in Wave 3 (Most Recent Prior Wave)",
    "SNAP":            "Coverage for SNAP in Wave 4",
}

# ── Instructions ────────────────────────────────────────────────────────
INSTRUCTION_STRUCTURED = (
    "You are an expert text classifier. "
    "The Supplemental Nutrition Assistance Program (SNAP) provides food-purchasing "
    "assistance to low-income individuals and families in the U.S. "
    "You will be given a respondent's demographic information and income from "
    "Wave 4 of the 2014 Survey of Income and Program Participation (SIPP), "
    "along with whether they had SNAP coverage in Wave 1 (first prior survey wave), Wave 2 (second prior survey wave) and in Wave 3 (the most recent prior survey wave)."
    "This Wave 1, 2 and 3 SNAP status captures prior "
    "program participation and benefit receipt for that individual. "
    "Based on all this information, classify if the person has SNAP coverage in Wave 4. "
    "Return only one label: 'Yes' or 'No', without any other text.\n"
)

INSTRUCTION_NARRATIVE = (
    "You are an expert text classifier. "
    "The Supplemental Nutrition Assistance Program (SNAP) provides food assistance "
    "to low-income households in the U.S. "
    "You will read a short profile of a survey respondent from the 2014 Survey of "
    "Income and Program Participation (SIPP), Wave 4. "
    "The profile includes whether the respondent received SNAP in Wave 3 (the "
    "immediately preceding survey wave), in Wave 2 (the wave prior to wave 3) and in Wave 1 (the wave prior to wave 2). "
    "Based on the full profile, decide whether this person has SNAP coverage in Wave 4. "
    "Return only one label: 'Yes' or 'No', without any other text.\n"
)

INSTRUCTION_MINIMAL = INSTRUCTION_STRUCTURED

# %% [markdown]
# ### Data Loading

# %%
df_train = pd.read_csv(TRAIN_PATH)
df_test  = pd.read_csv(TEST_PATH)

print(f"Train : {len(df_train):,} rows | SNAP distribution: {dict(Counter(df_train[LABEL]))}")
print(f"Test  : {len(df_test):,} rows  | SNAP distribution: {dict(Counter(df_test[LABEL]))}")

# Sanity-check that the longitudinal predictors are present
assert "SNAP_wave1" in df_train.columns, "SNAP_wave1 column missing from train_w4.csv"
assert "SNAP_wave1" in df_test.columns,  "SNAP_wave1 column missing from test_w4.csv"
print("\nSNAP_wave1 confirmed in both splits.")
print(f"Train SNAP_wave1 dist : {dict(Counter(df_train['SNAP_wave1']))}")
print(f"Test  SNAP_wave1 dist : {dict(Counter(df_test['SNAP_wave1']))}")

assert "SNAP_wave2" in df_train.columns, "SNAP_wave2 column missing from train_w4.csv"
assert "SNAP_wave2" in df_test.columns,  "SNAP_wave2 column missing from test_w4.csv"
print("\nSNAP_wave2 confirmed in both splits.")
print(f"Train SNAP_wave2 dist : {dict(Counter(df_train['SNAP_wave2']))}")
print(f"Test  SNAP_wave2 dist : {dict(Counter(df_test['SNAP_wave2']))}")

assert "SNAP_wave3" in df_train.columns, "SNAP_wave3 column missing from train_w4.csv"
assert "SNAP_wave3" in df_test.columns,  "SNAP_wave3 column missing from test_w4.csv"
print("\nSNAP_wave3 confirmed in both splits.")
print(f"Train SNAP_wave3 dist : {dict(Counter(df_train['SNAP_wave3']))}")
print(f"Test  SNAP_wave3 dist : {dict(Counter(df_test['SNAP_wave3']))}")
# Out:
# Train : 14,395 rows | SNAP distribution: {'No': 12864, 'Yes': 1531}
# Test  : 6,167 rows  | SNAP distribution: {'No': 5512, 'Yes': 655}
#
# SNAP_wave1 confirmed in both splits.
# Train SNAP_wave1 dist : {'No': 12880, 'Yes': 1515}
# Test  SNAP_wave1 dist : {'No': 5549, 'Yes': 618}
#
# SNAP_wave2 confirmed in both splits.
# Train SNAP_wave2 dist : {'No': 12777, 'Yes': 1618}
# Test  SNAP_wave2 dist : {'No': 5516, 'Yes': 651}
#
# SNAP_wave3 confirmed in both splits.
# Train SNAP_wave3 dist : {'No': 12818, 'Yes': 1577}
# Test  SNAP_wave3 dist : {'No': 5500, 'Yes': 667}

# %% [markdown]
# ### Oversampling

# %%
def oversample_minority(df, label_col, seed=SEED):
    majority = df[df[label_col] == "No"]
    minority = df[df[label_col] == "Yes"]
    minority_upsampled = minority.sample(
        n=len(majority), replace=True, random_state=seed
    )
    return pd.concat([majority, minority_upsampled]).sample(
        frac=1, random_state=seed
    ).reset_index(drop=True)

df_train_balanced = oversample_minority(df_train, LABEL)
print(f"\nBalanced train: {len(df_train_balanced):,} rows | "
      f"SNAP distribution: {dict(Counter(df_train_balanced[LABEL]))}")
# Out:
# Balanced train: 25,728 rows | SNAP distribution: {'Yes': 12864, 'No': 12864}

# %% [markdown]
# ### Prompt Builders

# %%
def build_structured_prompt(row, features, instruction=INSTRUCTION_STRUCTURED):
    user_content = "\n".join(
        f"{COL_MAP[k]}: {row[k]}" for k in features if k in row
    )
    return {
        "prompt":     [{"role": "system",    "content": instruction},
                       {"role": "user",      "content": user_content}],
        "completion": [{"role": "assistant", "content": str(row[LABEL])}],
    }


def build_narrative_prompt(row, features, instruction=INSTRUCTION_NARRATIVE):
    age        = row.get("age", "unknown age")
    sex        = row.get("sex", "").lower()
    hispanic   = row.get("hispanic.origin", "")
    race       = row.get("race", "")
    ethnicity  = f"{hispanic} {race}".strip()
    marital    = row.get("marital.status", "").lower()
    edu        = row.get("education", "").lower()
    employment = row.get("employment", "").lower()
    state      = row.get("state", "")
    income     = row.get("income", "")
    citizenship = row.get("citizenship", "").lower()
    snap_w1    = row.get("SNAP_wave1", "Unknown")
    snap_w2    = row.get("SNAP_wave2", "Unknown")
    snap_w3    = row.get("SNAP_wave3", "Unknown")

    narrative = (
        f"A {age}-year-old {ethnicity} {sex}, {marital}, residing in {state}. "
        f"Educational attainment: {edu}. "
        f"Citizenship: {citizenship}. "
        f"Employment in the reference month: {employment}. "
        f"Monthly household income (Wave 4): {income}. "
        f"SNAP coverage in Wave 1 (first prior wave): {snap_w1}."
        f"SNAP coverage in Wave 2 (second prior wave): {snap_w2}."
        f"SNAP coverage in Wave 3 (most recent prior wave): {snap_w3}."

    )
    return {
        "prompt":     [{"role": "system",    "content": instruction},
                       {"role": "user",      "content": narrative}],
        "completion": [{"role": "assistant", "content": str(row[LABEL])}],
    }


def make_dataset(df, prompt_fn, features):
    from datasets import Dataset
    records = [prompt_fn(row, features) for _, row in df.iterrows()]
    return Dataset.from_list(records)

# %% [markdown]
# ### Export to JSONL (MLX Format)

# %%
def export_to_jsonl(df, prompt_fn, features, path):
    with open(path, "w") as f:
        for _, row in df.iterrows():
            sample   = prompt_fn(row, features)
            messages = sample["prompt"] + sample["completion"]
            f.write(json.dumps({"messages": messages}) + "\n")


# Experiment matrix — same as Wave 1, 2 and 3 structure T2A uses INCOME_FEATURES
# (demographics + income, no longitudinal predictor) T2C_longitudinal_model uses
# SNAP_wave1, SNAP_wave2, SNAP_wave3 only as features.
experiments_data = {
    "T1A_imbalanced":   (df_train,          build_structured_prompt, FULL_FEATURES,     FULL_FEATURES),
    "T1B_oversampled":  (df_train_balanced,  build_structured_prompt, FULL_FEATURES,     FULL_FEATURES),
    "T2A_demo_only":    (df_train,          build_structured_prompt, INCOME_FEATURES,     INCOME_FEATURES),
    "T2C_longitudinal_model":   (df_train,          build_structured_prompt, LONGITUDINAL_FEATURES,     LONGITUDINAL_FEATURES),
    "T3A_narrative":    (df_train,          build_narrative_prompt,  FULL_FEATURES,     FULL_FEATURES),
    "T3B_minimal":      (df_train,          build_structured_prompt, MINIMAL_FEATURES,  MINIMAL_FEATURES),
}

os.makedirs("./mlx_data", exist_ok=True)
for run_label, (train_df, prompt_fn, train_feats, val_feats) in experiments_data.items():
    folder = f"./mlx_data/{run_label}"
    os.makedirs(folder, exist_ok=True)
    export_to_jsonl(train_df, prompt_fn, train_feats, f"{folder}/train.jsonl")
    export_to_jsonl(df_test,  prompt_fn, val_feats,   f"{folder}/valid.jsonl")
    print(f"Exported {folder}/")
# Out:
# Exported ./mlx_data/T1A_imbalanced/
# Exported ./mlx_data/T1B_oversampled/
# Exported ./mlx_data/T2A_demo_only/
# Exported ./mlx_data/T2C_longitudinal_model/
# Exported ./mlx_data/T3A_narrative/
# Exported ./mlx_data/T3B_minimal/

# %% [markdown]
# ### Making Test Datasets

# %%
test_ds_structured_full     = make_dataset(df_test, build_structured_prompt, FULL_FEATURES)
test_ds_structured_demo     = make_dataset(df_test, build_structured_prompt, INCOME_FEATURES)
test_ds_structured_longitudinal  = make_dataset(df_test, build_structured_prompt, LONGITUDINAL_FEATURES)
test_ds_narrative_full      = make_dataset(df_test, build_narrative_prompt,  FULL_FEATURES)
test_ds_structured_minimal  = make_dataset(df_test, build_structured_prompt, MINIMAL_FEATURES)
print("Test datasets ready.")
# Out:
# Test datasets ready.

# %% [markdown]
# ### Defining Predictions

# %%
from sklearn.metrics import (
    accuracy_score, f1_score, precision_score,
    recall_score, classification_report
)

def evaluate_predictions(predictions, references, label_name=""):
    valid         = [(p, r) for p, r in zip(predictions, references) if p in ["Yes", "No"]]
    unknown_count = len(predictions) - len(valid)
    if not valid:
        print("No valid predictions.")
        return {}
    y_pred, y_true = zip(*valid)
    metrics = {
        "Label":     label_name,
        "N_test":    len(df_test),
        "Accuracy":  round(accuracy_score(y_true, y_pred), 4),
        "Recall":    round(recall_score(y_true, y_pred, pos_label="Yes"), 4),
        "Precision": round(precision_score(y_true, y_pred, pos_label="Yes", zero_division=0), 4),
        "F1":        round(f1_score(y_true, y_pred, pos_label="Yes"), 4),
        "Unknown":   unknown_count,
    }
    print(f"\n── {label_name} ──")
    for k, v in metrics.items():
        print(f"  {k}: {v}")
    print(classification_report(y_true, y_pred, zero_division=0))
    return metrics

# %% [markdown]
# ### Calibration Analytics

# %%
import matplotlib.pyplot as plt
from sklearn.calibration import calibration_curve

def calibration_analysis(probabilities, references, label_name, save_path):
    y_true_bin = [1 if r == "Yes" else 0 for r in references]
    probs      = np.array(probabilities)

    n_bins    = 10
    bin_edges = np.linspace(0, 1, n_bins + 1)
    ece       = 0.0
    for i in range(n_bins):
        mask = (probs >= bin_edges[i]) & (probs < bin_edges[i + 1])
        if mask.sum() == 0:
            continue
        bin_acc  = np.mean(np.array(y_true_bin)[mask])
        bin_conf = np.mean(probs[mask])
        ece += mask.sum() / len(probs) * abs(bin_acc - bin_conf)

    frac_pos, mean_pred = calibration_curve(y_true_bin, probs, n_bins=10)
    fig, ax = plt.subplots(figsize=(6, 6))
    ax.plot([0, 1], [0, 1], "k--", label="Perfect calibration")
    ax.plot(mean_pred, frac_pos, "s-", label=f"{label_name} (ECE={ece:.4f})")
    ax.set_xlabel("Mean predicted probability")
    ax.set_ylabel("Fraction of positives")
    ax.set_title(f"Reliability Diagram — {label_name}")
    ax.legend()
    plt.tight_layout()
    plt.savefig(save_path, dpi=150)
    plt.close()
    print(f"  ECE: {ece:.4f} | Saved → {save_path}")
    return round(ece, 4)

# %% [markdown]
# ### Run Inference Function

# %%
from mlx_lm import load, generate

def format_chat_prompt(prompt_list):
    return "".join(
        f"<|{m['role']}|>\n{m['content']}\n" for m in prompt_list
    ) + "<|assistant|>\n"


def run_inference_mlx(model, tokenizer, dataset, return_probs=False):
    predictions, references, probabilities = [], [], []

    for example in tqdm(dataset, desc="Generating"):
        prompt_text = format_chat_prompt(example["prompt"])
        response    = generate(
            model, tokenizer,
            prompt=prompt_text,
            max_tokens=5,
            verbose=False
        )
        match = re.search(r"\b(Yes|No)\b", response, re.IGNORECASE)
        predictions.append(match.group(1).title() if match else "Unknown")
        references.append(example["completion"][0]["content"].strip().title())

        if return_probs:
            if match:
                probabilities.append(1.0 if match.group(1).title() == "Yes" else 0.0)
            else:
                probabilities.append(0.5)

    if return_probs:
        return predictions, references, probabilities
    return predictions, references

# %% [markdown]
# ### LoRA Configuration

# %%
import yaml

lora_config = {
    "lora_parameters": {
        "rank":    16,
        "scale":   2.0,   # equivalent to alpha=32 with rank=16 (scale = alpha/rank)
        "dropout": 0.05,
    }
}

os.makedirs("./configs", exist_ok=True)
with open("./configs/lora_config.yaml", "w") as f:
    yaml.dump(lora_config, f)

print("LoRA config saved to ./configs/lora_config.yaml")
# Out:
# LoRA config saved to ./configs/lora_config.yaml

# %% [markdown]
# ### Training and Inference for T1A_imbalanced

# %%
# !mlx_lm.lora \
  --model mlx-community/Qwen2.5-1.5B-Instruct-4bit \
  --train \
  --data ./mlx_data/T1A_imbalanced \
  --num-layers 16 \
  --batch-size 4 \
  --grad-accumulation-steps 4 \
  --iters 2000 \
  --learning-rate 2e-4 \
  --mask-prompt \
  --adapter-path ./adapters_w4/T1A_imbalanced \
  --save-every 500 \
  -c ./configs/lora_config.yaml
# Out:
# Loading configuration file ./configs/lora_config.yaml
# Loading pretrained model
# Downloading (incomplete total...): 0.00B [00:00, ?B/s]
# Fetching 9 files: 100%|████████████████████████| 9/9 [00:00<00:00, 75497.47it/s]
# Download complete: : 0.00B [00:00, ?B/s]
# Loading datasets
# Training
# Trainable parameters: 0.684% (10.551M/1543.714M)
# Starting training..., iters: 2000
# Calculating loss...: 100%|██████████████████████| 25/25 [00:27<00:00,  1.10s/it]
# Iter 1: Val loss 7.474, Val took 27.387s
# Iter 10: Train loss 3.455, Learning Rate 2.000e-04, It/sec 0.455, Tokens/sec 7.283, Trained Tokens 160, Peak mem 6.846 GB
# Iter 20: Train loss 0.124, Learning Rate 2.000e-04, It/sec 0.474, Tokens/sec 7.577, Trained Tokens 320, Peak mem 6.846 GB
# Iter 30: Train loss 0.041, Learning Rate 2.000e-04, It/sec 0.480, Tokens/sec 7.675, Trained Tokens 480, Peak mem 6.846 GB
# Iter 40: Train loss 0.025, Learning Rate 2.000e-04, It/sec 0.476, Tokens/sec 7.616, Trained Tokens 640, Peak mem 6.846 GB
# Iter 50: Train loss 0.034, Learning Rate 2.000e-04, It/sec 0.479, Tokens/sec 7.657, Trained Tokens 800, Peak mem 6.846 GB
# Iter 60: Train loss 0.022, Learning Rate 2.000e-04, It/sec 0.480, Tokens/sec 7.677, Trained Tokens 960, Peak mem 6.846 GB
# Iter 70: Train loss 0.063, Learning Rate 2.000e-04, It/sec 0.478, Tokens/sec 7.651, Trained Tokens 1120, Peak mem 6.846 GB
# Iter 80: Train loss 0.068, Learning Rate 2.000e-04, It/sec 0.478, Tokens/sec 7.649, Trained Tokens 1280, Peak mem 6.846 GB
# Iter 90: Train loss 0.025, Learning Rate 2.000e-04, It/sec 0.479, Tokens/sec 7.668, Trained Tokens 1440, Peak mem 6.846 GB
# Iter 100: Train loss 0.013, Learning Rate 2.000e-04, It/sec 0.479, Tokens/sec 7.667, Trained Tokens 1600, Peak mem 6.846 GB
# Iter 110: Train loss 0.003, Learning Rate 2.000e-04, It/sec 0.478, Tokens/sec 7.652, Trained Tokens 1760, Peak mem 6.846 GB
# Iter 120: Train loss 0.002, Learning Rate 2.000e-04, It/sec 0.479, Tokens/sec 7.658, Trained Tokens 1920, Peak mem 6.846 GB
# Iter 130: Train loss 0.000, Learning Rate 2.000e-04, It/sec 0.478, Tokens/sec 7.646, Trained Tokens 2080, Peak mem 6.846 GB
# Iter 140: Train loss 0.000, Learning Rate 2.000e-04, It/sec 0.479, Tokens/sec 7.658, Trained Tokens 2240, Peak mem 6.846 GB
# Iter 150: Train loss 0.048, Learning Rate 2.000e-04, It/sec 0.480, Tokens/sec 7.674, Trained Tokens 2400, Peak mem 6.846 GB
# Iter 160: Train loss 0.046, Learning Rate 2.000e-04, It/sec 0.478, Tokens/sec 7.646, Trained Tokens 2560, Peak mem 6.846 GB
# Iter 170: Train loss 0.035, Learning Rate 2.000e-04, It/sec 0.478, Tokens/sec 7.646, Trained Tokens 2720, Peak mem 6.846 GB
# Iter 180: Train loss 0.039, Learning Rate 2.000e-04, It/sec 0.478, Tokens/sec 7.654, Trained Tokens 2880, Peak mem 6.846 GB
# Iter 190: Train loss 0.011, Learning Rate 2.000e-04, It/sec 0.477, Tokens/sec 7.632, Trained Tokens 3040, Peak mem 6.846 GB
# Calculating loss...: 100%|██████████████████████| 25/25 [00:26<00:00,  1.07s/it]
# Iter 200: Val loss 0.047, Val took 26.843s
# Iter 200: Train loss 0.006, Learning Rate 2.000e-04, It/sec 0.478, Tokens/sec 7.647, Trained Tokens 3200, Peak mem 6.846 GB
# Iter 210: Train loss 0.001, Learning Rate 2.000e-04, It/sec 0.478, Tokens/sec 7.653, Trained Tokens 3360, Peak mem 6.846 GB
# Iter 220: Train loss 0.093, Learning Rate 2.000e-04, It/sec 0.479, Tokens/sec 7.664, Trained Tokens 3520, Peak mem 6.846 GB
# Iter 230: Train loss 0.115, Learning Rate 2.000e-04, It/sec 0.477, Tokens/sec 7.637, Trained Tokens 3680, Peak mem 6.846 GB
# Iter 240: Train loss 0.026, Learning Rate 2.000e-04, It/sec 0.473, Tokens/sec 7.574, Trained Tokens 3840, Peak mem 6.846 GB
# Iter 250: Train loss 0.027, Learning Rate 2.000e-04, It/sec 0.483, Tokens/sec 7.730, Trained Tokens 4000, Peak mem 6.846 GB
# Iter 260: Train loss 0.046, Learning Rate 2.000e-04, It/sec 0.427, Tokens/sec 6.840, Trained Tokens 4160, Peak mem 6.846 GB
# Iter 270: Train loss 0.055, Learning Rate 2.000e-04, It/sec 0.475, Tokens/sec 7.599, Trained Tokens 4320, Peak mem 6.846 GB
# Iter 280: Train loss 0.018, Learning Rate 2.000e-04, It/sec 0.466, Tokens/sec 7.463, Trained Tokens 4480, Peak mem 6.846 GB
# Iter 290: Train loss 0.056, Learning Rate 2.000e-04, It/sec 0.468, Tokens/sec 7.481, Trained Tokens 4640, Peak mem 6.846 GB
# Iter 300: Train loss 0.094, Learning Rate 2.000e-04, It/sec 0.451, Tokens/sec 7.220, Trained Tokens 4800, Peak mem 6.846 GB
# Iter 310: Train loss 0.034, Learning Rate 2.000e-04, It/sec 0.478, Tokens/sec 7.641, Trained Tokens 4960, Peak mem 6.846 GB
# Iter 320: Train loss 0.052, Learning Rate 2.000e-04, It/sec 0.478, Tokens/sec 7.641, Trained Tokens 5120, Peak mem 6.846 GB
# Iter 330: Train loss 0.043, Learning Rate 2.000e-04, It/sec 0.481, Tokens/sec 7.691, Trained Tokens 5280, Peak mem 6.846 GB
# Iter 340: Train loss 0.057, Learning Rate 2.000e-04, It/sec 0.479, Tokens/sec 7.670, Trained Tokens 5440, Peak mem 6.846 GB
# Iter 350: Train loss 0.036, Learning Rate 2.000e-04, It/sec 0.477, Tokens/sec 7.629, Trained Tokens 5600, Peak mem 6.846 GB
# Iter 360: Train loss 0.006, Learning Rate 2.000e-04, It/sec 0.459, Tokens/sec 7.347, Trained Tokens 5760, Peak mem 6.846 GB
# Iter 370: Train loss 0.047, Learning Rate 2.000e-04, It/sec 0.465, Tokens/sec 7.447, Trained Tokens 5920, Peak mem 7.397 GB
# Iter 380: Train loss 0.008, Learning Rate 2.000e-04, It/sec 0.466, Tokens/sec 7.463, Trained Tokens 6080, Peak mem 7.397 GB
# Iter 390: Train loss 0.008, Learning Rate 2.000e-04, It/sec 0.485, Tokens/sec 7.754, Trained Tokens 6240, Peak mem 7.397 GB
# Calculating loss...: 100%|██████████████████████| 25/25 [00:27<00:00,  1.08s/it]
# Iter 400: Val loss 0.054, Val took 27.041s
# Iter 400: Train loss 0.027, Learning Rate 2.000e-04, It/sec 0.473, Tokens/sec 7.563, Trained Tokens 6400, Peak mem 7.397 GB
# Iter 410: Train loss 0.003, Learning Rate 2.000e-04, It/sec 0.467, Tokens/sec 7.479, Trained Tokens 6560, Peak mem 7.397 GB
# Iter 420: Train loss 0.040, Learning Rate 2.000e-04, It/sec 0.453, Tokens/sec 7.246, Trained Tokens 6720, Peak mem 7.397 GB
# Iter 430: Train loss 0.077, Learning Rate 2.000e-04, It/sec 0.477, Tokens/sec 7.626, Trained Tokens 6880, Peak mem 7.397 GB
# Iter 440: Train loss 0.001, Learning Rate 2.000e-04, It/sec 0.464, Tokens/sec 7.420, Trained Tokens 7040, Peak mem 7.397 GB
# Iter 450: Train loss 0.050, Learning Rate 2.000e-04, It/sec 0.459, Tokens/sec 7.337, Trained Tokens 7200, Peak mem 7.397 GB
# Iter 460: Train loss 0.004, Learning Rate 2.000e-04, It/sec 0.461, Tokens/sec 7.374, Trained Tokens 7360, Peak mem 7.397 GB
# Iter 470: Train loss 0.008, Learning Rate 2.000e-04, It/sec 0.461, Tokens/sec 7.379, Trained Tokens 7520, Peak mem 7.397 GB
# Iter 480: Train loss 0.078, Learning Rate 2.000e-04, It/sec 0.461, Tokens/sec 7.370, Trained Tokens 7680, Peak mem 7.397 GB
# Iter 490: Train loss 0.076, Learning Rate 2.000e-04, It/sec 0.461, Tokens/sec 7.374, Trained Tokens 7840, Peak mem 7.397 GB
# Iter 500: Train loss 0.022, Learning Rate 2.000e-04, It/sec 0.460, Tokens/sec 7.355, Trained Tokens 8000, Peak mem 7.397 GB
# Iter 500: Saved adapter weights to adapters_w4/T1A_imbalanced/adapters.safetensors and adapters_w4/T1A_imbalanced/0000500_adapters.safetensors.
# Iter 510: Train loss 0.026, Learning Rate 2.000e-04, It/sec 0.458, Tokens/sec 7.328, Trained Tokens 8160, Peak mem 7.397 GB
# Iter 520: Train loss 0.043, Learning Rate 2.000e-04, It/sec 0.455, Tokens/sec 7.280, Trained Tokens 8320, Peak mem 7.397 GB
# Iter 530: Train loss 0.028, Learning Rate 2.000e-04, It/sec 0.460, Tokens/sec 7.366, Trained Tokens 8480, Peak mem 7.397 GB
# Iter 540: Train loss 0.033, Learning Rate 2.000e-04, It/sec 0.462, Tokens/sec 7.387, Trained Tokens 8640, Peak mem 7.397 GB
# Iter 550: Train loss 0.025, Learning Rate 2.000e-04, It/sec 0.457, Tokens/sec 7.310, Trained Tokens 8800, Peak mem 7.447 GB
# Iter 560: Train loss 0.016, Learning Rate 2.000e-04, It/sec 0.462, Tokens/sec 7.393, Trained Tokens 8960, Peak mem 7.447 GB
# Iter 570: Train loss 0.027, Learning Rate 2.000e-04, It/sec 0.462, Tokens/sec 7.392, Trained Tokens 9120, Peak mem 7.447 GB
# Iter 580: Train loss 0.059, Learning Rate 2.000e-04, It/sec 0.462, Tokens/sec 7.391, Trained Tokens 9280, Peak mem 7.447 GB
# Iter 590: Train loss 0.074, Learning Rate 2.000e-04, It/sec 0.461, Tokens/sec 7.373, Trained Tokens 9440, Peak mem 7.447 GB
# Calculating loss...: 100%|██████████████████████| 25/25 [00:27<00:00,  1.10s/it]
# Iter 600: Val loss 0.028, Val took 27.588s
# Iter 600: Train loss 0.006, Learning Rate 2.000e-04, It/sec 0.461, Tokens/sec 7.383, Trained Tokens 9600, Peak mem 7.447 GB
# Iter 610: Train loss 0.036, Learning Rate 2.000e-04, It/sec 0.462, Tokens/sec 7.388, Trained Tokens 9760, Peak mem 7.447 GB
# Iter 620: Train loss 0.005, Learning Rate 2.000e-04, It/sec 0.461, Tokens/sec 7.382, Trained Tokens 9920, Peak mem 7.447 GB
# Iter 630: Train loss 0.009, Learning Rate 2.000e-04, It/sec 0.461, Tokens/sec 7.383, Trained Tokens 10080, Peak mem 7.447 GB
# Iter 640: Train loss 0.009, Learning Rate 2.000e-04, It/sec 0.461, Tokens/sec 7.378, Trained Tokens 10240, Peak mem 7.447 GB
# Iter 650: Train loss 0.032, Learning Rate 2.000e-04, It/sec 0.461, Tokens/sec 7.375, Trained Tokens 10400, Peak mem 7.447 GB
# Iter 660: Train loss 0.003, Learning Rate 2.000e-04, It/sec 0.461, Tokens/sec 7.382, Trained Tokens 10560, Peak mem 7.447 GB
# Iter 670: Train loss 0.002, Learning Rate 2.000e-04, It/sec 0.462, Tokens/sec 7.388, Trained Tokens 10720, Peak mem 7.447 GB
# Iter 680: Train loss 0.026, Learning Rate 2.000e-04, It/sec 0.461, Tokens/sec 7.384, Trained Tokens 10880, Peak mem 7.447 GB
# Iter 690: Train loss 0.008, Learning Rate 2.000e-04, It/sec 0.454, Tokens/sec 7.262, Trained Tokens 11040, Peak mem 7.447 GB
# Iter 700: Train loss 0.017, Learning Rate 2.000e-04, It/sec 0.463, Tokens/sec 7.401, Trained Tokens 11200, Peak mem 7.447 GB
# Iter 710: Train loss 0.009, Learning Rate 2.000e-04, It/sec 0.462, Tokens/sec 7.396, Trained Tokens 11360, Peak mem 7.447 GB
# Iter 720: Train loss 0.006, Learning Rate 2.000e-04, It/sec 0.461, Tokens/sec 7.377, Trained Tokens 11520, Peak mem 7.447 GB
# Iter 730: Train loss 0.046, Learning Rate 2.000e-04, It/sec 0.462, Tokens/sec 7.394, Trained Tokens 11680, Peak mem 7.447 GB
# Iter 740: Train loss 0.020, Learning Rate 2.000e-04, It/sec 0.451, Tokens/sec 7.216, Trained Tokens 11840, Peak mem 7.447 GB
# Iter 750: Train loss 0.003, Learning Rate 2.000e-04, It/sec 0.460, Tokens/sec 7.366, Trained Tokens 12000, Peak mem 7.447 GB
# Iter 760: Train loss 0.092, Learning Rate 2.000e-04, It/sec 0.462, Tokens/sec 7.393, Trained Tokens 12160, Peak mem 7.447 GB
# Iter 770: Train loss 0.042, Learning Rate 2.000e-04, It/sec 0.461, Tokens/sec 7.377, Trained Tokens 12320, Peak mem 7.447 GB
# Iter 780: Train loss 0.066, Learning Rate 2.000e-04, It/sec 0.462, Tokens/sec 7.395, Trained Tokens 12480, Peak mem 7.447 GB
# Iter 790: Train loss 0.083, Learning Rate 2.000e-04, It/sec 0.462, Tokens/sec 7.398, Trained Tokens 12640, Peak mem 7.447 GB
# Calculating loss...: 100%|██████████████████████| 25/25 [00:27<00:00,  1.10s/it]
# Iter 800: Val loss 0.044, Val took 27.550s
# Iter 800: Train loss 0.026, Learning Rate 2.000e-04, It/sec 0.461, Tokens/sec 7.383, Trained Tokens 12800, Peak mem 7.447 GB
# Iter 810: Train loss 0.006, Learning Rate 2.000e-04, It/sec 0.461, Tokens/sec 7.378, Trained Tokens 12960, Peak mem 7.447 GB
# Iter 820: Train loss 0.032, Learning Rate 2.000e-04, It/sec 0.461, Tokens/sec 7.369, Trained Tokens 13120, Peak mem 7.447 GB
# Iter 830: Train loss 0.041, Learning Rate 2.000e-04, It/sec 0.461, Tokens/sec 7.370, Trained Tokens 13280, Peak mem 7.447 GB
# Iter 840: Train loss 0.038, Learning Rate 2.000e-04, It/sec 0.462, Tokens/sec 7.388, Trained Tokens 13440, Peak mem 7.447 GB
# Iter 850: Train loss 0.106, Learning Rate 2.000e-04, It/sec 0.461, Tokens/sec 7.376, Trained Tokens 13600, Peak mem 7.447 GB
# Iter 860: Train loss 0.025, Learning Rate 2.000e-04, It/sec 0.460, Tokens/sec 7.365, Trained Tokens 13760, Peak mem 7.447 GB
# Iter 870: Train loss 0.085, Learning Rate 2.000e-04, It/sec 0.461, Tokens/sec 7.368, Trained Tokens 13920, Peak mem 7.447 GB
# Iter 880: Train loss 0.013, Learning Rate 2.000e-04, It/sec 0.462, Tokens/sec 7.391, Trained Tokens 14080, Peak mem 7.447 GB
# Iter 890: Train loss 0.029, Learning Rate 2.000e-04, It/sec 0.461, Tokens/sec 7.382, Trained Tokens 14240, Peak mem 7.447 GB
# Iter 900: Train loss 0.007, Learning Rate 2.000e-04, It/sec 0.461, Tokens/sec 7.378, Trained Tokens 14400, Peak mem 7.447 GB
# Iter 910: Train loss 0.097, Learning Rate 2.000e-04, It/sec 0.462, Tokens/sec 7.396, Trained Tokens 14560, Peak mem 7.447 GB
# Iter 920: Train loss 0.048, Learning Rate 2.000e-04, It/sec 0.462, Tokens/sec 7.387, Trained Tokens 14720, Peak mem 7.447 GB
# Iter 930: Train loss 0.017, Learning Rate 2.000e-04, It/sec 0.461, Tokens/sec 7.382, Trained Tokens 14880, Peak mem 7.447 GB
# Iter 940: Train loss 0.009, Learning Rate 2.000e-04, It/sec 0.462, Tokens/sec 7.387, Trained Tokens 15040, Peak mem 7.447 GB
# Iter 950: Train loss 0.039, Learning Rate 2.000e-04, It/sec 0.462, Tokens/sec 7.386, Trained Tokens 15200, Peak mem 7.447 GB
# Iter 960: Train loss 0.088, Learning Rate 2.000e-04, It/sec 0.462, Tokens/sec 7.396, Trained Tokens 15360, Peak mem 7.447 GB
# Iter 970: Train loss 0.023, Learning Rate 2.000e-04, It/sec 0.461, Tokens/sec 7.368, Trained Tokens 15520, Peak mem 7.447 GB
# Iter 980: Train loss 0.064, Learning Rate 2.000e-04, It/sec 0.461, Tokens/sec 7.373, Trained Tokens 15680, Peak mem 7.447 GB
# Iter 990: Train loss 0.008, Learning Rate 2.000e-04, It/sec 0.462, Tokens/sec 7.389, Trained Tokens 15840, Peak mem 7.447 GB
# Calculating loss...: 100%|██████████████████████| 25/25 [00:27<00:00,  1.10s/it]
# Iter 1000: Val loss 0.017, Val took 27.556s
# Iter 1000: Train loss 0.035, Learning Rate 2.000e-04, It/sec 0.460, Tokens/sec 7.368, Trained Tokens 16000, Peak mem 7.447 GB
# Iter 1000: Saved adapter weights to adapters_w4/T1A_imbalanced/adapters.safetensors and adapters_w4/T1A_imbalanced/0001000_adapters.safetensors.
# Iter 1010: Train loss 0.005, Learning Rate 2.000e-04, It/sec 0.461, Tokens/sec 7.380, Trained Tokens 16160, Peak mem 7.447 GB
# Iter 1020: Train loss 0.013, Learning Rate 2.000e-04, It/sec 0.462, Tokens/sec 7.392, Trained Tokens 16320, Peak mem 7.447 GB
# Iter 1030: Train loss 0.052, Learning Rate 2.000e-04, It/sec 0.444, Tokens/sec 7.104, Trained Tokens 16480, Peak mem 7.447 GB
# Iter 1040: Train loss 0.018, Learning Rate 2.000e-04, It/sec 0.461, Tokens/sec 7.383, Trained Tokens 16640, Peak mem 7.447 GB
# Iter 1050: Train loss 0.043, Learning Rate 2.000e-04, It/sec 0.462, Tokens/sec 7.392, Trained Tokens 16800, Peak mem 7.447 GB
# Iter 1060: Train loss 0.007, Learning Rate 2.000e-04, It/sec 0.461, Tokens/sec 7.379, Trained Tokens 16960, Peak mem 7.447 GB
# Iter 1070: Train loss 0.012, Learning Rate 2.000e-04, It/sec 0.463, Tokens/sec 7.400, Trained Tokens 17120, Peak mem 7.447 GB
# Iter 1080: Train loss 0.033, Learning Rate 2.000e-04, It/sec 0.461, Tokens/sec 7.371, Trained Tokens 17280, Peak mem 7.447 GB
# Iter 1090: Train loss 0.038, Learning Rate 2.000e-04, It/sec 0.461, Tokens/sec 7.379, Trained Tokens 17440, Peak mem 7.447 GB
# Iter 1100: Train loss 0.089, Learning Rate 2.000e-04, It/sec 0.461, Tokens/sec 7.383, Trained Tokens 17600, Peak mem 7.447 GB
# Iter 1110: Train loss 0.008, Learning Rate 2.000e-04, It/sec 0.461, Tokens/sec 7.374, Trained Tokens 17760, Peak mem 7.447 GB
# Iter 1120: Train loss 0.092, Learning Rate 2.000e-04, It/sec 0.462, Tokens/sec 7.398, Trained Tokens 17920, Peak mem 7.447 GB
# Iter 1130: Train loss 0.049, Learning Rate 2.000e-04, It/sec 0.461, Tokens/sec 7.369, Trained Tokens 18080, Peak mem 7.447 GB
# Iter 1140: Train loss 0.078, Learning Rate 2.000e-04, It/sec 0.460, Tokens/sec 7.366, Trained Tokens 18240, Peak mem 7.447 GB
# Iter 1150: Train loss 0.069, Learning Rate 2.000e-04, It/sec 0.461, Tokens/sec 7.378, Trained Tokens 18400, Peak mem 7.447 GB
# Iter 1160: Train loss 0.020, Learning Rate 2.000e-04, It/sec 0.462, Tokens/sec 7.388, Trained Tokens 18560, Peak mem 7.447 GB
# Iter 1170: Train loss 0.007, Learning Rate 2.000e-04, It/sec 0.460, Tokens/sec 7.365, Trained Tokens 18720, Peak mem 7.447 GB
# Iter 1180: Train loss 0.017, Learning Rate 2.000e-04, It/sec 0.460, Tokens/sec 7.363, Trained Tokens 18880, Peak mem 7.447 GB
# Iter 1190: Train loss 0.019, Learning Rate 2.000e-04, It/sec 0.462, Tokens/sec 7.389, Trained Tokens 19040, Peak mem 7.447 GB
# Calculating loss...: 100%|██████████████████████| 25/25 [00:27<00:00,  1.10s/it]
# Iter 1200: Val loss 0.012, Val took 27.532s
# Iter 1200: Train loss 0.110, Learning Rate 2.000e-04, It/sec 0.460, Tokens/sec 7.366, Trained Tokens 19200, Peak mem 7.447 GB
# Iter 1210: Train loss 0.012, Learning Rate 2.000e-04, It/sec 0.462, Tokens/sec 7.393, Trained Tokens 19360, Peak mem 7.447 GB
# Iter 1220: Train loss 0.008, Learning Rate 2.000e-04, It/sec 0.461, Tokens/sec 7.368, Trained Tokens 19520, Peak mem 7.447 GB
# Iter 1230: Train loss 0.046, Learning Rate 2.000e-04, It/sec 0.461, Tokens/sec 7.383, Trained Tokens 19680, Peak mem 7.447 GB
# Iter 1240: Train loss 0.007, Learning Rate 2.000e-04, It/sec 0.462, Tokens/sec 7.387, Trained Tokens 19840, Peak mem 7.447 GB
# Iter 1250: Train loss 0.006, Learning Rate 2.000e-04, It/sec 0.462, Tokens/sec 7.391, Trained Tokens 20000, Peak mem 7.447 GB
# Iter 1260: Train loss 0.000, Learning Rate 2.000e-04, It/sec 0.461, Tokens/sec 7.377, Trained Tokens 20160, Peak mem 7.447 GB
# Iter 1270: Train loss 0.103, Learning Rate 2.000e-04, It/sec 0.462, Tokens/sec 7.385, Trained Tokens 20320, Peak mem 7.447 GB
# Iter 1280: Train loss 0.072, Learning Rate 2.000e-04, It/sec 0.460, Tokens/sec 7.366, Trained Tokens 20480, Peak mem 7.447 GB
# Iter 1290: Train loss 0.024, Learning Rate 2.000e-04, It/sec 0.461, Tokens/sec 7.380, Trained Tokens 20640, Peak mem 7.447 GB
# Iter 1300: Train loss 0.029, Learning Rate 2.000e-04, It/sec 0.461, Tokens/sec 7.377, Trained Tokens 20800, Peak mem 7.447 GB
# Iter 1310: Train loss 0.009, Learning Rate 2.000e-04, It/sec 0.462, Tokens/sec 7.386, Trained Tokens 20960, Peak mem 7.447 GB
# Iter 1320: Train loss 0.015, Learning Rate 2.000e-04, It/sec 0.461, Tokens/sec 7.384, Trained Tokens 21120, Peak mem 7.447 GB
# Iter 1330: Train loss 0.080, Learning Rate 2.000e-04, It/sec 0.461, Tokens/sec 7.383, Trained Tokens 21280, Peak mem 7.447 GB
# Iter 1340: Train loss 0.011, Learning Rate 2.000e-04, It/sec 0.461, Tokens/sec 7.380, Trained Tokens 21440, Peak mem 7.447 GB
# Iter 1350: Train loss 0.031, Learning Rate 2.000e-04, It/sec 0.462, Tokens/sec 7.385, Trained Tokens 21600, Peak mem 7.447 GB
# Iter 1360: Train loss 0.027, Learning Rate 2.000e-04, It/sec 0.462, Tokens/sec 7.396, Trained Tokens 21760, Peak mem 7.447 GB
# Iter 1370: Train loss 0.019, Learning Rate 2.000e-04, It/sec 0.461, Tokens/sec 7.377, Trained Tokens 21920, Peak mem 7.447 GB
# Iter 1380: Train loss 0.013, Learning Rate 2.000e-04, It/sec 0.461, Tokens/sec 7.383, Trained Tokens 22080, Peak mem 7.447 GB
# Iter 1390: Train loss 0.032, Learning Rate 2.000e-04, It/sec 0.462, Tokens/sec 7.391, Trained Tokens 22240, Peak mem 7.447 GB
# Calculating loss...: 100%|██████████████████████| 25/25 [00:27<00:00,  1.11s/it]
# Iter 1400: Val loss 0.057, Val took 27.650s
# Iter 1400: Train loss 0.035, Learning Rate 2.000e-04, It/sec 0.461, Tokens/sec 7.368, Trained Tokens 22400, Peak mem 7.447 GB
# Iter 1410: Train loss 0.106, Learning Rate 2.000e-04, It/sec 0.461, Tokens/sec 7.373, Trained Tokens 22560, Peak mem 7.447 GB
# Iter 1420: Train loss 0.011, Learning Rate 2.000e-04, It/sec 0.461, Tokens/sec 7.370, Trained Tokens 22720, Peak mem 7.447 GB
# Iter 1430: Train loss 0.057, Learning Rate 2.000e-04, It/sec 0.462, Tokens/sec 7.386, Trained Tokens 22880, Peak mem 7.447 GB
# Iter 1440: Train loss 0.028, Learning Rate 2.000e-04, It/sec 0.463, Tokens/sec 7.401, Trained Tokens 23040, Peak mem 7.447 GB
# Iter 1450: Train loss 0.014, Learning Rate 2.000e-04, It/sec 0.462, Tokens/sec 7.389, Trained Tokens 23200, Peak mem 7.447 GB
# Iter 1460: Train loss 0.013, Learning Rate 2.000e-04, It/sec 0.461, Tokens/sec 7.370, Trained Tokens 23360, Peak mem 7.447 GB
# Iter 1470: Train loss 0.005, Learning Rate 2.000e-04, It/sec 0.461, Tokens/sec 7.383, Trained Tokens 23520, Peak mem 7.447 GB
# Iter 1480: Train loss 0.008, Learning Rate 2.000e-04, It/sec 0.461, Tokens/sec 7.374, Trained Tokens 23680, Peak mem 7.447 GB
# Iter 1490: Train loss 0.016, Learning Rate 2.000e-04, It/sec 0.461, Tokens/sec 7.372, Trained Tokens 23840, Peak mem 7.447 GB
# Iter 1500: Train loss 0.011, Learning Rate 2.000e-04, It/sec 0.462, Tokens/sec 7.394, Trained Tokens 24000, Peak mem 7.447 GB
# Iter 1500: Saved adapter weights to adapters_w4/T1A_imbalanced/adapters.safetensors and adapters_w4/T1A_imbalanced/0001500_adapters.safetensors.
# Iter 1510: Train loss 0.030, Learning Rate 2.000e-04, It/sec 0.462, Tokens/sec 7.390, Trained Tokens 24160, Peak mem 7.447 GB
# Iter 1520: Train loss 0.096, Learning Rate 2.000e-04, It/sec 0.462, Tokens/sec 7.394, Trained Tokens 24320, Peak mem 7.447 GB
# Iter 1530: Train loss 0.017, Learning Rate 2.000e-04, It/sec 0.462, Tokens/sec 7.396, Trained Tokens 24480, Peak mem 7.447 GB
# Iter 1540: Train loss 0.060, Learning Rate 2.000e-04, It/sec 0.461, Tokens/sec 7.383, Trained Tokens 24640, Peak mem 7.447 GB
# Iter 1550: Train loss 0.028, Learning Rate 2.000e-04, It/sec 0.459, Tokens/sec 7.337, Trained Tokens 24800, Peak mem 7.447 GB
# Iter 1560: Train loss 0.028, Learning Rate 2.000e-04, It/sec 0.460, Tokens/sec 7.368, Trained Tokens 24960, Peak mem 7.447 GB
# Iter 1570: Train loss 0.058, Learning Rate 2.000e-04, It/sec 0.462, Tokens/sec 7.385, Trained Tokens 25120, Peak mem 7.447 GB
# Iter 1580: Train loss 0.050, Learning Rate 2.000e-04, It/sec 0.462, Tokens/sec 7.397, Trained Tokens 25280, Peak mem 7.447 GB
# Iter 1590: Train loss 0.019, Learning Rate 2.000e-04, It/sec 0.462, Tokens/sec 7.384, Trained Tokens 25440, Peak mem 7.447 GB
# Calculating loss...: 100%|██████████████████████| 25/25 [00:27<00:00,  1.10s/it]
# Iter 1600: Val loss 0.039, Val took 27.522s
# Iter 1600: Train loss 0.057, Learning Rate 2.000e-04, It/sec 0.461, Tokens/sec 7.372, Trained Tokens 25600, Peak mem 7.447 GB
# Iter 1610: Train loss 0.070, Learning Rate 2.000e-04, It/sec 0.461, Tokens/sec 7.375, Trained Tokens 25760, Peak mem 7.447 GB
# Iter 1620: Train loss 0.034, Learning Rate 2.000e-04, It/sec 0.461, Tokens/sec 7.375, Trained Tokens 25920, Peak mem 7.447 GB
# Iter 1630: Train loss 0.062, Learning Rate 2.000e-04, It/sec 0.461, Tokens/sec 7.381, Trained Tokens 26080, Peak mem 7.447 GB
# Iter 1640: Train loss 0.045, Learning Rate 2.000e-04, It/sec 0.461, Tokens/sec 7.371, Trained Tokens 26240, Peak mem 7.447 GB
# Iter 1650: Train loss 0.043, Learning Rate 2.000e-04, It/sec 0.462, Tokens/sec 7.387, Trained Tokens 26400, Peak mem 7.447 GB
# Iter 1660: Train loss 0.053, Learning Rate 2.000e-04, It/sec 0.462, Tokens/sec 7.386, Trained Tokens 26560, Peak mem 7.447 GB
# Iter 1670: Train loss 0.032, Learning Rate 2.000e-04, It/sec 0.462, Tokens/sec 7.388, Trained Tokens 26720, Peak mem 7.447 GB
# Iter 1680: Train loss 0.019, Learning Rate 2.000e-04, It/sec 0.457, Tokens/sec 7.306, Trained Tokens 26880, Peak mem 7.447 GB
# Iter 1690: Train loss 0.011, Learning Rate 2.000e-04, It/sec 0.463, Tokens/sec 7.412, Trained Tokens 27040, Peak mem 7.447 GB
# Iter 1700: Train loss 0.029, Learning Rate 2.000e-04, It/sec 0.461, Tokens/sec 7.376, Trained Tokens 27200, Peak mem 7.447 GB
# Iter 1710: Train loss 0.015, Learning Rate 2.000e-04, It/sec 0.461, Tokens/sec 7.379, Trained Tokens 27360, Peak mem 7.447 GB
# Iter 1720: Train loss 0.012, Learning Rate 2.000e-04, It/sec 0.461, Tokens/sec 7.380, Trained Tokens 27520, Peak mem 7.447 GB
# Iter 1730: Train loss 0.000, Learning Rate 2.000e-04, It/sec 0.462, Tokens/sec 7.398, Trained Tokens 27680, Peak mem 7.447 GB
# Iter 1740: Train loss 0.001, Learning Rate 2.000e-04, It/sec 0.462, Tokens/sec 7.387, Trained Tokens 27840, Peak mem 7.447 GB
# Iter 1750: Train loss 0.109, Learning Rate 2.000e-04, It/sec 0.462, Tokens/sec 7.390, Trained Tokens 28000, Peak mem 7.447 GB
# Iter 1760: Train loss 0.018, Learning Rate 2.000e-04, It/sec 0.462, Tokens/sec 7.388, Trained Tokens 28160, Peak mem 7.447 GB
# Iter 1770: Train loss 0.047, Learning Rate 2.000e-04, It/sec 0.462, Tokens/sec 7.387, Trained Tokens 28320, Peak mem 7.447 GB
# Iter 1780: Train loss 0.007, Learning Rate 2.000e-04, It/sec 0.461, Tokens/sec 7.375, Trained Tokens 28480, Peak mem 7.447 GB
# Iter 1790: Train loss 0.007, Learning Rate 2.000e-04, It/sec 0.462, Tokens/sec 7.397, Trained Tokens 28640, Peak mem 7.447 GB
# Calculating loss...: 100%|██████████████████████| 25/25 [00:27<00:00,  1.10s/it]
# Iter 1800: Val loss 0.036, Val took 27.524s
# Iter 1800: Train loss 0.033, Learning Rate 2.000e-04, It/sec 0.462, Tokens/sec 7.391, Trained Tokens 28800, Peak mem 7.447 GB
# Iter 1810: Train loss 0.078, Learning Rate 2.000e-04, It/sec 0.461, Tokens/sec 7.384, Trained Tokens 28960, Peak mem 7.447 GB
# Iter 1820: Train loss 0.033, Learning Rate 2.000e-04, It/sec 0.456, Tokens/sec 7.298, Trained Tokens 29120, Peak mem 7.447 GB
# Iter 1830: Train loss 0.036, Learning Rate 2.000e-04, It/sec 0.462, Tokens/sec 7.393, Trained Tokens 29280, Peak mem 7.447 GB
# Iter 1840: Train loss 0.038, Learning Rate 2.000e-04, It/sec 0.454, Tokens/sec 7.268, Trained Tokens 29440, Peak mem 7.447 GB
# Iter 1850: Train loss 0.016, Learning Rate 2.000e-04, It/sec 0.461, Tokens/sec 7.383, Trained Tokens 29600, Peak mem 7.447 GB
# Iter 1860: Train loss 0.028, Learning Rate 2.000e-04, It/sec 0.458, Tokens/sec 7.324, Trained Tokens 29760, Peak mem 7.447 GB
# Iter 1870: Train loss 0.046, Learning Rate 2.000e-04, It/sec 0.462, Tokens/sec 7.387, Trained Tokens 29920, Peak mem 7.447 GB
# Iter 1880: Train loss 0.013, Learning Rate 2.000e-04, It/sec 0.461, Tokens/sec 7.380, Trained Tokens 30080, Peak mem 7.447 GB
# Iter 1890: Train loss 0.011, Learning Rate 2.000e-04, It/sec 0.463, Tokens/sec 7.405, Trained Tokens 30240, Peak mem 7.447 GB
# Iter 1900: Train loss 0.005, Learning Rate 2.000e-04, It/sec 0.462, Tokens/sec 7.386, Trained Tokens 30400, Peak mem 7.447 GB
# Iter 1910: Train loss 0.028, Learning Rate 2.000e-04, It/sec 0.462, Tokens/sec 7.387, Trained Tokens 30560, Peak mem 7.447 GB
# Iter 1920: Train loss 0.018, Learning Rate 2.000e-04, It/sec 0.462, Tokens/sec 7.385, Trained Tokens 30720, Peak mem 7.447 GB
# Iter 1930: Train loss 0.004, Learning Rate 2.000e-04, It/sec 0.462, Tokens/sec 7.399, Trained Tokens 30880, Peak mem 7.447 GB
# Iter 1940: Train loss 0.070, Learning Rate 2.000e-04, It/sec 0.462, Tokens/sec 7.391, Trained Tokens 31040, Peak mem 7.447 GB
# Iter 1950: Train loss 0.018, Learning Rate 2.000e-04, It/sec 0.463, Tokens/sec 7.405, Trained Tokens 31200, Peak mem 7.447 GB
# Iter 1960: Train loss 0.123, Learning Rate 2.000e-04, It/sec 0.461, Tokens/sec 7.382, Trained Tokens 31360, Peak mem 7.447 GB
# Iter 1970: Train loss 0.040, Learning Rate 2.000e-04, It/sec 0.462, Tokens/sec 7.394, Trained Tokens 31520, Peak mem 7.447 GB
# Iter 1980: Train loss 0.058, Learning Rate 2.000e-04, It/sec 0.461, Tokens/sec 7.377, Trained Tokens 31680, Peak mem 7.447 GB
# Iter 1990: Train loss 0.028, Learning Rate 2.000e-04, It/sec 0.462, Tokens/sec 7.385, Trained Tokens 31840, Peak mem 7.447 GB
# Calculating loss...: 100%|██████████████████████| 25/25 [00:27<00:00,  1.10s/it]
# Iter 2000: Val loss 0.043, Val took 27.519s
# Iter 2000: Train loss 0.024, Learning Rate 2.000e-04, It/sec 0.462, Tokens/sec 7.387, Trained Tokens 32000, Peak mem 7.447 GB
# Iter 2000: Saved adapter weights to adapters_w4/T1A_imbalanced/adapters.safetensors and adapters_w4/T1A_imbalanced/0002000_adapters.safetensors.
# Saved final weights to adapters_w4/T1A_imbalanced/adapters.safetensors.

# %%
import time
# ── Initialise accumulators on first experiment ──────────────────
all_metrics      = []
experiment_times = {}

# ── Load model with T1A_imbalanced adapter ──────────────────────────────
model_mlx, tok_mlx = load(
    MODEL_ID,
    adapter_path="./adapters_w4/T1A_imbalanced",
)

# ── Inference ──────────────────────────────────────────────────────
t0 = time.time()
preds, refs, probs = run_inference_mlx(
    model_mlx, tok_mlx, test_ds_structured_full, return_probs=True
)

# ── Evaluate ───────────────────────────────────────────────────────
metrics = evaluate_predictions(preds, refs, label_name="T1A_imbalanced")

# ── Calibration ────────────────────────────────────────────────────
ece = calibration_analysis(
    probs, refs,
    label_name="T1A_imbalanced",
    save_path=os.path.join(OUTPUT_DIR, "calibration_T1A_imbalanced.png")
)
metrics["ECE"] = ece
all_metrics.append(metrics)

# ── Save predictions ───────────────────────────────────────────────
out_df = pd.DataFrame({"Predicted_Label": preds, "Ground_Truth": refs, "P_Yes": probs})
out_df.to_csv(os.path.join(OUTPUT_DIR, "predictions_T1A_imbalanced.csv"), index=False)

elapsed = round(time.time() - t0, 2)
experiment_times["T1A_imbalanced"] = elapsed
print(f"\n  ⏱ T1A_imbalanced done in {elapsed:.1f}s")

# ── Clean up ───────────────────────────────────────────────────────
del model_mlx, tok_mlx
# Out:
# Downloading (incomplete total...): 0.00B [00:00, ?B/s]
# Fetching 9 files:   0%|          | 0/9 [00:00<?, ?it/s]
# Generating:   0%|          | 0/6167 [00:00<?, ?it/s]
# ── T1A_imbalanced ──
#   Label: T1A_imbalanced
#   N_test: 6167
#   Accuracy: 0.9616
#   Recall: 0.7634
#   Precision: 0.8591
#   F1: 0.8084
#   Unknown: 0
#               precision    recall  f1-score   support
#
#           No       0.97      0.99      0.98      5512
#          Yes       0.86      0.76      0.81       655
#
#     accuracy                           0.96      6167
#    macro avg       0.92      0.87      0.89      6167
# weighted avg       0.96      0.96      0.96      6167
#
#   ECE: 0.0251 | Saved → ./results_wave4/calibration_T1A_imbalanced.png
#
#   ⏱ T1A_imbalanced done in 2354.3s

# %% [markdown]
# ### Training and Inference for T1B_oversampled

# %%
# !mlx_lm.lora \
    --model {MODEL_ID} \
    --train \
    --data ./mlx_data/T1B_oversampled \
    --num-layers 16 \
    --batch-size 4 \
    --grad-accumulation-steps 4 \
    --iters 2000 \
    --learning-rate 2e-4 \
    --mask-prompt \
    --adapter-path ./adapters_w4/T1B_oversampled \
    --save-every 500 \
    -c ./configs/lora_config.yaml
# Out:
# Loading configuration file ./configs/lora_config.yaml
# Loading pretrained model
# Downloading (incomplete total...): 0.00B [00:00, ?B/s]
# Fetching 9 files: 100%|████████████████████████| 9/9 [00:00<00:00, 58434.58it/s]
# Download complete: : 0.00B [00:00, ?B/s]
# Loading datasets
# Training
# Trainable parameters: 0.684% (10.551M/1543.714M)
# Starting training..., iters: 2000
# Calculating loss...: 100%|██████████████████████| 25/25 [00:26<00:00,  1.07s/it]
# Iter 1: Val loss 7.467, Val took 26.752s
# Iter 10: Train loss 3.470, Learning Rate 2.000e-04, It/sec 0.481, Tokens/sec 7.695, Trained Tokens 160, Peak mem 6.846 GB
# Iter 20: Train loss 0.176, Learning Rate 2.000e-04, It/sec 0.486, Tokens/sec 7.771, Trained Tokens 320, Peak mem 6.846 GB
# Iter 30: Train loss 0.129, Learning Rate 2.000e-04, It/sec 0.487, Tokens/sec 7.792, Trained Tokens 480, Peak mem 6.846 GB
# Iter 40: Train loss 0.087, Learning Rate 2.000e-04, It/sec 0.484, Tokens/sec 7.744, Trained Tokens 640, Peak mem 6.846 GB
# Iter 50: Train loss 0.092, Learning Rate 2.000e-04, It/sec 0.485, Tokens/sec 7.759, Trained Tokens 800, Peak mem 6.846 GB
# Iter 60: Train loss 0.014, Learning Rate 2.000e-04, It/sec 0.484, Tokens/sec 7.747, Trained Tokens 960, Peak mem 6.846 GB
# Iter 70: Train loss 0.063, Learning Rate 2.000e-04, It/sec 0.484, Tokens/sec 7.745, Trained Tokens 1120, Peak mem 6.846 GB
# Iter 80: Train loss 0.042, Learning Rate 2.000e-04, It/sec 0.486, Tokens/sec 7.779, Trained Tokens 1280, Peak mem 6.846 GB
# Iter 90: Train loss 0.039, Learning Rate 2.000e-04, It/sec 0.481, Tokens/sec 7.695, Trained Tokens 1440, Peak mem 6.846 GB
# Iter 100: Train loss 0.111, Learning Rate 2.000e-04, It/sec 0.487, Tokens/sec 7.793, Trained Tokens 1600, Peak mem 6.846 GB
# Iter 110: Train loss 0.145, Learning Rate 2.000e-04, It/sec 0.484, Tokens/sec 7.746, Trained Tokens 1760, Peak mem 6.846 GB
# Iter 120: Train loss 0.065, Learning Rate 2.000e-04, It/sec 0.486, Tokens/sec 7.773, Trained Tokens 1920, Peak mem 6.846 GB
# Iter 130: Train loss 0.021, Learning Rate 2.000e-04, It/sec 0.487, Tokens/sec 7.795, Trained Tokens 2080, Peak mem 6.846 GB
# Iter 140: Train loss 0.034, Learning Rate 2.000e-04, It/sec 0.482, Tokens/sec 7.705, Trained Tokens 2240, Peak mem 6.846 GB
# Iter 150: Train loss 0.016, Learning Rate 2.000e-04, It/sec 0.486, Tokens/sec 7.774, Trained Tokens 2400, Peak mem 6.846 GB
# Iter 160: Train loss 0.060, Learning Rate 2.000e-04, It/sec 0.486, Tokens/sec 7.780, Trained Tokens 2560, Peak mem 6.846 GB
# Iter 170: Train loss 0.061, Learning Rate 2.000e-04, It/sec 0.484, Tokens/sec 7.746, Trained Tokens 2720, Peak mem 6.846 GB
# Iter 180: Train loss 0.045, Learning Rate 2.000e-04, It/sec 0.484, Tokens/sec 7.739, Trained Tokens 2880, Peak mem 6.846 GB
# Iter 190: Train loss 0.119, Learning Rate 2.000e-04, It/sec 0.487, Tokens/sec 7.786, Trained Tokens 3040, Peak mem 6.846 GB
# Calculating loss...: 100%|██████████████████████| 25/25 [00:26<00:00,  1.07s/it]
# Iter 200: Val loss 0.062, Val took 26.675s
# Iter 200: Train loss 0.048, Learning Rate 2.000e-04, It/sec 0.485, Tokens/sec 7.755, Trained Tokens 3200, Peak mem 6.846 GB
# Iter 210: Train loss 0.073, Learning Rate 2.000e-04, It/sec 0.484, Tokens/sec 7.744, Trained Tokens 3360, Peak mem 6.846 GB
# Iter 220: Train loss 0.026, Learning Rate 2.000e-04, It/sec 0.486, Tokens/sec 7.779, Trained Tokens 3520, Peak mem 6.846 GB
# Iter 230: Train loss 0.057, Learning Rate 2.000e-04, It/sec 0.485, Tokens/sec 7.766, Trained Tokens 3680, Peak mem 6.846 GB
# Iter 240: Train loss 0.018, Learning Rate 2.000e-04, It/sec 0.484, Tokens/sec 7.748, Trained Tokens 3840, Peak mem 6.846 GB
# Iter 250: Train loss 0.045, Learning Rate 2.000e-04, It/sec 0.486, Tokens/sec 7.776, Trained Tokens 4000, Peak mem 6.846 GB
# Iter 260: Train loss 0.148, Learning Rate 2.000e-04, It/sec 0.487, Tokens/sec 7.791, Trained Tokens 4160, Peak mem 6.846 GB
# Iter 270: Train loss 0.037, Learning Rate 2.000e-04, It/sec 0.487, Tokens/sec 7.784, Trained Tokens 4320, Peak mem 6.846 GB
# Iter 280: Train loss 0.072, Learning Rate 2.000e-04, It/sec 0.485, Tokens/sec 7.755, Trained Tokens 4480, Peak mem 6.846 GB
# Iter 290: Train loss 0.107, Learning Rate 2.000e-04, It/sec 0.485, Tokens/sec 7.764, Trained Tokens 4640, Peak mem 6.846 GB
# Iter 300: Train loss 0.062, Learning Rate 2.000e-04, It/sec 0.487, Tokens/sec 7.799, Trained Tokens 4800, Peak mem 6.846 GB
# Iter 310: Train loss 0.043, Learning Rate 2.000e-04, It/sec 0.487, Tokens/sec 7.793, Trained Tokens 4960, Peak mem 6.846 GB
# Iter 320: Train loss 0.028, Learning Rate 2.000e-04, It/sec 0.485, Tokens/sec 7.757, Trained Tokens 5120, Peak mem 6.846 GB
# Iter 330: Train loss 0.035, Learning Rate 2.000e-04, It/sec 0.485, Tokens/sec 7.764, Trained Tokens 5280, Peak mem 6.846 GB
# Iter 340: Train loss 0.050, Learning Rate 2.000e-04, It/sec 0.487, Tokens/sec 7.790, Trained Tokens 5440, Peak mem 6.846 GB
# Iter 350: Train loss 0.040, Learning Rate 2.000e-04, It/sec 0.487, Tokens/sec 7.784, Trained Tokens 5600, Peak mem 6.846 GB
# Iter 360: Train loss 0.086, Learning Rate 2.000e-04, It/sec 0.484, Tokens/sec 7.742, Trained Tokens 5760, Peak mem 6.846 GB
# Iter 370: Train loss 0.049, Learning Rate 2.000e-04, It/sec 0.478, Tokens/sec 7.652, Trained Tokens 5920, Peak mem 7.354 GB
# Iter 380: Train loss 0.037, Learning Rate 2.000e-04, It/sec 0.485, Tokens/sec 7.760, Trained Tokens 6080, Peak mem 7.354 GB
# Iter 390: Train loss 0.038, Learning Rate 2.000e-04, It/sec 0.484, Tokens/sec 7.743, Trained Tokens 6240, Peak mem 7.354 GB
# Calculating loss...: 100%|██████████████████████| 25/25 [00:26<00:00,  1.06s/it]
# Iter 400: Val loss 0.094, Val took 26.598s
# Iter 400: Train loss 0.027, Learning Rate 2.000e-04, It/sec 0.485, Tokens/sec 7.767, Trained Tokens 6400, Peak mem 7.354 GB
# Iter 410: Train loss 0.055, Learning Rate 2.000e-04, It/sec 0.485, Tokens/sec 7.752, Trained Tokens 6560, Peak mem 7.354 GB
# Iter 420: Train loss 0.023, Learning Rate 2.000e-04, It/sec 0.483, Tokens/sec 7.722, Trained Tokens 6720, Peak mem 7.354 GB
# Iter 430: Train loss 0.056, Learning Rate 2.000e-04, It/sec 0.487, Tokens/sec 7.789, Trained Tokens 6880, Peak mem 7.354 GB
# Iter 440: Train loss 0.119, Learning Rate 2.000e-04, It/sec 0.487, Tokens/sec 7.787, Trained Tokens 7040, Peak mem 7.354 GB
# Iter 450: Train loss 0.149, Learning Rate 2.000e-04, It/sec 0.485, Tokens/sec 7.760, Trained Tokens 7200, Peak mem 7.354 GB
# Iter 460: Train loss 0.053, Learning Rate 2.000e-04, It/sec 0.485, Tokens/sec 7.753, Trained Tokens 7360, Peak mem 7.354 GB
# Iter 470: Train loss 0.060, Learning Rate 2.000e-04, It/sec 0.487, Tokens/sec 7.791, Trained Tokens 7520, Peak mem 7.354 GB
# Iter 480: Train loss 0.065, Learning Rate 2.000e-04, It/sec 0.485, Tokens/sec 7.764, Trained Tokens 7680, Peak mem 7.354 GB
# Iter 490: Train loss 0.052, Learning Rate 2.000e-04, It/sec 0.484, Tokens/sec 7.750, Trained Tokens 7840, Peak mem 7.354 GB
# Iter 500: Train loss 0.067, Learning Rate 2.000e-04, It/sec 0.486, Tokens/sec 7.778, Trained Tokens 8000, Peak mem 7.354 GB
# Iter 500: Saved adapter weights to adapters_w4/T1B_oversampled/adapters.safetensors and adapters_w4/T1B_oversampled/0000500_adapters.safetensors.
# Iter 510: Train loss 0.081, Learning Rate 2.000e-04, It/sec 0.487, Tokens/sec 7.796, Trained Tokens 8160, Peak mem 7.354 GB
# Iter 520: Train loss 0.101, Learning Rate 2.000e-04, It/sec 0.485, Tokens/sec 7.761, Trained Tokens 8320, Peak mem 7.354 GB
# Iter 530: Train loss 0.078, Learning Rate 2.000e-04, It/sec 0.484, Tokens/sec 7.738, Trained Tokens 8480, Peak mem 7.354 GB
# Iter 540: Train loss 0.062, Learning Rate 2.000e-04, It/sec 0.487, Tokens/sec 7.791, Trained Tokens 8640, Peak mem 7.354 GB
# Iter 550: Train loss 0.062, Learning Rate 2.000e-04, It/sec 0.485, Tokens/sec 7.767, Trained Tokens 8800, Peak mem 7.354 GB
# Iter 560: Train loss 0.042, Learning Rate 2.000e-04, It/sec 0.485, Tokens/sec 7.755, Trained Tokens 8960, Peak mem 7.354 GB
# Iter 570: Train loss 0.043, Learning Rate 2.000e-04, It/sec 0.484, Tokens/sec 7.751, Trained Tokens 9120, Peak mem 7.354 GB
# Iter 580: Train loss 0.034, Learning Rate 2.000e-04, It/sec 0.487, Tokens/sec 7.790, Trained Tokens 9280, Peak mem 7.354 GB
# Iter 590: Train loss 0.063, Learning Rate 2.000e-04, It/sec 0.486, Tokens/sec 7.776, Trained Tokens 9440, Peak mem 7.354 GB
# Calculating loss...: 100%|██████████████████████| 25/25 [00:26<00:00,  1.07s/it]
# Iter 600: Val loss 0.024, Val took 26.662s
# Iter 600: Train loss 0.086, Learning Rate 2.000e-04, It/sec 0.485, Tokens/sec 7.754, Trained Tokens 9600, Peak mem 7.354 GB
# Iter 610: Train loss 0.048, Learning Rate 2.000e-04, It/sec 0.487, Tokens/sec 7.786, Trained Tokens 9760, Peak mem 7.354 GB
# Iter 620: Train loss 0.029, Learning Rate 2.000e-04, It/sec 0.487, Tokens/sec 7.799, Trained Tokens 9920, Peak mem 7.354 GB
# Iter 630: Train loss 0.063, Learning Rate 2.000e-04, It/sec 0.485, Tokens/sec 7.759, Trained Tokens 10080, Peak mem 7.354 GB
# Iter 640: Train loss 0.013, Learning Rate 2.000e-04, It/sec 0.484, Tokens/sec 7.749, Trained Tokens 10240, Peak mem 7.354 GB
# Iter 650: Train loss 0.013, Learning Rate 2.000e-04, It/sec 0.487, Tokens/sec 7.798, Trained Tokens 10400, Peak mem 7.354 GB
# Iter 660: Train loss 0.093, Learning Rate 2.000e-04, It/sec 0.486, Tokens/sec 7.770, Trained Tokens 10560, Peak mem 7.354 GB
# Iter 670: Train loss 0.099, Learning Rate 2.000e-04, It/sec 0.485, Tokens/sec 7.758, Trained Tokens 10720, Peak mem 7.354 GB
# Iter 680: Train loss 0.109, Learning Rate 2.000e-04, It/sec 0.486, Tokens/sec 7.771, Trained Tokens 10880, Peak mem 7.354 GB
# Iter 690: Train loss 0.067, Learning Rate 2.000e-04, It/sec 0.488, Tokens/sec 7.802, Trained Tokens 11040, Peak mem 7.354 GB
# Iter 700: Train loss 0.061, Learning Rate 2.000e-04, It/sec 0.485, Tokens/sec 7.761, Trained Tokens 11200, Peak mem 7.354 GB
# Iter 710: Train loss 0.057, Learning Rate 2.000e-04, It/sec 0.485, Tokens/sec 7.755, Trained Tokens 11360, Peak mem 7.354 GB
# Iter 720: Train loss 0.106, Learning Rate 2.000e-04, It/sec 0.486, Tokens/sec 7.782, Trained Tokens 11520, Peak mem 7.354 GB
# Iter 730: Train loss 0.041, Learning Rate 2.000e-04, It/sec 0.487, Tokens/sec 7.800, Trained Tokens 11680, Peak mem 7.354 GB
# Iter 740: Train loss 0.053, Learning Rate 2.000e-04, It/sec 0.485, Tokens/sec 7.765, Trained Tokens 11840, Peak mem 7.354 GB
# Iter 750: Train loss 0.064, Learning Rate 2.000e-04, It/sec 0.485, Tokens/sec 7.766, Trained Tokens 12000, Peak mem 7.354 GB
# Iter 760: Train loss 0.073, Learning Rate 2.000e-04, It/sec 0.486, Tokens/sec 7.770, Trained Tokens 12160, Peak mem 7.354 GB
# Iter 770: Train loss 0.080, Learning Rate 2.000e-04, It/sec 0.487, Tokens/sec 7.799, Trained Tokens 12320, Peak mem 7.354 GB
# Iter 780: Train loss 0.069, Learning Rate 2.000e-04, It/sec 0.485, Tokens/sec 7.758, Trained Tokens 12480, Peak mem 7.354 GB
# Iter 790: Train loss 0.067, Learning Rate 2.000e-04, It/sec 0.484, Tokens/sec 7.748, Trained Tokens 12640, Peak mem 7.354 GB
# Calculating loss...: 100%|██████████████████████| 25/25 [00:26<00:00,  1.06s/it]
# Iter 800: Val loss 0.041, Val took 26.563s
# Iter 800: Train loss 0.052, Learning Rate 2.000e-04, It/sec 0.486, Tokens/sec 7.777, Trained Tokens 12800, Peak mem 7.354 GB
# Iter 810: Train loss 0.055, Learning Rate 2.000e-04, It/sec 0.485, Tokens/sec 7.760, Trained Tokens 12960, Peak mem 7.354 GB
# Iter 820: Train loss 0.053, Learning Rate 2.000e-04, It/sec 0.485, Tokens/sec 7.756, Trained Tokens 13120, Peak mem 7.354 GB
# Iter 830: Train loss 0.035, Learning Rate 2.000e-04, It/sec 0.485, Tokens/sec 7.762, Trained Tokens 13280, Peak mem 7.354 GB
# Iter 840: Train loss 0.044, Learning Rate 2.000e-04, It/sec 0.487, Tokens/sec 7.790, Trained Tokens 13440, Peak mem 7.354 GB
# Iter 850: Train loss 0.021, Learning Rate 2.000e-04, It/sec 0.485, Tokens/sec 7.762, Trained Tokens 13600, Peak mem 7.354 GB
# Iter 860: Train loss 0.056, Learning Rate 2.000e-04, It/sec 0.484, Tokens/sec 7.749, Trained Tokens 13760, Peak mem 7.354 GB
# Iter 870: Train loss 0.029, Learning Rate 2.000e-04, It/sec 0.486, Tokens/sec 7.778, Trained Tokens 13920, Peak mem 7.354 GB
# Iter 880: Train loss 0.074, Learning Rate 2.000e-04, It/sec 0.487, Tokens/sec 7.797, Trained Tokens 14080, Peak mem 7.354 GB
# Iter 890: Train loss 0.065, Learning Rate 2.000e-04, It/sec 0.485, Tokens/sec 7.760, Trained Tokens 14240, Peak mem 7.354 GB
# Iter 900: Train loss 0.075, Learning Rate 2.000e-04, It/sec 0.484, Tokens/sec 7.745, Trained Tokens 14400, Peak mem 7.354 GB
# Iter 910: Train loss 0.040, Learning Rate 2.000e-04, It/sec 0.486, Tokens/sec 7.783, Trained Tokens 14560, Peak mem 7.354 GB
# Iter 920: Train loss 0.105, Learning Rate 2.000e-04, It/sec 0.487, Tokens/sec 7.789, Trained Tokens 14720, Peak mem 7.354 GB
# Iter 930: Train loss 0.013, Learning Rate 2.000e-04, It/sec 0.484, Tokens/sec 7.746, Trained Tokens 14880, Peak mem 7.354 GB
# Iter 940: Train loss 0.088, Learning Rate 2.000e-04, It/sec 0.481, Tokens/sec 7.701, Trained Tokens 15040, Peak mem 7.354 GB
# Iter 950: Train loss 0.091, Learning Rate 2.000e-04, It/sec 0.487, Tokens/sec 7.787, Trained Tokens 15200, Peak mem 7.354 GB
# Iter 960: Train loss 0.047, Learning Rate 2.000e-04, It/sec 0.485, Tokens/sec 7.760, Trained Tokens 15360, Peak mem 7.354 GB
# Iter 970: Train loss 0.033, Learning Rate 2.000e-04, It/sec 0.484, Tokens/sec 7.752, Trained Tokens 15520, Peak mem 7.354 GB
# Iter 980: Train loss 0.060, Learning Rate 2.000e-04, It/sec 0.487, Tokens/sec 7.796, Trained Tokens 15680, Peak mem 7.354 GB
# Iter 990: Train loss 0.071, Learning Rate 2.000e-04, It/sec 0.487, Tokens/sec 7.800, Trained Tokens 15840, Peak mem 7.354 GB
# Calculating loss...: 100%|██████████████████████| 25/25 [00:26<00:00,  1.06s/it]
# Iter 1000: Val loss 0.077, Val took 26.578s
# Iter 1000: Train loss 0.024, Learning Rate 2.000e-04, It/sec 0.485, Tokens/sec 7.757, Trained Tokens 16000, Peak mem 7.354 GB
# Iter 1000: Saved adapter weights to adapters_w4/T1B_oversampled/adapters.safetensors and adapters_w4/T1B_oversampled/0001000_adapters.safetensors.
# Iter 1010: Train loss 0.071, Learning Rate 2.000e-04, It/sec 0.485, Tokens/sec 7.765, Trained Tokens 16160, Peak mem 7.354 GB
# Iter 1020: Train loss 0.086, Learning Rate 2.000e-04, It/sec 0.487, Tokens/sec 7.785, Trained Tokens 16320, Peak mem 7.354 GB
# Iter 1030: Train loss 0.078, Learning Rate 2.000e-04, It/sec 0.485, Tokens/sec 7.762, Trained Tokens 16480, Peak mem 7.354 GB
# Iter 1040: Train loss 0.089, Learning Rate 2.000e-04, It/sec 0.485, Tokens/sec 7.759, Trained Tokens 16640, Peak mem 7.354 GB
# Iter 1050: Train loss 0.028, Learning Rate 2.000e-04, It/sec 0.486, Tokens/sec 7.771, Trained Tokens 16800, Peak mem 7.354 GB
# Iter 1060: Train loss 0.061, Learning Rate 2.000e-04, It/sec 0.487, Tokens/sec 7.796, Trained Tokens 16960, Peak mem 7.354 GB
# Iter 1070: Train loss 0.072, Learning Rate 2.000e-04, It/sec 0.486, Tokens/sec 7.773, Trained Tokens 17120, Peak mem 7.354 GB
# Iter 1080: Train loss 0.059, Learning Rate 2.000e-04, It/sec 0.485, Tokens/sec 7.755, Trained Tokens 17280, Peak mem 7.354 GB
# Iter 1090: Train loss 0.057, Learning Rate 2.000e-04, It/sec 0.485, Tokens/sec 7.767, Trained Tokens 17440, Peak mem 7.354 GB
# Iter 1100: Train loss 0.049, Learning Rate 2.000e-04, It/sec 0.488, Tokens/sec 7.809, Trained Tokens 17600, Peak mem 7.354 GB
# Iter 1110: Train loss 0.064, Learning Rate 2.000e-04, It/sec 0.486, Tokens/sec 7.776, Trained Tokens 17760, Peak mem 7.354 GB
# Iter 1120: Train loss 0.074, Learning Rate 2.000e-04, It/sec 0.484, Tokens/sec 7.748, Trained Tokens 17920, Peak mem 7.354 GB
# Iter 1130: Train loss 0.035, Learning Rate 2.000e-04, It/sec 0.486, Tokens/sec 7.769, Trained Tokens 18080, Peak mem 7.354 GB
# Iter 1140: Train loss 0.018, Learning Rate 2.000e-04, It/sec 0.487, Tokens/sec 7.786, Trained Tokens 18240, Peak mem 7.354 GB
# Iter 1150: Train loss 0.099, Learning Rate 2.000e-04, It/sec 0.486, Tokens/sec 7.768, Trained Tokens 18400, Peak mem 7.354 GB
# Iter 1160: Train loss 0.078, Learning Rate 2.000e-04, It/sec 0.485, Tokens/sec 7.755, Trained Tokens 18560, Peak mem 7.354 GB
# Iter 1170: Train loss 0.026, Learning Rate 2.000e-04, It/sec 0.486, Tokens/sec 7.773, Trained Tokens 18720, Peak mem 7.354 GB
# Iter 1180: Train loss 0.021, Learning Rate 2.000e-04, It/sec 0.487, Tokens/sec 7.785, Trained Tokens 18880, Peak mem 7.354 GB
# Iter 1190: Train loss 0.024, Learning Rate 2.000e-04, It/sec 0.484, Tokens/sec 7.736, Trained Tokens 19040, Peak mem 7.354 GB
# Calculating loss...: 100%|██████████████████████| 25/25 [00:26<00:00,  1.06s/it]
# Iter 1200: Val loss 0.057, Val took 26.605s
# Iter 1200: Train loss 0.077, Learning Rate 2.000e-04, It/sec 0.485, Tokens/sec 7.758, Trained Tokens 19200, Peak mem 7.354 GB
# Iter 1210: Train loss 0.155, Learning Rate 2.000e-04, It/sec 0.488, Tokens/sec 7.808, Trained Tokens 19360, Peak mem 7.354 GB
# Iter 1220: Train loss 0.072, Learning Rate 2.000e-04, It/sec 0.486, Tokens/sec 7.769, Trained Tokens 19520, Peak mem 7.354 GB
# Iter 1230: Train loss 0.089, Learning Rate 2.000e-04, It/sec 0.484, Tokens/sec 7.738, Trained Tokens 19680, Peak mem 7.354 GB
# Iter 1240: Train loss 0.044, Learning Rate 2.000e-04, It/sec 0.486, Tokens/sec 7.768, Trained Tokens 19840, Peak mem 7.354 GB
# Iter 1250: Train loss 0.088, Learning Rate 2.000e-04, It/sec 0.480, Tokens/sec 7.686, Trained Tokens 20000, Peak mem 7.354 GB
# Iter 1260: Train loss 0.046, Learning Rate 2.000e-04, It/sec 0.485, Tokens/sec 7.754, Trained Tokens 20160, Peak mem 7.354 GB
# Iter 1270: Train loss 0.042, Learning Rate 2.000e-04, It/sec 0.486, Tokens/sec 7.774, Trained Tokens 20320, Peak mem 7.354 GB
# Iter 1280: Train loss 0.019, Learning Rate 2.000e-04, It/sec 0.488, Tokens/sec 7.810, Trained Tokens 20480, Peak mem 7.354 GB
# Iter 1290: Train loss 0.076, Learning Rate 2.000e-04, It/sec 0.485, Tokens/sec 7.761, Trained Tokens 20640, Peak mem 7.354 GB
# Iter 1300: Train loss 0.062, Learning Rate 2.000e-04, It/sec 0.483, Tokens/sec 7.734, Trained Tokens 20800, Peak mem 7.354 GB
# Iter 1310: Train loss 0.082, Learning Rate 2.000e-04, It/sec 0.487, Tokens/sec 7.791, Trained Tokens 20960, Peak mem 7.354 GB
# Iter 1320: Train loss 0.084, Learning Rate 2.000e-04, It/sec 0.487, Tokens/sec 7.791, Trained Tokens 21120, Peak mem 7.354 GB
# Iter 1330: Train loss 0.046, Learning Rate 2.000e-04, It/sec 0.485, Tokens/sec 7.760, Trained Tokens 21280, Peak mem 7.354 GB
# Iter 1340: Train loss 0.025, Learning Rate 2.000e-04, It/sec 0.484, Tokens/sec 7.747, Trained Tokens 21440, Peak mem 7.354 GB
# Iter 1350: Train loss 0.094, Learning Rate 2.000e-04, It/sec 0.487, Tokens/sec 7.794, Trained Tokens 21600, Peak mem 7.354 GB
# Iter 1360: Train loss 0.028, Learning Rate 2.000e-04, It/sec 0.486, Tokens/sec 7.779, Trained Tokens 21760, Peak mem 7.354 GB
# Iter 1370: Train loss 0.041, Learning Rate 2.000e-04, It/sec 0.485, Tokens/sec 7.755, Trained Tokens 21920, Peak mem 7.354 GB
# Iter 1380: Train loss 0.057, Learning Rate 2.000e-04, It/sec 0.486, Tokens/sec 7.768, Trained Tokens 22080, Peak mem 7.354 GB
# Iter 1390: Train loss 0.078, Learning Rate 2.000e-04, It/sec 0.487, Tokens/sec 7.794, Trained Tokens 22240, Peak mem 7.354 GB
# Calculating loss...: 100%|██████████████████████| 25/25 [00:26<00:00,  1.06s/it]
# Iter 1400: Val loss 0.042, Val took 26.563s
# Iter 1400: Train loss 0.033, Learning Rate 2.000e-04, It/sec 0.486, Tokens/sec 7.771, Trained Tokens 22400, Peak mem 7.354 GB
# Iter 1410: Train loss 0.049, Learning Rate 2.000e-04, It/sec 0.484, Tokens/sec 7.740, Trained Tokens 22560, Peak mem 7.354 GB
# Iter 1420: Train loss 0.073, Learning Rate 2.000e-04, It/sec 0.486, Tokens/sec 7.776, Trained Tokens 22720, Peak mem 7.354 GB
# Iter 1430: Train loss 0.056, Learning Rate 2.000e-04, It/sec 0.488, Tokens/sec 7.810, Trained Tokens 22880, Peak mem 7.354 GB
# Iter 1440: Train loss 0.040, Learning Rate 2.000e-04, It/sec 0.485, Tokens/sec 7.758, Trained Tokens 23040, Peak mem 7.354 GB
# Iter 1450: Train loss 0.071, Learning Rate 2.000e-04, It/sec 0.484, Tokens/sec 7.750, Trained Tokens 23200, Peak mem 7.354 GB
# Iter 1460: Train loss 0.075, Learning Rate 2.000e-04, It/sec 0.486, Tokens/sec 7.780, Trained Tokens 23360, Peak mem 7.354 GB
# Iter 1470: Train loss 0.090, Learning Rate 2.000e-04, It/sec 0.487, Tokens/sec 7.800, Trained Tokens 23520, Peak mem 7.354 GB
# Iter 1480: Train loss 0.053, Learning Rate 2.000e-04, It/sec 0.485, Tokens/sec 7.759, Trained Tokens 23680, Peak mem 7.354 GB
# Iter 1490: Train loss 0.093, Learning Rate 2.000e-04, It/sec 0.485, Tokens/sec 7.756, Trained Tokens 23840, Peak mem 7.354 GB
# Iter 1500: Train loss 0.024, Learning Rate 2.000e-04, It/sec 0.487, Tokens/sec 7.795, Trained Tokens 24000, Peak mem 7.354 GB
# Iter 1500: Saved adapter weights to adapters_w4/T1B_oversampled/adapters.safetensors and adapters_w4/T1B_oversampled/0001500_adapters.safetensors.
# Iter 1510: Train loss 0.036, Learning Rate 2.000e-04, It/sec 0.487, Tokens/sec 7.786, Trained Tokens 24160, Peak mem 7.354 GB
# Iter 1520: Train loss 0.056, Learning Rate 2.000e-04, It/sec 0.484, Tokens/sec 7.752, Trained Tokens 24320, Peak mem 7.354 GB
# Iter 1530: Train loss 0.065, Learning Rate 2.000e-04, It/sec 0.485, Tokens/sec 7.757, Trained Tokens 24480, Peak mem 7.354 GB
# Iter 1540: Train loss 0.053, Learning Rate 2.000e-04, It/sec 0.487, Tokens/sec 7.786, Trained Tokens 24640, Peak mem 7.354 GB
# Iter 1550: Train loss 0.068, Learning Rate 2.000e-04, It/sec 0.486, Tokens/sec 7.778, Trained Tokens 24800, Peak mem 7.354 GB
# Iter 1560: Train loss 0.055, Learning Rate 2.000e-04, It/sec 0.485, Tokens/sec 7.760, Trained Tokens 24960, Peak mem 7.354 GB
# Iter 1570: Train loss 0.032, Learning Rate 2.000e-04, It/sec 0.486, Tokens/sec 7.771, Trained Tokens 25120, Peak mem 7.354 GB
# Iter 1580: Train loss 0.034, Learning Rate 2.000e-04, It/sec 0.487, Tokens/sec 7.786, Trained Tokens 25280, Peak mem 7.354 GB
# Iter 1590: Train loss 0.083, Learning Rate 2.000e-04, It/sec 0.486, Tokens/sec 7.780, Trained Tokens 25440, Peak mem 7.354 GB
# Calculating loss...: 100%|██████████████████████| 25/25 [00:26<00:00,  1.06s/it]
# Iter 1600: Val loss 0.037, Val took 26.564s
# Iter 1600: Train loss 0.035, Learning Rate 2.000e-04, It/sec 0.485, Tokens/sec 7.753, Trained Tokens 25600, Peak mem 7.354 GB
# Iter 1610: Train loss 0.010, Learning Rate 2.000e-04, It/sec 0.486, Tokens/sec 7.771, Trained Tokens 25760, Peak mem 7.354 GB
# Iter 1620: Train loss 0.076, Learning Rate 2.000e-04, It/sec 0.487, Tokens/sec 7.797, Trained Tokens 25920, Peak mem 7.354 GB
# Iter 1630: Train loss 0.108, Learning Rate 2.000e-04, It/sec 0.485, Tokens/sec 7.757, Trained Tokens 26080, Peak mem 7.354 GB
# Iter 1640: Train loss 0.028, Learning Rate 2.000e-04, It/sec 0.484, Tokens/sec 7.741, Trained Tokens 26240, Peak mem 7.354 GB
# Iter 1650: Train loss 0.044, Learning Rate 2.000e-04, It/sec 0.485, Tokens/sec 7.764, Trained Tokens 26400, Peak mem 7.354 GB
# Iter 1660: Train loss 0.075, Learning Rate 2.000e-04, It/sec 0.487, Tokens/sec 7.791, Trained Tokens 26560, Peak mem 7.354 GB
# Iter 1670: Train loss 0.072, Learning Rate 2.000e-04, It/sec 0.485, Tokens/sec 7.760, Trained Tokens 26720, Peak mem 7.354 GB
# Iter 1680: Train loss 0.066, Learning Rate 2.000e-04, It/sec 0.484, Tokens/sec 7.743, Trained Tokens 26880, Peak mem 7.354 GB
# Iter 1690: Train loss 0.037, Learning Rate 2.000e-04, It/sec 0.487, Tokens/sec 7.800, Trained Tokens 27040, Peak mem 7.354 GB
# Iter 1700: Train loss 0.064, Learning Rate 2.000e-04, It/sec 0.487, Tokens/sec 7.787, Trained Tokens 27200, Peak mem 7.354 GB
# Iter 1710: Train loss 0.041, Learning Rate 2.000e-04, It/sec 0.484, Tokens/sec 7.742, Trained Tokens 27360, Peak mem 7.354 GB
# Iter 1720: Train loss 0.043, Learning Rate 2.000e-04, It/sec 0.485, Tokens/sec 7.762, Trained Tokens 27520, Peak mem 7.354 GB
# Iter 1730: Train loss 0.009, Learning Rate 2.000e-04, It/sec 0.487, Tokens/sec 7.794, Trained Tokens 27680, Peak mem 7.354 GB
# Iter 1740: Train loss 0.010, Learning Rate 2.000e-04, It/sec 0.485, Tokens/sec 7.756, Trained Tokens 27840, Peak mem 7.354 GB
# Iter 1750: Train loss 0.038, Learning Rate 2.000e-04, It/sec 0.485, Tokens/sec 7.763, Trained Tokens 28000, Peak mem 7.354 GB
# Iter 1760: Train loss 0.061, Learning Rate 2.000e-04, It/sec 0.486, Tokens/sec 7.771, Trained Tokens 28160, Peak mem 7.354 GB
# Iter 1770: Train loss 0.115, Learning Rate 2.000e-04, It/sec 0.483, Tokens/sec 7.733, Trained Tokens 28320, Peak mem 7.354 GB
# Iter 1780: Train loss 0.087, Learning Rate 2.000e-04, It/sec 0.484, Tokens/sec 7.746, Trained Tokens 28480, Peak mem 7.354 GB
# Iter 1790: Train loss 0.113, Learning Rate 2.000e-04, It/sec 0.485, Tokens/sec 7.760, Trained Tokens 28640, Peak mem 7.354 GB
# Calculating loss...: 100%|██████████████████████| 25/25 [00:26<00:00,  1.06s/it]
# Iter 1800: Val loss 0.024, Val took 26.562s
# Iter 1800: Train loss 0.084, Learning Rate 2.000e-04, It/sec 0.488, Tokens/sec 7.805, Trained Tokens 28800, Peak mem 7.354 GB
# Iter 1810: Train loss 0.053, Learning Rate 2.000e-04, It/sec 0.486, Tokens/sec 7.780, Trained Tokens 28960, Peak mem 7.354 GB
# Iter 1820: Train loss 0.045, Learning Rate 2.000e-04, It/sec 0.484, Tokens/sec 7.751, Trained Tokens 29120, Peak mem 7.354 GB
# Iter 1830: Train loss 0.041, Learning Rate 2.000e-04, It/sec 0.481, Tokens/sec 7.697, Trained Tokens 29280, Peak mem 7.354 GB
# Iter 1840: Train loss 0.096, Learning Rate 2.000e-04, It/sec 0.485, Tokens/sec 7.766, Trained Tokens 29440, Peak mem 7.354 GB
# Iter 1850: Train loss 0.061, Learning Rate 2.000e-04, It/sec 0.484, Tokens/sec 7.747, Trained Tokens 29600, Peak mem 7.354 GB
# Iter 1860: Train loss 0.091, Learning Rate 2.000e-04, It/sec 0.485, Tokens/sec 7.761, Trained Tokens 29760, Peak mem 7.354 GB
# Iter 1870: Train loss 0.058, Learning Rate 2.000e-04, It/sec 0.487, Tokens/sec 7.787, Trained Tokens 29920, Peak mem 7.354 GB
# Iter 1880: Train loss 0.069, Learning Rate 2.000e-04, It/sec 0.485, Tokens/sec 7.752, Trained Tokens 30080, Peak mem 7.354 GB
# Iter 1890: Train loss 0.085, Learning Rate 2.000e-04, It/sec 0.484, Tokens/sec 7.751, Trained Tokens 30240, Peak mem 7.354 GB
# Iter 1900: Train loss 0.023, Learning Rate 2.000e-04, It/sec 0.486, Tokens/sec 7.783, Trained Tokens 30400, Peak mem 7.354 GB
# Iter 1910: Train loss 0.078, Learning Rate 2.000e-04, It/sec 0.487, Tokens/sec 7.794, Trained Tokens 30560, Peak mem 7.354 GB
# Iter 1920: Train loss 0.093, Learning Rate 2.000e-04, It/sec 0.484, Tokens/sec 7.741, Trained Tokens 30720, Peak mem 7.354 GB
# Iter 1930: Train loss 0.081, Learning Rate 2.000e-04, It/sec 0.485, Tokens/sec 7.758, Trained Tokens 30880, Peak mem 7.354 GB
# Iter 1940: Train loss 0.078, Learning Rate 2.000e-04, It/sec 0.487, Tokens/sec 7.797, Trained Tokens 31040, Peak mem 7.354 GB
# Iter 1950: Train loss 0.042, Learning Rate 2.000e-04, It/sec 0.487, Tokens/sec 7.794, Trained Tokens 31200, Peak mem 7.354 GB
# Iter 1960: Train loss 0.037, Learning Rate 2.000e-04, It/sec 0.485, Tokens/sec 7.754, Trained Tokens 31360, Peak mem 7.354 GB
# Iter 1970: Train loss 0.088, Learning Rate 2.000e-04, It/sec 0.485, Tokens/sec 7.762, Trained Tokens 31520, Peak mem 7.354 GB
# Iter 1980: Train loss 0.062, Learning Rate 2.000e-04, It/sec 0.487, Tokens/sec 7.796, Trained Tokens 31680, Peak mem 7.354 GB
# Iter 1990: Train loss 0.057, Learning Rate 2.000e-04, It/sec 0.485, Tokens/sec 7.762, Trained Tokens 31840, Peak mem 7.354 GB
# Calculating loss...: 100%|██████████████████████| 25/25 [00:26<00:00,  1.06s/it]
# Iter 2000: Val loss 0.050, Val took 26.565s
# Iter 2000: Train loss 0.063, Learning Rate 2.000e-04, It/sec 0.484, Tokens/sec 7.739, Trained Tokens 32000, Peak mem 7.354 GB
# Iter 2000: Saved adapter weights to adapters_w4/T1B_oversampled/adapters.safetensors and adapters_w4/T1B_oversampled/0002000_adapters.safetensors.
# Saved final weights to adapters_w4/T1B_oversampled/adapters.safetensors.

# %%
# ── Load model with T1B_oversampled adapter ──────────────────────────────
model_mlx, tok_mlx = load(
    MODEL_ID,
    adapter_path="./adapters_w4/T1B_oversampled",
)

# ── Inference ──────────────────────────────────────────────────────
t0 = time.time()
preds, refs, probs = run_inference_mlx(
    model_mlx, tok_mlx, test_ds_structured_full, return_probs=True
)

# ── Evaluate ───────────────────────────────────────────────────────
metrics = evaluate_predictions(preds, refs, label_name="T1B_oversampled")

# ── Calibration ────────────────────────────────────────────────────
ece = calibration_analysis(
    probs, refs,
    label_name="T1B_oversampled",
    save_path=os.path.join(OUTPUT_DIR, "calibration_T1B_oversampled.png")
)
metrics["ECE"] = ece
all_metrics.append(metrics)

# ── Save predictions ───────────────────────────────────────────────
out_df = pd.DataFrame({"Predicted_Label": preds, "Ground_Truth": refs, "P_Yes": probs})
out_df.to_csv(os.path.join(OUTPUT_DIR, "predictions_T1B_oversampled.csv"), index=False)

elapsed = round(time.time() - t0, 2)
experiment_times["T1B_oversampled"] = elapsed
print(f"\n  ⏱ T1B_oversampled done in {elapsed:.1f}s")

# ── Clean up ───────────────────────────────────────────────────────
del model_mlx, tok_mlx
# Out:
# Downloading (incomplete total...): 0.00B [00:00, ?B/s]
# Fetching 9 files:   0%|          | 0/9 [00:00<?, ?it/s]
# Generating:   0%|          | 0/6167 [00:00<?, ?it/s]
# ── T1B_oversampled ──
#   Label: T1B_oversampled
#   N_test: 6167
#   Accuracy: 0.9527
#   Recall: 0.8779
#   Precision: 0.7306
#   F1: 0.7975
#   Unknown: 0
#               precision    recall  f1-score   support
#
#           No       0.99      0.96      0.97      5512
#          Yes       0.73      0.88      0.80       655
#
#     accuracy                           0.95      6167
#    macro avg       0.86      0.92      0.89      6167
# weighted avg       0.96      0.95      0.95      6167
#
#   ECE: 0.0130 | Saved → ./results_wave4/calibration_T1B_oversampled.png
#
#   ⏱ T1B_oversampled done in 2268.8s

# %% [markdown]
# ### Training and Inference for T2A_demo_only

# %%
# !mlx_lm.lora \
    --model {MODEL_ID} \
    --train \
    --data ./mlx_data/T2A_demo_only \
    --num-layers 16 \
    --batch-size 4 \
    --grad-accumulation-steps 4 \
    --iters 2000 \
    --learning-rate 2e-4 \
    --mask-prompt \
    --adapter-path ./adapters_w4/T2A_demo_only \
    --save-every 500 \
    -c ./configs/lora_config.yaml
# Out:
# Loading configuration file ./configs/lora_config.yaml
# Loading pretrained model
# Downloading (incomplete total...): 0.00B [00:00, ?B/s]
# Fetching 9 files: 100%|████████████████████████| 9/9 [00:00<00:00, 46204.08it/s]
# Download complete: : 0.00B [00:00, ?B/s]
# Loading datasets
# Training
# Trainable parameters: 0.684% (10.551M/1543.714M)
# Starting training..., iters: 2000
# Calculating loss...: 100%|██████████████████████| 25/25 [00:23<00:00,  1.04it/s]
# Iter 1: Val loss 7.656, Val took 23.934s
# Iter 10: Train loss 4.092, Learning Rate 2.000e-04, It/sec 0.538, Tokens/sec 8.614, Trained Tokens 160, Peak mem 6.323 GB
# Iter 20: Train loss 0.196, Learning Rate 2.000e-04, It/sec 0.543, Tokens/sec 8.685, Trained Tokens 320, Peak mem 6.323 GB
# Iter 30: Train loss 0.086, Learning Rate 2.000e-04, It/sec 0.542, Tokens/sec 8.676, Trained Tokens 480, Peak mem 6.323 GB
# Iter 40: Train loss 0.145, Learning Rate 2.000e-04, It/sec 0.543, Tokens/sec 8.688, Trained Tokens 640, Peak mem 6.323 GB
# Iter 50: Train loss 0.150, Learning Rate 2.000e-04, It/sec 0.543, Tokens/sec 8.694, Trained Tokens 800, Peak mem 6.323 GB
# Iter 60: Train loss 0.111, Learning Rate 2.000e-04, It/sec 0.542, Tokens/sec 8.675, Trained Tokens 960, Peak mem 6.323 GB
# Iter 70: Train loss 0.107, Learning Rate 2.000e-04, It/sec 0.544, Tokens/sec 8.697, Trained Tokens 1120, Peak mem 6.323 GB
# Iter 80: Train loss 0.078, Learning Rate 2.000e-04, It/sec 0.544, Tokens/sec 8.700, Trained Tokens 1280, Peak mem 6.323 GB
# Iter 90: Train loss 0.118, Learning Rate 2.000e-04, It/sec 0.544, Tokens/sec 8.700, Trained Tokens 1440, Peak mem 6.323 GB
# Iter 100: Train loss 0.144, Learning Rate 2.000e-04, It/sec 0.543, Tokens/sec 8.693, Trained Tokens 1600, Peak mem 6.323 GB
# Iter 110: Train loss 0.053, Learning Rate 2.000e-04, It/sec 0.543, Tokens/sec 8.689, Trained Tokens 1760, Peak mem 6.323 GB
# Iter 120: Train loss 0.084, Learning Rate 2.000e-04, It/sec 0.543, Tokens/sec 8.681, Trained Tokens 1920, Peak mem 6.323 GB
# Iter 130: Train loss 0.050, Learning Rate 2.000e-04, It/sec 0.543, Tokens/sec 8.681, Trained Tokens 2080, Peak mem 6.323 GB
# Iter 140: Train loss 0.081, Learning Rate 2.000e-04, It/sec 0.538, Tokens/sec 8.612, Trained Tokens 2240, Peak mem 6.323 GB
# Iter 150: Train loss 0.031, Learning Rate 2.000e-04, It/sec 0.543, Tokens/sec 8.684, Trained Tokens 2400, Peak mem 6.323 GB
# Iter 160: Train loss 0.067, Learning Rate 2.000e-04, It/sec 0.542, Tokens/sec 8.677, Trained Tokens 2560, Peak mem 6.323 GB
# Iter 170: Train loss 0.079, Learning Rate 2.000e-04, It/sec 0.543, Tokens/sec 8.694, Trained Tokens 2720, Peak mem 6.323 GB
# Iter 180: Train loss 0.071, Learning Rate 2.000e-04, It/sec 0.544, Tokens/sec 8.698, Trained Tokens 2880, Peak mem 6.323 GB
# Iter 190: Train loss 0.090, Learning Rate 2.000e-04, It/sec 0.542, Tokens/sec 8.674, Trained Tokens 3040, Peak mem 6.323 GB
# Calculating loss...: 100%|██████████████████████| 25/25 [00:23<00:00,  1.05it/s]
# Iter 200: Val loss 0.076, Val took 23.837s
# Iter 200: Train loss 0.040, Learning Rate 2.000e-04, It/sec 0.542, Tokens/sec 8.679, Trained Tokens 3200, Peak mem 6.323 GB
# Iter 210: Train loss 0.045, Learning Rate 2.000e-04, It/sec 0.541, Tokens/sec 8.652, Trained Tokens 3360, Peak mem 6.323 GB
# Iter 220: Train loss 0.216, Learning Rate 2.000e-04, It/sec 0.542, Tokens/sec 8.673, Trained Tokens 3520, Peak mem 6.323 GB
# Iter 230: Train loss 2.245, Learning Rate 2.000e-04, It/sec 0.542, Tokens/sec 8.666, Trained Tokens 3680, Peak mem 6.323 GB
# Iter 240: Train loss 1.393, Learning Rate 2.000e-04, It/sec 0.542, Tokens/sec 8.678, Trained Tokens 3840, Peak mem 6.323 GB
# Iter 250: Train loss 0.077, Learning Rate 2.000e-04, It/sec 0.544, Tokens/sec 8.700, Trained Tokens 4000, Peak mem 6.323 GB
# Iter 260: Train loss 0.085, Learning Rate 2.000e-04, It/sec 0.540, Tokens/sec 8.648, Trained Tokens 4160, Peak mem 6.323 GB
# Iter 270: Train loss 0.097, Learning Rate 2.000e-04, It/sec 0.544, Tokens/sec 8.710, Trained Tokens 4320, Peak mem 6.323 GB
# Iter 280: Train loss 0.160, Learning Rate 2.000e-04, It/sec 0.543, Tokens/sec 8.689, Trained Tokens 4480, Peak mem 6.323 GB
# Iter 290: Train loss 0.103, Learning Rate 2.000e-04, It/sec 0.542, Tokens/sec 8.669, Trained Tokens 4640, Peak mem 6.323 GB
# Iter 300: Train loss 0.252, Learning Rate 2.000e-04, It/sec 0.542, Tokens/sec 8.676, Trained Tokens 4800, Peak mem 6.323 GB
# Iter 310: Train loss 0.110, Learning Rate 2.000e-04, It/sec 0.544, Tokens/sec 8.697, Trained Tokens 4960, Peak mem 6.323 GB
# Iter 320: Train loss 0.111, Learning Rate 2.000e-04, It/sec 0.543, Tokens/sec 8.681, Trained Tokens 5120, Peak mem 6.323 GB
# Iter 330: Train loss 0.101, Learning Rate 2.000e-04, It/sec 0.543, Tokens/sec 8.682, Trained Tokens 5280, Peak mem 6.323 GB
# Iter 340: Train loss 0.130, Learning Rate 2.000e-04, It/sec 0.542, Tokens/sec 8.680, Trained Tokens 5440, Peak mem 6.323 GB
# Iter 350: Train loss 0.073, Learning Rate 2.000e-04, It/sec 0.544, Tokens/sec 8.708, Trained Tokens 5600, Peak mem 6.323 GB
# Iter 360: Train loss 0.057, Learning Rate 2.000e-04, It/sec 0.544, Tokens/sec 8.703, Trained Tokens 5760, Peak mem 6.323 GB
# Iter 370: Train loss 0.103, Learning Rate 2.000e-04, It/sec 0.544, Tokens/sec 8.701, Trained Tokens 5920, Peak mem 6.323 GB
# Iter 380: Train loss 0.112, Learning Rate 2.000e-04, It/sec 0.543, Tokens/sec 8.691, Trained Tokens 6080, Peak mem 6.323 GB
# Iter 390: Train loss 0.053, Learning Rate 2.000e-04, It/sec 0.543, Tokens/sec 8.691, Trained Tokens 6240, Peak mem 6.323 GB
# Calculating loss...: 100%|██████████████████████| 25/25 [00:23<00:00,  1.05it/s]
# Iter 400: Val loss 0.072, Val took 23.832s
# Iter 400: Train loss 0.126, Learning Rate 2.000e-04, It/sec 0.542, Tokens/sec 8.674, Trained Tokens 6400, Peak mem 6.323 GB
# Iter 410: Train loss 0.052, Learning Rate 2.000e-04, It/sec 0.543, Tokens/sec 8.690, Trained Tokens 6560, Peak mem 6.323 GB
# Iter 420: Train loss 0.070, Learning Rate 2.000e-04, It/sec 0.543, Tokens/sec 8.695, Trained Tokens 6720, Peak mem 6.323 GB
# Iter 430: Train loss 0.109, Learning Rate 2.000e-04, It/sec 0.543, Tokens/sec 8.690, Trained Tokens 6880, Peak mem 6.323 GB
# Iter 440: Train loss 0.060, Learning Rate 2.000e-04, It/sec 0.544, Tokens/sec 8.697, Trained Tokens 7040, Peak mem 6.323 GB
# Iter 450: Train loss 0.137, Learning Rate 2.000e-04, It/sec 0.542, Tokens/sec 8.677, Trained Tokens 7200, Peak mem 6.323 GB
# Iter 460: Train loss 0.043, Learning Rate 2.000e-04, It/sec 0.543, Tokens/sec 8.688, Trained Tokens 7360, Peak mem 6.323 GB
# Iter 470: Train loss 0.084, Learning Rate 2.000e-04, It/sec 0.544, Tokens/sec 8.697, Trained Tokens 7520, Peak mem 6.323 GB
# Iter 480: Train loss 0.092, Learning Rate 2.000e-04, It/sec 0.544, Tokens/sec 8.702, Trained Tokens 7680, Peak mem 6.323 GB
# Iter 490: Train loss 0.059, Learning Rate 2.000e-04, It/sec 0.544, Tokens/sec 8.700, Trained Tokens 7840, Peak mem 6.323 GB
# Iter 500: Train loss 0.057, Learning Rate 2.000e-04, It/sec 0.543, Tokens/sec 8.689, Trained Tokens 8000, Peak mem 6.323 GB
# Iter 500: Saved adapter weights to adapters_w4/T2A_demo_only/adapters.safetensors and adapters_w4/T2A_demo_only/0000500_adapters.safetensors.
# Iter 510: Train loss 0.082, Learning Rate 2.000e-04, It/sec 0.543, Tokens/sec 8.688, Trained Tokens 8160, Peak mem 6.365 GB
# Iter 520: Train loss 0.071, Learning Rate 2.000e-04, It/sec 0.543, Tokens/sec 8.686, Trained Tokens 8320, Peak mem 6.365 GB
# Iter 530: Train loss 0.115, Learning Rate 2.000e-04, It/sec 0.544, Tokens/sec 8.704, Trained Tokens 8480, Peak mem 6.365 GB
# Iter 540: Train loss 0.139, Learning Rate 2.000e-04, It/sec 0.544, Tokens/sec 8.700, Trained Tokens 8640, Peak mem 6.365 GB
# Iter 550: Train loss 0.070, Learning Rate 2.000e-04, It/sec 0.544, Tokens/sec 8.699, Trained Tokens 8800, Peak mem 6.365 GB
# Iter 560: Train loss 0.059, Learning Rate 2.000e-04, It/sec 0.543, Tokens/sec 8.690, Trained Tokens 8960, Peak mem 6.365 GB
# Iter 570: Train loss 0.037, Learning Rate 2.000e-04, It/sec 0.544, Tokens/sec 8.704, Trained Tokens 9120, Peak mem 6.365 GB
# Iter 580: Train loss 0.094, Learning Rate 2.000e-04, It/sec 0.543, Tokens/sec 8.687, Trained Tokens 9280, Peak mem 6.365 GB
# Iter 590: Train loss 0.049, Learning Rate 2.000e-04, It/sec 0.543, Tokens/sec 8.689, Trained Tokens 9440, Peak mem 6.365 GB
# Calculating loss...: 100%|██████████████████████| 25/25 [00:23<00:00,  1.05it/s]
# Iter 600: Val loss 0.064, Val took 23.829s
# Iter 600: Train loss 0.051, Learning Rate 2.000e-04, It/sec 0.544, Tokens/sec 8.699, Trained Tokens 9600, Peak mem 6.365 GB
# Iter 610: Train loss 0.075, Learning Rate 2.000e-04, It/sec 0.543, Tokens/sec 8.696, Trained Tokens 9760, Peak mem 6.365 GB
# Iter 620: Train loss 0.025, Learning Rate 2.000e-04, It/sec 0.544, Tokens/sec 8.708, Trained Tokens 9920, Peak mem 6.365 GB
# Iter 630: Train loss 0.091, Learning Rate 2.000e-04, It/sec 0.544, Tokens/sec 8.709, Trained Tokens 10080, Peak mem 6.365 GB
# Iter 640: Train loss 0.149, Learning Rate 2.000e-04, It/sec 0.544, Tokens/sec 8.709, Trained Tokens 10240, Peak mem 6.365 GB
# Iter 650: Train loss 0.080, Learning Rate 2.000e-04, It/sec 0.544, Tokens/sec 8.701, Trained Tokens 10400, Peak mem 6.365 GB
# Iter 660: Train loss 0.043, Learning Rate 2.000e-04, It/sec 0.543, Tokens/sec 8.696, Trained Tokens 10560, Peak mem 6.365 GB
# Iter 670: Train loss 0.038, Learning Rate 2.000e-04, It/sec 0.542, Tokens/sec 8.675, Trained Tokens 10720, Peak mem 6.365 GB
# Iter 680: Train loss 0.026, Learning Rate 2.000e-04, It/sec 0.543, Tokens/sec 8.689, Trained Tokens 10880, Peak mem 6.365 GB
# Iter 690: Train loss 0.027, Learning Rate 2.000e-04, It/sec 0.544, Tokens/sec 8.702, Trained Tokens 11040, Peak mem 6.365 GB
# Iter 700: Train loss 0.166, Learning Rate 2.000e-04, It/sec 0.543, Tokens/sec 8.689, Trained Tokens 11200, Peak mem 6.365 GB
# Iter 710: Train loss 0.095, Learning Rate 2.000e-04, It/sec 0.542, Tokens/sec 8.678, Trained Tokens 11360, Peak mem 6.365 GB
# Iter 720: Train loss 0.086, Learning Rate 2.000e-04, It/sec 0.543, Tokens/sec 8.688, Trained Tokens 11520, Peak mem 6.365 GB
# Iter 730: Train loss 0.085, Learning Rate 2.000e-04, It/sec 0.543, Tokens/sec 8.683, Trained Tokens 11680, Peak mem 6.365 GB
# Iter 740: Train loss 0.073, Learning Rate 2.000e-04, It/sec 0.545, Tokens/sec 8.717, Trained Tokens 11840, Peak mem 6.365 GB
# Iter 750: Train loss 0.064, Learning Rate 2.000e-04, It/sec 0.543, Tokens/sec 8.688, Trained Tokens 12000, Peak mem 6.365 GB
# Iter 760: Train loss 0.109, Learning Rate 2.000e-04, It/sec 0.543, Tokens/sec 8.694, Trained Tokens 12160, Peak mem 6.365 GB
# Iter 770: Train loss 0.053, Learning Rate 2.000e-04, It/sec 0.544, Tokens/sec 8.704, Trained Tokens 12320, Peak mem 6.365 GB
# Iter 780: Train loss 0.147, Learning Rate 2.000e-04, It/sec 0.543, Tokens/sec 8.685, Trained Tokens 12480, Peak mem 6.365 GB
# Iter 790: Train loss 0.091, Learning Rate 2.000e-04, It/sec 0.545, Tokens/sec 8.715, Trained Tokens 12640, Peak mem 6.365 GB
# Calculating loss...: 100%|██████████████████████| 25/25 [00:23<00:00,  1.05it/s]
# Iter 800: Val loss 0.074, Val took 23.838s
# Iter 800: Train loss 0.056, Learning Rate 2.000e-04, It/sec 0.543, Tokens/sec 8.687, Trained Tokens 12800, Peak mem 6.365 GB
# Iter 810: Train loss 0.033, Learning Rate 2.000e-04, It/sec 0.543, Tokens/sec 8.690, Trained Tokens 12960, Peak mem 6.365 GB
# Iter 820: Train loss 0.039, Learning Rate 2.000e-04, It/sec 0.543, Tokens/sec 8.688, Trained Tokens 13120, Peak mem 6.365 GB
# Iter 830: Train loss 0.052, Learning Rate 2.000e-04, It/sec 0.543, Tokens/sec 8.693, Trained Tokens 13280, Peak mem 6.365 GB
# Iter 840: Train loss 0.065, Learning Rate 2.000e-04, It/sec 0.543, Tokens/sec 8.682, Trained Tokens 13440, Peak mem 6.365 GB
# Iter 850: Train loss 0.276, Learning Rate 2.000e-04, It/sec 0.543, Tokens/sec 8.681, Trained Tokens 13600, Peak mem 6.365 GB
# Iter 860: Train loss 0.047, Learning Rate 2.000e-04, It/sec 0.543, Tokens/sec 8.691, Trained Tokens 13760, Peak mem 6.365 GB
# Iter 870: Train loss 0.107, Learning Rate 2.000e-04, It/sec 0.544, Tokens/sec 8.697, Trained Tokens 13920, Peak mem 6.365 GB
# Iter 880: Train loss 0.089, Learning Rate 2.000e-04, It/sec 0.543, Tokens/sec 8.690, Trained Tokens 14080, Peak mem 6.365 GB
# Iter 890: Train loss 0.078, Learning Rate 2.000e-04, It/sec 0.543, Tokens/sec 8.694, Trained Tokens 14240, Peak mem 6.365 GB
# Iter 900: Train loss 0.061, Learning Rate 2.000e-04, It/sec 0.544, Tokens/sec 8.696, Trained Tokens 14400, Peak mem 6.365 GB
# Iter 910: Train loss 0.102, Learning Rate 2.000e-04, It/sec 0.543, Tokens/sec 8.692, Trained Tokens 14560, Peak mem 6.365 GB
# Iter 920: Train loss 0.105, Learning Rate 2.000e-04, It/sec 0.544, Tokens/sec 8.700, Trained Tokens 14720, Peak mem 6.365 GB
# Iter 930: Train loss 0.022, Learning Rate 2.000e-04, It/sec 0.543, Tokens/sec 8.682, Trained Tokens 14880, Peak mem 6.365 GB
# Iter 940: Train loss 0.055, Learning Rate 2.000e-04, It/sec 0.543, Tokens/sec 8.692, Trained Tokens 15040, Peak mem 6.365 GB
# Iter 950: Train loss 0.072, Learning Rate 2.000e-04, It/sec 0.542, Tokens/sec 8.670, Trained Tokens 15200, Peak mem 6.365 GB
# Iter 960: Train loss 0.126, Learning Rate 2.000e-04, It/sec 0.543, Tokens/sec 8.687, Trained Tokens 15360, Peak mem 6.365 GB
# Iter 970: Train loss 0.102, Learning Rate 2.000e-04, It/sec 0.543, Tokens/sec 8.691, Trained Tokens 15520, Peak mem 6.365 GB
# Iter 980: Train loss 0.093, Learning Rate 2.000e-04, It/sec 0.543, Tokens/sec 8.684, Trained Tokens 15680, Peak mem 6.365 GB
# Iter 990: Train loss 0.095, Learning Rate 2.000e-04, It/sec 0.543, Tokens/sec 8.693, Trained Tokens 15840, Peak mem 6.365 GB
# Calculating loss...: 100%|██████████████████████| 25/25 [00:23<00:00,  1.05it/s]
# Iter 1000: Val loss 0.082, Val took 23.827s
# Iter 1000: Train loss 0.091, Learning Rate 2.000e-04, It/sec 0.542, Tokens/sec 8.676, Trained Tokens 16000, Peak mem 6.365 GB
# Iter 1000: Saved adapter weights to adapters_w4/T2A_demo_only/adapters.safetensors and adapters_w4/T2A_demo_only/0001000_adapters.safetensors.
# Iter 1010: Train loss 0.069, Learning Rate 2.000e-04, It/sec 0.544, Tokens/sec 8.696, Trained Tokens 16160, Peak mem 6.365 GB
# Iter 1020: Train loss 0.069, Learning Rate 2.000e-04, It/sec 0.544, Tokens/sec 8.697, Trained Tokens 16320, Peak mem 6.365 GB
# Iter 1030: Train loss 0.054, Learning Rate 2.000e-04, It/sec 0.544, Tokens/sec 8.698, Trained Tokens 16480, Peak mem 6.365 GB
# Iter 1040: Train loss 0.045, Learning Rate 2.000e-04, It/sec 0.544, Tokens/sec 8.701, Trained Tokens 16640, Peak mem 6.365 GB
# Iter 1050: Train loss 0.055, Learning Rate 2.000e-04, It/sec 0.542, Tokens/sec 8.670, Trained Tokens 16800, Peak mem 6.365 GB
# Iter 1060: Train loss 0.033, Learning Rate 2.000e-04, It/sec 0.544, Tokens/sec 8.699, Trained Tokens 16960, Peak mem 6.365 GB
# Iter 1070: Train loss 0.066, Learning Rate 2.000e-04, It/sec 0.543, Tokens/sec 8.694, Trained Tokens 17120, Peak mem 6.365 GB
# Iter 1080: Train loss 0.050, Learning Rate 2.000e-04, It/sec 0.543, Tokens/sec 8.688, Trained Tokens 17280, Peak mem 6.365 GB
# Iter 1090: Train loss 0.051, Learning Rate 2.000e-04, It/sec 0.543, Tokens/sec 8.690, Trained Tokens 17440, Peak mem 6.365 GB
# Iter 1100: Train loss 0.038, Learning Rate 2.000e-04, It/sec 0.544, Tokens/sec 8.696, Trained Tokens 17600, Peak mem 6.365 GB
# Iter 1110: Train loss 0.029, Learning Rate 2.000e-04, It/sec 0.543, Tokens/sec 8.689, Trained Tokens 17760, Peak mem 6.365 GB
# Iter 1120: Train loss 0.119, Learning Rate 2.000e-04, It/sec 0.543, Tokens/sec 8.683, Trained Tokens 17920, Peak mem 6.365 GB
# Iter 1130: Train loss 0.068, Learning Rate 2.000e-04, It/sec 0.544, Tokens/sec 8.699, Trained Tokens 18080, Peak mem 6.365 GB
# Iter 1140: Train loss 0.107, Learning Rate 2.000e-04, It/sec 0.542, Tokens/sec 8.675, Trained Tokens 18240, Peak mem 6.365 GB
# Iter 1150: Train loss 0.137, Learning Rate 2.000e-04, It/sec 0.545, Tokens/sec 8.716, Trained Tokens 18400, Peak mem 6.365 GB
# Iter 1160: Train loss 0.027, Learning Rate 2.000e-04, It/sec 0.543, Tokens/sec 8.695, Trained Tokens 18560, Peak mem 6.365 GB
# Iter 1170: Train loss 0.031, Learning Rate 2.000e-04, It/sec 0.544, Tokens/sec 8.705, Trained Tokens 18720, Peak mem 6.365 GB
# Iter 1180: Train loss 0.072, Learning Rate 2.000e-04, It/sec 0.544, Tokens/sec 8.701, Trained Tokens 18880, Peak mem 6.365 GB
# Iter 1190: Train loss 0.034, Learning Rate 2.000e-04, It/sec 0.544, Tokens/sec 8.707, Trained Tokens 19040, Peak mem 6.365 GB
# Calculating loss...: 100%|██████████████████████| 25/25 [00:23<00:00,  1.05it/s]
# Iter 1200: Val loss 0.103, Val took 23.831s
# Iter 1200: Train loss 0.187, Learning Rate 2.000e-04, It/sec 0.543, Tokens/sec 8.695, Trained Tokens 19200, Peak mem 6.365 GB
# Iter 1210: Train loss 0.054, Learning Rate 2.000e-04, It/sec 0.543, Tokens/sec 8.681, Trained Tokens 19360, Peak mem 6.365 GB
# Iter 1220: Train loss 0.063, Learning Rate 2.000e-04, It/sec 0.544, Tokens/sec 8.700, Trained Tokens 19520, Peak mem 6.365 GB
# Iter 1230: Train loss 0.082, Learning Rate 2.000e-04, It/sec 0.543, Tokens/sec 8.691, Trained Tokens 19680, Peak mem 6.365 GB
# Iter 1240: Train loss 0.076, Learning Rate 2.000e-04, It/sec 0.544, Tokens/sec 8.699, Trained Tokens 19840, Peak mem 6.365 GB
# Iter 1250: Train loss 0.074, Learning Rate 2.000e-04, It/sec 0.541, Tokens/sec 8.662, Trained Tokens 20000, Peak mem 6.365 GB
# Iter 1260: Train loss 0.029, Learning Rate 2.000e-04, It/sec 0.543, Tokens/sec 8.689, Trained Tokens 20160, Peak mem 6.365 GB
# Iter 1270: Train loss 0.089, Learning Rate 2.000e-04, It/sec 0.544, Tokens/sec 8.700, Trained Tokens 20320, Peak mem 6.365 GB
# Iter 1280: Train loss 0.124, Learning Rate 2.000e-04, It/sec 0.543, Tokens/sec 8.689, Trained Tokens 20480, Peak mem 6.365 GB
# Iter 1290: Train loss 0.060, Learning Rate 2.000e-04, It/sec 0.543, Tokens/sec 8.693, Trained Tokens 20640, Peak mem 6.365 GB
# Iter 1300: Train loss 0.060, Learning Rate 2.000e-04, It/sec 0.543, Tokens/sec 8.695, Trained Tokens 20800, Peak mem 6.365 GB
# Iter 1310: Train loss 0.038, Learning Rate 2.000e-04, It/sec 0.543, Tokens/sec 8.685, Trained Tokens 20960, Peak mem 6.365 GB
# Iter 1320: Train loss 0.025, Learning Rate 2.000e-04, It/sec 0.543, Tokens/sec 8.686, Trained Tokens 21120, Peak mem 6.365 GB
# Iter 1330: Train loss 0.080, Learning Rate 2.000e-04, It/sec 0.543, Tokens/sec 8.680, Trained Tokens 21280, Peak mem 6.365 GB
# Iter 1340: Train loss 0.044, Learning Rate 2.000e-04, It/sec 0.542, Tokens/sec 8.678, Trained Tokens 21440, Peak mem 6.365 GB
# Iter 1350: Train loss 0.057, Learning Rate 2.000e-04, It/sec 0.543, Tokens/sec 8.682, Trained Tokens 21600, Peak mem 6.365 GB
# Iter 1360: Train loss 0.135, Learning Rate 2.000e-04, It/sec 0.543, Tokens/sec 8.692, Trained Tokens 21760, Peak mem 6.365 GB
# Iter 1370: Train loss 0.056, Learning Rate 2.000e-04, It/sec 0.544, Tokens/sec 8.699, Trained Tokens 21920, Peak mem 6.365 GB
# Iter 1380: Train loss 0.069, Learning Rate 2.000e-04, It/sec 0.544, Tokens/sec 8.705, Trained Tokens 22080, Peak mem 6.365 GB
# Iter 1390: Train loss 0.078, Learning Rate 2.000e-04, It/sec 0.544, Tokens/sec 8.698, Trained Tokens 22240, Peak mem 6.365 GB
# Calculating loss...: 100%|██████████████████████| 25/25 [00:23<00:00,  1.05it/s]
# Iter 1400: Val loss 0.060, Val took 23.825s
# Iter 1400: Train loss 0.031, Learning Rate 2.000e-04, It/sec 0.544, Tokens/sec 8.703, Trained Tokens 22400, Peak mem 6.365 GB
# Iter 1410: Train loss 0.091, Learning Rate 2.000e-04, It/sec 0.543, Tokens/sec 8.680, Trained Tokens 22560, Peak mem 6.365 GB
# Iter 1420: Train loss 0.037, Learning Rate 2.000e-04, It/sec 0.543, Tokens/sec 8.693, Trained Tokens 22720, Peak mem 6.365 GB
# Iter 1430: Train loss 0.062, Learning Rate 2.000e-04, It/sec 0.544, Tokens/sec 8.707, Trained Tokens 22880, Peak mem 6.365 GB
# Iter 1440: Train loss 0.085, Learning Rate 2.000e-04, It/sec 0.543, Tokens/sec 8.682, Trained Tokens 23040, Peak mem 6.365 GB
# Iter 1450: Train loss 0.051, Learning Rate 2.000e-04, It/sec 0.543, Tokens/sec 8.688, Trained Tokens 23200, Peak mem 6.365 GB
# Iter 1460: Train loss 0.039, Learning Rate 2.000e-04, It/sec 0.543, Tokens/sec 8.690, Trained Tokens 23360, Peak mem 6.365 GB
# Iter 1470: Train loss 0.023, Learning Rate 2.000e-04, It/sec 0.543, Tokens/sec 8.682, Trained Tokens 23520, Peak mem 6.365 GB
# Iter 1480: Train loss 0.047, Learning Rate 2.000e-04, It/sec 0.543, Tokens/sec 8.691, Trained Tokens 23680, Peak mem 6.365 GB
# Iter 1490: Train loss 0.048, Learning Rate 2.000e-04, It/sec 0.544, Tokens/sec 8.710, Trained Tokens 23840, Peak mem 6.365 GB
# Iter 1500: Train loss 0.054, Learning Rate 2.000e-04, It/sec 0.543, Tokens/sec 8.683, Trained Tokens 24000, Peak mem 6.365 GB
# Iter 1500: Saved adapter weights to adapters_w4/T2A_demo_only/adapters.safetensors and adapters_w4/T2A_demo_only/0001500_adapters.safetensors.
# Iter 1510: Train loss 0.074, Learning Rate 2.000e-04, It/sec 0.543, Tokens/sec 8.686, Trained Tokens 24160, Peak mem 6.365 GB
# Iter 1520: Train loss 0.052, Learning Rate 2.000e-04, It/sec 0.543, Tokens/sec 8.681, Trained Tokens 24320, Peak mem 6.365 GB
# Iter 1530: Train loss 0.093, Learning Rate 2.000e-04, It/sec 0.544, Tokens/sec 8.701, Trained Tokens 24480, Peak mem 6.365 GB
# Iter 1540: Train loss 0.045, Learning Rate 2.000e-04, It/sec 0.544, Tokens/sec 8.696, Trained Tokens 24640, Peak mem 6.365 GB
# Iter 1550: Train loss 0.086, Learning Rate 2.000e-04, It/sec 0.542, Tokens/sec 8.673, Trained Tokens 24800, Peak mem 6.365 GB
# Iter 1560: Train loss 0.042, Learning Rate 2.000e-04, It/sec 0.543, Tokens/sec 8.686, Trained Tokens 24960, Peak mem 6.365 GB
# Iter 1570: Train loss 0.056, Learning Rate 2.000e-04, It/sec 0.542, Tokens/sec 8.679, Trained Tokens 25120, Peak mem 6.365 GB
# Iter 1580: Train loss 0.055, Learning Rate 2.000e-04, It/sec 0.544, Tokens/sec 8.697, Trained Tokens 25280, Peak mem 6.365 GB
# Iter 1590: Train loss 0.047, Learning Rate 2.000e-04, It/sec 0.543, Tokens/sec 8.693, Trained Tokens 25440, Peak mem 6.365 GB
# Calculating loss...: 100%|██████████████████████| 25/25 [00:23<00:00,  1.05it/s]
# Iter 1600: Val loss 0.061, Val took 23.831s
# Iter 1600: Train loss 0.124, Learning Rate 2.000e-04, It/sec 0.543, Tokens/sec 8.694, Trained Tokens 25600, Peak mem 6.365 GB
# Iter 1610: Train loss 0.067, Learning Rate 2.000e-04, It/sec 0.544, Tokens/sec 8.699, Trained Tokens 25760, Peak mem 6.365 GB
# Iter 1620: Train loss 0.062, Learning Rate 2.000e-04, It/sec 0.544, Tokens/sec 8.701, Trained Tokens 25920, Peak mem 6.365 GB
# Iter 1630: Train loss 0.070, Learning Rate 2.000e-04, It/sec 0.544, Tokens/sec 8.704, Trained Tokens 26080, Peak mem 6.365 GB
# Iter 1640: Train loss 0.091, Learning Rate 2.000e-04, It/sec 0.544, Tokens/sec 8.696, Trained Tokens 26240, Peak mem 6.365 GB
# Iter 1650: Train loss 0.093, Learning Rate 2.000e-04, It/sec 0.543, Tokens/sec 8.682, Trained Tokens 26400, Peak mem 6.365 GB
# Iter 1660: Train loss 0.058, Learning Rate 2.000e-04, It/sec 0.543, Tokens/sec 8.683, Trained Tokens 26560, Peak mem 6.365 GB
# Iter 1670: Train loss 0.096, Learning Rate 2.000e-04, It/sec 0.543, Tokens/sec 8.687, Trained Tokens 26720, Peak mem 6.365 GB
# Iter 1680: Train loss 0.058, Learning Rate 2.000e-04, It/sec 0.544, Tokens/sec 8.702, Trained Tokens 26880, Peak mem 6.365 GB
# Iter 1690: Train loss 0.064, Learning Rate 2.000e-04, It/sec 0.544, Tokens/sec 8.703, Trained Tokens 27040, Peak mem 6.365 GB
# Iter 1700: Train loss 0.039, Learning Rate 2.000e-04, It/sec 0.544, Tokens/sec 8.700, Trained Tokens 27200, Peak mem 6.365 GB
# Iter 1710: Train loss 0.053, Learning Rate 2.000e-04, It/sec 0.544, Tokens/sec 8.709, Trained Tokens 27360, Peak mem 6.365 GB
# Iter 1720: Train loss 0.085, Learning Rate 2.000e-04, It/sec 0.543, Tokens/sec 8.684, Trained Tokens 27520, Peak mem 6.365 GB
# Iter 1730: Train loss 0.026, Learning Rate 2.000e-04, It/sec 0.543, Tokens/sec 8.696, Trained Tokens 27680, Peak mem 6.365 GB
# Iter 1740: Train loss 0.034, Learning Rate 2.000e-04, It/sec 0.544, Tokens/sec 8.698, Trained Tokens 27840, Peak mem 6.365 GB
# Iter 1750: Train loss 0.067, Learning Rate 2.000e-04, It/sec 0.544, Tokens/sec 8.698, Trained Tokens 28000, Peak mem 6.365 GB
# Iter 1760: Train loss 0.088, Learning Rate 2.000e-04, It/sec 0.543, Tokens/sec 8.692, Trained Tokens 28160, Peak mem 6.365 GB
# Iter 1770: Train loss 0.016, Learning Rate 2.000e-04, It/sec 0.544, Tokens/sec 8.696, Trained Tokens 28320, Peak mem 6.365 GB
# Iter 1780: Train loss 0.038, Learning Rate 2.000e-04, It/sec 0.543, Tokens/sec 8.688, Trained Tokens 28480, Peak mem 6.365 GB
# Iter 1790: Train loss 0.048, Learning Rate 2.000e-04, It/sec 0.541, Tokens/sec 8.660, Trained Tokens 28640, Peak mem 6.365 GB
# Calculating loss...: 100%|██████████████████████| 25/25 [00:23<00:00,  1.05it/s]
# Iter 1800: Val loss 0.054, Val took 23.823s
# Iter 1800: Train loss 0.028, Learning Rate 2.000e-04, It/sec 0.543, Tokens/sec 8.690, Trained Tokens 28800, Peak mem 6.365 GB
# Iter 1810: Train loss 0.091, Learning Rate 2.000e-04, It/sec 0.543, Tokens/sec 8.686, Trained Tokens 28960, Peak mem 6.365 GB
# Iter 1820: Train loss 0.035, Learning Rate 2.000e-04, It/sec 0.543, Tokens/sec 8.690, Trained Tokens 29120, Peak mem 6.365 GB
# Iter 1830: Train loss 0.104, Learning Rate 2.000e-04, It/sec 0.544, Tokens/sec 8.702, Trained Tokens 29280, Peak mem 6.365 GB
# Iter 1840: Train loss 0.071, Learning Rate 2.000e-04, It/sec 0.542, Tokens/sec 8.673, Trained Tokens 29440, Peak mem 6.365 GB
# Iter 1850: Train loss 0.053, Learning Rate 2.000e-04, It/sec 0.543, Tokens/sec 8.685, Trained Tokens 29600, Peak mem 6.365 GB
# Iter 1860: Train loss 0.063, Learning Rate 2.000e-04, It/sec 0.542, Tokens/sec 8.673, Trained Tokens 29760, Peak mem 6.365 GB
# Iter 1870: Train loss 0.099, Learning Rate 2.000e-04, It/sec 0.541, Tokens/sec 8.658, Trained Tokens 29920, Peak mem 6.365 GB
# Iter 1880: Train loss 0.062, Learning Rate 2.000e-04, It/sec 0.545, Tokens/sec 8.717, Trained Tokens 30080, Peak mem 6.365 GB
# Iter 1890: Train loss 0.114, Learning Rate 2.000e-04, It/sec 0.544, Tokens/sec 8.711, Trained Tokens 30240, Peak mem 6.365 GB
# Iter 1900: Train loss 0.051, Learning Rate 2.000e-04, It/sec 0.544, Tokens/sec 8.705, Trained Tokens 30400, Peak mem 6.365 GB
# Iter 1910: Train loss 0.082, Learning Rate 2.000e-04, It/sec 0.544, Tokens/sec 8.703, Trained Tokens 30560, Peak mem 6.365 GB
# Iter 1920: Train loss 0.040, Learning Rate 2.000e-04, It/sec 0.543, Tokens/sec 8.688, Trained Tokens 30720, Peak mem 6.365 GB
# Iter 1930: Train loss 0.067, Learning Rate 2.000e-04, It/sec 0.543, Tokens/sec 8.692, Trained Tokens 30880, Peak mem 6.365 GB
# Iter 1940: Train loss 0.076, Learning Rate 2.000e-04, It/sec 0.543, Tokens/sec 8.687, Trained Tokens 31040, Peak mem 6.365 GB
# Iter 1950: Train loss 0.064, Learning Rate 2.000e-04, It/sec 0.544, Tokens/sec 8.698, Trained Tokens 31200, Peak mem 6.365 GB
# Iter 1960: Train loss 0.063, Learning Rate 2.000e-04, It/sec 0.544, Tokens/sec 8.708, Trained Tokens 31360, Peak mem 6.365 GB
# Iter 1970: Train loss 0.050, Learning Rate 2.000e-04, It/sec 0.543, Tokens/sec 8.689, Trained Tokens 31520, Peak mem 6.365 GB
# Iter 1980: Train loss 0.083, Learning Rate 2.000e-04, It/sec 0.543, Tokens/sec 8.692, Trained Tokens 31680, Peak mem 6.365 GB
# Iter 1990: Train loss 0.061, Learning Rate 2.000e-04, It/sec 0.543, Tokens/sec 8.692, Trained Tokens 31840, Peak mem 6.365 GB
# Calculating loss...: 100%|██████████████████████| 25/25 [00:23<00:00,  1.05it/s]
# Iter 2000: Val loss 0.062, Val took 23.828s
# Iter 2000: Train loss 0.029, Learning Rate 2.000e-04, It/sec 0.543, Tokens/sec 8.686, Trained Tokens 32000, Peak mem 6.365 GB
# Iter 2000: Saved adapter weights to adapters_w4/T2A_demo_only/adapters.safetensors and adapters_w4/T2A_demo_only/0002000_adapters.safetensors.
# Saved final weights to adapters_w4/T2A_demo_only/adapters.safetensors.

# %%
# ── Load model with T2A_demo_only adapter ──────────────────────────────
model_mlx, tok_mlx = load(
    MODEL_ID,
    adapter_path="./adapters_w4/T2A_demo_only",
)

# ── Inference ──────────────────────────────────────────────────────
t0 = time.time()
preds, refs, probs = run_inference_mlx(
    model_mlx, tok_mlx, test_ds_structured_demo, return_probs=True
)

# ── Evaluate ───────────────────────────────────────────────────────
metrics = evaluate_predictions(preds, refs, label_name="T2A_demo_only")

# ── Calibration ────────────────────────────────────────────────────
ece = calibration_analysis(
    probs, refs,
    label_name="T2A_demo_only",
    save_path=os.path.join(OUTPUT_DIR, "calibration_T2A_demo_only.png")
)
metrics["ECE"] = ece
all_metrics.append(metrics)

# ── Save predictions ───────────────────────────────────────────────
out_df = pd.DataFrame({"Predicted_Label": preds, "Ground_Truth": refs, "P_Yes": probs})
out_df.to_csv(os.path.join(OUTPUT_DIR, "predictions_T2A_demo_only.csv"), index=False)

elapsed = round(time.time() - t0, 2)
experiment_times["T2A_demo_only"] = elapsed
print(f"\n  ⏱ T2A_demo_only done in {elapsed:.1f}s")

# ── Clean up ───────────────────────────────────────────────────────
del model_mlx, tok_mlx
# Out:
# Downloading (incomplete total...): 0.00B [00:00, ?B/s]
# Fetching 9 files:   0%|          | 0/9 [00:00<?, ?it/s]
# Generating:   0%|          | 0/6167 [00:00<?, ?it/s]
# ── T2A_demo_only ──
#   Label: T2A_demo_only
#   N_test: 6167
#   Accuracy: 0.9027
#   Recall: 0.142
#   Precision: 0.7099
#   F1: 0.2366
#   Unknown: 0
#               precision    recall  f1-score   support
#
#           No       0.91      0.99      0.95      5512
#          Yes       0.71      0.14      0.24       655
#
#     accuracy                           0.90      6167
#    macro avg       0.81      0.57      0.59      6167
# weighted avg       0.89      0.90      0.87      6167
#
#   ECE: 0.0911 | Saved → ./results_wave4/calibration_T2A_demo_only.png
#
#   ⏱ T2A_demo_only done in 2102.6s

# %% [markdown]
# ### Training and Inference for T2C_longitudinal_model

# %%
# !mlx_lm.lora \
    --model {MODEL_ID} \
    --train \
    --data ./mlx_data/T2C_longitudinal_model \
    --num-layers 16 \
    --batch-size 4 \
    --grad-accumulation-steps 4 \
    --iters 2000 \
    --learning-rate 2e-4 \
    --mask-prompt \
    --adapter-path ./adapters_w4/T2C_longitudinal_model \
    --save-every 500 \
    -c ./configs/lora_config.yaml
# Out:
# Loading configuration file ./configs/lora_config.yaml
# Loading pretrained model
# Downloading (incomplete total...): 0.00B [00:00, ?B/s]
# Fetching 9 files: 100%|████████████████████████| 9/9 [00:00<00:00, 70295.60it/s]
# Download complete: : 0.00B [00:00, ?B/s]
# Loading datasets
# Training
# Trainable parameters: 0.684% (10.551M/1543.714M)
# Starting training..., iters: 2000
# Calculating loss...: 100%|██████████████████████| 25/25 [00:18<00:00,  1.35it/s]
# Iter 1: Val loss 7.456, Val took 18.545s
# Iter 10: Train loss 3.580, Learning Rate 2.000e-04, It/sec 0.698, Tokens/sec 11.162, Trained Tokens 160, Peak mem 5.275 GB
# Iter 20: Train loss 0.248, Learning Rate 2.000e-04, It/sec 0.703, Tokens/sec 11.243, Trained Tokens 320, Peak mem 5.275 GB
# Iter 30: Train loss 0.042, Learning Rate 2.000e-04, It/sec 0.704, Tokens/sec 11.261, Trained Tokens 480, Peak mem 5.275 GB
# Iter 40: Train loss 0.037, Learning Rate 2.000e-04, It/sec 0.704, Tokens/sec 11.259, Trained Tokens 640, Peak mem 5.275 GB
# Iter 50: Train loss 0.035, Learning Rate 2.000e-04, It/sec 0.704, Tokens/sec 11.257, Trained Tokens 800, Peak mem 5.275 GB
# Iter 60: Train loss 0.007, Learning Rate 2.000e-04, It/sec 0.702, Tokens/sec 11.239, Trained Tokens 960, Peak mem 5.275 GB
# Iter 70: Train loss 0.072, Learning Rate 2.000e-04, It/sec 0.703, Tokens/sec 11.255, Trained Tokens 1120, Peak mem 5.275 GB
# Iter 80: Train loss 0.048, Learning Rate 2.000e-04, It/sec 0.703, Tokens/sec 11.250, Trained Tokens 1280, Peak mem 5.275 GB
# Iter 90: Train loss 0.039, Learning Rate 2.000e-04, It/sec 0.702, Tokens/sec 11.235, Trained Tokens 1440, Peak mem 5.275 GB
# Iter 100: Train loss 0.014, Learning Rate 2.000e-04, It/sec 0.702, Tokens/sec 11.231, Trained Tokens 1600, Peak mem 5.275 GB
# Iter 110: Train loss 0.000, Learning Rate 2.000e-04, It/sec 0.701, Tokens/sec 11.211, Trained Tokens 1760, Peak mem 5.275 GB
# Iter 120: Train loss 0.000, Learning Rate 2.000e-04, It/sec 0.702, Tokens/sec 11.234, Trained Tokens 1920, Peak mem 5.275 GB
# Iter 130: Train loss 0.000, Learning Rate 2.000e-04, It/sec 0.700, Tokens/sec 11.203, Trained Tokens 2080, Peak mem 5.275 GB
# Iter 140: Train loss 0.000, Learning Rate 2.000e-04, It/sec 0.701, Tokens/sec 11.215, Trained Tokens 2240, Peak mem 5.275 GB
# Iter 150: Train loss 0.084, Learning Rate 2.000e-04, It/sec 0.703, Tokens/sec 11.255, Trained Tokens 2400, Peak mem 5.275 GB
# Iter 160: Train loss 0.063, Learning Rate 2.000e-04, It/sec 0.704, Tokens/sec 11.269, Trained Tokens 2560, Peak mem 5.275 GB
# Iter 170: Train loss 0.034, Learning Rate 2.000e-04, It/sec 0.703, Tokens/sec 11.253, Trained Tokens 2720, Peak mem 5.275 GB
# Iter 180: Train loss 0.041, Learning Rate 2.000e-04, It/sec 0.702, Tokens/sec 11.240, Trained Tokens 2880, Peak mem 5.275 GB
# Iter 190: Train loss 0.008, Learning Rate 2.000e-04, It/sec 0.703, Tokens/sec 11.246, Trained Tokens 3040, Peak mem 5.275 GB
# Calculating loss...: 100%|██████████████████████| 25/25 [00:18<00:00,  1.35it/s]
# Iter 200: Val loss 0.038, Val took 18.533s
# Iter 200: Train loss 0.006, Learning Rate 2.000e-04, It/sec 0.703, Tokens/sec 11.255, Trained Tokens 3200, Peak mem 5.275 GB
# Iter 210: Train loss 0.002, Learning Rate 2.000e-04, It/sec 0.702, Tokens/sec 11.227, Trained Tokens 3360, Peak mem 5.275 GB
# Iter 220: Train loss 0.108, Learning Rate 2.000e-04, It/sec 0.704, Tokens/sec 11.259, Trained Tokens 3520, Peak mem 5.275 GB
# Iter 230: Train loss 0.089, Learning Rate 2.000e-04, It/sec 0.703, Tokens/sec 11.243, Trained Tokens 3680, Peak mem 5.275 GB
# Iter 240: Train loss 0.039, Learning Rate 2.000e-04, It/sec 0.704, Tokens/sec 11.268, Trained Tokens 3840, Peak mem 5.275 GB
# Iter 250: Train loss 0.018, Learning Rate 2.000e-04, It/sec 0.703, Tokens/sec 11.255, Trained Tokens 4000, Peak mem 5.275 GB
# Iter 260: Train loss 0.039, Learning Rate 2.000e-04, It/sec 0.699, Tokens/sec 11.177, Trained Tokens 4160, Peak mem 5.275 GB
# Iter 270: Train loss 0.055, Learning Rate 2.000e-04, It/sec 0.706, Tokens/sec 11.289, Trained Tokens 4320, Peak mem 5.275 GB
# Iter 280: Train loss 0.019, Learning Rate 2.000e-04, It/sec 0.705, Tokens/sec 11.281, Trained Tokens 4480, Peak mem 5.275 GB
# Iter 290: Train loss 0.050, Learning Rate 2.000e-04, It/sec 0.704, Tokens/sec 11.260, Trained Tokens 4640, Peak mem 5.275 GB
# Iter 300: Train loss 0.090, Learning Rate 2.000e-04, It/sec 0.703, Tokens/sec 11.253, Trained Tokens 4800, Peak mem 5.275 GB
# Iter 310: Train loss 0.045, Learning Rate 2.000e-04, It/sec 0.703, Tokens/sec 11.251, Trained Tokens 4960, Peak mem 5.275 GB
# Iter 320: Train loss 0.043, Learning Rate 2.000e-04, It/sec 0.704, Tokens/sec 11.267, Trained Tokens 5120, Peak mem 5.275 GB
# Iter 330: Train loss 0.046, Learning Rate 2.000e-04, It/sec 0.703, Tokens/sec 11.254, Trained Tokens 5280, Peak mem 5.275 GB
# Iter 340: Train loss 0.047, Learning Rate 2.000e-04, It/sec 0.702, Tokens/sec 11.240, Trained Tokens 5440, Peak mem 5.275 GB
# Iter 350: Train loss 0.038, Learning Rate 2.000e-04, It/sec 0.703, Tokens/sec 11.253, Trained Tokens 5600, Peak mem 5.275 GB
# Iter 360: Train loss 0.006, Learning Rate 2.000e-04, It/sec 0.703, Tokens/sec 11.241, Trained Tokens 5760, Peak mem 5.275 GB
# Iter 370: Train loss 0.031, Learning Rate 2.000e-04, It/sec 0.704, Tokens/sec 11.260, Trained Tokens 5920, Peak mem 5.275 GB
# Iter 380: Train loss 0.007, Learning Rate 2.000e-04, It/sec 0.702, Tokens/sec 11.236, Trained Tokens 6080, Peak mem 5.275 GB
# Iter 390: Train loss 0.006, Learning Rate 2.000e-04, It/sec 0.705, Tokens/sec 11.273, Trained Tokens 6240, Peak mem 5.275 GB
# Calculating loss...: 100%|██████████████████████| 25/25 [00:18<00:00,  1.35it/s]
# Iter 400: Val loss 0.055, Val took 18.520s
# Iter 400: Train loss 0.014, Learning Rate 2.000e-04, It/sec 0.703, Tokens/sec 11.253, Trained Tokens 6400, Peak mem 5.275 GB
# Iter 410: Train loss 0.003, Learning Rate 2.000e-04, It/sec 0.702, Tokens/sec 11.237, Trained Tokens 6560, Peak mem 5.275 GB
# Iter 420: Train loss 0.049, Learning Rate 2.000e-04, It/sec 0.703, Tokens/sec 11.254, Trained Tokens 6720, Peak mem 5.275 GB
# Iter 430: Train loss 0.080, Learning Rate 2.000e-04, It/sec 0.704, Tokens/sec 11.269, Trained Tokens 6880, Peak mem 5.275 GB
# Iter 440: Train loss 0.001, Learning Rate 2.000e-04, It/sec 0.703, Tokens/sec 11.248, Trained Tokens 7040, Peak mem 5.275 GB
# Iter 450: Train loss 0.054, Learning Rate 2.000e-04, It/sec 0.704, Tokens/sec 11.257, Trained Tokens 7200, Peak mem 5.275 GB
# Iter 460: Train loss 0.004, Learning Rate 2.000e-04, It/sec 0.704, Tokens/sec 11.261, Trained Tokens 7360, Peak mem 5.275 GB
# Iter 470: Train loss 0.007, Learning Rate 2.000e-04, It/sec 0.703, Tokens/sec 11.249, Trained Tokens 7520, Peak mem 5.275 GB
# Iter 480: Train loss 0.077, Learning Rate 2.000e-04, It/sec 0.704, Tokens/sec 11.269, Trained Tokens 7680, Peak mem 5.275 GB
# Iter 490: Train loss 0.075, Learning Rate 2.000e-04, It/sec 0.703, Tokens/sec 11.250, Trained Tokens 7840, Peak mem 5.275 GB
# Iter 500: Train loss 0.022, Learning Rate 2.000e-04, It/sec 0.703, Tokens/sec 11.254, Trained Tokens 8000, Peak mem 5.275 GB
# Iter 500: Saved adapter weights to adapters_w4/T2C_longitudinal_model/adapters.safetensors and adapters_w4/T2C_longitudinal_model/0000500_adapters.safetensors.
# Iter 510: Train loss 0.025, Learning Rate 2.000e-04, It/sec 0.702, Tokens/sec 11.238, Trained Tokens 8160, Peak mem 5.317 GB
# Iter 520: Train loss 0.042, Learning Rate 2.000e-04, It/sec 0.703, Tokens/sec 11.246, Trained Tokens 8320, Peak mem 5.317 GB
# Iter 530: Train loss 0.029, Learning Rate 2.000e-04, It/sec 0.702, Tokens/sec 11.225, Trained Tokens 8480, Peak mem 5.317 GB
# Iter 540: Train loss 0.033, Learning Rate 2.000e-04, It/sec 0.702, Tokens/sec 11.231, Trained Tokens 8640, Peak mem 5.317 GB
# Iter 550: Train loss 0.024, Learning Rate 2.000e-04, It/sec 0.702, Tokens/sec 11.231, Trained Tokens 8800, Peak mem 5.317 GB
# Iter 560: Train loss 0.015, Learning Rate 2.000e-04, It/sec 0.705, Tokens/sec 11.273, Trained Tokens 8960, Peak mem 5.317 GB
# Iter 570: Train loss 0.035, Learning Rate 2.000e-04, It/sec 0.702, Tokens/sec 11.229, Trained Tokens 9120, Peak mem 5.317 GB
# Iter 580: Train loss 0.057, Learning Rate 2.000e-04, It/sec 0.702, Tokens/sec 11.234, Trained Tokens 9280, Peak mem 5.317 GB
# Iter 590: Train loss 0.069, Learning Rate 2.000e-04, It/sec 0.704, Tokens/sec 11.260, Trained Tokens 9440, Peak mem 5.317 GB
# Calculating loss...: 100%|██████████████████████| 25/25 [00:18<00:00,  1.35it/s]
# Iter 600: Val loss 0.026, Val took 18.525s
# Iter 600: Train loss 0.007, Learning Rate 2.000e-04, It/sec 0.704, Tokens/sec 11.264, Trained Tokens 9600, Peak mem 5.317 GB
# Iter 610: Train loss 0.040, Learning Rate 2.000e-04, It/sec 0.703, Tokens/sec 11.245, Trained Tokens 9760, Peak mem 5.317 GB
# Iter 620: Train loss 0.009, Learning Rate 2.000e-04, It/sec 0.704, Tokens/sec 11.257, Trained Tokens 9920, Peak mem 5.317 GB
# Iter 630: Train loss 0.012, Learning Rate 2.000e-04, It/sec 0.704, Tokens/sec 11.272, Trained Tokens 10080, Peak mem 5.317 GB
# Iter 640: Train loss 0.010, Learning Rate 2.000e-04, It/sec 0.703, Tokens/sec 11.248, Trained Tokens 10240, Peak mem 5.317 GB
# Iter 650: Train loss 0.033, Learning Rate 2.000e-04, It/sec 0.702, Tokens/sec 11.239, Trained Tokens 10400, Peak mem 5.317 GB
# Iter 660: Train loss 0.002, Learning Rate 2.000e-04, It/sec 0.700, Tokens/sec 11.208, Trained Tokens 10560, Peak mem 5.317 GB
# Iter 670: Train loss 0.001, Learning Rate 2.000e-04, It/sec 0.703, Tokens/sec 11.254, Trained Tokens 10720, Peak mem 5.317 GB
# Iter 680: Train loss 0.025, Learning Rate 2.000e-04, It/sec 0.703, Tokens/sec 11.246, Trained Tokens 10880, Peak mem 5.317 GB
# Iter 690: Train loss 0.007, Learning Rate 2.000e-04, It/sec 0.703, Tokens/sec 11.249, Trained Tokens 11040, Peak mem 5.317 GB
# Iter 700: Train loss 0.021, Learning Rate 2.000e-04, It/sec 0.703, Tokens/sec 11.242, Trained Tokens 11200, Peak mem 5.317 GB
# Iter 710: Train loss 0.011, Learning Rate 2.000e-04, It/sec 0.702, Tokens/sec 11.240, Trained Tokens 11360, Peak mem 5.317 GB
# Iter 720: Train loss 0.004, Learning Rate 2.000e-04, It/sec 0.703, Tokens/sec 11.255, Trained Tokens 11520, Peak mem 5.317 GB
# Iter 730: Train loss 0.048, Learning Rate 2.000e-04, It/sec 0.703, Tokens/sec 11.253, Trained Tokens 11680, Peak mem 5.317 GB
# Iter 740: Train loss 0.026, Learning Rate 2.000e-04, It/sec 0.703, Tokens/sec 11.252, Trained Tokens 11840, Peak mem 5.317 GB
# Iter 750: Train loss 0.001, Learning Rate 2.000e-04, It/sec 0.704, Tokens/sec 11.260, Trained Tokens 12000, Peak mem 5.317 GB
# Iter 760: Train loss 0.099, Learning Rate 2.000e-04, It/sec 0.705, Tokens/sec 11.272, Trained Tokens 12160, Peak mem 5.317 GB
# Iter 770: Train loss 0.042, Learning Rate 2.000e-04, It/sec 0.703, Tokens/sec 11.252, Trained Tokens 12320, Peak mem 5.317 GB
# Iter 780: Train loss 0.072, Learning Rate 2.000e-04, It/sec 0.704, Tokens/sec 11.269, Trained Tokens 12480, Peak mem 5.317 GB
# Iter 790: Train loss 0.086, Learning Rate 2.000e-04, It/sec 0.704, Tokens/sec 11.265, Trained Tokens 12640, Peak mem 5.317 GB
# Calculating loss...: 100%|██████████████████████| 25/25 [00:18<00:00,  1.35it/s]
# Iter 800: Val loss 0.059, Val took 18.511s
# Iter 800: Train loss 0.024, Learning Rate 2.000e-04, It/sec 0.704, Tokens/sec 11.259, Trained Tokens 12800, Peak mem 5.317 GB
# Iter 810: Train loss 0.004, Learning Rate 2.000e-04, It/sec 0.702, Tokens/sec 11.229, Trained Tokens 12960, Peak mem 5.317 GB
# Iter 820: Train loss 0.077, Learning Rate 2.000e-04, It/sec 0.702, Tokens/sec 11.234, Trained Tokens 13120, Peak mem 5.317 GB
# Iter 830: Train loss 0.041, Learning Rate 2.000e-04, It/sec 0.701, Tokens/sec 11.224, Trained Tokens 13280, Peak mem 5.317 GB
# Iter 840: Train loss 0.033, Learning Rate 2.000e-04, It/sec 0.704, Tokens/sec 11.260, Trained Tokens 13440, Peak mem 5.317 GB
# Iter 850: Train loss 0.087, Learning Rate 2.000e-04, It/sec 0.704, Tokens/sec 11.257, Trained Tokens 13600, Peak mem 5.317 GB
# Iter 860: Train loss 0.027, Learning Rate 2.000e-04, It/sec 0.703, Tokens/sec 11.249, Trained Tokens 13760, Peak mem 5.317 GB
# Iter 870: Train loss 0.090, Learning Rate 2.000e-04, It/sec 0.702, Tokens/sec 11.232, Trained Tokens 13920, Peak mem 5.317 GB
# Iter 880: Train loss 0.011, Learning Rate 2.000e-04, It/sec 0.701, Tokens/sec 11.219, Trained Tokens 14080, Peak mem 5.317 GB
# Iter 890: Train loss 0.030, Learning Rate 2.000e-04, It/sec 0.702, Tokens/sec 11.237, Trained Tokens 14240, Peak mem 5.317 GB
# Iter 900: Train loss 0.007, Learning Rate 2.000e-04, It/sec 0.704, Tokens/sec 11.272, Trained Tokens 14400, Peak mem 5.317 GB
# Iter 910: Train loss 0.101, Learning Rate 2.000e-04, It/sec 0.703, Tokens/sec 11.246, Trained Tokens 14560, Peak mem 5.317 GB
# Iter 920: Train loss 0.046, Learning Rate 2.000e-04, It/sec 0.703, Tokens/sec 11.245, Trained Tokens 14720, Peak mem 5.317 GB
# Iter 930: Train loss 0.020, Learning Rate 2.000e-04, It/sec 0.703, Tokens/sec 11.241, Trained Tokens 14880, Peak mem 5.317 GB
# Iter 940: Train loss 0.005, Learning Rate 2.000e-04, It/sec 0.702, Tokens/sec 11.239, Trained Tokens 15040, Peak mem 5.317 GB
# Iter 950: Train loss 0.040, Learning Rate 2.000e-04, It/sec 0.704, Tokens/sec 11.262, Trained Tokens 15200, Peak mem 5.317 GB
# Iter 960: Train loss 0.094, Learning Rate 2.000e-04, It/sec 0.703, Tokens/sec 11.241, Trained Tokens 15360, Peak mem 5.317 GB
# Iter 970: Train loss 0.025, Learning Rate 2.000e-04, It/sec 0.704, Tokens/sec 11.261, Trained Tokens 15520, Peak mem 5.317 GB
# Iter 980: Train loss 0.053, Learning Rate 2.000e-04, It/sec 0.704, Tokens/sec 11.257, Trained Tokens 15680, Peak mem 5.317 GB
# Iter 990: Train loss 0.015, Learning Rate 2.000e-04, It/sec 0.702, Tokens/sec 11.239, Trained Tokens 15840, Peak mem 5.317 GB
# Calculating loss...: 100%|██████████████████████| 25/25 [00:18<00:00,  1.35it/s]
# Iter 1000: Val loss 0.017, Val took 18.514s
# Iter 1000: Train loss 0.045, Learning Rate 2.000e-04, It/sec 0.702, Tokens/sec 11.238, Trained Tokens 16000, Peak mem 5.317 GB
# Iter 1000: Saved adapter weights to adapters_w4/T2C_longitudinal_model/adapters.safetensors and adapters_w4/T2C_longitudinal_model/0001000_adapters.safetensors.
# Iter 1010: Train loss 0.010, Learning Rate 2.000e-04, It/sec 0.702, Tokens/sec 11.240, Trained Tokens 16160, Peak mem 5.317 GB
# Iter 1020: Train loss 0.013, Learning Rate 2.000e-04, It/sec 0.703, Tokens/sec 11.244, Trained Tokens 16320, Peak mem 5.317 GB
# Iter 1030: Train loss 0.051, Learning Rate 2.000e-04, It/sec 0.702, Tokens/sec 11.238, Trained Tokens 16480, Peak mem 5.317 GB
# Iter 1040: Train loss 0.020, Learning Rate 2.000e-04, It/sec 0.704, Tokens/sec 11.263, Trained Tokens 16640, Peak mem 5.317 GB
# Iter 1050: Train loss 0.045, Learning Rate 2.000e-04, It/sec 0.700, Tokens/sec 11.198, Trained Tokens 16800, Peak mem 5.317 GB
# Iter 1060: Train loss 0.006, Learning Rate 2.000e-04, It/sec 0.705, Tokens/sec 11.285, Trained Tokens 16960, Peak mem 5.317 GB
# Iter 1070: Train loss 0.015, Learning Rate 2.000e-04, It/sec 0.703, Tokens/sec 11.248, Trained Tokens 17120, Peak mem 5.317 GB
# Iter 1080: Train loss 0.037, Learning Rate 2.000e-04, It/sec 0.703, Tokens/sec 11.253, Trained Tokens 17280, Peak mem 5.317 GB
# Iter 1090: Train loss 0.030, Learning Rate 2.000e-04, It/sec 0.704, Tokens/sec 11.272, Trained Tokens 17440, Peak mem 5.317 GB
# Iter 1100: Train loss 0.088, Learning Rate 2.000e-04, It/sec 0.703, Tokens/sec 11.246, Trained Tokens 17600, Peak mem 5.317 GB
# Iter 1110: Train loss 0.004, Learning Rate 2.000e-04, It/sec 0.703, Tokens/sec 11.247, Trained Tokens 17760, Peak mem 5.317 GB
# Iter 1120: Train loss 0.071, Learning Rate 2.000e-04, It/sec 0.702, Tokens/sec 11.238, Trained Tokens 17920, Peak mem 5.317 GB
# Iter 1130: Train loss 0.052, Learning Rate 2.000e-04, It/sec 0.703, Tokens/sec 11.241, Trained Tokens 18080, Peak mem 5.317 GB
# Iter 1140: Train loss 0.077, Learning Rate 2.000e-04, It/sec 0.703, Tokens/sec 11.246, Trained Tokens 18240, Peak mem 5.317 GB
# Iter 1150: Train loss 0.075, Learning Rate 2.000e-04, It/sec 0.704, Tokens/sec 11.270, Trained Tokens 18400, Peak mem 5.317 GB
# Iter 1160: Train loss 0.033, Learning Rate 2.000e-04, It/sec 0.703, Tokens/sec 11.255, Trained Tokens 18560, Peak mem 5.317 GB
# Iter 1170: Train loss 0.017, Learning Rate 2.000e-04, It/sec 0.703, Tokens/sec 11.253, Trained Tokens 18720, Peak mem 5.317 GB
# Iter 1180: Train loss 0.020, Learning Rate 2.000e-04, It/sec 0.703, Tokens/sec 11.247, Trained Tokens 18880, Peak mem 5.317 GB
# Iter 1190: Train loss 0.020, Learning Rate 2.000e-04, It/sec 0.703, Tokens/sec 11.248, Trained Tokens 19040, Peak mem 5.317 GB
# Calculating loss...: 100%|██████████████████████| 25/25 [00:18<00:00,  1.35it/s]
# Iter 1200: Val loss 0.018, Val took 18.517s
# Iter 1200: Train loss 0.097, Learning Rate 2.000e-04, It/sec 0.703, Tokens/sec 11.249, Trained Tokens 19200, Peak mem 5.317 GB
# Iter 1210: Train loss 0.015, Learning Rate 2.000e-04, It/sec 0.701, Tokens/sec 11.217, Trained Tokens 19360, Peak mem 5.317 GB
# Iter 1220: Train loss 0.008, Learning Rate 2.000e-04, It/sec 0.704, Tokens/sec 11.256, Trained Tokens 19520, Peak mem 5.317 GB
# Iter 1230: Train loss 0.029, Learning Rate 2.000e-04, It/sec 0.704, Tokens/sec 11.268, Trained Tokens 19680, Peak mem 5.317 GB
# Iter 1240: Train loss 0.009, Learning Rate 2.000e-04, It/sec 0.700, Tokens/sec 11.200, Trained Tokens 19840, Peak mem 5.317 GB
# Iter 1250: Train loss 0.007, Learning Rate 2.000e-04, It/sec 0.701, Tokens/sec 11.222, Trained Tokens 20000, Peak mem 5.317 GB
# Iter 1260: Train loss 0.004, Learning Rate 2.000e-04, It/sec 0.701, Tokens/sec 11.223, Trained Tokens 20160, Peak mem 5.317 GB
# Iter 1270: Train loss 0.092, Learning Rate 2.000e-04, It/sec 0.702, Tokens/sec 11.237, Trained Tokens 20320, Peak mem 5.317 GB
# Iter 1280: Train loss 0.070, Learning Rate 2.000e-04, It/sec 0.704, Tokens/sec 11.262, Trained Tokens 20480, Peak mem 5.317 GB
# Iter 1290: Train loss 0.029, Learning Rate 2.000e-04, It/sec 0.703, Tokens/sec 11.254, Trained Tokens 20640, Peak mem 5.317 GB
# Iter 1300: Train loss 0.032, Learning Rate 2.000e-04, It/sec 0.703, Tokens/sec 11.253, Trained Tokens 20800, Peak mem 5.317 GB
# Iter 1310: Train loss 0.006, Learning Rate 2.000e-04, It/sec 0.704, Tokens/sec 11.260, Trained Tokens 20960, Peak mem 5.317 GB
# Iter 1320: Train loss 0.021, Learning Rate 2.000e-04, It/sec 0.704, Tokens/sec 11.265, Trained Tokens 21120, Peak mem 5.317 GB
# Iter 1330: Train loss 0.084, Learning Rate 2.000e-04, It/sec 0.703, Tokens/sec 11.249, Trained Tokens 21280, Peak mem 5.317 GB
# Iter 1340: Train loss 0.009, Learning Rate 2.000e-04, It/sec 0.704, Tokens/sec 11.257, Trained Tokens 21440, Peak mem 5.317 GB
# Iter 1350: Train loss 0.030, Learning Rate 2.000e-04, It/sec 0.704, Tokens/sec 11.257, Trained Tokens 21600, Peak mem 5.317 GB
# Iter 1360: Train loss 0.023, Learning Rate 2.000e-04, It/sec 0.703, Tokens/sec 11.249, Trained Tokens 21760, Peak mem 5.317 GB
# Iter 1370: Train loss 0.019, Learning Rate 2.000e-04, It/sec 0.702, Tokens/sec 11.237, Trained Tokens 21920, Peak mem 5.317 GB
# Iter 1380: Train loss 0.016, Learning Rate 2.000e-04, It/sec 0.703, Tokens/sec 11.251, Trained Tokens 22080, Peak mem 5.317 GB
# Iter 1390: Train loss 0.037, Learning Rate 2.000e-04, It/sec 0.704, Tokens/sec 11.267, Trained Tokens 22240, Peak mem 5.317 GB
# Calculating loss...: 100%|██████████████████████| 25/25 [00:18<00:00,  1.35it/s]
# Iter 1400: Val loss 0.054, Val took 18.510s
# Iter 1400: Train loss 0.039, Learning Rate 2.000e-04, It/sec 0.703, Tokens/sec 11.246, Trained Tokens 22400, Peak mem 5.317 GB
# Iter 1410: Train loss 0.094, Learning Rate 2.000e-04, It/sec 0.702, Tokens/sec 11.234, Trained Tokens 22560, Peak mem 5.317 GB
# Iter 1420: Train loss 0.009, Learning Rate 2.000e-04, It/sec 0.704, Tokens/sec 11.259, Trained Tokens 22720, Peak mem 5.317 GB
# Iter 1430: Train loss 0.076, Learning Rate 2.000e-04, It/sec 0.701, Tokens/sec 11.223, Trained Tokens 22880, Peak mem 5.317 GB
# Iter 1440: Train loss 0.020, Learning Rate 2.000e-04, It/sec 0.704, Tokens/sec 11.266, Trained Tokens 23040, Peak mem 5.317 GB
# Iter 1450: Train loss 0.011, Learning Rate 2.000e-04, It/sec 0.705, Tokens/sec 11.278, Trained Tokens 23200, Peak mem 5.317 GB
# Iter 1460: Train loss 0.007, Learning Rate 2.000e-04, It/sec 0.704, Tokens/sec 11.258, Trained Tokens 23360, Peak mem 5.317 GB
# Iter 1470: Train loss 0.006, Learning Rate 2.000e-04, It/sec 0.704, Tokens/sec 11.261, Trained Tokens 23520, Peak mem 5.317 GB
# Iter 1480: Train loss 0.009, Learning Rate 2.000e-04, It/sec 0.703, Tokens/sec 11.250, Trained Tokens 23680, Peak mem 5.317 GB
# Iter 1490: Train loss 0.021, Learning Rate 2.000e-04, It/sec 0.704, Tokens/sec 11.262, Trained Tokens 23840, Peak mem 5.317 GB
# Iter 1500: Train loss 0.015, Learning Rate 2.000e-04, It/sec 0.703, Tokens/sec 11.245, Trained Tokens 24000, Peak mem 5.317 GB
# Iter 1500: Saved adapter weights to adapters_w4/T2C_longitudinal_model/adapters.safetensors and adapters_w4/T2C_longitudinal_model/0001500_adapters.safetensors.
# Iter 1510: Train loss 0.038, Learning Rate 2.000e-04, It/sec 0.704, Tokens/sec 11.262, Trained Tokens 24160, Peak mem 5.317 GB
# Iter 1520: Train loss 0.083, Learning Rate 2.000e-04, It/sec 0.702, Tokens/sec 11.232, Trained Tokens 24320, Peak mem 5.317 GB
# Iter 1530: Train loss 0.017, Learning Rate 2.000e-04, It/sec 0.704, Tokens/sec 11.260, Trained Tokens 24480, Peak mem 5.317 GB
# Iter 1540: Train loss 0.053, Learning Rate 2.000e-04, It/sec 0.703, Tokens/sec 11.256, Trained Tokens 24640, Peak mem 5.317 GB
# Iter 1550: Train loss 0.027, Learning Rate 2.000e-04, It/sec 0.704, Tokens/sec 11.265, Trained Tokens 24800, Peak mem 5.317 GB
# Iter 1560: Train loss 0.032, Learning Rate 2.000e-04, It/sec 0.703, Tokens/sec 11.244, Trained Tokens 24960, Peak mem 5.317 GB
# Iter 1570: Train loss 0.069, Learning Rate 2.000e-04, It/sec 0.701, Tokens/sec 11.214, Trained Tokens 25120, Peak mem 5.317 GB
# Iter 1580: Train loss 0.046, Learning Rate 2.000e-04, It/sec 0.702, Tokens/sec 11.232, Trained Tokens 25280, Peak mem 5.317 GB
# Iter 1590: Train loss 0.011, Learning Rate 2.000e-04, It/sec 0.704, Tokens/sec 11.268, Trained Tokens 25440, Peak mem 5.317 GB
# Calculating loss...: 100%|██████████████████████| 25/25 [00:18<00:00,  1.35it/s]
# Iter 1600: Val loss 0.043, Val took 18.518s
# Iter 1600: Train loss 0.048, Learning Rate 2.000e-04, It/sec 0.703, Tokens/sec 11.251, Trained Tokens 25600, Peak mem 5.317 GB
# Iter 1610: Train loss 0.081, Learning Rate 2.000e-04, It/sec 0.702, Tokens/sec 11.238, Trained Tokens 25760, Peak mem 5.317 GB
# Iter 1620: Train loss 0.035, Learning Rate 2.000e-04, It/sec 0.703, Tokens/sec 11.249, Trained Tokens 25920, Peak mem 5.317 GB
# Iter 1630: Train loss 0.064, Learning Rate 2.000e-04, It/sec 0.702, Tokens/sec 11.238, Trained Tokens 26080, Peak mem 5.317 GB
# Iter 1640: Train loss 0.044, Learning Rate 2.000e-04, It/sec 0.703, Tokens/sec 11.241, Trained Tokens 26240, Peak mem 5.317 GB
# Iter 1650: Train loss 0.035, Learning Rate 2.000e-04, It/sec 0.702, Tokens/sec 11.232, Trained Tokens 26400, Peak mem 5.317 GB
# Iter 1660: Train loss 0.052, Learning Rate 2.000e-04, It/sec 0.704, Tokens/sec 11.257, Trained Tokens 26560, Peak mem 5.317 GB
# Iter 1670: Train loss 0.028, Learning Rate 2.000e-04, It/sec 0.704, Tokens/sec 11.270, Trained Tokens 26720, Peak mem 5.317 GB
# Iter 1680: Train loss 0.020, Learning Rate 2.000e-04, It/sec 0.701, Tokens/sec 11.215, Trained Tokens 26880, Peak mem 5.317 GB
# Iter 1690: Train loss 0.013, Learning Rate 2.000e-04, It/sec 0.705, Tokens/sec 11.278, Trained Tokens 27040, Peak mem 5.317 GB
# Iter 1700: Train loss 0.032, Learning Rate 2.000e-04, It/sec 0.703, Tokens/sec 11.243, Trained Tokens 27200, Peak mem 5.317 GB
# Iter 1710: Train loss 0.019, Learning Rate 2.000e-04, It/sec 0.706, Tokens/sec 11.294, Trained Tokens 27360, Peak mem 5.317 GB
# Iter 1720: Train loss 0.012, Learning Rate 2.000e-04, It/sec 0.705, Tokens/sec 11.273, Trained Tokens 27520, Peak mem 5.317 GB
# Iter 1730: Train loss 0.002, Learning Rate 2.000e-04, It/sec 0.705, Tokens/sec 11.273, Trained Tokens 27680, Peak mem 5.317 GB
# Iter 1740: Train loss 0.005, Learning Rate 2.000e-04, It/sec 0.702, Tokens/sec 11.232, Trained Tokens 27840, Peak mem 5.317 GB
# Iter 1750: Train loss 0.094, Learning Rate 2.000e-04, It/sec 0.703, Tokens/sec 11.244, Trained Tokens 28000, Peak mem 5.317 GB
# Iter 1760: Train loss 0.021, Learning Rate 2.000e-04, It/sec 0.703, Tokens/sec 11.254, Trained Tokens 28160, Peak mem 5.317 GB
# Iter 1770: Train loss 0.029, Learning Rate 2.000e-04, It/sec 0.702, Tokens/sec 11.236, Trained Tokens 28320, Peak mem 5.317 GB
# Iter 1780: Train loss 0.004, Learning Rate 2.000e-04, It/sec 0.704, Tokens/sec 11.259, Trained Tokens 28480, Peak mem 5.317 GB
# Iter 1790: Train loss 0.008, Learning Rate 2.000e-04, It/sec 0.704, Tokens/sec 11.258, Trained Tokens 28640, Peak mem 5.317 GB
# Calculating loss...: 100%|██████████████████████| 25/25 [00:18<00:00,  1.35it/s]
# Iter 1800: Val loss 0.043, Val took 18.516s
# Iter 1800: Train loss 0.034, Learning Rate 2.000e-04, It/sec 0.701, Tokens/sec 11.221, Trained Tokens 28800, Peak mem 5.317 GB
# Iter 1810: Train loss 0.063, Learning Rate 2.000e-04, It/sec 0.702, Tokens/sec 11.228, Trained Tokens 28960, Peak mem 5.317 GB
# Iter 1820: Train loss 0.047, Learning Rate 2.000e-04, It/sec 0.703, Tokens/sec 11.240, Trained Tokens 29120, Peak mem 5.317 GB
# Iter 1830: Train loss 0.034, Learning Rate 2.000e-04, It/sec 0.704, Tokens/sec 11.269, Trained Tokens 29280, Peak mem 5.317 GB
# Iter 1840: Train loss 0.036, Learning Rate 2.000e-04, It/sec 0.702, Tokens/sec 11.236, Trained Tokens 29440, Peak mem 5.317 GB
# Iter 1850: Train loss 0.008, Learning Rate 2.000e-04, It/sec 0.704, Tokens/sec 11.261, Trained Tokens 29600, Peak mem 5.317 GB
# Iter 1860: Train loss 0.026, Learning Rate 2.000e-04, It/sec 0.703, Tokens/sec 11.251, Trained Tokens 29760, Peak mem 5.317 GB
# Iter 1870: Train loss 0.045, Learning Rate 2.000e-04, It/sec 0.699, Tokens/sec 11.176, Trained Tokens 29920, Peak mem 5.317 GB
# Iter 1880: Train loss 0.019, Learning Rate 2.000e-04, It/sec 0.706, Tokens/sec 11.298, Trained Tokens 30080, Peak mem 5.317 GB
# Iter 1890: Train loss 0.015, Learning Rate 2.000e-04, It/sec 0.704, Tokens/sec 11.267, Trained Tokens 30240, Peak mem 5.317 GB
# Iter 1900: Train loss 0.006, Learning Rate 2.000e-04, It/sec 0.704, Tokens/sec 11.268, Trained Tokens 30400, Peak mem 5.317 GB
# Iter 1910: Train loss 0.020, Learning Rate 2.000e-04, It/sec 0.704, Tokens/sec 11.270, Trained Tokens 30560, Peak mem 5.317 GB
# Iter 1920: Train loss 0.015, Learning Rate 2.000e-04, It/sec 0.704, Tokens/sec 11.262, Trained Tokens 30720, Peak mem 5.317 GB
# Iter 1930: Train loss 0.004, Learning Rate 2.000e-04, It/sec 0.703, Tokens/sec 11.243, Trained Tokens 30880, Peak mem 5.317 GB
# Iter 1940: Train loss 0.048, Learning Rate 2.000e-04, It/sec 0.702, Tokens/sec 11.235, Trained Tokens 31040, Peak mem 5.317 GB
# Iter 1950: Train loss 0.022, Learning Rate 2.000e-04, It/sec 0.704, Tokens/sec 11.266, Trained Tokens 31200, Peak mem 5.317 GB
# Iter 1960: Train loss 0.144, Learning Rate 2.000e-04, It/sec 0.703, Tokens/sec 11.248, Trained Tokens 31360, Peak mem 5.317 GB
# Iter 1970: Train loss 0.042, Learning Rate 2.000e-04, It/sec 0.702, Tokens/sec 11.237, Trained Tokens 31520, Peak mem 5.317 GB
# Iter 1980: Train loss 0.057, Learning Rate 2.000e-04, It/sec 0.703, Tokens/sec 11.254, Trained Tokens 31680, Peak mem 5.317 GB
# Iter 1990: Train loss 0.019, Learning Rate 2.000e-04, It/sec 0.704, Tokens/sec 11.268, Trained Tokens 31840, Peak mem 5.317 GB
# Calculating loss...: 100%|██████████████████████| 25/25 [00:18<00:00,  1.35it/s]
# Iter 2000: Val loss 0.045, Val took 18.509s
# Iter 2000: Train loss 0.019, Learning Rate 2.000e-04, It/sec 0.703, Tokens/sec 11.254, Trained Tokens 32000, Peak mem 5.317 GB
# Iter 2000: Saved adapter weights to adapters_w4/T2C_longitudinal_model/adapters.safetensors and adapters_w4/T2C_longitudinal_model/0002000_adapters.safetensors.
# Saved final weights to adapters_w4/T2C_longitudinal_model/adapters.safetensors.

# %%
# ── Load model with T2C_longitudinal_model adapter ──────────────────────────────
model_mlx, tok_mlx = load(
    MODEL_ID,
    adapter_path="./adapters_w4/T2C_longitudinal_model",
)

# ── Inference ──────────────────────────────────────────────────────
t0 = time.time()
preds, refs, probs = run_inference_mlx(
    model_mlx, tok_mlx, test_ds_structured_longitudinal, return_probs=True
)

# ── Evaluate ───────────────────────────────────────────────────────
metrics = evaluate_predictions(preds, refs, label_name="T2C_longitudinal_model")

# ── Calibration ────────────────────────────────────────────────────
ece = calibration_analysis(
    probs, refs,
    label_name="T2C_longitudinal_model",
    save_path=os.path.join(OUTPUT_DIR, "calibration_T2C_longitudinal_model.png")
)
metrics["ECE"] = ece
all_metrics.append(metrics)

# ── Save predictions ───────────────────────────────────────────────
out_df = pd.DataFrame({"Predicted_Label": preds, "Ground_Truth": refs, "P_Yes": probs})
out_df.to_csv(os.path.join(OUTPUT_DIR, "predictions_T2C_longitudinal_model.csv"), index=False)

elapsed = round(time.time() - t0, 2)
experiment_times["T2C_longitudinal_model"] = elapsed
print(f"\n  ⏱ T2C_longitudinal_model done in {elapsed:.1f}s")

# ── Clean up ───────────────────────────────────────────────────────
del model_mlx, tok_mlx
# Out:
# Downloading (incomplete total...): 0.00B [00:00, ?B/s]
# Fetching 9 files:   0%|          | 0/9 [00:00<?, ?it/s]
# Generating:   0%|          | 0/6167 [00:00<?, ?it/s]
# ── T2C_longitudinal_model ──
#   Label: T2C_longitudinal_model
#   N_test: 6167
#   Accuracy: 0.9551
#   Recall: 0.7069
#   Precision: 0.8449
#   F1: 0.7697
#   Unknown: 0
#               precision    recall  f1-score   support
#
#           No       0.97      0.98      0.98      5512
#          Yes       0.84      0.71      0.77       655
#
#     accuracy                           0.96      6167
#    macro avg       0.91      0.85      0.87      6167
# weighted avg       0.95      0.96      0.95      6167
#
#   ECE: 0.0311 | Saved → ./results_wave4/calibration_T2C_longitudinal_model.png
#
#   ⏱ T2C_longitudinal_model done in 1862.2s

# %% [markdown]
# ### Rest for the machine

# %%
# Rest for the machine
import json

checkpoint = {
    "all_metrics":       all_metrics,
    "experiment_times":  experiment_times,
}

with open(os.path.join(OUTPUT_DIR, "session_checkpoint.json"), "w") as f:
    json.dump(checkpoint, f, indent=2)

print(f"Checkpoint saved — {len(all_metrics)} experiment(s) stored.")

# %%
import json

checkpoint_path = os.path.join(OUTPUT_DIR, "session_checkpoint.json")

with open(checkpoint_path, "r") as f:
    checkpoint = json.load(f)

all_metrics      = checkpoint["all_metrics"]
experiment_times = checkpoint["experiment_times"]

print(f"Restored — {len(all_metrics)} experiment(s) loaded:")
for m in all_metrics:
    print(f"  {m['Label']} — F1: {m['F1']}, ECE: {m.get('ECE', 'N/A')}")

# %%
import time

# %% [markdown]
# ### Inference for zero shot

# %%
## Inference for zero shot
t0 = time.time()

model_mlx, tok_mlx = load(
    MODEL_ID,
    # no adapter_path — base model only
)

preds, refs, probs = run_inference_mlx(
    model_mlx, tok_mlx, test_ds_structured_full, return_probs=True
)

metrics = evaluate_predictions(preds, refs, label_name="T3A_zeroshot")

ece = calibration_analysis(
    probs, refs,
    label_name="T3A_zeroshot",
    save_path=os.path.join(OUTPUT_DIR, "calibration_T3A_zeroshot.png")
)
metrics["ECE"] = ece
all_metrics.append(metrics)

out_df = pd.DataFrame({"Predicted_Label": preds, "Ground_Truth": refs, "P_Yes": probs})
out_df.to_csv(os.path.join(OUTPUT_DIR, "predictions_T3A_zeroshot.csv"), index=False)

elapsed = round(time.time() - t0, 2)
experiment_times["T3A_zeroshot"] = elapsed
print(f"\n  ⏱ T3A_zeroshot done in {elapsed:.1f}s")

del model_mlx, tok_mlx
# Out:
# Downloading (incomplete total...): 0.00B [00:00, ?B/s]
# Fetching 9 files:   0%|          | 0/9 [00:00<?, ?it/s]
# Generating:   0%|          | 0/6167 [00:00<?, ?it/s]
# ── T3A_zeroshot ──
#   Label: T3A_zeroshot
#   N_test: 6167
#   Accuracy: 0.9491
#   Recall: 0.8794
#   Precision: 0.7102
#   F1: 0.7858
#   Unknown: 0
#               precision    recall  f1-score   support
#
#           No       0.99      0.96      0.97      5512
#          Yes       0.71      0.88      0.79       655
#
#     accuracy                           0.95      6167
#    macro avg       0.85      0.92      0.88      6167
# weighted avg       0.96      0.95      0.95      6167
#
#   ECE: 0.0128 | Saved → ./results_wave4/calibration_T3A_zeroshot.png
#
#   ⏱ T3A_zeroshot done in 1982.8s

# %% [markdown]
# ### Training and Inference for T3A_narrative

# %%
# !mlx_lm.lora \
    --model {MODEL_ID} \
    --train \
    --data ./mlx_data/T3A_narrative \
    --num-layers 16 \
    --batch-size 4 \
    --grad-accumulation-steps 4 \
    --iters 2000 \
    --learning-rate 2e-4 \
    --mask-prompt \
    --adapter-path ./adapters_w4/T3A_narrative \
    --save-every 500 \
    -c ./configs/lora_config.yaml
# Out:
# Loading configuration file ./configs/lora_config.yaml
# Loading pretrained model
# Downloading (incomplete total...): 0.00B [00:00, ?B/s]
# Fetching 9 files: 100%|████████████████████████| 9/9 [00:00<00:00, 16015.59it/s]
# Download complete: : 0.00B [00:00, ?B/s]
# Loading datasets
# Training
# Trainable parameters: 0.684% (10.551M/1543.714M)
# Starting training..., iters: 2000
# Calculating loss...: 100%|██████████████████████| 25/25 [00:23<00:00,  1.05it/s]
# Iter 1: Val loss 7.551, Val took 23.926s
# Iter 10: Train loss 3.646, Learning Rate 2.000e-04, It/sec 0.537, Tokens/sec 8.585, Trained Tokens 160, Peak mem 6.323 GB
# Iter 20: Train loss 0.213, Learning Rate 2.000e-04, It/sec 0.543, Tokens/sec 8.688, Trained Tokens 320, Peak mem 6.323 GB
# Iter 30: Train loss 0.047, Learning Rate 2.000e-04, It/sec 0.543, Tokens/sec 8.692, Trained Tokens 480, Peak mem 6.323 GB
# Iter 40: Train loss 0.030, Learning Rate 2.000e-04, It/sec 0.542, Tokens/sec 8.679, Trained Tokens 640, Peak mem 6.323 GB
# Iter 50: Train loss 0.031, Learning Rate 2.000e-04, It/sec 0.543, Tokens/sec 8.683, Trained Tokens 800, Peak mem 6.323 GB
# Iter 60: Train loss 0.013, Learning Rate 2.000e-04, It/sec 0.542, Tokens/sec 8.680, Trained Tokens 960, Peak mem 6.323 GB
# Iter 70: Train loss 0.124, Learning Rate 2.000e-04, It/sec 0.543, Tokens/sec 8.683, Trained Tokens 1120, Peak mem 6.323 GB
# Iter 80: Train loss 0.103, Learning Rate 2.000e-04, It/sec 0.542, Tokens/sec 8.680, Trained Tokens 1280, Peak mem 6.323 GB
# Iter 90: Train loss 0.065, Learning Rate 2.000e-04, It/sec 0.543, Tokens/sec 8.682, Trained Tokens 1440, Peak mem 6.323 GB
# Iter 100: Train loss 0.018, Learning Rate 2.000e-04, It/sec 0.542, Tokens/sec 8.679, Trained Tokens 1600, Peak mem 6.323 GB
# Iter 110: Train loss 0.003, Learning Rate 2.000e-04, It/sec 0.543, Tokens/sec 8.688, Trained Tokens 1760, Peak mem 6.323 GB
# Iter 120: Train loss 0.002, Learning Rate 2.000e-04, It/sec 0.542, Tokens/sec 8.668, Trained Tokens 1920, Peak mem 6.323 GB
# Iter 130: Train loss 0.000, Learning Rate 2.000e-04, It/sec 0.542, Tokens/sec 8.673, Trained Tokens 2080, Peak mem 6.323 GB
# Iter 140: Train loss 0.000, Learning Rate 2.000e-04, It/sec 0.542, Tokens/sec 8.673, Trained Tokens 2240, Peak mem 6.323 GB
# Iter 150: Train loss 0.073, Learning Rate 2.000e-04, It/sec 0.542, Tokens/sec 8.668, Trained Tokens 2400, Peak mem 6.323 GB
# Iter 160: Train loss 2.734, Learning Rate 2.000e-04, It/sec 0.541, Tokens/sec 8.648, Trained Tokens 2560, Peak mem 6.323 GB
# Iter 170: Train loss 3.635, Learning Rate 2.000e-04, It/sec 0.542, Tokens/sec 8.678, Trained Tokens 2720, Peak mem 6.323 GB
# Iter 180: Train loss 0.355, Learning Rate 2.000e-04, It/sec 0.541, Tokens/sec 8.662, Trained Tokens 2880, Peak mem 6.323 GB
# Iter 190: Train loss 0.051, Learning Rate 2.000e-04, It/sec 0.542, Tokens/sec 8.668, Trained Tokens 3040, Peak mem 6.323 GB
# Calculating loss...: 100%|██████████████████████| 25/25 [00:23<00:00,  1.05it/s]
# Iter 200: Val loss 0.072, Val took 23.859s
# Iter 200: Train loss 0.011, Learning Rate 2.000e-04, It/sec 0.540, Tokens/sec 8.647, Trained Tokens 3200, Peak mem 6.323 GB
# Iter 210: Train loss 0.001, Learning Rate 2.000e-04, It/sec 0.542, Tokens/sec 8.668, Trained Tokens 3360, Peak mem 6.323 GB
# Iter 220: Train loss 0.076, Learning Rate 2.000e-04, It/sec 0.541, Tokens/sec 8.655, Trained Tokens 3520, Peak mem 6.323 GB
# Iter 230: Train loss 0.192, Learning Rate 2.000e-04, It/sec 0.543, Tokens/sec 8.683, Trained Tokens 3680, Peak mem 6.323 GB
# Iter 240: Train loss 0.227, Learning Rate 2.000e-04, It/sec 0.543, Tokens/sec 8.692, Trained Tokens 3840, Peak mem 6.323 GB
# Iter 250: Train loss 0.035, Learning Rate 2.000e-04, It/sec 0.541, Tokens/sec 8.657, Trained Tokens 4000, Peak mem 6.323 GB
# Iter 260: Train loss 0.052, Learning Rate 2.000e-04, It/sec 0.540, Tokens/sec 8.643, Trained Tokens 4160, Peak mem 6.323 GB
# Iter 270: Train loss 0.141, Learning Rate 2.000e-04, It/sec 0.543, Tokens/sec 8.685, Trained Tokens 4320, Peak mem 6.323 GB
# Iter 280: Train loss 0.031, Learning Rate 2.000e-04, It/sec 0.543, Tokens/sec 8.683, Trained Tokens 4480, Peak mem 6.323 GB
# Iter 290: Train loss 0.053, Learning Rate 2.000e-04, It/sec 0.544, Tokens/sec 8.699, Trained Tokens 4640, Peak mem 6.323 GB
# Iter 300: Train loss 0.126, Learning Rate 2.000e-04, It/sec 0.543, Tokens/sec 8.687, Trained Tokens 4800, Peak mem 6.323 GB
# Iter 310: Train loss 0.031, Learning Rate 2.000e-04, It/sec 0.543, Tokens/sec 8.690, Trained Tokens 4960, Peak mem 6.323 GB
# Iter 320: Train loss 0.053, Learning Rate 2.000e-04, It/sec 0.542, Tokens/sec 8.668, Trained Tokens 5120, Peak mem 6.323 GB
# Iter 330: Train loss 0.037, Learning Rate 2.000e-04, It/sec 0.543, Tokens/sec 8.689, Trained Tokens 5280, Peak mem 6.323 GB
# Iter 340: Train loss 0.086, Learning Rate 2.000e-04, It/sec 0.542, Tokens/sec 8.670, Trained Tokens 5440, Peak mem 6.323 GB
# Iter 350: Train loss 0.045, Learning Rate 2.000e-04, It/sec 0.542, Tokens/sec 8.674, Trained Tokens 5600, Peak mem 6.323 GB
# Iter 360: Train loss 0.011, Learning Rate 2.000e-04, It/sec 0.542, Tokens/sec 8.670, Trained Tokens 5760, Peak mem 6.323 GB
# Iter 370: Train loss 0.052, Learning Rate 2.000e-04, It/sec 0.543, Tokens/sec 8.685, Trained Tokens 5920, Peak mem 6.323 GB
# Iter 380: Train loss 0.016, Learning Rate 2.000e-04, It/sec 0.542, Tokens/sec 8.679, Trained Tokens 6080, Peak mem 6.323 GB
# Iter 390: Train loss 0.014, Learning Rate 2.000e-04, It/sec 0.541, Tokens/sec 8.663, Trained Tokens 6240, Peak mem 6.323 GB
# Calculating loss...: 100%|██████████████████████| 25/25 [00:23<00:00,  1.05it/s]
# Iter 400: Val loss 0.052, Val took 23.836s
# Iter 400: Train loss 0.017, Learning Rate 2.000e-04, It/sec 0.543, Tokens/sec 8.694, Trained Tokens 6400, Peak mem 6.323 GB
# Iter 410: Train loss 0.012, Learning Rate 2.000e-04, It/sec 0.542, Tokens/sec 8.673, Trained Tokens 6560, Peak mem 6.323 GB
# Iter 420: Train loss 0.059, Learning Rate 2.000e-04, It/sec 0.542, Tokens/sec 8.674, Trained Tokens 6720, Peak mem 6.323 GB
# Iter 430: Train loss 0.061, Learning Rate 2.000e-04, It/sec 0.543, Tokens/sec 8.682, Trained Tokens 6880, Peak mem 6.323 GB
# Iter 440: Train loss 0.006, Learning Rate 2.000e-04, It/sec 0.543, Tokens/sec 8.682, Trained Tokens 7040, Peak mem 6.323 GB
# Iter 450: Train loss 0.065, Learning Rate 2.000e-04, It/sec 0.543, Tokens/sec 8.693, Trained Tokens 7200, Peak mem 6.323 GB
# Iter 460: Train loss 0.006, Learning Rate 2.000e-04, It/sec 0.542, Tokens/sec 8.672, Trained Tokens 7360, Peak mem 6.323 GB
# Iter 470: Train loss 0.003, Learning Rate 2.000e-04, It/sec 0.543, Tokens/sec 8.684, Trained Tokens 7520, Peak mem 6.323 GB
# Iter 480: Train loss 0.086, Learning Rate 2.000e-04, It/sec 0.543, Tokens/sec 8.686, Trained Tokens 7680, Peak mem 6.323 GB
# Iter 490: Train loss 0.087, Learning Rate 2.000e-04, It/sec 0.543, Tokens/sec 8.694, Trained Tokens 7840, Peak mem 6.323 GB
# Iter 500: Train loss 0.020, Learning Rate 2.000e-04, It/sec 0.542, Tokens/sec 8.674, Trained Tokens 8000, Peak mem 6.323 GB
# Iter 500: Saved adapter weights to adapters_w4/T3A_narrative/adapters.safetensors and adapters_w4/T3A_narrative/0000500_adapters.safetensors.
# Iter 510: Train loss 0.039, Learning Rate 2.000e-04, It/sec 0.543, Tokens/sec 8.694, Trained Tokens 8160, Peak mem 6.365 GB
# Iter 520: Train loss 0.044, Learning Rate 2.000e-04, It/sec 0.544, Tokens/sec 8.697, Trained Tokens 8320, Peak mem 6.365 GB
# Iter 530: Train loss 0.022, Learning Rate 2.000e-04, It/sec 0.543, Tokens/sec 8.689, Trained Tokens 8480, Peak mem 6.365 GB
# Iter 540: Train loss 0.024, Learning Rate 2.000e-04, It/sec 0.542, Tokens/sec 8.666, Trained Tokens 8640, Peak mem 6.365 GB
# Iter 550: Train loss 0.027, Learning Rate 2.000e-04, It/sec 0.543, Tokens/sec 8.683, Trained Tokens 8800, Peak mem 6.365 GB
# Iter 560: Train loss 0.017, Learning Rate 2.000e-04, It/sec 0.543, Tokens/sec 8.681, Trained Tokens 8960, Peak mem 6.365 GB
# Iter 570: Train loss 0.031, Learning Rate 2.000e-04, It/sec 0.543, Tokens/sec 8.682, Trained Tokens 9120, Peak mem 6.365 GB
# Iter 580: Train loss 0.056, Learning Rate 2.000e-04, It/sec 0.542, Tokens/sec 8.676, Trained Tokens 9280, Peak mem 6.365 GB
# Iter 590: Train loss 0.076, Learning Rate 2.000e-04, It/sec 0.543, Tokens/sec 8.684, Trained Tokens 9440, Peak mem 6.365 GB
# Calculating loss...: 100%|██████████████████████| 25/25 [00:23<00:00,  1.05it/s]
# Iter 600: Val loss 0.027, Val took 23.838s
# Iter 600: Train loss 0.008, Learning Rate 2.000e-04, It/sec 0.543, Tokens/sec 8.681, Trained Tokens 9600, Peak mem 6.365 GB
# Iter 610: Train loss 0.037, Learning Rate 2.000e-04, It/sec 0.543, Tokens/sec 8.687, Trained Tokens 9760, Peak mem 6.365 GB
# Iter 620: Train loss 0.006, Learning Rate 2.000e-04, It/sec 0.542, Tokens/sec 8.672, Trained Tokens 9920, Peak mem 6.365 GB
# Iter 630: Train loss 0.010, Learning Rate 2.000e-04, It/sec 0.543, Tokens/sec 8.683, Trained Tokens 10080, Peak mem 6.365 GB
# Iter 640: Train loss 0.010, Learning Rate 2.000e-04, It/sec 0.544, Tokens/sec 8.697, Trained Tokens 10240, Peak mem 6.365 GB
# Iter 650: Train loss 0.032, Learning Rate 2.000e-04, It/sec 0.542, Tokens/sec 8.672, Trained Tokens 10400, Peak mem 6.365 GB
# Iter 660: Train loss 0.006, Learning Rate 2.000e-04, It/sec 0.542, Tokens/sec 8.674, Trained Tokens 10560, Peak mem 6.365 GB
# Iter 670: Train loss 0.002, Learning Rate 2.000e-04, It/sec 0.543, Tokens/sec 8.682, Trained Tokens 10720, Peak mem 6.365 GB
# Iter 680: Train loss 0.024, Learning Rate 2.000e-04, It/sec 0.543, Tokens/sec 8.683, Trained Tokens 10880, Peak mem 6.365 GB
# Iter 690: Train loss 0.006, Learning Rate 2.000e-04, It/sec 0.543, Tokens/sec 8.691, Trained Tokens 11040, Peak mem 6.365 GB
# Iter 700: Train loss 0.020, Learning Rate 2.000e-04, It/sec 0.543, Tokens/sec 8.691, Trained Tokens 11200, Peak mem 6.365 GB
# Iter 710: Train loss 0.009, Learning Rate 2.000e-04, It/sec 0.542, Tokens/sec 8.670, Trained Tokens 11360, Peak mem 6.365 GB
# Iter 720: Train loss 0.006, Learning Rate 2.000e-04, It/sec 0.543, Tokens/sec 8.691, Trained Tokens 11520, Peak mem 6.365 GB
# Iter 730: Train loss 0.047, Learning Rate 2.000e-04, It/sec 0.542, Tokens/sec 8.677, Trained Tokens 11680, Peak mem 6.365 GB
# Iter 740: Train loss 0.023, Learning Rate 2.000e-04, It/sec 0.542, Tokens/sec 8.676, Trained Tokens 11840, Peak mem 6.365 GB
# Iter 750: Train loss 0.002, Learning Rate 2.000e-04, It/sec 0.543, Tokens/sec 8.687, Trained Tokens 12000, Peak mem 6.365 GB
# Iter 760: Train loss 0.094, Learning Rate 2.000e-04, It/sec 0.543, Tokens/sec 8.692, Trained Tokens 12160, Peak mem 6.365 GB
# Iter 770: Train loss 0.042, Learning Rate 2.000e-04, It/sec 0.543, Tokens/sec 8.685, Trained Tokens 12320, Peak mem 6.365 GB
# Iter 780: Train loss 0.072, Learning Rate 2.000e-04, It/sec 0.542, Tokens/sec 8.671, Trained Tokens 12480, Peak mem 6.365 GB
# Iter 790: Train loss 0.100, Learning Rate 2.000e-04, It/sec 0.543, Tokens/sec 8.681, Trained Tokens 12640, Peak mem 6.365 GB
# Calculating loss...: 100%|██████████████████████| 25/25 [00:23<00:00,  1.05it/s]
# Iter 800: Val loss 0.038, Val took 23.841s
# Iter 800: Train loss 0.034, Learning Rate 2.000e-04, It/sec 0.543, Tokens/sec 8.692, Trained Tokens 12800, Peak mem 6.365 GB
# Iter 810: Train loss 0.004, Learning Rate 2.000e-04, It/sec 0.543, Tokens/sec 8.687, Trained Tokens 12960, Peak mem 6.365 GB
# Iter 820: Train loss 0.030, Learning Rate 2.000e-04, It/sec 0.543, Tokens/sec 8.685, Trained Tokens 13120, Peak mem 6.365 GB
# Iter 830: Train loss 0.042, Learning Rate 2.000e-04, It/sec 0.543, Tokens/sec 8.693, Trained Tokens 13280, Peak mem 6.365 GB
# Iter 840: Train loss 0.039, Learning Rate 2.000e-04, It/sec 0.543, Tokens/sec 8.681, Trained Tokens 13440, Peak mem 6.365 GB
# Iter 850: Train loss 0.136, Learning Rate 2.000e-04, It/sec 0.544, Tokens/sec 8.697, Trained Tokens 13600, Peak mem 6.365 GB
# Iter 860: Train loss 0.018, Learning Rate 2.000e-04, It/sec 0.543, Tokens/sec 8.694, Trained Tokens 13760, Peak mem 6.365 GB
# Iter 870: Train loss 0.071, Learning Rate 2.000e-04, It/sec 0.544, Tokens/sec 8.702, Trained Tokens 13920, Peak mem 6.365 GB
# Iter 880: Train loss 0.029, Learning Rate 2.000e-04, It/sec 0.543, Tokens/sec 8.685, Trained Tokens 14080, Peak mem 6.365 GB
# Iter 890: Train loss 0.032, Learning Rate 2.000e-04, It/sec 0.543, Tokens/sec 8.690, Trained Tokens 14240, Peak mem 6.365 GB
# Iter 900: Train loss 0.010, Learning Rate 2.000e-04, It/sec 0.543, Tokens/sec 8.683, Trained Tokens 14400, Peak mem 6.365 GB
# Iter 910: Train loss 0.100, Learning Rate 2.000e-04, It/sec 0.543, Tokens/sec 8.681, Trained Tokens 14560, Peak mem 6.365 GB
# Iter 920: Train loss 0.049, Learning Rate 2.000e-04, It/sec 0.543, Tokens/sec 8.692, Trained Tokens 14720, Peak mem 6.365 GB
# Iter 930: Train loss 0.018, Learning Rate 2.000e-04, It/sec 0.544, Tokens/sec 8.702, Trained Tokens 14880, Peak mem 6.365 GB
# Iter 940: Train loss 0.004, Learning Rate 2.000e-04, It/sec 0.543, Tokens/sec 8.684, Trained Tokens 15040, Peak mem 6.365 GB
# Iter 950: Train loss 0.026, Learning Rate 2.000e-04, It/sec 0.542, Tokens/sec 8.677, Trained Tokens 15200, Peak mem 6.365 GB
# Iter 960: Train loss 0.097, Learning Rate 2.000e-04, It/sec 0.542, Tokens/sec 8.678, Trained Tokens 15360, Peak mem 6.365 GB
# Iter 970: Train loss 0.018, Learning Rate 2.000e-04, It/sec 0.543, Tokens/sec 8.689, Trained Tokens 15520, Peak mem 6.365 GB
# Iter 980: Train loss 0.051, Learning Rate 2.000e-04, It/sec 0.542, Tokens/sec 8.679, Trained Tokens 15680, Peak mem 6.365 GB
# Iter 990: Train loss 0.007, Learning Rate 2.000e-04, It/sec 0.543, Tokens/sec 8.687, Trained Tokens 15840, Peak mem 6.365 GB
# Calculating loss...: 100%|██████████████████████| 25/25 [00:23<00:00,  1.05it/s]
# Iter 1000: Val loss 0.020, Val took 23.840s
# Iter 1000: Train loss 0.041, Learning Rate 2.000e-04, It/sec 0.542, Tokens/sec 8.678, Trained Tokens 16000, Peak mem 6.365 GB
# Iter 1000: Saved adapter weights to adapters_w4/T3A_narrative/adapters.safetensors and adapters_w4/T3A_narrative/0001000_adapters.safetensors.
# Iter 1010: Train loss 0.011, Learning Rate 2.000e-04, It/sec 0.543, Tokens/sec 8.689, Trained Tokens 16160, Peak mem 6.365 GB
# Iter 1020: Train loss 0.019, Learning Rate 2.000e-04, It/sec 0.543, Tokens/sec 8.687, Trained Tokens 16320, Peak mem 6.365 GB
# Iter 1030: Train loss 0.038, Learning Rate 2.000e-04, It/sec 0.543, Tokens/sec 8.688, Trained Tokens 16480, Peak mem 6.365 GB
# Iter 1040: Train loss 0.021, Learning Rate 2.000e-04, It/sec 0.542, Tokens/sec 8.677, Trained Tokens 16640, Peak mem 6.365 GB
# Iter 1050: Train loss 0.043, Learning Rate 2.000e-04, It/sec 0.540, Tokens/sec 8.635, Trained Tokens 16800, Peak mem 6.365 GB
# Iter 1060: Train loss 0.006, Learning Rate 2.000e-04, It/sec 0.543, Tokens/sec 8.689, Trained Tokens 16960, Peak mem 6.365 GB
# Iter 1070: Train loss 0.017, Learning Rate 2.000e-04, It/sec 0.542, Tokens/sec 8.674, Trained Tokens 17120, Peak mem 6.365 GB
# Iter 1080: Train loss 0.032, Learning Rate 2.000e-04, It/sec 0.542, Tokens/sec 8.670, Trained Tokens 17280, Peak mem 6.365 GB
# Iter 1090: Train loss 0.037, Learning Rate 2.000e-04, It/sec 0.543, Tokens/sec 8.685, Trained Tokens 17440, Peak mem 6.365 GB
# Iter 1100: Train loss 0.089, Learning Rate 2.000e-04, It/sec 0.543, Tokens/sec 8.681, Trained Tokens 17600, Peak mem 6.365 GB
# Iter 1110: Train loss 0.004, Learning Rate 2.000e-04, It/sec 0.543, Tokens/sec 8.683, Trained Tokens 17760, Peak mem 6.365 GB
# Iter 1120: Train loss 0.073, Learning Rate 2.000e-04, It/sec 0.542, Tokens/sec 8.677, Trained Tokens 17920, Peak mem 6.365 GB
# Iter 1130: Train loss 0.052, Learning Rate 2.000e-04, It/sec 0.542, Tokens/sec 8.674, Trained Tokens 18080, Peak mem 6.365 GB
# Iter 1140: Train loss 0.078, Learning Rate 2.000e-04, It/sec 0.543, Tokens/sec 8.682, Trained Tokens 18240, Peak mem 6.365 GB
# Iter 1150: Train loss 0.065, Learning Rate 2.000e-04, It/sec 0.543, Tokens/sec 8.688, Trained Tokens 18400, Peak mem 6.365 GB
# Iter 1160: Train loss 0.026, Learning Rate 2.000e-04, It/sec 0.543, Tokens/sec 8.688, Trained Tokens 18560, Peak mem 6.365 GB
# Iter 1170: Train loss 0.018, Learning Rate 2.000e-04, It/sec 0.543, Tokens/sec 8.687, Trained Tokens 18720, Peak mem 6.365 GB
# Iter 1180: Train loss 0.019, Learning Rate 2.000e-04, It/sec 0.542, Tokens/sec 8.677, Trained Tokens 18880, Peak mem 6.365 GB
# Iter 1190: Train loss 0.021, Learning Rate 2.000e-04, It/sec 0.542, Tokens/sec 8.679, Trained Tokens 19040, Peak mem 6.365 GB
# Calculating loss...: 100%|██████████████████████| 25/25 [00:23<00:00,  1.05it/s]
# Iter 1200: Val loss 0.023, Val took 23.839s
# Iter 1200: Train loss 0.084, Learning Rate 2.000e-04, It/sec 0.543, Tokens/sec 8.681, Trained Tokens 19200, Peak mem 6.365 GB
# Iter 1210: Train loss 0.020, Learning Rate 2.000e-04, It/sec 0.543, Tokens/sec 8.684, Trained Tokens 19360, Peak mem 6.365 GB
# Iter 1220: Train loss 0.011, Learning Rate 2.000e-04, It/sec 0.542, Tokens/sec 8.675, Trained Tokens 19520, Peak mem 6.365 GB
# Iter 1230: Train loss 0.029, Learning Rate 2.000e-04, It/sec 0.542, Tokens/sec 8.673, Trained Tokens 19680, Peak mem 6.365 GB
# Iter 1240: Train loss 0.012, Learning Rate 2.000e-04, It/sec 0.543, Tokens/sec 8.696, Trained Tokens 19840, Peak mem 6.365 GB
# Iter 1250: Train loss 0.009, Learning Rate 2.000e-04, It/sec 0.544, Tokens/sec 8.699, Trained Tokens 20000, Peak mem 6.365 GB
# Iter 1260: Train loss 0.004, Learning Rate 2.000e-04, It/sec 0.543, Tokens/sec 8.691, Trained Tokens 20160, Peak mem 6.365 GB
# Iter 1270: Train loss 0.083, Learning Rate 2.000e-04, It/sec 0.543, Tokens/sec 8.686, Trained Tokens 20320, Peak mem 6.365 GB
# Iter 1280: Train loss 0.065, Learning Rate 2.000e-04, It/sec 0.543, Tokens/sec 8.680, Trained Tokens 20480, Peak mem 6.365 GB
# Iter 1290: Train loss 0.026, Learning Rate 2.000e-04, It/sec 0.543, Tokens/sec 8.685, Trained Tokens 20640, Peak mem 6.365 GB
# Iter 1300: Train loss 0.031, Learning Rate 2.000e-04, It/sec 0.542, Tokens/sec 8.673, Trained Tokens 20800, Peak mem 6.365 GB
# Iter 1310: Train loss 0.006, Learning Rate 2.000e-04, It/sec 0.543, Tokens/sec 8.694, Trained Tokens 20960, Peak mem 6.365 GB
# Iter 1320: Train loss 0.015, Learning Rate 2.000e-04, It/sec 0.542, Tokens/sec 8.674, Trained Tokens 21120, Peak mem 6.365 GB
# Iter 1330: Train loss 0.085, Learning Rate 2.000e-04, It/sec 0.542, Tokens/sec 8.678, Trained Tokens 21280, Peak mem 6.365 GB
# Iter 1340: Train loss 0.008, Learning Rate 2.000e-04, It/sec 0.543, Tokens/sec 8.680, Trained Tokens 21440, Peak mem 6.365 GB
# Iter 1350: Train loss 0.035, Learning Rate 2.000e-04, It/sec 0.542, Tokens/sec 8.671, Trained Tokens 21600, Peak mem 6.365 GB
# Iter 1360: Train loss 0.024, Learning Rate 2.000e-04, It/sec 0.542, Tokens/sec 8.671, Trained Tokens 21760, Peak mem 6.365 GB
# Iter 1370: Train loss 0.015, Learning Rate 2.000e-04, It/sec 0.543, Tokens/sec 8.690, Trained Tokens 21920, Peak mem 6.365 GB
# Iter 1380: Train loss 0.018, Learning Rate 2.000e-04, It/sec 0.542, Tokens/sec 8.668, Trained Tokens 22080, Peak mem 6.365 GB
# Iter 1390: Train loss 0.032, Learning Rate 2.000e-04, It/sec 0.542, Tokens/sec 8.676, Trained Tokens 22240, Peak mem 6.365 GB
# Calculating loss...: 100%|██████████████████████| 25/25 [00:23<00:00,  1.05it/s]
# Iter 1400: Val loss 0.055, Val took 23.867s
# Iter 1400: Train loss 0.039, Learning Rate 2.000e-04, It/sec 0.542, Tokens/sec 8.672, Trained Tokens 22400, Peak mem 6.365 GB
# Iter 1410: Train loss 0.095, Learning Rate 2.000e-04, It/sec 0.542, Tokens/sec 8.677, Trained Tokens 22560, Peak mem 6.365 GB
# Iter 1420: Train loss 0.009, Learning Rate 2.000e-04, It/sec 0.542, Tokens/sec 8.668, Trained Tokens 22720, Peak mem 6.365 GB
# Iter 1430: Train loss 0.079, Learning Rate 2.000e-04, It/sec 0.542, Tokens/sec 8.677, Trained Tokens 22880, Peak mem 6.365 GB
# Iter 1440: Train loss 0.017, Learning Rate 2.000e-04, It/sec 0.543, Tokens/sec 8.682, Trained Tokens 23040, Peak mem 6.365 GB
# Iter 1450: Train loss 0.011, Learning Rate 2.000e-04, It/sec 0.544, Tokens/sec 8.700, Trained Tokens 23200, Peak mem 6.365 GB
# Iter 1460: Train loss 0.008, Learning Rate 2.000e-04, It/sec 0.542, Tokens/sec 8.671, Trained Tokens 23360, Peak mem 6.365 GB
# Iter 1470: Train loss 0.006, Learning Rate 2.000e-04, It/sec 0.542, Tokens/sec 8.677, Trained Tokens 23520, Peak mem 6.365 GB
# Iter 1480: Train loss 0.009, Learning Rate 2.000e-04, It/sec 0.543, Tokens/sec 8.682, Trained Tokens 23680, Peak mem 6.365 GB
# Iter 1490: Train loss 0.021, Learning Rate 2.000e-04, It/sec 0.543, Tokens/sec 8.688, Trained Tokens 23840, Peak mem 6.365 GB
# Iter 1500: Train loss 0.016, Learning Rate 2.000e-04, It/sec 0.542, Tokens/sec 8.677, Trained Tokens 24000, Peak mem 6.365 GB
# Iter 1500: Saved adapter weights to adapters_w4/T3A_narrative/adapters.safetensors and adapters_w4/T3A_narrative/0001500_adapters.safetensors.
# Iter 1510: Train loss 0.037, Learning Rate 2.000e-04, It/sec 0.543, Tokens/sec 8.690, Trained Tokens 24160, Peak mem 6.365 GB
# Iter 1520: Train loss 0.083, Learning Rate 2.000e-04, It/sec 0.543, Tokens/sec 8.681, Trained Tokens 24320, Peak mem 6.365 GB
# Iter 1530: Train loss 0.018, Learning Rate 2.000e-04, It/sec 0.544, Tokens/sec 8.707, Trained Tokens 24480, Peak mem 6.365 GB
# Iter 1540: Train loss 0.054, Learning Rate 2.000e-04, It/sec 0.543, Tokens/sec 8.687, Trained Tokens 24640, Peak mem 6.365 GB
# Iter 1550: Train loss 0.028, Learning Rate 2.000e-04, It/sec 0.542, Tokens/sec 8.679, Trained Tokens 24800, Peak mem 6.365 GB
# Iter 1560: Train loss 0.031, Learning Rate 2.000e-04, It/sec 0.542, Tokens/sec 8.677, Trained Tokens 24960, Peak mem 6.365 GB
# Iter 1570: Train loss 0.066, Learning Rate 2.000e-04, It/sec 0.543, Tokens/sec 8.695, Trained Tokens 25120, Peak mem 6.365 GB
# Iter 1580: Train loss 0.046, Learning Rate 2.000e-04, It/sec 0.543, Tokens/sec 8.696, Trained Tokens 25280, Peak mem 6.365 GB
# Iter 1590: Train loss 0.009, Learning Rate 2.000e-04, It/sec 0.543, Tokens/sec 8.682, Trained Tokens 25440, Peak mem 6.365 GB
# Calculating loss...: 100%|██████████████████████| 25/25 [00:23<00:00,  1.05it/s]
# Iter 1600: Val loss 0.043, Val took 23.838s
# Iter 1600: Train loss 0.047, Learning Rate 2.000e-04, It/sec 0.542, Tokens/sec 8.668, Trained Tokens 25600, Peak mem 6.365 GB
# Iter 1610: Train loss 0.080, Learning Rate 2.000e-04, It/sec 0.542, Tokens/sec 8.677, Trained Tokens 25760, Peak mem 6.365 GB
# Iter 1620: Train loss 0.034, Learning Rate 2.000e-04, It/sec 0.542, Tokens/sec 8.671, Trained Tokens 25920, Peak mem 6.365 GB
# Iter 1630: Train loss 0.062, Learning Rate 2.000e-04, It/sec 0.543, Tokens/sec 8.680, Trained Tokens 26080, Peak mem 6.365 GB
# Iter 1640: Train loss 0.046, Learning Rate 2.000e-04, It/sec 0.542, Tokens/sec 8.674, Trained Tokens 26240, Peak mem 6.365 GB
# Iter 1650: Train loss 0.037, Learning Rate 2.000e-04, It/sec 0.543, Tokens/sec 8.695, Trained Tokens 26400, Peak mem 6.365 GB
# Iter 1660: Train loss 0.053, Learning Rate 2.000e-04, It/sec 0.542, Tokens/sec 8.675, Trained Tokens 26560, Peak mem 6.365 GB
# Iter 1670: Train loss 0.030, Learning Rate 2.000e-04, It/sec 0.543, Tokens/sec 8.682, Trained Tokens 26720, Peak mem 6.365 GB
# Iter 1680: Train loss 0.020, Learning Rate 2.000e-04, It/sec 0.543, Tokens/sec 8.690, Trained Tokens 26880, Peak mem 6.365 GB
# Iter 1690: Train loss 0.014, Learning Rate 2.000e-04, It/sec 0.542, Tokens/sec 8.674, Trained Tokens 27040, Peak mem 6.365 GB
# Iter 1700: Train loss 0.029, Learning Rate 2.000e-04, It/sec 0.542, Tokens/sec 8.672, Trained Tokens 27200, Peak mem 6.365 GB
# Iter 1710: Train loss 0.019, Learning Rate 2.000e-04, It/sec 0.542, Tokens/sec 8.675, Trained Tokens 27360, Peak mem 6.365 GB
# Iter 1720: Train loss 0.015, Learning Rate 2.000e-04, It/sec 0.542, Tokens/sec 8.678, Trained Tokens 27520, Peak mem 6.365 GB
# Iter 1730: Train loss 0.002, Learning Rate 2.000e-04, It/sec 0.541, Tokens/sec 8.660, Trained Tokens 27680, Peak mem 6.365 GB
# Iter 1740: Train loss 0.006, Learning Rate 2.000e-04, It/sec 0.543, Tokens/sec 8.684, Trained Tokens 27840, Peak mem 6.365 GB
# Iter 1750: Train loss 0.090, Learning Rate 2.000e-04, It/sec 0.542, Tokens/sec 8.666, Trained Tokens 28000, Peak mem 6.365 GB
# Iter 1760: Train loss 0.026, Learning Rate 2.000e-04, It/sec 0.543, Tokens/sec 8.688, Trained Tokens 28160, Peak mem 6.365 GB
# Iter 1770: Train loss 0.023, Learning Rate 2.000e-04, It/sec 0.543, Tokens/sec 8.681, Trained Tokens 28320, Peak mem 6.365 GB
# Iter 1780: Train loss 0.001, Learning Rate 2.000e-04, It/sec 0.543, Tokens/sec 8.694, Trained Tokens 28480, Peak mem 6.365 GB
# Iter 1790: Train loss 0.005, Learning Rate 2.000e-04, It/sec 0.543, Tokens/sec 8.684, Trained Tokens 28640, Peak mem 6.365 GB
# Calculating loss...: 100%|██████████████████████| 25/25 [00:23<00:00,  1.05it/s]
# Iter 1800: Val loss 0.041, Val took 23.838s
# Iter 1800: Train loss 0.033, Learning Rate 2.000e-04, It/sec 0.543, Tokens/sec 8.689, Trained Tokens 28800, Peak mem 6.365 GB
# Iter 1810: Train loss 0.065, Learning Rate 2.000e-04, It/sec 0.543, Tokens/sec 8.688, Trained Tokens 28960, Peak mem 6.365 GB
# Iter 1820: Train loss 0.047, Learning Rate 2.000e-04, It/sec 0.542, Tokens/sec 8.672, Trained Tokens 29120, Peak mem 6.365 GB
# Iter 1830: Train loss 0.032, Learning Rate 2.000e-04, It/sec 0.543, Tokens/sec 8.684, Trained Tokens 29280, Peak mem 6.365 GB
# Iter 1840: Train loss 0.032, Learning Rate 2.000e-04, It/sec 0.542, Tokens/sec 8.671, Trained Tokens 29440, Peak mem 6.365 GB
# Iter 1850: Train loss 0.008, Learning Rate 2.000e-04, It/sec 0.542, Tokens/sec 8.677, Trained Tokens 29600, Peak mem 6.365 GB
# Iter 1860: Train loss 0.021, Learning Rate 2.000e-04, It/sec 0.543, Tokens/sec 8.686, Trained Tokens 29760, Peak mem 6.365 GB
# Iter 1870: Train loss 0.042, Learning Rate 2.000e-04, It/sec 0.538, Tokens/sec 8.609, Trained Tokens 29920, Peak mem 6.365 GB
# Iter 1880: Train loss 0.016, Learning Rate 2.000e-04, It/sec 0.542, Tokens/sec 8.675, Trained Tokens 30080, Peak mem 6.365 GB
# Iter 1890: Train loss 0.012, Learning Rate 2.000e-04, It/sec 0.542, Tokens/sec 8.676, Trained Tokens 30240, Peak mem 6.365 GB
# Iter 1900: Train loss 0.006, Learning Rate 2.000e-04, It/sec 0.543, Tokens/sec 8.684, Trained Tokens 30400, Peak mem 6.365 GB
# Iter 1910: Train loss 0.022, Learning Rate 2.000e-04, It/sec 0.543, Tokens/sec 8.693, Trained Tokens 30560, Peak mem 6.365 GB
# Iter 1920: Train loss 0.016, Learning Rate 2.000e-04, It/sec 0.543, Tokens/sec 8.690, Trained Tokens 30720, Peak mem 6.365 GB
# Iter 1930: Train loss 0.004, Learning Rate 2.000e-04, It/sec 0.543, Tokens/sec 8.690, Trained Tokens 30880, Peak mem 6.365 GB
# Iter 1940: Train loss 0.043, Learning Rate 2.000e-04, It/sec 0.542, Tokens/sec 8.672, Trained Tokens 31040, Peak mem 6.365 GB
# Iter 1950: Train loss 0.019, Learning Rate 2.000e-04, It/sec 0.542, Tokens/sec 8.674, Trained Tokens 31200, Peak mem 6.365 GB
# Iter 1960: Train loss 0.136, Learning Rate 2.000e-04, It/sec 0.542, Tokens/sec 8.677, Trained Tokens 31360, Peak mem 6.365 GB
# Iter 1970: Train loss 0.041, Learning Rate 2.000e-04, It/sec 0.543, Tokens/sec 8.694, Trained Tokens 31520, Peak mem 6.365 GB
# Iter 1980: Train loss 0.062, Learning Rate 2.000e-04, It/sec 0.543, Tokens/sec 8.681, Trained Tokens 31680, Peak mem 6.365 GB
# Iter 1990: Train loss 0.015, Learning Rate 2.000e-04, It/sec 0.543, Tokens/sec 8.684, Trained Tokens 31840, Peak mem 6.365 GB
# Calculating loss...: 100%|██████████████████████| 25/25 [00:23<00:00,  1.05it/s]
# Iter 2000: Val loss 0.048, Val took 23.836s
# Iter 2000: Train loss 0.013, Learning Rate 2.000e-04, It/sec 0.542, Tokens/sec 8.679, Trained Tokens 32000, Peak mem 6.365 GB
# Iter 2000: Saved adapter weights to adapters_w4/T3A_narrative/adapters.safetensors and adapters_w4/T3A_narrative/0002000_adapters.safetensors.
# Saved final weights to adapters_w4/T3A_narrative/adapters.safetensors.

# %%
# ── Load model with T3A_narrative adapter ──────────────────────────────
model_mlx, tok_mlx = load(
    MODEL_ID,
    adapter_path="./adapters_w4/T3A_narrative",
)

# ── Inference ──────────────────────────────────────────────────────
t0 = time.time()
preds, refs, probs = run_inference_mlx(
    model_mlx, tok_mlx, test_ds_narrative_full, return_probs=True
)

# ── Evaluate ───────────────────────────────────────────────────────
metrics = evaluate_predictions(preds, refs, label_name="T3A_narrative")

# ── Calibration ────────────────────────────────────────────────────
ece = calibration_analysis(
    probs, refs,
    label_name="T3A_narrative",
    save_path=os.path.join(OUTPUT_DIR, "calibration_T3A_narrative.png")
)
metrics["ECE"] = ece
all_metrics.append(metrics)

# ── Save predictions ───────────────────────────────────────────────
out_df = pd.DataFrame({"Predicted_Label": preds, "Ground_Truth": refs, "P_Yes": probs})
out_df.to_csv(os.path.join(OUTPUT_DIR, "predictions_T3A_narrative.csv"), index=False)

elapsed = round(time.time() - t0, 2)
experiment_times["T3A_narrative"] = elapsed
print(f"\n  ⏱ T3A_narrative done in {elapsed:.1f}s")

# ── Clean up ───────────────────────────────────────────────────────
del model_mlx, tok_mlx
# Out:
# Downloading (incomplete total...): 0.00B [00:00, ?B/s]
# Fetching 9 files:   0%|          | 0/9 [00:00<?, ?it/s]
# Generating:   0%|          | 0/6167 [00:00<?, ?it/s]
# ── T3A_narrative ──
#   Label: T3A_narrative
#   N_test: 6167
#   Accuracy: 0.9572
#   Recall: 0.7374
#   Precision: 0.84
#   F1: 0.7854
#   Unknown: 0
#               precision    recall  f1-score   support
#
#           No       0.97      0.98      0.98      5512
#          Yes       0.84      0.74      0.79       655
#
#     accuracy                           0.96      6167
#    macro avg       0.90      0.86      0.88      6167
# weighted avg       0.96      0.96      0.96      6167
#
#   ECE: 0.0279 | Saved → ./results_wave4/calibration_T3A_narrative.png
#
#   ⏱ T3A_narrative done in 2110.7s

# %% [markdown]
# ### Training and Inference for T3B_minimal

# %%
# !mlx_lm.lora \
    --model {MODEL_ID} \
    --train \
    --data ./mlx_data/T3B_minimal \
    --num-layers 16 \
    --batch-size 4 \
    --grad-accumulation-steps 4 \
    --iters 2000 \
    --learning-rate 2e-4 \
    --mask-prompt \
    --adapter-path ./adapters_w4/T3B_minimal \
    --save-every 500 \
    -c ./configs/lora_config.yaml
# Out:
# Loading configuration file ./configs/lora_config.yaml
# Loading pretrained model
# Downloading (incomplete total...): 0.00B [00:00, ?B/s]
# Fetching 9 files: 100%|███████████████████████| 9/9 [00:00<00:00, 120218.90it/s]
# Download complete: : 0.00B [00:00, ?B/s]
# Loading datasets
# Training
# Trainable parameters: 0.684% (10.551M/1543.714M)
# Starting training..., iters: 2000
# Calculating loss...: 100%|██████████████████████| 25/25 [00:24<00:00,  1.03it/s]
# Iter 1: Val loss 7.466, Val took 24.194s
# Iter 10: Train loss 3.800, Learning Rate 2.000e-04, It/sec 0.523, Tokens/sec 8.364, Trained Tokens 160, Peak mem 6.323 GB
# Iter 20: Train loss 0.146, Learning Rate 2.000e-04, It/sec 0.498, Tokens/sec 7.973, Trained Tokens 320, Peak mem 6.323 GB
# Iter 30: Train loss 0.036, Learning Rate 2.000e-04, It/sec 0.501, Tokens/sec 8.015, Trained Tokens 480, Peak mem 6.323 GB
# Iter 40: Train loss 0.022, Learning Rate 2.000e-04, It/sec 0.512, Tokens/sec 8.194, Trained Tokens 640, Peak mem 6.323 GB
# Iter 50: Train loss 0.028, Learning Rate 2.000e-04, It/sec 0.526, Tokens/sec 8.410, Trained Tokens 800, Peak mem 6.323 GB
# Iter 60: Train loss 0.009, Learning Rate 2.000e-04, It/sec 0.527, Tokens/sec 8.430, Trained Tokens 960, Peak mem 6.323 GB
# Iter 70: Train loss 0.100, Learning Rate 2.000e-04, It/sec 0.531, Tokens/sec 8.500, Trained Tokens 1120, Peak mem 6.323 GB
# Iter 80: Train loss 0.107, Learning Rate 2.000e-04, It/sec 0.532, Tokens/sec 8.512, Trained Tokens 1280, Peak mem 6.323 GB
# Iter 90: Train loss 0.058, Learning Rate 2.000e-04, It/sec 0.521, Tokens/sec 8.329, Trained Tokens 1440, Peak mem 6.323 GB
# Iter 100: Train loss 0.389, Learning Rate 2.000e-04, It/sec 0.530, Tokens/sec 8.479, Trained Tokens 1600, Peak mem 6.323 GB
# Iter 110: Train loss 0.187, Learning Rate 2.000e-04, It/sec 0.528, Tokens/sec 8.441, Trained Tokens 1760, Peak mem 6.323 GB
# Iter 120: Train loss 0.179, Learning Rate 2.000e-04, It/sec 0.532, Tokens/sec 8.511, Trained Tokens 1920, Peak mem 6.323 GB
# Iter 130: Train loss 0.017, Learning Rate 2.000e-04, It/sec 0.532, Tokens/sec 8.515, Trained Tokens 2080, Peak mem 6.323 GB
# Iter 140: Train loss 0.032, Learning Rate 2.000e-04, It/sec 0.531, Tokens/sec 8.490, Trained Tokens 2240, Peak mem 6.323 GB
# Iter 150: Train loss 0.037, Learning Rate 2.000e-04, It/sec 0.530, Tokens/sec 8.476, Trained Tokens 2400, Peak mem 6.323 GB
# Iter 160: Train loss 0.368, Learning Rate 2.000e-04, It/sec 0.530, Tokens/sec 8.485, Trained Tokens 2560, Peak mem 6.323 GB
# Iter 170: Train loss 0.138, Learning Rate 2.000e-04, It/sec 0.532, Tokens/sec 8.506, Trained Tokens 2720, Peak mem 6.323 GB
# Iter 180: Train loss 0.098, Learning Rate 2.000e-04, It/sec 0.530, Tokens/sec 8.474, Trained Tokens 2880, Peak mem 6.323 GB
# Iter 190: Train loss 0.003, Learning Rate 2.000e-04, It/sec 0.532, Tokens/sec 8.505, Trained Tokens 3040, Peak mem 6.323 GB
# Calculating loss...: 100%|██████████████████████| 25/25 [00:24<00:00,  1.03it/s]
# Iter 200: Val loss 0.051, Val took 24.202s
# Iter 200: Train loss 0.000, Learning Rate 2.000e-04, It/sec 0.531, Tokens/sec 8.490, Trained Tokens 3200, Peak mem 6.323 GB
# Iter 210: Train loss 0.000, Learning Rate 2.000e-04, It/sec 0.531, Tokens/sec 8.502, Trained Tokens 3360, Peak mem 6.323 GB
# Iter 220: Train loss 0.111, Learning Rate 2.000e-04, It/sec 0.530, Tokens/sec 8.482, Trained Tokens 3520, Peak mem 6.323 GB
# Iter 230: Train loss 0.121, Learning Rate 2.000e-04, It/sec 0.526, Tokens/sec 8.410, Trained Tokens 3680, Peak mem 6.323 GB
# Iter 240: Train loss 0.037, Learning Rate 2.000e-04, It/sec 0.530, Tokens/sec 8.478, Trained Tokens 3840, Peak mem 6.323 GB
# Iter 250: Train loss 0.022, Learning Rate 2.000e-04, It/sec 0.516, Tokens/sec 8.252, Trained Tokens 4000, Peak mem 6.323 GB
# Iter 260: Train loss 0.044, Learning Rate 2.000e-04, It/sec 0.524, Tokens/sec 8.381, Trained Tokens 4160, Peak mem 6.323 GB
# Iter 270: Train loss 0.049, Learning Rate 2.000e-04, It/sec 0.533, Tokens/sec 8.534, Trained Tokens 4320, Peak mem 6.323 GB
# Iter 280: Train loss 0.019, Learning Rate 2.000e-04, It/sec 0.526, Tokens/sec 8.422, Trained Tokens 4480, Peak mem 6.323 GB
# Iter 290: Train loss 0.047, Learning Rate 2.000e-04, It/sec 0.530, Tokens/sec 8.486, Trained Tokens 4640, Peak mem 6.323 GB
# Iter 300: Train loss 0.082, Learning Rate 2.000e-04, It/sec 0.532, Tokens/sec 8.512, Trained Tokens 4800, Peak mem 6.323 GB
# Iter 310: Train loss 0.036, Learning Rate 2.000e-04, It/sec 0.532, Tokens/sec 8.513, Trained Tokens 4960, Peak mem 6.323 GB
# Iter 320: Train loss 0.040, Learning Rate 2.000e-04, It/sec 0.532, Tokens/sec 8.510, Trained Tokens 5120, Peak mem 6.323 GB
# Iter 330: Train loss 0.042, Learning Rate 2.000e-04, It/sec 0.533, Tokens/sec 8.521, Trained Tokens 5280, Peak mem 6.323 GB
# Iter 340: Train loss 0.049, Learning Rate 2.000e-04, It/sec 0.532, Tokens/sec 8.515, Trained Tokens 5440, Peak mem 6.323 GB
# Iter 350: Train loss 0.035, Learning Rate 2.000e-04, It/sec 0.521, Tokens/sec 8.341, Trained Tokens 5600, Peak mem 6.323 GB
# Iter 360: Train loss 0.006, Learning Rate 2.000e-04, It/sec 0.535, Tokens/sec 8.553, Trained Tokens 5760, Peak mem 6.323 GB
# Iter 370: Train loss 0.037, Learning Rate 2.000e-04, It/sec 0.530, Tokens/sec 8.477, Trained Tokens 5920, Peak mem 6.323 GB
# Iter 380: Train loss 0.008, Learning Rate 2.000e-04, It/sec 0.537, Tokens/sec 8.593, Trained Tokens 6080, Peak mem 6.323 GB
# Iter 390: Train loss 0.007, Learning Rate 2.000e-04, It/sec 0.531, Tokens/sec 8.501, Trained Tokens 6240, Peak mem 6.323 GB
# Calculating loss...: 100%|██████████████████████| 25/25 [00:24<00:00,  1.03it/s]
# Iter 400: Val loss 0.048, Val took 24.331s
# Iter 400: Train loss 0.021, Learning Rate 2.000e-04, It/sec 0.531, Tokens/sec 8.503, Trained Tokens 6400, Peak mem 6.323 GB
# Iter 410: Train loss 0.003, Learning Rate 2.000e-04, It/sec 0.536, Tokens/sec 8.574, Trained Tokens 6560, Peak mem 6.323 GB
# Iter 420: Train loss 0.032, Learning Rate 2.000e-04, It/sec 0.529, Tokens/sec 8.465, Trained Tokens 6720, Peak mem 6.323 GB
# Iter 430: Train loss 0.064, Learning Rate 2.000e-04, It/sec 0.507, Tokens/sec 8.112, Trained Tokens 6880, Peak mem 6.323 GB
# Iter 440: Train loss 0.002, Learning Rate 2.000e-04, It/sec 0.533, Tokens/sec 8.526, Trained Tokens 7040, Peak mem 6.323 GB
# Iter 450: Train loss 0.042, Learning Rate 2.000e-04, It/sec 0.531, Tokens/sec 8.497, Trained Tokens 7200, Peak mem 6.323 GB
# Iter 460: Train loss 0.004, Learning Rate 2.000e-04, It/sec 0.532, Tokens/sec 8.510, Trained Tokens 7360, Peak mem 6.323 GB
# Iter 470: Train loss 0.008, Learning Rate 2.000e-04, It/sec 0.521, Tokens/sec 8.328, Trained Tokens 7520, Peak mem 6.323 GB
# Iter 480: Train loss 0.088, Learning Rate 2.000e-04, It/sec 0.528, Tokens/sec 8.450, Trained Tokens 7680, Peak mem 6.323 GB
# Iter 490: Train loss 0.083, Learning Rate 2.000e-04, It/sec 0.523, Tokens/sec 8.362, Trained Tokens 7840, Peak mem 6.323 GB
# Iter 500: Train loss 0.019, Learning Rate 2.000e-04, It/sec 0.533, Tokens/sec 8.525, Trained Tokens 8000, Peak mem 6.323 GB
# Iter 500: Saved adapter weights to adapters_w4/T3B_minimal/adapters.safetensors and adapters_w4/T3B_minimal/0000500_adapters.safetensors.
# Iter 510: Train loss 0.014, Learning Rate 2.000e-04, It/sec 0.533, Tokens/sec 8.530, Trained Tokens 8160, Peak mem 6.365 GB
# Iter 520: Train loss 0.041, Learning Rate 2.000e-04, It/sec 0.532, Tokens/sec 8.515, Trained Tokens 8320, Peak mem 6.365 GB
# Iter 530: Train loss 0.024, Learning Rate 2.000e-04, It/sec 0.532, Tokens/sec 8.513, Trained Tokens 8480, Peak mem 6.365 GB
# Iter 540: Train loss 0.046, Learning Rate 2.000e-04, It/sec 0.532, Tokens/sec 8.517, Trained Tokens 8640, Peak mem 6.365 GB
# Iter 550: Train loss 0.022, Learning Rate 2.000e-04, It/sec 0.542, Tokens/sec 8.667, Trained Tokens 8800, Peak mem 6.365 GB
# Iter 560: Train loss 0.017, Learning Rate 2.000e-04, It/sec 0.543, Tokens/sec 8.681, Trained Tokens 8960, Peak mem 6.365 GB
# Iter 570: Train loss 0.033, Learning Rate 2.000e-04, It/sec 0.543, Tokens/sec 8.693, Trained Tokens 9120, Peak mem 6.365 GB
# Iter 580: Train loss 0.062, Learning Rate 2.000e-04, It/sec 0.544, Tokens/sec 8.697, Trained Tokens 9280, Peak mem 6.365 GB
# Iter 590: Train loss 0.062, Learning Rate 2.000e-04, It/sec 0.543, Tokens/sec 8.694, Trained Tokens 9440, Peak mem 6.365 GB
# Calculating loss...: 100%|██████████████████████| 25/25 [00:23<00:00,  1.05it/s]
# Iter 600: Val loss 0.027, Val took 23.865s
# Iter 600: Train loss 0.006, Learning Rate 2.000e-04, It/sec 0.544, Tokens/sec 8.705, Trained Tokens 9600, Peak mem 6.365 GB
# Iter 610: Train loss 0.033, Learning Rate 2.000e-04, It/sec 0.540, Tokens/sec 8.647, Trained Tokens 9760, Peak mem 6.365 GB
# Iter 620: Train loss 0.006, Learning Rate 2.000e-04, It/sec 0.543, Tokens/sec 8.695, Trained Tokens 9920, Peak mem 6.365 GB
# Iter 630: Train loss 0.013, Learning Rate 2.000e-04, It/sec 0.541, Tokens/sec 8.664, Trained Tokens 10080, Peak mem 6.365 GB
# Iter 640: Train loss 0.010, Learning Rate 2.000e-04, It/sec 0.542, Tokens/sec 8.675, Trained Tokens 10240, Peak mem 6.365 GB
# Iter 650: Train loss 0.032, Learning Rate 2.000e-04, It/sec 0.542, Tokens/sec 8.668, Trained Tokens 10400, Peak mem 6.365 GB
# Iter 660: Train loss 0.002, Learning Rate 2.000e-04, It/sec 0.542, Tokens/sec 8.678, Trained Tokens 10560, Peak mem 6.365 GB
# Iter 670: Train loss 0.002, Learning Rate 2.000e-04, It/sec 0.542, Tokens/sec 8.679, Trained Tokens 10720, Peak mem 6.365 GB
# Iter 680: Train loss 0.019, Learning Rate 2.000e-04, It/sec 0.540, Tokens/sec 8.645, Trained Tokens 10880, Peak mem 6.365 GB
# Iter 690: Train loss 0.006, Learning Rate 2.000e-04, It/sec 0.541, Tokens/sec 8.658, Trained Tokens 11040, Peak mem 6.365 GB
# Iter 700: Train loss 0.028, Learning Rate 2.000e-04, It/sec 0.543, Tokens/sec 8.689, Trained Tokens 11200, Peak mem 6.365 GB
# Iter 710: Train loss 0.013, Learning Rate 2.000e-04, It/sec 0.544, Tokens/sec 8.697, Trained Tokens 11360, Peak mem 6.365 GB
# Iter 720: Train loss 0.004, Learning Rate 2.000e-04, It/sec 0.540, Tokens/sec 8.640, Trained Tokens 11520, Peak mem 6.365 GB
# Iter 730: Train loss 0.037, Learning Rate 2.000e-04, It/sec 0.542, Tokens/sec 8.673, Trained Tokens 11680, Peak mem 6.365 GB
# Iter 740: Train loss 0.026, Learning Rate 2.000e-04, It/sec 0.540, Tokens/sec 8.637, Trained Tokens 11840, Peak mem 6.365 GB
# Iter 750: Train loss 0.004, Learning Rate 2.000e-04, It/sec 0.539, Tokens/sec 8.630, Trained Tokens 12000, Peak mem 6.365 GB
# Iter 760: Train loss 0.096, Learning Rate 2.000e-04, It/sec 0.540, Tokens/sec 8.638, Trained Tokens 12160, Peak mem 6.365 GB
# Iter 770: Train loss 0.043, Learning Rate 2.000e-04, It/sec 0.542, Tokens/sec 8.667, Trained Tokens 12320, Peak mem 6.365 GB
# Iter 780: Train loss 0.079, Learning Rate 2.000e-04, It/sec 0.540, Tokens/sec 8.641, Trained Tokens 12480, Peak mem 6.365 GB
# Iter 790: Train loss 0.099, Learning Rate 2.000e-04, It/sec 0.540, Tokens/sec 8.644, Trained Tokens 12640, Peak mem 6.365 GB
# Calculating loss...: 100%|██████████████████████| 25/25 [00:23<00:00,  1.05it/s]
# Iter 800: Val loss 0.054, Val took 23.829s
# Iter 800: Train loss 0.025, Learning Rate 2.000e-04, It/sec 0.543, Tokens/sec 8.691, Trained Tokens 12800, Peak mem 6.365 GB
# Iter 810: Train loss 0.000, Learning Rate 2.000e-04, It/sec 0.542, Tokens/sec 8.680, Trained Tokens 12960, Peak mem 6.365 GB
# Iter 820: Train loss 0.033, Learning Rate 2.000e-04, It/sec 0.543, Tokens/sec 8.684, Trained Tokens 13120, Peak mem 6.365 GB
# Iter 830: Train loss 0.052, Learning Rate 2.000e-04, It/sec 0.544, Tokens/sec 8.698, Trained Tokens 13280, Peak mem 6.365 GB
# Iter 840: Train loss 0.047, Learning Rate 2.000e-04, It/sec 0.543, Tokens/sec 8.691, Trained Tokens 13440, Peak mem 6.365 GB
# Iter 850: Train loss 0.133, Learning Rate 2.000e-04, It/sec 0.543, Tokens/sec 8.688, Trained Tokens 13600, Peak mem 6.365 GB
# Iter 860: Train loss 0.030, Learning Rate 2.000e-04, It/sec 0.543, Tokens/sec 8.681, Trained Tokens 13760, Peak mem 6.365 GB
# Iter 870: Train loss 0.089, Learning Rate 2.000e-04, It/sec 0.543, Tokens/sec 8.691, Trained Tokens 13920, Peak mem 6.365 GB
# Iter 880: Train loss 0.025, Learning Rate 2.000e-04, It/sec 0.543, Tokens/sec 8.681, Trained Tokens 14080, Peak mem 6.365 GB
# Iter 890: Train loss 0.029, Learning Rate 2.000e-04, It/sec 0.542, Tokens/sec 8.675, Trained Tokens 14240, Peak mem 6.365 GB
# Iter 900: Train loss 0.011, Learning Rate 2.000e-04, It/sec 0.543, Tokens/sec 8.690, Trained Tokens 14400, Peak mem 6.365 GB
# Iter 910: Train loss 0.100, Learning Rate 2.000e-04, It/sec 0.538, Tokens/sec 8.613, Trained Tokens 14560, Peak mem 6.365 GB
# Iter 920: Train loss 0.050, Learning Rate 2.000e-04, It/sec 0.543, Tokens/sec 8.682, Trained Tokens 14720, Peak mem 6.365 GB
# Iter 930: Train loss 0.016, Learning Rate 2.000e-04, It/sec 0.535, Tokens/sec 8.566, Trained Tokens 14880, Peak mem 6.365 GB
# Iter 940: Train loss 0.004, Learning Rate 2.000e-04, It/sec 0.533, Tokens/sec 8.530, Trained Tokens 15040, Peak mem 6.365 GB
# Iter 950: Train loss 0.026, Learning Rate 2.000e-04, It/sec 0.545, Tokens/sec 8.722, Trained Tokens 15200, Peak mem 6.365 GB
# Iter 960: Train loss 0.100, Learning Rate 2.000e-04, It/sec 0.542, Tokens/sec 8.679, Trained Tokens 15360, Peak mem 6.365 GB
# Iter 970: Train loss 0.017, Learning Rate 2.000e-04, It/sec 0.540, Tokens/sec 8.633, Trained Tokens 15520, Peak mem 6.365 GB
# Iter 980: Train loss 0.053, Learning Rate 2.000e-04, It/sec 0.538, Tokens/sec 8.612, Trained Tokens 15680, Peak mem 6.365 GB
# Iter 990: Train loss 0.007, Learning Rate 2.000e-04, It/sec 0.542, Tokens/sec 8.668, Trained Tokens 15840, Peak mem 6.365 GB
# Calculating loss...: 100%|██████████████████████| 25/25 [00:23<00:00,  1.04it/s]
# Iter 1000: Val loss 0.021, Val took 24.000s
# Iter 1000: Train loss 0.041, Learning Rate 2.000e-04, It/sec 0.535, Tokens/sec 8.559, Trained Tokens 16000, Peak mem 6.365 GB
# Iter 1000: Saved adapter weights to adapters_w4/T3B_minimal/adapters.safetensors and adapters_w4/T3B_minimal/0001000_adapters.safetensors.
# Iter 1010: Train loss 0.009, Learning Rate 2.000e-04, It/sec 0.534, Tokens/sec 8.548, Trained Tokens 16160, Peak mem 6.365 GB
# Iter 1020: Train loss 0.020, Learning Rate 2.000e-04, It/sec 0.544, Tokens/sec 8.703, Trained Tokens 16320, Peak mem 6.365 GB
# Iter 1030: Train loss 0.039, Learning Rate 2.000e-04, It/sec 0.541, Tokens/sec 8.652, Trained Tokens 16480, Peak mem 6.365 GB
# Iter 1040: Train loss 0.021, Learning Rate 2.000e-04, It/sec 0.539, Tokens/sec 8.628, Trained Tokens 16640, Peak mem 6.365 GB
# Iter 1050: Train loss 0.046, Learning Rate 2.000e-04, It/sec 0.534, Tokens/sec 8.537, Trained Tokens 16800, Peak mem 6.365 GB
# Iter 1060: Train loss 0.007, Learning Rate 2.000e-04, It/sec 0.538, Tokens/sec 8.608, Trained Tokens 16960, Peak mem 6.365 GB
# Iter 1070: Train loss 0.018, Learning Rate 2.000e-04, It/sec 0.539, Tokens/sec 8.631, Trained Tokens 17120, Peak mem 6.365 GB
# Iter 1080: Train loss 0.029, Learning Rate 2.000e-04, It/sec 0.544, Tokens/sec 8.705, Trained Tokens 17280, Peak mem 6.365 GB
# Iter 1090: Train loss 0.035, Learning Rate 2.000e-04, It/sec 0.525, Tokens/sec 8.402, Trained Tokens 17440, Peak mem 6.365 GB
# Iter 1100: Train loss 0.090, Learning Rate 2.000e-04, It/sec 0.524, Tokens/sec 8.382, Trained Tokens 17600, Peak mem 6.365 GB
# Iter 1110: Train loss 0.005, Learning Rate 2.000e-04, It/sec 0.522, Tokens/sec 8.360, Trained Tokens 17760, Peak mem 6.365 GB
# Iter 1120: Train loss 0.077, Learning Rate 2.000e-04, It/sec 0.522, Tokens/sec 8.355, Trained Tokens 17920, Peak mem 6.365 GB
# Iter 1130: Train loss 0.049, Learning Rate 2.000e-04, It/sec 0.532, Tokens/sec 8.507, Trained Tokens 18080, Peak mem 6.365 GB
# Iter 1140: Train loss 0.082, Learning Rate 2.000e-04, It/sec 0.531, Tokens/sec 8.500, Trained Tokens 18240, Peak mem 6.365 GB
# Iter 1150: Train loss 0.073, Learning Rate 2.000e-04, It/sec 0.529, Tokens/sec 8.465, Trained Tokens 18400, Peak mem 6.365 GB
# Iter 1160: Train loss 0.023, Learning Rate 2.000e-04, It/sec 0.526, Tokens/sec 8.411, Trained Tokens 18560, Peak mem 6.365 GB
# Iter 1170: Train loss 0.013, Learning Rate 2.000e-04, It/sec 0.525, Tokens/sec 8.396, Trained Tokens 18720, Peak mem 6.365 GB
# Iter 1180: Train loss 0.015, Learning Rate 2.000e-04, It/sec 0.526, Tokens/sec 8.421, Trained Tokens 18880, Peak mem 6.365 GB
# Iter 1190: Train loss 0.020, Learning Rate 2.000e-04, It/sec 0.526, Tokens/sec 8.423, Trained Tokens 19040, Peak mem 6.365 GB
# Calculating loss...: 100%|██████████████████████| 25/25 [00:24<00:00,  1.02it/s]
# Iter 1200: Val loss 0.022, Val took 24.519s
# Iter 1200: Train loss 0.088, Learning Rate 2.000e-04, It/sec 0.527, Tokens/sec 8.427, Trained Tokens 19200, Peak mem 6.365 GB
# Iter 1210: Train loss 0.018, Learning Rate 2.000e-04, It/sec 0.531, Tokens/sec 8.504, Trained Tokens 19360, Peak mem 6.365 GB
# Iter 1220: Train loss 0.010, Learning Rate 2.000e-04, It/sec 0.525, Tokens/sec 8.396, Trained Tokens 19520, Peak mem 6.365 GB
# Iter 1230: Train loss 0.032, Learning Rate 2.000e-04, It/sec 0.526, Tokens/sec 8.412, Trained Tokens 19680, Peak mem 6.365 GB
# Iter 1240: Train loss 0.011, Learning Rate 2.000e-04, It/sec 0.525, Tokens/sec 8.395, Trained Tokens 19840, Peak mem 6.365 GB
# Iter 1250: Train loss 0.008, Learning Rate 2.000e-04, It/sec 0.527, Tokens/sec 8.428, Trained Tokens 20000, Peak mem 6.365 GB
# Iter 1260: Train loss 0.004, Learning Rate 2.000e-04, It/sec 0.529, Tokens/sec 8.466, Trained Tokens 20160, Peak mem 6.365 GB
# Iter 1270: Train loss 0.082, Learning Rate 2.000e-04, It/sec 0.527, Tokens/sec 8.428, Trained Tokens 20320, Peak mem 6.365 GB
# Iter 1280: Train loss 0.064, Learning Rate 2.000e-04, It/sec 0.525, Tokens/sec 8.404, Trained Tokens 20480, Peak mem 6.365 GB
# Iter 1290: Train loss 0.025, Learning Rate 2.000e-04, It/sec 0.528, Tokens/sec 8.445, Trained Tokens 20640, Peak mem 6.365 GB
# Iter 1300: Train loss 0.031, Learning Rate 2.000e-04, It/sec 0.527, Tokens/sec 8.438, Trained Tokens 20800, Peak mem 6.365 GB
# Iter 1310: Train loss 0.006, Learning Rate 2.000e-04, It/sec 0.525, Tokens/sec 8.396, Trained Tokens 20960, Peak mem 6.365 GB
# Iter 1320: Train loss 0.016, Learning Rate 2.000e-04, It/sec 0.526, Tokens/sec 8.419, Trained Tokens 21120, Peak mem 6.365 GB
# Iter 1330: Train loss 0.087, Learning Rate 2.000e-04, It/sec 0.528, Tokens/sec 8.448, Trained Tokens 21280, Peak mem 6.365 GB
# Iter 1340: Train loss 0.007, Learning Rate 2.000e-04, It/sec 0.528, Tokens/sec 8.441, Trained Tokens 21440, Peak mem 6.365 GB
# Iter 1350: Train loss 0.033, Learning Rate 2.000e-04, It/sec 0.535, Tokens/sec 8.552, Trained Tokens 21600, Peak mem 6.365 GB
# Iter 1360: Train loss 0.025, Learning Rate 2.000e-04, It/sec 0.539, Tokens/sec 8.631, Trained Tokens 21760, Peak mem 6.365 GB
# Iter 1370: Train loss 0.016, Learning Rate 2.000e-04, It/sec 0.541, Tokens/sec 8.652, Trained Tokens 21920, Peak mem 6.365 GB
# Iter 1380: Train loss 0.018, Learning Rate 2.000e-04, It/sec 0.540, Tokens/sec 8.647, Trained Tokens 22080, Peak mem 6.365 GB
# Iter 1390: Train loss 0.030, Learning Rate 2.000e-04, It/sec 0.542, Tokens/sec 8.672, Trained Tokens 22240, Peak mem 6.365 GB
# Calculating loss...: 100%|██████████████████████| 25/25 [00:23<00:00,  1.05it/s]
# Iter 1400: Val loss 0.057, Val took 23.870s
# Iter 1400: Train loss 0.035, Learning Rate 2.000e-04, It/sec 0.540, Tokens/sec 8.639, Trained Tokens 22400, Peak mem 6.365 GB
# Iter 1410: Train loss 0.099, Learning Rate 2.000e-04, It/sec 0.541, Tokens/sec 8.656, Trained Tokens 22560, Peak mem 6.365 GB
# Iter 1420: Train loss 0.011, Learning Rate 2.000e-04, It/sec 0.540, Tokens/sec 8.648, Trained Tokens 22720, Peak mem 6.365 GB
# Iter 1430: Train loss 0.079, Learning Rate 2.000e-04, It/sec 0.541, Tokens/sec 8.654, Trained Tokens 22880, Peak mem 6.365 GB
# Iter 1440: Train loss 0.019, Learning Rate 2.000e-04, It/sec 0.542, Tokens/sec 8.666, Trained Tokens 23040, Peak mem 6.365 GB
# Iter 1450: Train loss 0.010, Learning Rate 2.000e-04, It/sec 0.541, Tokens/sec 8.656, Trained Tokens 23200, Peak mem 6.365 GB
# Iter 1460: Train loss 0.007, Learning Rate 2.000e-04, It/sec 0.540, Tokens/sec 8.642, Trained Tokens 23360, Peak mem 6.365 GB
# Iter 1470: Train loss 0.006, Learning Rate 2.000e-04, It/sec 0.541, Tokens/sec 8.663, Trained Tokens 23520, Peak mem 6.365 GB
# Iter 1480: Train loss 0.008, Learning Rate 2.000e-04, It/sec 0.540, Tokens/sec 8.641, Trained Tokens 23680, Peak mem 6.365 GB
# Iter 1490: Train loss 0.021, Learning Rate 2.000e-04, It/sec 0.542, Tokens/sec 8.665, Trained Tokens 23840, Peak mem 6.365 GB
# Iter 1500: Train loss 0.016, Learning Rate 2.000e-04, It/sec 0.541, Tokens/sec 8.659, Trained Tokens 24000, Peak mem 6.365 GB
# Iter 1500: Saved adapter weights to adapters_w4/T3B_minimal/adapters.safetensors and adapters_w4/T3B_minimal/0001500_adapters.safetensors.
# Iter 1510: Train loss 0.036, Learning Rate 2.000e-04, It/sec 0.533, Tokens/sec 8.529, Trained Tokens 24160, Peak mem 6.365 GB
# Iter 1520: Train loss 0.083, Learning Rate 2.000e-04, It/sec 0.538, Tokens/sec 8.614, Trained Tokens 24320, Peak mem 6.365 GB
# Iter 1530: Train loss 0.018, Learning Rate 2.000e-04, It/sec 0.543, Tokens/sec 8.687, Trained Tokens 24480, Peak mem 6.365 GB
# Iter 1540: Train loss 0.051, Learning Rate 2.000e-04, It/sec 0.542, Tokens/sec 8.677, Trained Tokens 24640, Peak mem 6.365 GB
# Iter 1550: Train loss 0.028, Learning Rate 2.000e-04, It/sec 0.543, Tokens/sec 8.685, Trained Tokens 24800, Peak mem 6.365 GB
# Iter 1560: Train loss 0.033, Learning Rate 2.000e-04, It/sec 0.543, Tokens/sec 8.680, Trained Tokens 24960, Peak mem 6.365 GB
# Iter 1570: Train loss 0.067, Learning Rate 2.000e-04, It/sec 0.543, Tokens/sec 8.687, Trained Tokens 25120, Peak mem 6.365 GB
# Iter 1580: Train loss 0.049, Learning Rate 2.000e-04, It/sec 0.539, Tokens/sec 8.618, Trained Tokens 25280, Peak mem 6.365 GB
# Iter 1590: Train loss 0.010, Learning Rate 2.000e-04, It/sec 0.542, Tokens/sec 8.674, Trained Tokens 25440, Peak mem 6.365 GB
# Calculating loss...: 100%|██████████████████████| 25/25 [00:23<00:00,  1.05it/s]
# Iter 1600: Val loss 0.044, Val took 23.829s
# Iter 1600: Train loss 0.046, Learning Rate 2.000e-04, It/sec 0.544, Tokens/sec 8.696, Trained Tokens 25600, Peak mem 6.365 GB
# Iter 1610: Train loss 0.082, Learning Rate 2.000e-04, It/sec 0.543, Tokens/sec 8.683, Trained Tokens 25760, Peak mem 6.365 GB
# Iter 1620: Train loss 0.033, Learning Rate 2.000e-04, It/sec 0.543, Tokens/sec 8.688, Trained Tokens 25920, Peak mem 6.365 GB
# Iter 1630: Train loss 0.063, Learning Rate 2.000e-04, It/sec 0.542, Tokens/sec 8.678, Trained Tokens 26080, Peak mem 6.365 GB
# Iter 1640: Train loss 0.042, Learning Rate 2.000e-04, It/sec 0.543, Tokens/sec 8.690, Trained Tokens 26240, Peak mem 6.365 GB
# Iter 1650: Train loss 0.036, Learning Rate 2.000e-04, It/sec 0.543, Tokens/sec 8.695, Trained Tokens 26400, Peak mem 6.365 GB
# Iter 1660: Train loss 0.055, Learning Rate 2.000e-04, It/sec 0.543, Tokens/sec 8.690, Trained Tokens 26560, Peak mem 6.365 GB
# Iter 1670: Train loss 0.030, Learning Rate 2.000e-04, It/sec 0.543, Tokens/sec 8.689, Trained Tokens 26720, Peak mem 6.365 GB
# Iter 1680: Train loss 0.021, Learning Rate 2.000e-04, It/sec 0.543, Tokens/sec 8.687, Trained Tokens 26880, Peak mem 6.365 GB
# Iter 1690: Train loss 0.016, Learning Rate 2.000e-04, It/sec 0.543, Tokens/sec 8.680, Trained Tokens 27040, Peak mem 6.365 GB
# Iter 1700: Train loss 0.026, Learning Rate 2.000e-04, It/sec 0.543, Tokens/sec 8.681, Trained Tokens 27200, Peak mem 6.365 GB
# Iter 1710: Train loss 0.021, Learning Rate 2.000e-04, It/sec 0.543, Tokens/sec 8.691, Trained Tokens 27360, Peak mem 6.365 GB
# Iter 1720: Train loss 0.019, Learning Rate 2.000e-04, It/sec 0.542, Tokens/sec 8.676, Trained Tokens 27520, Peak mem 6.365 GB
# Iter 1730: Train loss 0.003, Learning Rate 2.000e-04, It/sec 0.542, Tokens/sec 8.673, Trained Tokens 27680, Peak mem 6.365 GB
# Iter 1740: Train loss 0.005, Learning Rate 2.000e-04, It/sec 0.543, Tokens/sec 8.686, Trained Tokens 27840, Peak mem 6.365 GB
# Iter 1750: Train loss 0.078, Learning Rate 2.000e-04, It/sec 0.543, Tokens/sec 8.685, Trained Tokens 28000, Peak mem 6.365 GB
# Iter 1760: Train loss 0.021, Learning Rate 2.000e-04, It/sec 0.542, Tokens/sec 8.666, Trained Tokens 28160, Peak mem 6.365 GB
# Iter 1770: Train loss 0.033, Learning Rate 2.000e-04, It/sec 0.533, Tokens/sec 8.534, Trained Tokens 28320, Peak mem 6.365 GB
# Iter 1780: Train loss 0.005, Learning Rate 2.000e-04, It/sec 0.532, Tokens/sec 8.512, Trained Tokens 28480, Peak mem 6.365 GB
# Iter 1790: Train loss 0.009, Learning Rate 2.000e-04, It/sec 0.533, Tokens/sec 8.530, Trained Tokens 28640, Peak mem 6.365 GB
# Calculating loss...: 100%|██████████████████████| 25/25 [00:23<00:00,  1.05it/s]
# Iter 1800: Val loss 0.039, Val took 23.856s
# Iter 1800: Train loss 0.031, Learning Rate 2.000e-04, It/sec 0.533, Tokens/sec 8.535, Trained Tokens 28800, Peak mem 6.365 GB
# Iter 1810: Train loss 0.063, Learning Rate 2.000e-04, It/sec 0.542, Tokens/sec 8.678, Trained Tokens 28960, Peak mem 6.365 GB
# Iter 1820: Train loss 0.047, Learning Rate 2.000e-04, It/sec 0.543, Tokens/sec 8.687, Trained Tokens 29120, Peak mem 6.365 GB
# Iter 1830: Train loss 0.032, Learning Rate 2.000e-04, It/sec 0.543, Tokens/sec 8.691, Trained Tokens 29280, Peak mem 6.365 GB
# Iter 1840: Train loss 0.032, Learning Rate 2.000e-04, It/sec 0.542, Tokens/sec 8.667, Trained Tokens 29440, Peak mem 6.365 GB
# Iter 1850: Train loss 0.006, Learning Rate 2.000e-04, It/sec 0.542, Tokens/sec 8.676, Trained Tokens 29600, Peak mem 6.365 GB
# Iter 1860: Train loss 0.019, Learning Rate 2.000e-04, It/sec 0.543, Tokens/sec 8.685, Trained Tokens 29760, Peak mem 6.365 GB
# Iter 1870: Train loss 0.042, Learning Rate 2.000e-04, It/sec 0.538, Tokens/sec 8.607, Trained Tokens 29920, Peak mem 6.365 GB
# Iter 1880: Train loss 0.014, Learning Rate 2.000e-04, It/sec 0.543, Tokens/sec 8.682, Trained Tokens 30080, Peak mem 6.365 GB
# Iter 1890: Train loss 0.013, Learning Rate 2.000e-04, It/sec 0.542, Tokens/sec 8.674, Trained Tokens 30240, Peak mem 6.365 GB
# Iter 1900: Train loss 0.006, Learning Rate 2.000e-04, It/sec 0.543, Tokens/sec 8.696, Trained Tokens 30400, Peak mem 6.365 GB
# Iter 1910: Train loss 0.024, Learning Rate 2.000e-04, It/sec 0.543, Tokens/sec 8.689, Trained Tokens 30560, Peak mem 6.365 GB
# Iter 1920: Train loss 0.018, Learning Rate 2.000e-04, It/sec 0.542, Tokens/sec 8.678, Trained Tokens 30720, Peak mem 6.365 GB
# Iter 1930: Train loss 0.005, Learning Rate 2.000e-04, It/sec 0.543, Tokens/sec 8.690, Trained Tokens 30880, Peak mem 6.365 GB
# Iter 1940: Train loss 0.043, Learning Rate 2.000e-04, It/sec 0.543, Tokens/sec 8.686, Trained Tokens 31040, Peak mem 6.365 GB
# Iter 1950: Train loss 0.017, Learning Rate 2.000e-04, It/sec 0.543, Tokens/sec 8.681, Trained Tokens 31200, Peak mem 6.365 GB
# Iter 1960: Train loss 0.123, Learning Rate 2.000e-04, It/sec 0.542, Tokens/sec 8.679, Trained Tokens 31360, Peak mem 6.365 GB
# Iter 1970: Train loss 0.042, Learning Rate 2.000e-04, It/sec 0.543, Tokens/sec 8.681, Trained Tokens 31520, Peak mem 6.365 GB
# Iter 1980: Train loss 0.064, Learning Rate 2.000e-04, It/sec 0.542, Tokens/sec 8.678, Trained Tokens 31680, Peak mem 6.365 GB
# Iter 1990: Train loss 0.016, Learning Rate 2.000e-04, It/sec 0.543, Tokens/sec 8.683, Trained Tokens 31840, Peak mem 6.365 GB
# Calculating loss...: 100%|██████████████████████| 25/25 [00:23<00:00,  1.05it/s]
# Iter 2000: Val loss 0.048, Val took 23.828s
# Iter 2000: Train loss 0.011, Learning Rate 2.000e-04, It/sec 0.543, Tokens/sec 8.683, Trained Tokens 32000, Peak mem 6.365 GB
# Iter 2000: Saved adapter weights to adapters_w4/T3B_minimal/adapters.safetensors and adapters_w4/T3B_minimal/0002000_adapters.safetensors.
# Saved final weights to adapters_w4/T3B_minimal/adapters.safetensors.

# %%
# ── Load model with T3B_minimal adapter ──────────────────────────────
model_mlx, tok_mlx = load(
    MODEL_ID,
    adapter_path="./adapters_w4/T3B_minimal",
)

# ── Inference ──────────────────────────────────────────────────────
t0 = time.time()
preds, refs, probs = run_inference_mlx(
    model_mlx, tok_mlx, test_ds_structured_minimal, return_probs=True
)

# ── Evaluate ───────────────────────────────────────────────────────
metrics = evaluate_predictions(preds, refs, label_name="T3B_minimal")

# ── Calibration ────────────────────────────────────────────────────
ece = calibration_analysis(
    probs, refs,
    label_name="T3B_minimal",
    save_path=os.path.join(OUTPUT_DIR, "calibration_T3B_minimal.png")
)
metrics["ECE"] = ece
all_metrics.append(metrics)

# ── Save predictions ───────────────────────────────────────────────
out_df = pd.DataFrame({"Predicted_Label": preds, "Ground_Truth": refs, "P_Yes": probs})
out_df.to_csv(os.path.join(OUTPUT_DIR, "predictions_T3B_minimal.csv"), index=False)

elapsed = round(time.time() - t0, 2)
experiment_times["T3B_minimal"] = elapsed
print(f"\n  ⏱ T3B_minimal done in {elapsed:.1f}s")

# ── Clean up ───────────────────────────────────────────────────────
del model_mlx, tok_mlx
# Out:
# Downloading (incomplete total...): 0.00B [00:00, ?B/s]
# Fetching 9 files:   0%|          | 0/9 [00:00<?, ?it/s]
# Generating:   0%|          | 0/6167 [00:00<?, ?it/s]
# ── T3B_minimal ──
#   Label: T3B_minimal
#   N_test: 6167
#   Accuracy: 0.9557
#   Recall: 0.6992
#   Precision: 0.8577
#   F1: 0.7704
#   Unknown: 0
#               precision    recall  f1-score   support
#
#           No       0.97      0.99      0.98      5512
#          Yes       0.86      0.70      0.77       655
#
#     accuracy                           0.96      6167
#    macro avg       0.91      0.84      0.87      6167
# weighted avg       0.95      0.96      0.95      6167
#
#   ECE: 0.0319 | Saved → ./results_wave4/calibration_T3B_minimal.png
#
#   ⏱ T3B_minimal done in 2119.6s

# %% [markdown]
# ### Save Results Summary

# %%
results_df = pd.DataFrame(all_metrics)
results_csv = os.path.join(OUTPUT_DIR, "results_wave4_summary.csv")
results_df.to_csv(results_csv, index=False)
print("\n── Final Results (Wave 4) ──")
print(results_df.to_string(index=False))
print(f"\nSaved → {results_csv}")

print("\n── Experiment Runtimes ──")
for exp, t in experiment_times.items():
    print(f"  {exp}: {t:.1f}s")
# Out:
# ── Final Results (Wave 4) ──
#                  Label  N_test  Accuracy  Recall  Precision     F1  Unknown    ECE
#         T1A_imbalanced    6167    0.9616  0.7634     0.8591 0.8084        0 0.0251
#        T1B_oversampled    6167    0.9527  0.8779     0.7306 0.7975        0 0.0130
#          T2A_demo_only    6167    0.9027  0.1420     0.7099 0.2366        0 0.0911
# T2C_longitudinal_model    6167    0.9551  0.7069     0.8449 0.7697        0 0.0311
#           T3A_zeroshot    6167    0.9491  0.8794     0.7102 0.7858        0 0.0128
#          T3A_narrative    6167    0.9572  0.7374     0.8400 0.7854        0 0.0279
#            T3B_minimal    6167    0.9557  0.6992     0.8577 0.7704        0 0.0319
#
# Saved → ./results_wave4/results_wave4_summary.csv
#
# ── Experiment Runtimes ──
#   T1A_imbalanced: 2354.3s
#   T1B_oversampled: 2268.8s
#   T2A_demo_only: 2102.6s
#   T2C_longitudinal_model: 1862.2s
#   T3A_zeroshot: 1982.8s
#   T3A_narrative: 2110.7s
#   T3B_minimal: 2119.6s
