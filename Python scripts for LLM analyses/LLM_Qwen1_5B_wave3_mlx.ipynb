# %% [markdown]
# ### Import Libraries and Reproducibility

# %%
import sys, os, re, json, pandas as pd, numpy as np
from datetime import datetime
from collections import Counter
from tqdm.auto import tqdm
import transformers

SEED = 22
transformers.set_seed(SEED)
rng = np.random.default_rng(SEED)

# %% [markdown]
# ### Configuration and Instructions

# %%
TRAIN_PATH = "train_w3.csv"
TEST_PATH  = "test_w3.csv"
LABEL      = "SNAP"
OUTPUT_DIR = "./results_wave3"
os.makedirs(OUTPUT_DIR, exist_ok=True)

MODEL_ID = "mlx-community/Qwen2.5-1.5B-Instruct-4bit"

# ── Feature sets ────────────────────────────────────────────────────────
# SNAP_wave1  and SNAP_wave2 are LONGITUDINAL predictors: self-reported Wave 1 and 2 SNAP
# participation carried forward into the Wave 3 feature set.

DEMO_FEATURES     = [
    "marital.status", "sex", "hispanic.origin", "race",
    "education", "citizenship", "employment", "state", "age",
]
INCOME_FEATURES   = DEMO_FEATURES + ["income"]
LONGITUDINAL_FEATURES = ["SNAP_wave1"] + ["SNAP_wave2"]
FULL_FEATURES     = INCOME_FEATURES + LONGITUDINAL_FEATURES          # canonical Wave 3 full model
MINIMAL_FEATURES  = ["income", "employment", "education", "SNAP_wave1", "SNAP_wave2"]

COL_MAP = {
    "marital.status":  "Marital Status",
    "sex":             "Sex",
    "hispanic.origin": "Hispanic Origin",
    "race":            "Race",
    "education":       "Educational Attainment",
    "citizenship":     "Citizenship",
    "employment":      "Employment Status",
    "state":           "State of Residence",
    "age":             "Age",
    "income":          "Income (Wave 3)",
    "SNAP_wave1":      "SNAP Coverage in Wave 1 (Prior Wave)",
    "SNAP_wave2":      "SNAP Coverage in Wave 2 (Most Recent Prior Wave)",
    "SNAP":            "Coverage for SNAP in Wave 3",
}

# ── Instructions ────────────────────────────────────────────────────────
INSTRUCTION_STRUCTURED = (
    "You are an expert text classifier. "
    "The Supplemental Nutrition Assistance Program (SNAP) provides food-purchasing "
    "assistance to low-income individuals and families in the U.S. "
    "You will be given a respondent's demographic information and income from "
    "Wave 3 of the 2014 Survey of Income and Program Participation (SIPP), "
    "along with whether they had SNAP coverage in Wave 1 (the prior survey wave) and in Wave 2 (the most recent prior survey wave)."
    "This Wave 1 and 2 SNAP status captures prior "
    "program participation and benefit receipt for that individual. "
    "Based on all this information, classify if the person has SNAP coverage in Wave 3. "
    "Return only one label: 'Yes' or 'No', without any other text.\n"
)

INSTRUCTION_NARRATIVE = (
    "You are an expert text classifier. "
    "The Supplemental Nutrition Assistance Program (SNAP) provides food assistance "
    "to low-income households in the U.S. "
    "You will read a short profile of a survey respondent from the 2014 Survey of "
    "Income and Program Participation (SIPP), Wave 3. "
    "The profile includes whether the respondent received SNAP in Wave 2 (the "
    "immediately preceding survey wave) and in Wave 1 (the prior wave before wave 2). "
    "Based on the full profile, decide whether this person has SNAP coverage in Wave 3. "
    "Return only one label: 'Yes' or 'No', without any other text.\n"
)

INSTRUCTION_MINIMAL = INSTRUCTION_STRUCTURED

# %% [markdown]
# ### Data Loading

# %%
df_train = pd.read_csv(TRAIN_PATH)
df_test  = pd.read_csv(TEST_PATH)

print(f"Train : {len(df_train):,} rows | SNAP distribution: {dict(Counter(df_train[LABEL]))}")
print(f"Test  : {len(df_test):,} rows  | SNAP distribution: {dict(Counter(df_test[LABEL]))}")

# Sanity-check that the longitudinal predictors are present
assert "SNAP_wave1" in df_train.columns, "SNAP_wave1 column missing from train_w3.csv"
assert "SNAP_wave1" in df_test.columns,  "SNAP_wave1 column missing from test_w3.csv"
print("\nSNAP_wave1 confirmed in both splits.")
print(f"Train SNAP_wave1 dist : {dict(Counter(df_train['SNAP_wave1']))}")
print(f"Test  SNAP_wave1 dist : {dict(Counter(df_test['SNAP_wave1']))}")

assert "SNAP_wave2" in df_train.columns, "SNAP_wave2 column missing from train_w3.csv"
assert "SNAP_wave2" in df_test.columns,  "SNAP_wave2 column missing from test_w3.csv"
print("\nSNAP_wave2 confirmed in both splits.")
print(f"Train SNAP_wave2 dist : {dict(Counter(df_train['SNAP_wave2']))}")
print(f"Test  SNAP_wave2 dist : {dict(Counter(df_test['SNAP_wave2']))}")
# Out:
# Train : 19,309 rows | SNAP distribution: {'No': 17120, 'Yes': 2189}
# Test  : 8,275 rows  | SNAP distribution: {'No': 7337, 'Yes': 938}
#
# SNAP_wave1 confirmed in both splits.
# Train SNAP_wave1 dist : {'No': 17210, 'Yes': 2099}
# Test  SNAP_wave1 dist : {'No': 7369, 'Yes': 906}
#
# SNAP_wave2 confirmed in both splits.
# Train SNAP_wave2 dist : {'No': 17101, 'Yes': 2208}
# Test  SNAP_wave2 dist : {'No': 7305, 'Yes': 970}

# %% [markdown]
# ### Oversampling

# %%
def oversample_minority(df, label_col, seed=SEED):
    majority = df[df[label_col] == "No"]
    minority = df[df[label_col] == "Yes"]
    minority_upsampled = minority.sample(
        n=len(majority), replace=True, random_state=seed
    )
    return pd.concat([majority, minority_upsampled]).sample(
        frac=1, random_state=seed
    ).reset_index(drop=True)

df_train_balanced = oversample_minority(df_train, LABEL)
print(f"\nBalanced train: {len(df_train_balanced):,} rows | "
      f"SNAP distribution: {dict(Counter(df_train_balanced[LABEL]))}")
# Out:
# Balanced train: 34,240 rows | SNAP distribution: {'Yes': 17120, 'No': 17120}

# %% [markdown]
# ### Prompt Builders

# %%
def build_structured_prompt(row, features, instruction=INSTRUCTION_STRUCTURED):
    user_content = "\n".join(
        f"{COL_MAP[k]}: {row[k]}" for k in features if k in row
    )
    return {
        "prompt":     [{"role": "system",    "content": instruction},
                       {"role": "user",      "content": user_content}],
        "completion": [{"role": "assistant", "content": str(row[LABEL])}],
    }


def build_narrative_prompt(row, features, instruction=INSTRUCTION_NARRATIVE):
    age        = row.get("age", "unknown age")
    sex        = row.get("sex", "").lower()
    hispanic   = row.get("hispanic.origin", "")
    race       = row.get("race", "")
    ethnicity  = f"{hispanic} {race}".strip()
    marital    = row.get("marital.status", "").lower()
    edu        = row.get("education", "").lower()
    employment = row.get("employment", "").lower()
    state      = row.get("state", "")
    income     = row.get("income", "")
    citizenship = row.get("citizenship", "").lower()
    snap_w1    = row.get("SNAP_wave1", "Unknown")
    snap_w2    = row.get("SNAP_wave2", "Unknown")

    narrative = (
        f"A {age}-year-old {ethnicity} {sex}, {marital}, residing in {state}. "
        f"Educational attainment: {edu}. "
        f"Citizenship: {citizenship}. "
        f"Employment in the reference month: {employment}. "
        f"Monthly household income (Wave 2): {income}. "
        f"SNAP coverage in Wave 1 (prior wave): {snap_w1}."
        f"SNAP coverage in Wave 2 (most recent prior wave): {snap_w2}."
    )
    return {
        "prompt":     [{"role": "system",    "content": instruction},
                       {"role": "user",      "content": narrative}],
        "completion": [{"role": "assistant", "content": str(row[LABEL])}],
    }


def make_dataset(df, prompt_fn, features):
    from datasets import Dataset
    records = [prompt_fn(row, features) for _, row in df.iterrows()]
    return Dataset.from_list(records)

# %% [markdown]
# ### Export to JSONL (MLX Format)

# %%
def export_to_jsonl(df, prompt_fn, features, path):
    with open(path, "w") as f:
        for _, row in df.iterrows():
            sample   = prompt_fn(row, features)
            messages = sample["prompt"] + sample["completion"]
            f.write(json.dumps({"messages": messages}) + "\n")


# Experiment matrix — same as Wave 1 and 2 structure T2A uses INCOME_FEATURES
# (demographics + income, no longitudinal predictor) T2C_longitudinal_model uses
# SNAP_wave1 and SNAP_wave2 only as features.
experiments_data = {
    "T1A_imbalanced":   (df_train,          build_structured_prompt, FULL_FEATURES,     FULL_FEATURES),
    "T1B_oversampled":  (df_train_balanced,  build_structured_prompt, FULL_FEATURES,     FULL_FEATURES),
    "T2A_demo_only":    (df_train,          build_structured_prompt, INCOME_FEATURES,     INCOME_FEATURES),
    "T2C_longitudinal_model":   (df_train,          build_structured_prompt, LONGITUDINAL_FEATURES,     LONGITUDINAL_FEATURES),
    "T3A_narrative":    (df_train,          build_narrative_prompt,  FULL_FEATURES,     FULL_FEATURES),
    "T3B_minimal":      (df_train,          build_structured_prompt, MINIMAL_FEATURES,  MINIMAL_FEATURES),
}

os.makedirs("./mlx_data", exist_ok=True)
for run_label, (train_df, prompt_fn, train_feats, val_feats) in experiments_data.items():
    folder = f"./mlx_data/{run_label}"
    os.makedirs(folder, exist_ok=True)
    export_to_jsonl(train_df, prompt_fn, train_feats, f"{folder}/train.jsonl")
    export_to_jsonl(df_test,  prompt_fn, val_feats,   f"{folder}/valid.jsonl")
    print(f"Exported {folder}/")
# Out:
# Exported ./mlx_data/T1A_imbalanced/
# Exported ./mlx_data/T1B_oversampled/
# Exported ./mlx_data/T2A_demo_only/
# Exported ./mlx_data/T2C_longitudinal_model/
# Exported ./mlx_data/T3A_narrative/
# Exported ./mlx_data/T3B_minimal/

# %% [markdown]
# ### Making Test Datasets

# %%
test_ds_structured_full     = make_dataset(df_test, build_structured_prompt, FULL_FEATURES)
test_ds_structured_demo     = make_dataset(df_test, build_structured_prompt, INCOME_FEATURES)
test_ds_structured_longitudinal  = make_dataset(df_test, build_structured_prompt, LONGITUDINAL_FEATURES)
test_ds_narrative_full      = make_dataset(df_test, build_narrative_prompt,  FULL_FEATURES)
test_ds_structured_minimal  = make_dataset(df_test, build_structured_prompt, MINIMAL_FEATURES)
print("Test datasets ready.")
# Out:
# Test datasets ready.

# %% [markdown]
# ### Defining Predictions

# %%
from sklearn.metrics import (
    accuracy_score, f1_score, precision_score,
    recall_score, classification_report
)

def evaluate_predictions(predictions, references, label_name=""):
    valid         = [(p, r) for p, r in zip(predictions, references) if p in ["Yes", "No"]]
    unknown_count = len(predictions) - len(valid)
    if not valid:
        print("No valid predictions.")
        return {}
    y_pred, y_true = zip(*valid)
    metrics = {
        "Label":     label_name,
        "N_test":    len(df_test),
        "Accuracy":  round(accuracy_score(y_true, y_pred), 4),
        "Recall":    round(recall_score(y_true, y_pred, pos_label="Yes"), 4),
        "Precision": round(precision_score(y_true, y_pred, pos_label="Yes", zero_division=0), 4),
        "F1":        round(f1_score(y_true, y_pred, pos_label="Yes"), 4),
        "Unknown":   unknown_count,
    }
    print(f"\n── {label_name} ──")
    for k, v in metrics.items():
        print(f"  {k}: {v}")
    print(classification_report(y_true, y_pred, zero_division=0))
    return metrics

# %% [markdown]
# ### Calibration Analytics

# %%
import matplotlib.pyplot as plt
from sklearn.calibration import calibration_curve

def calibration_analysis(probabilities, references, label_name, save_path):
    y_true_bin = [1 if r == "Yes" else 0 for r in references]
    probs      = np.array(probabilities)

    n_bins    = 10
    bin_edges = np.linspace(0, 1, n_bins + 1)
    ece       = 0.0
    for i in range(n_bins):
        mask = (probs >= bin_edges[i]) & (probs < bin_edges[i + 1])
        if mask.sum() == 0:
            continue
        bin_acc  = np.mean(np.array(y_true_bin)[mask])
        bin_conf = np.mean(probs[mask])
        ece += mask.sum() / len(probs) * abs(bin_acc - bin_conf)

    frac_pos, mean_pred = calibration_curve(y_true_bin, probs, n_bins=10)
    fig, ax = plt.subplots(figsize=(6, 6))
    ax.plot([0, 1], [0, 1], "k--", label="Perfect calibration")
    ax.plot(mean_pred, frac_pos, "s-", label=f"{label_name} (ECE={ece:.4f})")
    ax.set_xlabel("Mean predicted probability")
    ax.set_ylabel("Fraction of positives")
    ax.set_title(f"Reliability Diagram — {label_name}")
    ax.legend()
    plt.tight_layout()
    plt.savefig(save_path, dpi=150)
    plt.close()
    print(f"  ECE: {ece:.4f} | Saved → {save_path}")
    return round(ece, 4)

# %% [markdown]
# ### Run Inference Function

# %%
from mlx_lm import load, generate

def format_chat_prompt(prompt_list):
    return "".join(
        f"<|{m['role']}|>\n{m['content']}\n" for m in prompt_list
    ) + "<|assistant|>\n"


def run_inference_mlx(model, tokenizer, dataset, return_probs=False):
    predictions, references, probabilities = [], [], []

    for example in tqdm(dataset, desc="Generating"):
        prompt_text = format_chat_prompt(example["prompt"])
        response    = generate(
            model, tokenizer,
            prompt=prompt_text,
            max_tokens=5,
            verbose=False
        )
        match = re.search(r"\b(Yes|No)\b", response, re.IGNORECASE)
        predictions.append(match.group(1).title() if match else "Unknown")
        references.append(example["completion"][0]["content"].strip().title())

        if return_probs:
            if match:
                probabilities.append(1.0 if match.group(1).title() == "Yes" else 0.0)
            else:
                probabilities.append(0.5)

    if return_probs:
        return predictions, references, probabilities
    return predictions, references

# %% [markdown]
# ### LoRA Configuration

# %%
import yaml

lora_config = {
    "lora_parameters": {
        "rank":    16,
        "scale":   2.0,   # equivalent to alpha=32 with rank=16 (scale = alpha/rank)
        "dropout": 0.05,
    }
}

os.makedirs("./configs", exist_ok=True)
with open("./configs/lora_config.yaml", "w") as f:
    yaml.dump(lora_config, f)

print("LoRA config saved to ./configs/lora_config.yaml")
# Out:
# LoRA config saved to ./configs/lora_config.yaml

# %% [markdown]
# ### Training and Inference for T1A_imbalanced

# %%
# !mlx_lm.lora \
  --model mlx-community/Qwen2.5-1.5B-Instruct-4bit \
  --train \
  --data ./mlx_data/T1A_imbalanced \
  --num-layers 16 \
  --batch-size 4 \
  --grad-accumulation-steps 4 \
  --iters 2000 \
  --learning-rate 2e-4 \
  --mask-prompt \
  --adapter-path ./adapters_w3/T1A_imbalanced \
  --save-every 500 \
  -c ./configs/lora_config.yaml
# Out:
# Loading configuration file ./configs/lora_config.yaml
# Loading pretrained model
# Downloading (incomplete total...): 0.00B [00:00, ?B/s]
# Fetching 9 files: 100%|████████████████████████| 9/9 [00:00<00:00, 52356.08it/s]
# Download complete: : 0.00B [00:00, ?B/s]
# Loading datasets
# Training
# Trainable parameters: 0.684% (10.551M/1543.714M)
# Starting training..., iters: 2000
# Calculating loss...: 100%|██████████████████████| 25/25 [00:24<00:00,  1.01it/s]
# Iter 1: Val loss 7.539, Val took 24.648s
# Iter 10: Train loss 3.652, Learning Rate 2.000e-04, It/sec 0.504, Tokens/sec 8.065, Trained Tokens 160, Peak mem 6.848 GB
# Iter 20: Train loss 0.171, Learning Rate 2.000e-04, It/sec 0.519, Tokens/sec 8.304, Trained Tokens 320, Peak mem 6.848 GB
# Iter 30: Train loss 0.048, Learning Rate 2.000e-04, It/sec 0.526, Tokens/sec 8.421, Trained Tokens 480, Peak mem 6.848 GB
# Iter 40: Train loss 0.069, Learning Rate 2.000e-04, It/sec 0.519, Tokens/sec 8.302, Trained Tokens 640, Peak mem 6.848 GB
# Iter 50: Train loss 0.020, Learning Rate 2.000e-04, It/sec 0.536, Tokens/sec 8.577, Trained Tokens 800, Peak mem 6.848 GB
# Iter 60: Train loss 0.060, Learning Rate 2.000e-04, It/sec 0.531, Tokens/sec 8.492, Trained Tokens 960, Peak mem 6.848 GB
# Iter 70: Train loss 0.052, Learning Rate 2.000e-04, It/sec 0.537, Tokens/sec 8.595, Trained Tokens 1120, Peak mem 6.848 GB
# Iter 80: Train loss 0.055, Learning Rate 2.000e-04, It/sec 0.537, Tokens/sec 8.587, Trained Tokens 1280, Peak mem 6.848 GB
# Iter 90: Train loss 0.084, Learning Rate 2.000e-04, It/sec 0.532, Tokens/sec 8.506, Trained Tokens 1440, Peak mem 6.848 GB
# Iter 100: Train loss 0.094, Learning Rate 2.000e-04, It/sec 0.532, Tokens/sec 8.513, Trained Tokens 1600, Peak mem 6.848 GB
# Iter 110: Train loss 0.033, Learning Rate 2.000e-04, It/sec 0.515, Tokens/sec 8.232, Trained Tokens 1760, Peak mem 6.848 GB
# Iter 120: Train loss 0.035, Learning Rate 2.000e-04, It/sec 0.533, Tokens/sec 8.521, Trained Tokens 1920, Peak mem 6.848 GB
# Iter 130: Train loss 0.070, Learning Rate 2.000e-04, It/sec 0.518, Tokens/sec 8.295, Trained Tokens 2080, Peak mem 6.848 GB
# Iter 140: Train loss 0.082, Learning Rate 2.000e-04, It/sec 0.530, Tokens/sec 8.482, Trained Tokens 2240, Peak mem 6.848 GB
# Iter 150: Train loss 0.078, Learning Rate 2.000e-04, It/sec 0.525, Tokens/sec 8.395, Trained Tokens 2400, Peak mem 6.848 GB
# Iter 160: Train loss 0.038, Learning Rate 2.000e-04, It/sec 0.519, Tokens/sec 8.301, Trained Tokens 2560, Peak mem 6.848 GB
# Iter 170: Train loss 0.050, Learning Rate 2.000e-04, It/sec 0.526, Tokens/sec 8.409, Trained Tokens 2720, Peak mem 6.848 GB
# Iter 180: Train loss 0.077, Learning Rate 2.000e-04, It/sec 0.514, Tokens/sec 8.231, Trained Tokens 2880, Peak mem 6.848 GB
# Iter 190: Train loss 0.064, Learning Rate 2.000e-04, It/sec 0.534, Tokens/sec 8.540, Trained Tokens 3040, Peak mem 6.848 GB
# Calculating loss...: 100%|██████████████████████| 25/25 [00:24<00:00,  1.01it/s]
# Iter 200: Val loss 0.047, Val took 24.749s
# Iter 200: Train loss 0.030, Learning Rate 2.000e-04, It/sec 0.542, Tokens/sec 8.674, Trained Tokens 3200, Peak mem 6.848 GB
# Iter 210: Train loss 0.048, Learning Rate 2.000e-04, It/sec 0.531, Tokens/sec 8.493, Trained Tokens 3360, Peak mem 6.848 GB
# Iter 220: Train loss 0.073, Learning Rate 2.000e-04, It/sec 0.525, Tokens/sec 8.403, Trained Tokens 3520, Peak mem 6.848 GB
# Iter 230: Train loss 0.035, Learning Rate 2.000e-04, It/sec 0.542, Tokens/sec 8.670, Trained Tokens 3680, Peak mem 6.848 GB
# Iter 240: Train loss 0.007, Learning Rate 2.000e-04, It/sec 0.531, Tokens/sec 8.503, Trained Tokens 3840, Peak mem 6.848 GB
# Iter 250: Train loss 0.034, Learning Rate 2.000e-04, It/sec 0.536, Tokens/sec 8.581, Trained Tokens 4000, Peak mem 6.848 GB
# Iter 260: Train loss 0.008, Learning Rate 2.000e-04, It/sec 0.524, Tokens/sec 8.384, Trained Tokens 4160, Peak mem 6.848 GB
# Iter 270: Train loss 0.006, Learning Rate 2.000e-04, It/sec 0.524, Tokens/sec 8.387, Trained Tokens 4320, Peak mem 6.848 GB
# Iter 280: Train loss 0.016, Learning Rate 2.000e-04, It/sec 0.523, Tokens/sec 8.366, Trained Tokens 4480, Peak mem 6.848 GB
# Iter 290: Train loss 0.114, Learning Rate 2.000e-04, It/sec 0.512, Tokens/sec 8.196, Trained Tokens 4640, Peak mem 6.848 GB
# Iter 300: Train loss 0.048, Learning Rate 2.000e-04, It/sec 0.518, Tokens/sec 8.289, Trained Tokens 4800, Peak mem 6.848 GB
# Iter 310: Train loss 0.073, Learning Rate 2.000e-04, It/sec 0.534, Tokens/sec 8.550, Trained Tokens 4960, Peak mem 6.848 GB
# Iter 320: Train loss 0.065, Learning Rate 2.000e-04, It/sec 0.524, Tokens/sec 8.391, Trained Tokens 5120, Peak mem 6.848 GB
# Iter 330: Train loss 0.030, Learning Rate 2.000e-04, It/sec 0.518, Tokens/sec 8.290, Trained Tokens 5280, Peak mem 6.848 GB
# Iter 340: Train loss 0.045, Learning Rate 2.000e-04, It/sec 0.530, Tokens/sec 8.484, Trained Tokens 5440, Peak mem 6.848 GB
# Iter 350: Train loss 0.026, Learning Rate 2.000e-04, It/sec 0.531, Tokens/sec 8.491, Trained Tokens 5600, Peak mem 6.848 GB
# Iter 360: Train loss 0.055, Learning Rate 2.000e-04, It/sec 0.526, Tokens/sec 8.414, Trained Tokens 5760, Peak mem 6.848 GB
# Iter 370: Train loss 0.013, Learning Rate 2.000e-04, It/sec 0.537, Tokens/sec 8.592, Trained Tokens 5920, Peak mem 6.848 GB
# Iter 380: Train loss 0.015, Learning Rate 2.000e-04, It/sec 0.544, Tokens/sec 8.705, Trained Tokens 6080, Peak mem 6.848 GB
# Iter 390: Train loss 0.007, Learning Rate 2.000e-04, It/sec 0.525, Tokens/sec 8.397, Trained Tokens 6240, Peak mem 6.848 GB
# Calculating loss...: 100%|██████████████████████| 25/25 [00:24<00:00,  1.03it/s]
# Iter 400: Val loss 0.053, Val took 24.300s
# Iter 400: Train loss 0.015, Learning Rate 2.000e-04, It/sec 0.526, Tokens/sec 8.414, Trained Tokens 6400, Peak mem 6.848 GB
# Iter 410: Train loss 0.018, Learning Rate 2.000e-04, It/sec 0.532, Tokens/sec 8.512, Trained Tokens 6560, Peak mem 6.848 GB
# Iter 420: Train loss 0.032, Learning Rate 2.000e-04, It/sec 0.520, Tokens/sec 8.323, Trained Tokens 6720, Peak mem 6.848 GB
# Iter 430: Train loss 0.003, Learning Rate 2.000e-04, It/sec 0.537, Tokens/sec 8.599, Trained Tokens 6880, Peak mem 6.848 GB
# Iter 440: Train loss 0.110, Learning Rate 2.000e-04, It/sec 0.531, Tokens/sec 8.492, Trained Tokens 7040, Peak mem 6.848 GB
# Iter 450: Train loss 0.021, Learning Rate 2.000e-04, It/sec 0.514, Tokens/sec 8.231, Trained Tokens 7200, Peak mem 6.848 GB
# Iter 460: Train loss 0.044, Learning Rate 2.000e-04, It/sec 0.531, Tokens/sec 8.504, Trained Tokens 7360, Peak mem 6.848 GB
# Iter 470: Train loss 0.022, Learning Rate 2.000e-04, It/sec 0.531, Tokens/sec 8.491, Trained Tokens 7520, Peak mem 6.848 GB
# Iter 480: Train loss 0.030, Learning Rate 2.000e-04, It/sec 0.526, Tokens/sec 8.416, Trained Tokens 7680, Peak mem 6.848 GB
# Iter 490: Train loss 0.007, Learning Rate 2.000e-04, It/sec 0.520, Tokens/sec 8.324, Trained Tokens 7840, Peak mem 6.848 GB
# Iter 500: Train loss 0.020, Learning Rate 2.000e-04, It/sec 0.531, Tokens/sec 8.489, Trained Tokens 8000, Peak mem 6.848 GB
# Iter 500: Saved adapter weights to adapters_w3/T1A_imbalanced/adapters.safetensors and adapters_w3/T1A_imbalanced/0000500_adapters.safetensors.
# Iter 510: Train loss 0.016, Learning Rate 2.000e-04, It/sec 0.514, Tokens/sec 8.226, Trained Tokens 8160, Peak mem 6.891 GB
# Iter 520: Train loss 0.004, Learning Rate 2.000e-04, It/sec 0.509, Tokens/sec 8.142, Trained Tokens 8320, Peak mem 6.891 GB
# Iter 530: Train loss 0.014, Learning Rate 2.000e-04, It/sec 0.538, Tokens/sec 8.609, Trained Tokens 8480, Peak mem 6.891 GB
# Iter 540: Train loss 0.086, Learning Rate 2.000e-04, It/sec 0.526, Tokens/sec 8.411, Trained Tokens 8640, Peak mem 6.891 GB
# Iter 550: Train loss 0.055, Learning Rate 2.000e-04, It/sec 0.520, Tokens/sec 8.317, Trained Tokens 8800, Peak mem 6.891 GB
# Iter 560: Train loss 0.089, Learning Rate 2.000e-04, It/sec 0.531, Tokens/sec 8.498, Trained Tokens 8960, Peak mem 6.891 GB
# Iter 570: Train loss 0.046, Learning Rate 2.000e-04, It/sec 0.520, Tokens/sec 8.325, Trained Tokens 9120, Peak mem 6.891 GB
# Iter 580: Train loss 0.019, Learning Rate 2.000e-04, It/sec 0.526, Tokens/sec 8.413, Trained Tokens 9280, Peak mem 6.891 GB
# Iter 590: Train loss 0.034, Learning Rate 2.000e-04, It/sec 0.531, Tokens/sec 8.503, Trained Tokens 9440, Peak mem 6.891 GB
# Calculating loss...: 100%|██████████████████████| 25/25 [00:24<00:00,  1.02it/s]
# Iter 600: Val loss 0.036, Val took 24.457s
# Iter 600: Train loss 0.058, Learning Rate 2.000e-04, It/sec 0.536, Tokens/sec 8.582, Trained Tokens 9600, Peak mem 6.891 GB
# Iter 610: Train loss 0.036, Learning Rate 2.000e-04, It/sec 0.536, Tokens/sec 8.579, Trained Tokens 9760, Peak mem 6.891 GB
# Iter 620: Train loss 0.052, Learning Rate 2.000e-04, It/sec 0.525, Tokens/sec 8.401, Trained Tokens 9920, Peak mem 6.891 GB
# Iter 630: Train loss 0.021, Learning Rate 2.000e-04, It/sec 0.525, Tokens/sec 8.407, Trained Tokens 10080, Peak mem 6.891 GB
# Iter 640: Train loss 0.073, Learning Rate 2.000e-04, It/sec 0.536, Tokens/sec 8.578, Trained Tokens 10240, Peak mem 6.891 GB
# Iter 650: Train loss 0.074, Learning Rate 2.000e-04, It/sec 0.537, Tokens/sec 8.587, Trained Tokens 10400, Peak mem 6.891 GB
# Iter 660: Train loss 0.015, Learning Rate 2.000e-04, It/sec 0.537, Tokens/sec 8.590, Trained Tokens 10560, Peak mem 6.891 GB
# Iter 670: Train loss 0.033, Learning Rate 2.000e-04, It/sec 0.525, Tokens/sec 8.406, Trained Tokens 10720, Peak mem 6.891 GB
# Iter 680: Train loss 0.032, Learning Rate 2.000e-04, It/sec 0.537, Tokens/sec 8.593, Trained Tokens 10880, Peak mem 6.891 GB
# Iter 690: Train loss 0.037, Learning Rate 2.000e-04, It/sec 0.543, Tokens/sec 8.684, Trained Tokens 11040, Peak mem 6.891 GB
# Iter 700: Train loss 0.086, Learning Rate 2.000e-04, It/sec 0.542, Tokens/sec 8.678, Trained Tokens 11200, Peak mem 6.891 GB
# Iter 710: Train loss 0.007, Learning Rate 2.000e-04, It/sec 0.538, Tokens/sec 8.600, Trained Tokens 11360, Peak mem 6.891 GB
# Iter 720: Train loss 0.012, Learning Rate 2.000e-04, It/sec 0.526, Tokens/sec 8.413, Trained Tokens 11520, Peak mem 6.891 GB
# Iter 730: Train loss 0.048, Learning Rate 2.000e-04, It/sec 0.532, Tokens/sec 8.509, Trained Tokens 11680, Peak mem 6.891 GB
# Iter 740: Train loss 0.008, Learning Rate 2.000e-04, It/sec 0.539, Tokens/sec 8.618, Trained Tokens 11840, Peak mem 6.891 GB
# Iter 750: Train loss 0.006, Learning Rate 2.000e-04, It/sec 0.526, Tokens/sec 8.409, Trained Tokens 12000, Peak mem 6.891 GB
# Iter 760: Train loss 0.060, Learning Rate 2.000e-04, It/sec 0.532, Tokens/sec 8.505, Trained Tokens 12160, Peak mem 6.891 GB
# Iter 770: Train loss 0.044, Learning Rate 2.000e-04, It/sec 0.538, Tokens/sec 8.603, Trained Tokens 12320, Peak mem 6.891 GB
# Iter 780: Train loss 0.018, Learning Rate 2.000e-04, It/sec 0.525, Tokens/sec 8.398, Trained Tokens 12480, Peak mem 6.891 GB
# Iter 790: Train loss 0.005, Learning Rate 2.000e-04, It/sec 0.526, Tokens/sec 8.417, Trained Tokens 12640, Peak mem 6.891 GB
# Calculating loss...: 100%|██████████████████████| 25/25 [00:24<00:00,  1.02it/s]
# Iter 800: Val loss 0.023, Val took 24.447s
# Iter 800: Train loss 0.057, Learning Rate 2.000e-04, It/sec 0.537, Tokens/sec 8.590, Trained Tokens 12800, Peak mem 6.891 GB
# Iter 810: Train loss 0.025, Learning Rate 2.000e-04, It/sec 0.524, Tokens/sec 8.389, Trained Tokens 12960, Peak mem 6.891 GB
# Iter 820: Train loss 0.016, Learning Rate 2.000e-04, It/sec 0.521, Tokens/sec 8.332, Trained Tokens 13120, Peak mem 6.891 GB
# Iter 830: Train loss 0.051, Learning Rate 2.000e-04, It/sec 0.526, Tokens/sec 8.415, Trained Tokens 13280, Peak mem 6.891 GB
# Iter 840: Train loss 0.043, Learning Rate 2.000e-04, It/sec 0.543, Tokens/sec 8.688, Trained Tokens 13440, Peak mem 6.891 GB
# Iter 850: Train loss 0.021, Learning Rate 2.000e-04, It/sec 0.520, Tokens/sec 8.322, Trained Tokens 13600, Peak mem 6.891 GB
# Iter 860: Train loss 0.056, Learning Rate 2.000e-04, It/sec 0.524, Tokens/sec 8.392, Trained Tokens 13760, Peak mem 6.891 GB
# Iter 870: Train loss 0.033, Learning Rate 2.000e-04, It/sec 0.537, Tokens/sec 8.597, Trained Tokens 13920, Peak mem 6.891 GB
# Iter 880: Train loss 0.023, Learning Rate 2.000e-04, It/sec 0.523, Tokens/sec 8.375, Trained Tokens 14080, Peak mem 6.891 GB
# Iter 890: Train loss 0.032, Learning Rate 2.000e-04, It/sec 0.538, Tokens/sec 8.605, Trained Tokens 14240, Peak mem 6.891 GB
# Iter 900: Train loss 0.076, Learning Rate 2.000e-04, It/sec 0.531, Tokens/sec 8.502, Trained Tokens 14400, Peak mem 6.891 GB
# Iter 910: Train loss 0.039, Learning Rate 2.000e-04, It/sec 0.543, Tokens/sec 8.691, Trained Tokens 14560, Peak mem 6.891 GB
# Iter 920: Train loss 0.011, Learning Rate 2.000e-04, It/sec 0.515, Tokens/sec 8.243, Trained Tokens 14720, Peak mem 6.891 GB
# Iter 930: Train loss 0.043, Learning Rate 2.000e-04, It/sec 0.520, Tokens/sec 8.318, Trained Tokens 14880, Peak mem 6.891 GB
# Iter 940: Train loss 0.031, Learning Rate 2.000e-04, It/sec 0.543, Tokens/sec 8.690, Trained Tokens 15040, Peak mem 6.891 GB
# Iter 950: Train loss 0.067, Learning Rate 2.000e-04, It/sec 0.531, Tokens/sec 8.493, Trained Tokens 15200, Peak mem 6.891 GB
# Iter 960: Train loss 0.025, Learning Rate 2.000e-04, It/sec 0.532, Tokens/sec 8.512, Trained Tokens 15360, Peak mem 6.891 GB
# Iter 970: Train loss 0.009, Learning Rate 2.000e-04, It/sec 0.538, Tokens/sec 8.614, Trained Tokens 15520, Peak mem 6.891 GB
# Iter 980: Train loss 0.040, Learning Rate 2.000e-04, It/sec 0.520, Tokens/sec 8.325, Trained Tokens 15680, Peak mem 6.891 GB
# Iter 990: Train loss 0.085, Learning Rate 2.000e-04, It/sec 0.544, Tokens/sec 8.708, Trained Tokens 15840, Peak mem 6.891 GB
# Calculating loss...: 100%|██████████████████████| 25/25 [00:24<00:00,  1.03it/s]
# Iter 1000: Val loss 0.049, Val took 24.290s
# Iter 1000: Train loss 0.014, Learning Rate 2.000e-04, It/sec 0.519, Tokens/sec 8.308, Trained Tokens 16000, Peak mem 6.891 GB
# Iter 1000: Saved adapter weights to adapters_w3/T1A_imbalanced/adapters.safetensors and adapters_w3/T1A_imbalanced/0001000_adapters.safetensors.
# Iter 1010: Train loss 0.026, Learning Rate 2.000e-04, It/sec 0.537, Tokens/sec 8.593, Trained Tokens 16160, Peak mem 6.891 GB
# Iter 1020: Train loss 0.023, Learning Rate 2.000e-04, It/sec 0.515, Tokens/sec 8.246, Trained Tokens 16320, Peak mem 6.891 GB
# Iter 1030: Train loss 0.064, Learning Rate 2.000e-04, It/sec 0.520, Tokens/sec 8.325, Trained Tokens 16480, Peak mem 6.891 GB
# Iter 1040: Train loss 0.029, Learning Rate 2.000e-04, It/sec 0.543, Tokens/sec 8.692, Trained Tokens 16640, Peak mem 6.891 GB
# Iter 1050: Train loss 0.042, Learning Rate 2.000e-04, It/sec 0.525, Tokens/sec 8.405, Trained Tokens 16800, Peak mem 6.891 GB
# Iter 1060: Train loss 0.013, Learning Rate 2.000e-04, It/sec 0.531, Tokens/sec 8.500, Trained Tokens 16960, Peak mem 6.891 GB
# Iter 1070: Train loss 0.073, Learning Rate 2.000e-04, It/sec 0.538, Tokens/sec 8.607, Trained Tokens 17120, Peak mem 6.891 GB
# Iter 1080: Train loss 0.060, Learning Rate 2.000e-04, It/sec 0.526, Tokens/sec 8.410, Trained Tokens 17280, Peak mem 6.891 GB
# Iter 1090: Train loss 0.037, Learning Rate 2.000e-04, It/sec 0.532, Tokens/sec 8.508, Trained Tokens 17440, Peak mem 6.891 GB
# Iter 1100: Train loss 0.017, Learning Rate 2.000e-04, It/sec 0.531, Tokens/sec 8.501, Trained Tokens 17600, Peak mem 6.891 GB
# Iter 1110: Train loss 0.009, Learning Rate 2.000e-04, It/sec 0.526, Tokens/sec 8.411, Trained Tokens 17760, Peak mem 6.891 GB
# Iter 1120: Train loss 0.001, Learning Rate 2.000e-04, It/sec 0.525, Tokens/sec 8.407, Trained Tokens 17920, Peak mem 6.891 GB
# Iter 1130: Train loss 0.036, Learning Rate 2.000e-04, It/sec 0.531, Tokens/sec 8.495, Trained Tokens 18080, Peak mem 6.891 GB
# Iter 1140: Train loss 0.080, Learning Rate 2.000e-04, It/sec 0.526, Tokens/sec 8.409, Trained Tokens 18240, Peak mem 6.891 GB
# Iter 1150: Train loss 0.038, Learning Rate 2.000e-04, It/sec 0.527, Tokens/sec 8.434, Trained Tokens 18400, Peak mem 6.891 GB
# Iter 1160: Train loss 0.010, Learning Rate 2.000e-04, It/sec 0.532, Tokens/sec 8.511, Trained Tokens 18560, Peak mem 6.891 GB
# Iter 1170: Train loss 0.011, Learning Rate 2.000e-04, It/sec 0.521, Tokens/sec 8.330, Trained Tokens 18720, Peak mem 6.891 GB
# Iter 1180: Train loss 0.008, Learning Rate 2.000e-04, It/sec 0.526, Tokens/sec 8.413, Trained Tokens 18880, Peak mem 6.891 GB
# Iter 1190: Train loss 0.017, Learning Rate 2.000e-04, It/sec 0.527, Tokens/sec 8.425, Trained Tokens 19040, Peak mem 6.891 GB
# Calculating loss...: 100%|██████████████████████| 25/25 [00:24<00:00,  1.03it/s]
# Iter 1200: Val loss 0.025, Val took 24.395s
# Iter 1200: Train loss 0.064, Learning Rate 2.000e-04, It/sec 0.524, Tokens/sec 8.392, Trained Tokens 19200, Peak mem 6.891 GB
# Iter 1210: Train loss 0.047, Learning Rate 2.000e-04, It/sec 0.519, Tokens/sec 8.307, Trained Tokens 19360, Peak mem 6.891 GB
# Iter 1220: Train loss 0.070, Learning Rate 2.000e-04, It/sec 0.525, Tokens/sec 8.405, Trained Tokens 19520, Peak mem 6.891 GB
# Iter 1230: Train loss 0.036, Learning Rate 2.000e-04, It/sec 0.520, Tokens/sec 8.319, Trained Tokens 19680, Peak mem 6.891 GB
# Iter 1240: Train loss 0.025, Learning Rate 2.000e-04, It/sec 0.504, Tokens/sec 8.060, Trained Tokens 19840, Peak mem 6.891 GB
# Iter 1250: Train loss 0.088, Learning Rate 2.000e-04, It/sec 0.532, Tokens/sec 8.509, Trained Tokens 20000, Peak mem 6.891 GB
# Iter 1260: Train loss 0.017, Learning Rate 2.000e-04, It/sec 0.520, Tokens/sec 8.315, Trained Tokens 20160, Peak mem 6.891 GB
# Iter 1270: Train loss 0.018, Learning Rate 2.000e-04, It/sec 0.533, Tokens/sec 8.521, Trained Tokens 20320, Peak mem 6.891 GB
# Iter 1280: Train loss 0.046, Learning Rate 2.000e-04, It/sec 0.531, Tokens/sec 8.502, Trained Tokens 20480, Peak mem 6.891 GB
# Iter 1290: Train loss 0.006, Learning Rate 2.000e-04, It/sec 0.533, Tokens/sec 8.522, Trained Tokens 20640, Peak mem 6.891 GB
# Iter 1300: Train loss 0.044, Learning Rate 2.000e-04, It/sec 0.538, Tokens/sec 8.609, Trained Tokens 20800, Peak mem 6.891 GB
# Iter 1310: Train loss 0.074, Learning Rate 2.000e-04, It/sec 0.520, Tokens/sec 8.316, Trained Tokens 20960, Peak mem 6.891 GB
# Iter 1320: Train loss 0.026, Learning Rate 2.000e-04, It/sec 0.515, Tokens/sec 8.239, Trained Tokens 21120, Peak mem 6.891 GB
# Iter 1330: Train loss 0.008, Learning Rate 2.000e-04, It/sec 0.526, Tokens/sec 8.411, Trained Tokens 21280, Peak mem 6.891 GB
# Iter 1340: Train loss 0.036, Learning Rate 2.000e-04, It/sec 0.544, Tokens/sec 8.708, Trained Tokens 21440, Peak mem 6.891 GB
# Iter 1350: Train loss 0.006, Learning Rate 2.000e-04, It/sec 0.524, Tokens/sec 8.392, Trained Tokens 21600, Peak mem 6.891 GB
# Iter 1360: Train loss 0.007, Learning Rate 2.000e-04, It/sec 0.525, Tokens/sec 8.405, Trained Tokens 21760, Peak mem 6.891 GB
# Iter 1370: Train loss 0.024, Learning Rate 2.000e-04, It/sec 0.531, Tokens/sec 8.488, Trained Tokens 21920, Peak mem 6.891 GB
# Iter 1380: Train loss 0.008, Learning Rate 2.000e-04, It/sec 0.531, Tokens/sec 8.502, Trained Tokens 22080, Peak mem 6.891 GB
# Iter 1390: Train loss 0.061, Learning Rate 2.000e-04, It/sec 0.533, Tokens/sec 8.523, Trained Tokens 22240, Peak mem 6.891 GB
# Calculating loss...: 100%|██████████████████████| 25/25 [00:24<00:00,  1.02it/s]
# Iter 1400: Val loss 0.025, Val took 24.600s
# Iter 1400: Train loss 0.004, Learning Rate 2.000e-04, It/sec 0.536, Tokens/sec 8.575, Trained Tokens 22400, Peak mem 6.891 GB
# Iter 1410: Train loss 0.022, Learning Rate 2.000e-04, It/sec 0.520, Tokens/sec 8.317, Trained Tokens 22560, Peak mem 6.891 GB
# Iter 1420: Train loss 0.088, Learning Rate 2.000e-04, It/sec 0.526, Tokens/sec 8.411, Trained Tokens 22720, Peak mem 6.891 GB
# Iter 1430: Train loss 0.042, Learning Rate 2.000e-04, It/sec 0.531, Tokens/sec 8.501, Trained Tokens 22880, Peak mem 6.891 GB
# Iter 1440: Train loss 0.027, Learning Rate 2.000e-04, It/sec 0.536, Tokens/sec 8.574, Trained Tokens 23040, Peak mem 6.891 GB
# Iter 1450: Train loss 0.008, Learning Rate 2.000e-04, It/sec 0.531, Tokens/sec 8.498, Trained Tokens 23200, Peak mem 6.891 GB
# Iter 1460: Train loss 0.015, Learning Rate 2.000e-04, It/sec 0.528, Tokens/sec 8.451, Trained Tokens 23360, Peak mem 6.891 GB
# Iter 1470: Train loss 0.015, Learning Rate 2.000e-04, It/sec 0.538, Tokens/sec 8.608, Trained Tokens 23520, Peak mem 6.891 GB
# Iter 1480: Train loss 0.028, Learning Rate 2.000e-04, It/sec 0.538, Tokens/sec 8.602, Trained Tokens 23680, Peak mem 6.891 GB
# Iter 1490: Train loss 0.133, Learning Rate 2.000e-04, It/sec 0.527, Tokens/sec 8.425, Trained Tokens 23840, Peak mem 6.891 GB
# Iter 1500: Train loss 0.022, Learning Rate 2.000e-04, It/sec 0.531, Tokens/sec 8.500, Trained Tokens 24000, Peak mem 6.891 GB
# Iter 1500: Saved adapter weights to adapters_w3/T1A_imbalanced/adapters.safetensors and adapters_w3/T1A_imbalanced/0001500_adapters.safetensors.
# Iter 1510: Train loss 0.033, Learning Rate 2.000e-04, It/sec 0.528, Tokens/sec 8.453, Trained Tokens 24160, Peak mem 6.891 GB
# Iter 1520: Train loss 0.052, Learning Rate 2.000e-04, It/sec 0.536, Tokens/sec 8.583, Trained Tokens 24320, Peak mem 6.891 GB
# Iter 1530: Train loss 0.022, Learning Rate 2.000e-04, It/sec 0.532, Tokens/sec 8.511, Trained Tokens 24480, Peak mem 6.891 GB
# Iter 1540: Train loss 0.009, Learning Rate 2.000e-04, It/sec 0.536, Tokens/sec 8.584, Trained Tokens 24640, Peak mem 6.891 GB
# Iter 1550: Train loss 0.028, Learning Rate 2.000e-04, It/sec 0.538, Tokens/sec 8.607, Trained Tokens 24800, Peak mem 6.891 GB
# Iter 1560: Train loss 0.106, Learning Rate 2.000e-04, It/sec 0.532, Tokens/sec 8.505, Trained Tokens 24960, Peak mem 6.891 GB
# Iter 1570: Train loss 0.074, Learning Rate 2.000e-04, It/sec 0.526, Tokens/sec 8.422, Trained Tokens 25120, Peak mem 6.891 GB
# Iter 1580: Train loss 0.031, Learning Rate 2.000e-04, It/sec 0.530, Tokens/sec 8.487, Trained Tokens 25280, Peak mem 6.891 GB
# Iter 1590: Train loss 0.028, Learning Rate 2.000e-04, It/sec 0.525, Tokens/sec 8.404, Trained Tokens 25440, Peak mem 6.891 GB
# Calculating loss...: 100%|██████████████████████| 25/25 [00:24<00:00,  1.02it/s]
# Iter 1600: Val loss 0.029, Val took 24.543s
# Iter 1600: Train loss 0.018, Learning Rate 2.000e-04, It/sec 0.532, Tokens/sec 8.520, Trained Tokens 25600, Peak mem 6.891 GB
# Iter 1610: Train loss 0.090, Learning Rate 2.000e-04, It/sec 0.531, Tokens/sec 8.498, Trained Tokens 25760, Peak mem 6.891 GB
# Iter 1620: Train loss 0.019, Learning Rate 2.000e-04, It/sec 0.526, Tokens/sec 8.414, Trained Tokens 25920, Peak mem 6.891 GB
# Iter 1630: Train loss 0.070, Learning Rate 2.000e-04, It/sec 0.510, Tokens/sec 8.161, Trained Tokens 26080, Peak mem 6.891 GB
# Iter 1640: Train loss 0.037, Learning Rate 2.000e-04, It/sec 0.537, Tokens/sec 8.592, Trained Tokens 26240, Peak mem 6.891 GB
# Iter 1650: Train loss 0.012, Learning Rate 2.000e-04, It/sec 0.509, Tokens/sec 8.140, Trained Tokens 26400, Peak mem 6.891 GB
# Iter 1660: Train loss 0.011, Learning Rate 2.000e-04, It/sec 0.508, Tokens/sec 8.130, Trained Tokens 26560, Peak mem 6.891 GB
# Iter 1670: Train loss 0.040, Learning Rate 2.000e-04, It/sec 0.531, Tokens/sec 8.494, Trained Tokens 26720, Peak mem 6.891 GB
# Iter 1680: Train loss 0.010, Learning Rate 2.000e-04, It/sec 0.537, Tokens/sec 8.594, Trained Tokens 26880, Peak mem 6.891 GB
# Iter 1690: Train loss 0.023, Learning Rate 2.000e-04, It/sec 0.519, Tokens/sec 8.303, Trained Tokens 27040, Peak mem 6.891 GB
# Iter 1700: Train loss 0.021, Learning Rate 2.000e-04, It/sec 0.532, Tokens/sec 8.504, Trained Tokens 27200, Peak mem 6.891 GB
# Iter 1710: Train loss 0.028, Learning Rate 2.000e-04, It/sec 0.500, Tokens/sec 7.996, Trained Tokens 27360, Peak mem 6.891 GB
# Iter 1720: Train loss 0.101, Learning Rate 2.000e-04, It/sec 0.536, Tokens/sec 8.568, Trained Tokens 27520, Peak mem 6.891 GB
# Iter 1730: Train loss 0.012, Learning Rate 2.000e-04, It/sec 0.520, Tokens/sec 8.319, Trained Tokens 27680, Peak mem 6.891 GB
# Iter 1740: Train loss 0.018, Learning Rate 2.000e-04, It/sec 0.516, Tokens/sec 8.254, Trained Tokens 27840, Peak mem 6.891 GB
# Iter 1750: Train loss 0.009, Learning Rate 2.000e-04, It/sec 0.528, Tokens/sec 8.455, Trained Tokens 28000, Peak mem 6.891 GB
# Iter 1760: Train loss 0.130, Learning Rate 2.000e-04, It/sec 0.534, Tokens/sec 8.536, Trained Tokens 28160, Peak mem 6.891 GB

# %%
import time
# ── Initialise accumulators on first experiment ──────────────────
all_metrics      = []
experiment_times = {}

# ── Load model with T1A_imbalanced adapter ──────────────────────────────
model_mlx, tok_mlx = load(
    MODEL_ID,
    adapter_path="./adapters_w3/T1A_imbalanced",
)

# ── Inference ──────────────────────────────────────────────────────
t0 = time.time()
preds, refs, probs = run_inference_mlx(
    model_mlx, tok_mlx, test_ds_structured_full, return_probs=True
)

# ── Evaluate ───────────────────────────────────────────────────────
metrics = evaluate_predictions(preds, refs, label_name="T1A_imbalanced")

# ── Calibration ────────────────────────────────────────────────────
ece = calibration_analysis(
    probs, refs,
    label_name="T1A_imbalanced",
    save_path=os.path.join(OUTPUT_DIR, "calibration_T1A_imbalanced.png")
)
metrics["ECE"] = ece
all_metrics.append(metrics)

# ── Save predictions ───────────────────────────────────────────────
out_df = pd.DataFrame({"Predicted_Label": preds, "Ground_Truth": refs, "P_Yes": probs})
out_df.to_csv(os.path.join(OUTPUT_DIR, "predictions_T1A_imbalanced.csv"), index=False)

elapsed = round(time.time() - t0, 2)
experiment_times["T1A_imbalanced"] = elapsed
print(f"\n  ⏱ T1A_imbalanced done in {elapsed:.1f}s")

# ── Clean up ───────────────────────────────────────────────────────
del model_mlx, tok_mlx
# Out:
# Downloading (incomplete total...): 0.00B [00:00, ?B/s]
# Fetching 9 files:   0%|          | 0/9 [00:00<?, ?it/s]
# Generating:   0%|          | 0/8275 [00:00<?, ?it/s]
# ── T1A_imbalanced ──
#   Label: T1A_imbalanced
#   N_test: 8275
#   Accuracy: 0.9601
#   Recall: 0.8412
#   Precision: 0.8134
#   F1: 0.827
#   Unknown: 0
#               precision    recall  f1-score   support
#
#           No       0.98      0.98      0.98      7337
#          Yes       0.81      0.84      0.83       938
#
#     accuracy                           0.96      8275
#    macro avg       0.90      0.91      0.90      8275
# weighted avg       0.96      0.96      0.96      8275
#
#   ECE: 0.0180 | Saved → ./results_wave3/calibration_T1A_imbalanced.png
#
#   ⏱ T1A_imbalanced done in 2913.0s

# %% [markdown]
# ### Rest for the Machine

# %%
# Rest for the machine
import json

checkpoint = {
    "all_metrics":       all_metrics,
    "experiment_times":  experiment_times,
}

with open(os.path.join(OUTPUT_DIR, "session_checkpoint.json"), "w") as f:
    json.dump(checkpoint, f, indent=2)

print(f"Checkpoint saved — {len(all_metrics)} experiment(s) stored.")
# Out:
# Checkpoint saved — 2 experiment(s) stored.

# %%
import json

checkpoint_path = os.path.join(OUTPUT_DIR, "session_checkpoint.json")

with open(checkpoint_path, "r") as f:
    checkpoint = json.load(f)

all_metrics      = checkpoint["all_metrics"]
experiment_times = checkpoint["experiment_times"]

print(f"Restored — {len(all_metrics)} experiment(s) loaded:")
for m in all_metrics:
    print(f"  {m['Label']} — F1: {m['F1']}, ECE: {m.get('ECE', 'N/A')}")
# Out:
# Restored — 1 experiment(s) loaded:
#   T1A_imbalanced — F1: 0.827, ECE: 0.018

# %%
import time

# %% [markdown]
# ### Training and Inference for T1B_oversampled

# %%
# !mlx_lm.lora \
    --model {MODEL_ID} \
    --train \
    --data ./mlx_data/T1B_oversampled \
    --num-layers 16 \
    --batch-size 4 \
    --grad-accumulation-steps 4 \
    --iters 2000 \
    --learning-rate 2e-4 \
    --mask-prompt \
    --adapter-path ./adapters_w3/T1B_oversampled \
    --save-every 500 \
    -c ./configs/lora_config.yaml
# Out:
# Loading configuration file ./configs/lora_config.yaml
# Loading pretrained model
# Downloading (incomplete total...): 0.00B [00:00, ?B/s]
# Fetching 9 files: 100%|████████████████████████| 9/9 [00:00<00:00, 11480.76it/s]
# Download complete: : 0.00B [00:00, ?B/s]
# Loading datasets
# Training
# Trainable parameters: 0.684% (10.551M/1543.714M)
# Starting training..., iters: 2000
# Calculating loss...: 100%|██████████████████████| 25/25 [00:24<00:00,  1.03it/s]
# Iter 1: Val loss 7.566, Val took 24.194s
# Iter 10: Train loss 3.857, Learning Rate 2.000e-04, It/sec 0.490, Tokens/sec 7.837, Trained Tokens 160, Peak mem 6.848 GB
# Iter 20: Train loss 0.187, Learning Rate 2.000e-04, It/sec 0.527, Tokens/sec 8.427, Trained Tokens 320, Peak mem 6.848 GB
# Iter 30: Train loss 0.154, Learning Rate 2.000e-04, It/sec 0.513, Tokens/sec 8.209, Trained Tokens 480, Peak mem 6.848 GB
# Iter 40: Train loss 0.149, Learning Rate 2.000e-04, It/sec 0.515, Tokens/sec 8.233, Trained Tokens 640, Peak mem 6.848 GB
# Iter 50: Train loss 0.063, Learning Rate 2.000e-04, It/sec 0.535, Tokens/sec 8.562, Trained Tokens 800, Peak mem 6.848 GB
# Iter 60: Train loss 0.067, Learning Rate 2.000e-04, It/sec 0.526, Tokens/sec 8.414, Trained Tokens 960, Peak mem 6.848 GB
# Iter 70: Train loss 0.206, Learning Rate 2.000e-04, It/sec 0.523, Tokens/sec 8.364, Trained Tokens 1120, Peak mem 6.848 GB
# Iter 80: Train loss 0.073, Learning Rate 2.000e-04, It/sec 0.515, Tokens/sec 8.244, Trained Tokens 1280, Peak mem 6.848 GB
# Iter 90: Train loss 0.087, Learning Rate 2.000e-04, It/sec 0.527, Tokens/sec 8.436, Trained Tokens 1440, Peak mem 6.848 GB
# Iter 100: Train loss 0.034, Learning Rate 2.000e-04, It/sec 0.521, Tokens/sec 8.331, Trained Tokens 1600, Peak mem 6.848 GB
# Iter 110: Train loss 0.098, Learning Rate 2.000e-04, It/sec 0.537, Tokens/sec 8.584, Trained Tokens 1760, Peak mem 6.848 GB
# Iter 120: Train loss 0.099, Learning Rate 2.000e-04, It/sec 0.523, Tokens/sec 8.367, Trained Tokens 1920, Peak mem 6.848 GB
# Iter 130: Train loss 0.080, Learning Rate 2.000e-04, It/sec 0.518, Tokens/sec 8.285, Trained Tokens 2080, Peak mem 6.848 GB
# Iter 140: Train loss 0.043, Learning Rate 2.000e-04, It/sec 0.524, Tokens/sec 8.392, Trained Tokens 2240, Peak mem 6.848 GB
# Iter 150: Train loss 0.080, Learning Rate 2.000e-04, It/sec 0.513, Tokens/sec 8.208, Trained Tokens 2400, Peak mem 6.848 GB
# Iter 160: Train loss 0.055, Learning Rate 2.000e-04, It/sec 0.502, Tokens/sec 8.035, Trained Tokens 2560, Peak mem 6.848 GB
# Iter 170: Train loss 0.071, Learning Rate 2.000e-04, It/sec 0.521, Tokens/sec 8.343, Trained Tokens 2720, Peak mem 6.848 GB
# Iter 180: Train loss 0.045, Learning Rate 2.000e-04, It/sec 0.515, Tokens/sec 8.241, Trained Tokens 2880, Peak mem 6.848 GB
# Iter 190: Train loss 0.079, Learning Rate 2.000e-04, It/sec 0.522, Tokens/sec 8.353, Trained Tokens 3040, Peak mem 6.848 GB
# Calculating loss...: 100%|██████████████████████| 25/25 [00:25<00:00,  1.00s/it]
# Iter 200: Val loss 0.093, Val took 25.110s
# Iter 200: Train loss 0.113, Learning Rate 2.000e-04, It/sec 0.533, Tokens/sec 8.526, Trained Tokens 3200, Peak mem 6.848 GB
# Iter 210: Train loss 0.090, Learning Rate 2.000e-04, It/sec 0.526, Tokens/sec 8.418, Trained Tokens 3360, Peak mem 6.848 GB
# Iter 220: Train loss 0.066, Learning Rate 2.000e-04, It/sec 0.530, Tokens/sec 8.474, Trained Tokens 3520, Peak mem 6.848 GB
# Iter 230: Train loss 0.053, Learning Rate 2.000e-04, It/sec 0.535, Tokens/sec 8.567, Trained Tokens 3680, Peak mem 6.848 GB
# Iter 240: Train loss 0.084, Learning Rate 2.000e-04, It/sec 0.511, Tokens/sec 8.177, Trained Tokens 3840, Peak mem 6.848 GB
# Iter 250: Train loss 0.087, Learning Rate 2.000e-04, It/sec 0.502, Tokens/sec 8.035, Trained Tokens 4000, Peak mem 6.848 GB
# Iter 260: Train loss 0.079, Learning Rate 2.000e-04, It/sec 0.533, Tokens/sec 8.527, Trained Tokens 4160, Peak mem 6.848 GB
# Iter 270: Train loss 0.062, Learning Rate 2.000e-04, It/sec 0.516, Tokens/sec 8.260, Trained Tokens 4320, Peak mem 6.848 GB
# Iter 280: Train loss 0.053, Learning Rate 2.000e-04, It/sec 0.523, Tokens/sec 8.362, Trained Tokens 4480, Peak mem 6.848 GB
# Iter 290: Train loss 0.051, Learning Rate 2.000e-04, It/sec 0.505, Tokens/sec 8.086, Trained Tokens 4640, Peak mem 6.848 GB
# Iter 300: Train loss 0.097, Learning Rate 2.000e-04, It/sec 0.516, Tokens/sec 8.255, Trained Tokens 4800, Peak mem 6.848 GB
# Iter 310: Train loss 0.108, Learning Rate 2.000e-04, It/sec 0.534, Tokens/sec 8.540, Trained Tokens 4960, Peak mem 6.848 GB
# Iter 320: Train loss 0.041, Learning Rate 2.000e-04, It/sec 0.526, Tokens/sec 8.411, Trained Tokens 5120, Peak mem 6.848 GB
# Iter 330: Train loss 0.058, Learning Rate 2.000e-04, It/sec 0.522, Tokens/sec 8.352, Trained Tokens 5280, Peak mem 6.848 GB
# Iter 340: Train loss 0.058, Learning Rate 2.000e-04, It/sec 0.515, Tokens/sec 8.237, Trained Tokens 5440, Peak mem 6.848 GB
# Iter 350: Train loss 0.072, Learning Rate 2.000e-04, It/sec 0.520, Tokens/sec 8.320, Trained Tokens 5600, Peak mem 6.848 GB
# Iter 360: Train loss 0.072, Learning Rate 2.000e-04, It/sec 0.525, Tokens/sec 8.398, Trained Tokens 5760, Peak mem 6.848 GB
# Iter 370: Train loss 0.044, Learning Rate 2.000e-04, It/sec 0.499, Tokens/sec 7.986, Trained Tokens 5920, Peak mem 6.848 GB
# Iter 380: Train loss 0.051, Learning Rate 2.000e-04, It/sec 0.523, Tokens/sec 8.368, Trained Tokens 6080, Peak mem 6.848 GB
# Iter 390: Train loss 0.079, Learning Rate 2.000e-04, It/sec 0.528, Tokens/sec 8.447, Trained Tokens 6240, Peak mem 6.848 GB
# Calculating loss...: 100%|██████████████████████| 25/25 [00:25<00:00,  1.00s/it]
# Iter 400: Val loss 0.033, Val took 25.139s
# Iter 400: Train loss 0.075, Learning Rate 2.000e-04, It/sec 0.531, Tokens/sec 8.495, Trained Tokens 6400, Peak mem 6.848 GB
# Iter 410: Train loss 0.031, Learning Rate 2.000e-04, It/sec 0.520, Tokens/sec 8.317, Trained Tokens 6560, Peak mem 6.848 GB
# Iter 420: Train loss 0.072, Learning Rate 2.000e-04, It/sec 0.512, Tokens/sec 8.188, Trained Tokens 6720, Peak mem 6.848 GB
# Iter 430: Train loss 0.064, Learning Rate 2.000e-04, It/sec 0.518, Tokens/sec 8.294, Trained Tokens 6880, Peak mem 6.848 GB
# Iter 440: Train loss 0.075, Learning Rate 2.000e-04, It/sec 0.511, Tokens/sec 8.176, Trained Tokens 7040, Peak mem 6.848 GB
# Iter 450: Train loss 0.087, Learning Rate 2.000e-04, It/sec 0.512, Tokens/sec 8.185, Trained Tokens 7200, Peak mem 6.848 GB
# Iter 460: Train loss 0.076, Learning Rate 2.000e-04, It/sec 0.504, Tokens/sec 8.071, Trained Tokens 7360, Peak mem 6.848 GB
# Iter 470: Train loss 0.094, Learning Rate 2.000e-04, It/sec 0.506, Tokens/sec 8.099, Trained Tokens 7520, Peak mem 6.848 GB
# Iter 480: Train loss 0.082, Learning Rate 2.000e-04, It/sec 0.514, Tokens/sec 8.219, Trained Tokens 7680, Peak mem 6.848 GB
# Iter 490: Train loss 0.062, Learning Rate 2.000e-04, It/sec 0.518, Tokens/sec 8.284, Trained Tokens 7840, Peak mem 6.848 GB
# Iter 500: Train loss 0.094, Learning Rate 2.000e-04, It/sec 0.519, Tokens/sec 8.310, Trained Tokens 8000, Peak mem 6.848 GB
# Iter 500: Saved adapter weights to adapters_w3/T1B_oversampled/adapters.safetensors and adapters_w3/T1B_oversampled/0000500_adapters.safetensors.
# Iter 510: Train loss 0.124, Learning Rate 2.000e-04, It/sec 0.519, Tokens/sec 8.302, Trained Tokens 8160, Peak mem 6.891 GB
# Iter 520: Train loss 0.076, Learning Rate 2.000e-04, It/sec 0.527, Tokens/sec 8.440, Trained Tokens 8320, Peak mem 6.891 GB
# Iter 530: Train loss 0.076, Learning Rate 2.000e-04, It/sec 0.523, Tokens/sec 8.364, Trained Tokens 8480, Peak mem 6.891 GB
# Iter 540: Train loss 0.100, Learning Rate 2.000e-04, It/sec 0.499, Tokens/sec 7.984, Trained Tokens 8640, Peak mem 6.891 GB
# Iter 550: Train loss 0.050, Learning Rate 2.000e-04, It/sec 0.517, Tokens/sec 8.271, Trained Tokens 8800, Peak mem 6.891 GB
# Iter 560: Train loss 0.105, Learning Rate 2.000e-04, It/sec 0.519, Tokens/sec 8.310, Trained Tokens 8960, Peak mem 6.891 GB
# Iter 570: Train loss 0.092, Learning Rate 2.000e-04, It/sec 0.531, Tokens/sec 8.503, Trained Tokens 9120, Peak mem 6.891 GB
# Iter 580: Train loss 0.048, Learning Rate 2.000e-04, It/sec 0.526, Tokens/sec 8.420, Trained Tokens 9280, Peak mem 6.891 GB
# Iter 590: Train loss 0.068, Learning Rate 2.000e-04, It/sec 0.531, Tokens/sec 8.498, Trained Tokens 9440, Peak mem 6.891 GB
# Calculating loss...: 100%|██████████████████████| 25/25 [00:24<00:00,  1.01it/s]
# Iter 600: Val loss 0.066, Val took 24.811s
# Iter 600: Train loss 0.092, Learning Rate 2.000e-04, It/sec 0.533, Tokens/sec 8.521, Trained Tokens 9600, Peak mem 6.891 GB
# Iter 610: Train loss 0.070, Learning Rate 2.000e-04, It/sec 0.537, Tokens/sec 8.593, Trained Tokens 9760, Peak mem 6.891 GB
# Iter 620: Train loss 0.071, Learning Rate 2.000e-04, It/sec 0.521, Tokens/sec 8.329, Trained Tokens 9920, Peak mem 6.891 GB
# Iter 630: Train loss 0.078, Learning Rate 2.000e-04, It/sec 0.531, Tokens/sec 8.499, Trained Tokens 10080, Peak mem 6.891 GB
# Iter 640: Train loss 0.031, Learning Rate 2.000e-04, It/sec 0.530, Tokens/sec 8.478, Trained Tokens 10240, Peak mem 6.891 GB
# Iter 650: Train loss 0.107, Learning Rate 2.000e-04, It/sec 0.530, Tokens/sec 8.485, Trained Tokens 10400, Peak mem 6.891 GB
# Iter 660: Train loss 0.085, Learning Rate 2.000e-04, It/sec 0.543, Tokens/sec 8.694, Trained Tokens 10560, Peak mem 6.891 GB
# Iter 670: Train loss 0.050, Learning Rate 2.000e-04, It/sec 0.525, Tokens/sec 8.403, Trained Tokens 10720, Peak mem 6.891 GB
# Iter 680: Train loss 0.080, Learning Rate 2.000e-04, It/sec 0.544, Tokens/sec 8.704, Trained Tokens 10880, Peak mem 6.891 GB
# Iter 690: Train loss 0.104, Learning Rate 2.000e-04, It/sec 0.538, Tokens/sec 8.614, Trained Tokens 11040, Peak mem 6.891 GB
# Iter 700: Train loss 0.049, Learning Rate 2.000e-04, It/sec 0.519, Tokens/sec 8.309, Trained Tokens 11200, Peak mem 6.891 GB
# Iter 710: Train loss 0.056, Learning Rate 2.000e-04, It/sec 0.532, Tokens/sec 8.515, Trained Tokens 11360, Peak mem 6.891 GB
# Iter 720: Train loss 0.076, Learning Rate 2.000e-04, It/sec 0.522, Tokens/sec 8.352, Trained Tokens 11520, Peak mem 6.891 GB
# Iter 730: Train loss 0.031, Learning Rate 2.000e-04, It/sec 0.528, Tokens/sec 8.454, Trained Tokens 11680, Peak mem 6.891 GB
# Iter 740: Train loss 0.117, Learning Rate 2.000e-04, It/sec 0.526, Tokens/sec 8.414, Trained Tokens 11840, Peak mem 6.891 GB
# Iter 750: Train loss 0.068, Learning Rate 2.000e-04, It/sec 0.522, Tokens/sec 8.344, Trained Tokens 12000, Peak mem 6.891 GB
# Iter 760: Train loss 0.064, Learning Rate 2.000e-04, It/sec 0.479, Tokens/sec 7.669, Trained Tokens 12160, Peak mem 6.891 GB
# Iter 770: Train loss 0.062, Learning Rate 2.000e-04, It/sec 0.535, Tokens/sec 8.566, Trained Tokens 12320, Peak mem 6.891 GB
# Iter 780: Train loss 0.043, Learning Rate 2.000e-04, It/sec 0.505, Tokens/sec 8.076, Trained Tokens 12480, Peak mem 6.891 GB
# Iter 790: Train loss 0.063, Learning Rate 2.000e-04, It/sec 0.507, Tokens/sec 8.116, Trained Tokens 12640, Peak mem 6.891 GB
# Calculating loss...: 100%|██████████████████████| 25/25 [00:24<00:00,  1.02it/s]
# Iter 800: Val loss 0.054, Val took 24.468s
# Iter 800: Train loss 0.042, Learning Rate 2.000e-04, It/sec 0.513, Tokens/sec 8.213, Trained Tokens 12800, Peak mem 6.891 GB
# Iter 810: Train loss 0.067, Learning Rate 2.000e-04, It/sec 0.533, Tokens/sec 8.526, Trained Tokens 12960, Peak mem 6.891 GB
# Iter 820: Train loss 0.041, Learning Rate 2.000e-04, It/sec 0.533, Tokens/sec 8.522, Trained Tokens 13120, Peak mem 6.891 GB
# Iter 830: Train loss 0.072, Learning Rate 2.000e-04, It/sec 0.521, Tokens/sec 8.337, Trained Tokens 13280, Peak mem 6.891 GB
# Iter 840: Train loss 0.095, Learning Rate 2.000e-04, It/sec 0.519, Tokens/sec 8.299, Trained Tokens 13440, Peak mem 6.891 GB
# Iter 850: Train loss 0.060, Learning Rate 2.000e-04, It/sec 0.533, Tokens/sec 8.526, Trained Tokens 13600, Peak mem 6.891 GB
# Iter 860: Train loss 0.045, Learning Rate 2.000e-04, It/sec 0.489, Tokens/sec 7.816, Trained Tokens 13760, Peak mem 6.891 GB
# Iter 870: Train loss 0.063, Learning Rate 2.000e-04, It/sec 0.511, Tokens/sec 8.173, Trained Tokens 13920, Peak mem 6.891 GB
# Iter 880: Train loss 0.098, Learning Rate 2.000e-04, It/sec 0.525, Tokens/sec 8.408, Trained Tokens 14080, Peak mem 6.891 GB
# Iter 890: Train loss 0.054, Learning Rate 2.000e-04, It/sec 0.534, Tokens/sec 8.547, Trained Tokens 14240, Peak mem 6.891 GB
# Iter 900: Train loss 0.031, Learning Rate 2.000e-04, It/sec 0.531, Tokens/sec 8.496, Trained Tokens 14400, Peak mem 6.891 GB
# Iter 910: Train loss 0.015, Learning Rate 2.000e-04, It/sec 0.526, Tokens/sec 8.411, Trained Tokens 14560, Peak mem 6.891 GB
# Iter 920: Train loss 0.020, Learning Rate 2.000e-04, It/sec 0.537, Tokens/sec 8.599, Trained Tokens 14720, Peak mem 6.891 GB
# Iter 930: Train loss 0.095, Learning Rate 2.000e-04, It/sec 0.538, Tokens/sec 8.605, Trained Tokens 14880, Peak mem 6.891 GB
# Iter 940: Train loss 0.082, Learning Rate 2.000e-04, It/sec 0.525, Tokens/sec 8.393, Trained Tokens 15040, Peak mem 6.891 GB
# Iter 950: Train loss 0.129, Learning Rate 2.000e-04, It/sec 0.525, Tokens/sec 8.399, Trained Tokens 15200, Peak mem 6.891 GB
# Iter 960: Train loss 0.115, Learning Rate 2.000e-04, It/sec 0.517, Tokens/sec 8.270, Trained Tokens 15360, Peak mem 6.891 GB
# Iter 970: Train loss 0.073, Learning Rate 2.000e-04, It/sec 0.519, Tokens/sec 8.306, Trained Tokens 15520, Peak mem 6.891 GB
# Iter 980: Train loss 0.062, Learning Rate 2.000e-04, It/sec 0.527, Tokens/sec 8.425, Trained Tokens 15680, Peak mem 6.891 GB
# Iter 990: Train loss 0.101, Learning Rate 2.000e-04, It/sec 0.533, Tokens/sec 8.530, Trained Tokens 15840, Peak mem 6.891 GB
# Calculating loss...: 100%|██████████████████████| 25/25 [00:24<00:00,  1.01it/s]
# Iter 1000: Val loss 0.044, Val took 24.699s
# Iter 1000: Train loss 0.065, Learning Rate 2.000e-04, It/sec 0.516, Tokens/sec 8.251, Trained Tokens 16000, Peak mem 6.891 GB
# Iter 1000: Saved adapter weights to adapters_w3/T1B_oversampled/adapters.safetensors and adapters_w3/T1B_oversampled/0001000_adapters.safetensors.
# Iter 1010: Train loss 0.032, Learning Rate 2.000e-04, It/sec 0.523, Tokens/sec 8.374, Trained Tokens 16160, Peak mem 6.891 GB
# Iter 1020: Train loss 0.073, Learning Rate 2.000e-04, It/sec 0.524, Tokens/sec 8.377, Trained Tokens 16320, Peak mem 6.891 GB
# Iter 1030: Train loss 0.085, Learning Rate 2.000e-04, It/sec 0.525, Tokens/sec 8.398, Trained Tokens 16480, Peak mem 6.891 GB
# Iter 1040: Train loss 0.070, Learning Rate 2.000e-04, It/sec 0.518, Tokens/sec 8.287, Trained Tokens 16640, Peak mem 6.891 GB
# Iter 1050: Train loss 0.041, Learning Rate 2.000e-04, It/sec 0.531, Tokens/sec 8.494, Trained Tokens 16800, Peak mem 6.891 GB
# Iter 1060: Train loss 0.065, Learning Rate 2.000e-04, It/sec 0.525, Tokens/sec 8.396, Trained Tokens 16960, Peak mem 6.891 GB
# Iter 1070: Train loss 0.071, Learning Rate 2.000e-04, It/sec 0.542, Tokens/sec 8.675, Trained Tokens 17120, Peak mem 6.891 GB
# Iter 1080: Train loss 0.068, Learning Rate 2.000e-04, It/sec 0.519, Tokens/sec 8.298, Trained Tokens 17280, Peak mem 6.891 GB
# Iter 1090: Train loss 0.092, Learning Rate 2.000e-04, It/sec 0.513, Tokens/sec 8.205, Trained Tokens 17440, Peak mem 6.891 GB
# Iter 1100: Train loss 0.044, Learning Rate 2.000e-04, It/sec 0.508, Tokens/sec 8.124, Trained Tokens 17600, Peak mem 6.891 GB
# Iter 1110: Train loss 0.059, Learning Rate 2.000e-04, It/sec 0.508, Tokens/sec 8.123, Trained Tokens 17760, Peak mem 6.891 GB
# Iter 1120: Train loss 0.047, Learning Rate 2.000e-04, It/sec 0.524, Tokens/sec 8.389, Trained Tokens 17920, Peak mem 6.891 GB
# Iter 1130: Train loss 0.066, Learning Rate 2.000e-04, It/sec 0.531, Tokens/sec 8.492, Trained Tokens 18080, Peak mem 6.891 GB
# Iter 1140: Train loss 0.055, Learning Rate 2.000e-04, It/sec 0.531, Tokens/sec 8.490, Trained Tokens 18240, Peak mem 6.891 GB
# Iter 1150: Train loss 0.057, Learning Rate 2.000e-04, It/sec 0.513, Tokens/sec 8.208, Trained Tokens 18400, Peak mem 6.891 GB
# Iter 1160: Train loss 0.104, Learning Rate 2.000e-04, It/sec 0.536, Tokens/sec 8.578, Trained Tokens 18560, Peak mem 6.891 GB
# Iter 1170: Train loss 0.040, Learning Rate 2.000e-04, It/sec 0.519, Tokens/sec 8.302, Trained Tokens 18720, Peak mem 6.891 GB
# Iter 1180: Train loss 0.053, Learning Rate 2.000e-04, It/sec 0.530, Tokens/sec 8.487, Trained Tokens 18880, Peak mem 6.891 GB
# Iter 1190: Train loss 0.066, Learning Rate 2.000e-04, It/sec 0.536, Tokens/sec 8.577, Trained Tokens 19040, Peak mem 6.891 GB
# Calculating loss...: 100%|██████████████████████| 25/25 [00:24<00:00,  1.03it/s]
# Iter 1200: Val loss 0.053, Val took 24.331s
# Iter 1200: Train loss 0.049, Learning Rate 2.000e-04, It/sec 0.530, Tokens/sec 8.474, Trained Tokens 19200, Peak mem 6.891 GB
# Iter 1210: Train loss 0.062, Learning Rate 2.000e-04, It/sec 0.536, Tokens/sec 8.583, Trained Tokens 19360, Peak mem 6.891 GB
# Iter 1220: Train loss 0.047, Learning Rate 2.000e-04, It/sec 0.523, Tokens/sec 8.370, Trained Tokens 19520, Peak mem 6.891 GB
# Iter 1230: Train loss 0.045, Learning Rate 2.000e-04, It/sec 0.529, Tokens/sec 8.470, Trained Tokens 19680, Peak mem 6.891 GB
# Iter 1240: Train loss 0.029, Learning Rate 2.000e-04, It/sec 0.518, Tokens/sec 8.282, Trained Tokens 19840, Peak mem 6.891 GB
# Iter 1250: Train loss 0.044, Learning Rate 2.000e-04, It/sec 0.536, Tokens/sec 8.583, Trained Tokens 20000, Peak mem 6.891 GB
# Iter 1260: Train loss 0.063, Learning Rate 2.000e-04, It/sec 0.521, Tokens/sec 8.342, Trained Tokens 20160, Peak mem 6.891 GB
# Iter 1270: Train loss 0.185, Learning Rate 2.000e-04, It/sec 0.530, Tokens/sec 8.486, Trained Tokens 20320, Peak mem 6.891 GB
# Iter 1280: Train loss 0.103, Learning Rate 2.000e-04, It/sec 0.531, Tokens/sec 8.492, Trained Tokens 20480, Peak mem 6.891 GB
# Iter 1290: Train loss 0.050, Learning Rate 2.000e-04, It/sec 0.527, Tokens/sec 8.432, Trained Tokens 20640, Peak mem 6.891 GB
# Iter 1300: Train loss 0.079, Learning Rate 2.000e-04, It/sec 0.530, Tokens/sec 8.482, Trained Tokens 20800, Peak mem 6.891 GB
# Iter 1310: Train loss 0.071, Learning Rate 2.000e-04, It/sec 0.533, Tokens/sec 8.534, Trained Tokens 20960, Peak mem 6.891 GB
# Iter 1320: Train loss 0.073, Learning Rate 2.000e-04, It/sec 0.520, Tokens/sec 8.323, Trained Tokens 21120, Peak mem 6.891 GB
# Iter 1330: Train loss 0.108, Learning Rate 2.000e-04, It/sec 0.536, Tokens/sec 8.573, Trained Tokens 21280, Peak mem 6.891 GB
# Iter 1340: Train loss 0.036, Learning Rate 2.000e-04, It/sec 0.532, Tokens/sec 8.515, Trained Tokens 21440, Peak mem 6.891 GB
# Iter 1350: Train loss 0.057, Learning Rate 2.000e-04, It/sec 0.531, Tokens/sec 8.494, Trained Tokens 21600, Peak mem 6.891 GB
# Iter 1360: Train loss 0.081, Learning Rate 2.000e-04, It/sec 0.538, Tokens/sec 8.606, Trained Tokens 21760, Peak mem 6.891 GB
# Iter 1370: Train loss 0.041, Learning Rate 2.000e-04, It/sec 0.531, Tokens/sec 8.503, Trained Tokens 21920, Peak mem 6.891 GB
# Iter 1380: Train loss 0.024, Learning Rate 2.000e-04, It/sec 0.525, Tokens/sec 8.400, Trained Tokens 22080, Peak mem 6.891 GB
# Iter 1390: Train loss 0.035, Learning Rate 2.000e-04, It/sec 0.531, Tokens/sec 8.489, Trained Tokens 22240, Peak mem 6.891 GB
# Calculating loss...: 100%|██████████████████████| 25/25 [00:24<00:00,  1.02it/s]
# Iter 1400: Val loss 0.069, Val took 24.443s
# Iter 1400: Train loss 0.069, Learning Rate 2.000e-04, It/sec 0.532, Tokens/sec 8.510, Trained Tokens 22400, Peak mem 6.891 GB
# Iter 1410: Train loss 0.097, Learning Rate 2.000e-04, It/sec 0.544, Tokens/sec 8.710, Trained Tokens 22560, Peak mem 6.891 GB
# Iter 1420: Train loss 0.038, Learning Rate 2.000e-04, It/sec 0.532, Tokens/sec 8.519, Trained Tokens 22720, Peak mem 6.891 GB
# Iter 1430: Train loss 0.067, Learning Rate 2.000e-04, It/sec 0.537, Tokens/sec 8.591, Trained Tokens 22880, Peak mem 6.891 GB
# Iter 1440: Train loss 0.116, Learning Rate 2.000e-04, It/sec 0.536, Tokens/sec 8.577, Trained Tokens 23040, Peak mem 6.891 GB
# Iter 1450: Train loss 0.060, Learning Rate 2.000e-04, It/sec 0.514, Tokens/sec 8.223, Trained Tokens 23200, Peak mem 6.891 GB
# Iter 1460: Train loss 0.049, Learning Rate 2.000e-04, It/sec 0.519, Tokens/sec 8.301, Trained Tokens 23360, Peak mem 6.891 GB
# Iter 1470: Train loss 0.082, Learning Rate 2.000e-04, It/sec 0.494, Tokens/sec 7.902, Trained Tokens 23520, Peak mem 6.891 GB
# Iter 1480: Train loss 0.098, Learning Rate 2.000e-04, It/sec 0.531, Tokens/sec 8.504, Trained Tokens 23680, Peak mem 6.891 GB
# Iter 1490: Train loss 0.058, Learning Rate 2.000e-04, It/sec 0.531, Tokens/sec 8.493, Trained Tokens 23840, Peak mem 6.891 GB
# Iter 1500: Train loss 0.042, Learning Rate 2.000e-04, It/sec 0.537, Tokens/sec 8.587, Trained Tokens 24000, Peak mem 6.891 GB
# Iter 1500: Saved adapter weights to adapters_w3/T1B_oversampled/adapters.safetensors and adapters_w3/T1B_oversampled/0001500_adapters.safetensors.
# Iter 1510: Train loss 0.041, Learning Rate 2.000e-04, It/sec 0.515, Tokens/sec 8.245, Trained Tokens 24160, Peak mem 6.891 GB
# Iter 1520: Train loss 0.077, Learning Rate 2.000e-04, It/sec 0.527, Tokens/sec 8.431, Trained Tokens 24320, Peak mem 6.891 GB
# Iter 1530: Train loss 0.046, Learning Rate 2.000e-04, It/sec 0.534, Tokens/sec 8.547, Trained Tokens 24480, Peak mem 6.891 GB
# Iter 1540: Train loss 0.059, Learning Rate 2.000e-04, It/sec 0.543, Tokens/sec 8.685, Trained Tokens 24640, Peak mem 6.891 GB
# Iter 1550: Train loss 0.052, Learning Rate 2.000e-04, It/sec 0.517, Tokens/sec 8.268, Trained Tokens 24800, Peak mem 6.891 GB
# Iter 1560: Train loss 0.076, Learning Rate 2.000e-04, It/sec 0.517, Tokens/sec 8.269, Trained Tokens 24960, Peak mem 6.891 GB
# Iter 1570: Train loss 0.026, Learning Rate 2.000e-04, It/sec 0.523, Tokens/sec 8.372, Trained Tokens 25120, Peak mem 6.891 GB
# Iter 1580: Train loss 0.029, Learning Rate 2.000e-04, It/sec 0.535, Tokens/sec 8.560, Trained Tokens 25280, Peak mem 6.891 GB
# Iter 1590: Train loss 0.082, Learning Rate 2.000e-04, It/sec 0.532, Tokens/sec 8.515, Trained Tokens 25440, Peak mem 6.891 GB
# Calculating loss...: 100%|██████████████████████| 25/25 [00:25<00:00,  1.03s/it]
# Iter 1600: Val loss 0.111, Val took 25.834s
# Iter 1600: Train loss 0.024, Learning Rate 2.000e-04, It/sec 0.525, Tokens/sec 8.405, Trained Tokens 25600, Peak mem 6.891 GB
# Iter 1610: Train loss 0.062, Learning Rate 2.000e-04, It/sec 0.523, Tokens/sec 8.374, Trained Tokens 25760, Peak mem 6.891 GB
# Iter 1620: Train loss 0.044, Learning Rate 2.000e-04, It/sec 0.525, Tokens/sec 8.394, Trained Tokens 25920, Peak mem 6.891 GB
# Iter 1630: Train loss 0.042, Learning Rate 2.000e-04, It/sec 0.528, Tokens/sec 8.442, Trained Tokens 26080, Peak mem 6.891 GB
# Iter 1640: Train loss 0.038, Learning Rate 2.000e-04, It/sec 0.511, Tokens/sec 8.182, Trained Tokens 26240, Peak mem 6.891 GB
# Iter 1650: Train loss 0.066, Learning Rate 2.000e-04, It/sec 0.521, Tokens/sec 8.334, Trained Tokens 26400, Peak mem 6.891 GB
# Iter 1660: Train loss 0.049, Learning Rate 2.000e-04, It/sec 0.528, Tokens/sec 8.455, Trained Tokens 26560, Peak mem 6.891 GB
# Iter 1670: Train loss 0.029, Learning Rate 2.000e-04, It/sec 0.517, Tokens/sec 8.268, Trained Tokens 26720, Peak mem 6.891 GB
# Iter 1680: Train loss 0.090, Learning Rate 2.000e-04, It/sec 0.522, Tokens/sec 8.358, Trained Tokens 26880, Peak mem 6.891 GB
# Iter 1690: Train loss 0.077, Learning Rate 2.000e-04, It/sec 0.528, Tokens/sec 8.452, Trained Tokens 27040, Peak mem 6.891 GB
# Iter 1700: Train loss 0.033, Learning Rate 2.000e-04, It/sec 0.517, Tokens/sec 8.269, Trained Tokens 27200, Peak mem 6.891 GB
# Iter 1710: Train loss 0.017, Learning Rate 2.000e-04, It/sec 0.529, Tokens/sec 8.461, Trained Tokens 27360, Peak mem 6.891 GB
# Iter 1720: Train loss 0.104, Learning Rate 2.000e-04, It/sec 0.525, Tokens/sec 8.398, Trained Tokens 27520, Peak mem 6.891 GB
# Iter 1730: Train loss 0.086, Learning Rate 2.000e-04, It/sec 0.532, Tokens/sec 8.510, Trained Tokens 27680, Peak mem 6.891 GB
# Iter 1740: Train loss 0.109, Learning Rate 2.000e-04, It/sec 0.532, Tokens/sec 8.507, Trained Tokens 27840, Peak mem 6.891 GB
# Iter 1750: Train loss 0.077, Learning Rate 2.000e-04, It/sec 0.527, Tokens/sec 8.436, Trained Tokens 28000, Peak mem 6.891 GB
# Iter 1760: Train loss 0.037, Learning Rate 2.000e-04, It/sec 0.524, Tokens/sec 8.383, Trained Tokens 28160, Peak mem 6.891 GB
# Iter 1770: Train loss 0.048, Learning Rate 2.000e-04, It/sec 0.523, Tokens/sec 8.362, Trained Tokens 28320, Peak mem 6.891 GB
# Iter 1780: Train loss 0.074, Learning Rate 2.000e-04, It/sec 0.525, Tokens/sec 8.396, Trained Tokens 28480, Peak mem 6.891 GB
# Iter 1790: Train loss 0.037, Learning Rate 2.000e-04, It/sec 0.523, Tokens/sec 8.361, Trained Tokens 28640, Peak mem 6.891 GB
# Calculating loss...: 100%|██████████████████████| 25/25 [00:24<00:00,  1.01it/s]
# Iter 1800: Val loss 0.086, Val took 24.836s
# Iter 1800: Train loss 0.066, Learning Rate 2.000e-04, It/sec 0.518, Tokens/sec 8.283, Trained Tokens 28800, Peak mem 6.891 GB
# Iter 1810: Train loss 0.038, Learning Rate 2.000e-04, It/sec 0.514, Tokens/sec 8.225, Trained Tokens 28960, Peak mem 6.891 GB
# Iter 1820: Train loss 0.077, Learning Rate 2.000e-04, It/sec 0.508, Tokens/sec 8.131, Trained Tokens 29120, Peak mem 6.891 GB
# Iter 1830: Train loss 0.072, Learning Rate 2.000e-04, It/sec 0.528, Tokens/sec 8.441, Trained Tokens 29280, Peak mem 6.891 GB
# Iter 1840: Train loss 0.039, Learning Rate 2.000e-04, It/sec 0.516, Tokens/sec 8.259, Trained Tokens 29440, Peak mem 6.891 GB
# Iter 1850: Train loss 0.059, Learning Rate 2.000e-04, It/sec 0.528, Tokens/sec 8.456, Trained Tokens 29600, Peak mem 6.891 GB
# Iter 1860: Train loss 0.086, Learning Rate 2.000e-04, It/sec 0.541, Tokens/sec 8.653, Trained Tokens 29760, Peak mem 6.891 GB
# Iter 1870: Train loss 0.094, Learning Rate 2.000e-04, It/sec 0.521, Tokens/sec 8.343, Trained Tokens 29920, Peak mem 6.891 GB
# Iter 1880: Train loss 0.041, Learning Rate 2.000e-04, It/sec 0.525, Tokens/sec 8.401, Trained Tokens 30080, Peak mem 6.891 GB
# Iter 1890: Train loss 0.046, Learning Rate 2.000e-04, It/sec 0.511, Tokens/sec 8.174, Trained Tokens 30240, Peak mem 6.891 GB
# Iter 1900: Train loss 0.034, Learning Rate 2.000e-04, It/sec 0.520, Tokens/sec 8.314, Trained Tokens 30400, Peak mem 6.891 GB
# Iter 1910: Train loss 0.051, Learning Rate 2.000e-04, It/sec 0.520, Tokens/sec 8.320, Trained Tokens 30560, Peak mem 6.891 GB
# Iter 1920: Train loss 0.135, Learning Rate 2.000e-04, It/sec 0.534, Tokens/sec 8.552, Trained Tokens 30720, Peak mem 6.891 GB
# Iter 1930: Train loss 0.048, Learning Rate 2.000e-04, It/sec 0.522, Tokens/sec 8.356, Trained Tokens 30880, Peak mem 6.891 GB
# Iter 1940: Train loss 0.078, Learning Rate 2.000e-04, It/sec 0.512, Tokens/sec 8.189, Trained Tokens 31040, Peak mem 6.891 GB
# Iter 1950: Train loss 0.092, Learning Rate 2.000e-04, It/sec 0.519, Tokens/sec 8.304, Trained Tokens 31200, Peak mem 6.891 GB
# Iter 1960: Train loss 0.050, Learning Rate 2.000e-04, It/sec 0.523, Tokens/sec 8.360, Trained Tokens 31360, Peak mem 6.891 GB
# Iter 1970: Train loss 0.053, Learning Rate 2.000e-04, It/sec 0.532, Tokens/sec 8.506, Trained Tokens 31520, Peak mem 6.891 GB
# Iter 1980: Train loss 0.050, Learning Rate 2.000e-04, It/sec 0.523, Tokens/sec 8.373, Trained Tokens 31680, Peak mem 6.891 GB
# Iter 1990: Train loss 0.064, Learning Rate 2.000e-04, It/sec 0.536, Tokens/sec 8.574, Trained Tokens 31840, Peak mem 6.891 GB
# Calculating loss...: 100%|██████████████████████| 25/25 [00:24<00:00,  1.01it/s]
# Iter 2000: Val loss 0.043, Val took 24.854s
# Iter 2000: Train loss 0.068, Learning Rate 2.000e-04, It/sec 0.522, Tokens/sec 8.356, Trained Tokens 32000, Peak mem 6.891 GB
# Iter 2000: Saved adapter weights to adapters_w3/T1B_oversampled/adapters.safetensors and adapters_w3/T1B_oversampled/0002000_adapters.safetensors.
# Saved final weights to adapters_w3/T1B_oversampled/adapters.safetensors.

# %%
# ── Load model with T1B_oversampled adapter ──────────────────────────────
model_mlx, tok_mlx = load(
    MODEL_ID,
    adapter_path="./adapters_w3/T1B_oversampled",
)

# ── Inference ──────────────────────────────────────────────────────
t0 = time.time()
preds, refs, probs = run_inference_mlx(
    model_mlx, tok_mlx, test_ds_structured_full, return_probs=True
)

# ── Evaluate ───────────────────────────────────────────────────────
metrics = evaluate_predictions(preds, refs, label_name="T1B_oversampled")

# ── Calibration ────────────────────────────────────────────────────
ece = calibration_analysis(
    probs, refs,
    label_name="T1B_oversampled",
    save_path=os.path.join(OUTPUT_DIR, "calibration_T1B_oversampled.png")
)
metrics["ECE"] = ece
all_metrics.append(metrics)

# ── Save predictions ───────────────────────────────────────────────
out_df = pd.DataFrame({"Predicted_Label": preds, "Ground_Truth": refs, "P_Yes": probs})
out_df.to_csv(os.path.join(OUTPUT_DIR, "predictions_T1B_oversampled.csv"), index=False)

elapsed = round(time.time() - t0, 2)
experiment_times["T1B_oversampled"] = elapsed
print(f"\n  ⏱ T1B_oversampled done in {elapsed:.1f}s")

# ── Clean up ───────────────────────────────────────────────────────
del model_mlx, tok_mlx
# Out:
# Downloading (incomplete total...): 0.00B [00:00, ?B/s]
# Fetching 9 files:   0%|          | 0/9 [00:00<?, ?it/s]
# Generating:   0%|          | 0/8275 [00:00<?, ?it/s]
# ── T1B_oversampled ──
#   Label: T1B_oversampled
#   N_test: 8275
#   Accuracy: 0.9473
#   Recall: 0.8923
#   Precision: 0.7142
#   F1: 0.7934
#   Unknown: 0
#               precision    recall  f1-score   support
#
#           No       0.99      0.95      0.97      7337
#          Yes       0.71      0.89      0.79       938
#
#     accuracy                           0.95      8275
#    macro avg       0.85      0.92      0.88      8275
# weighted avg       0.95      0.95      0.95      8275
#
#   ECE: 0.0122 | Saved → ./results_wave3/calibration_T1B_oversampled.png
#
#   ⏱ T1B_oversampled done in 2915.5s

# %% [markdown]
# ### Training and Inference for T2A_demo_only

# %%
# !mlx_lm.lora \
    --model {MODEL_ID} \
    --train \
    --data ./mlx_data/T2A_demo_only \
    --num-layers 16 \
    --batch-size 4 \
    --grad-accumulation-steps 4 \
    --iters 2000 \
    --learning-rate 2e-4 \
    --mask-prompt \
    --adapter-path ./adapters_w3/T2A_demo_only \
    --save-every 500 \
    -c ./configs/lora_config.yaml
# Out:
# Loading configuration file ./configs/lora_config.yaml
# Loading pretrained model
# Downloading (incomplete total...): 0.00B [00:00, ?B/s]
# Fetching 9 files: 100%|████████████████████████| 9/9 [00:00<00:00, 75196.69it/s]
# Download complete: : 0.00B [00:00, ?B/s]
# Loading datasets
# Training
# Trainable parameters: 0.684% (10.551M/1543.714M)
# Starting training..., iters: 2000
# Calculating loss...: 100%|██████████████████████| 25/25 [00:23<00:00,  1.04it/s]
# Iter 1: Val loss 7.730, Val took 23.947s
# Iter 10: Train loss 3.862, Learning Rate 2.000e-04, It/sec 0.524, Tokens/sec 8.376, Trained Tokens 160, Peak mem 6.323 GB
# Iter 20: Train loss 0.223, Learning Rate 2.000e-04, It/sec 0.546, Tokens/sec 8.740, Trained Tokens 320, Peak mem 6.323 GB
# Iter 30: Train loss 0.163, Learning Rate 2.000e-04, It/sec 0.546, Tokens/sec 8.730, Trained Tokens 480, Peak mem 6.323 GB
# Iter 40: Train loss 0.103, Learning Rate 2.000e-04, It/sec 0.551, Tokens/sec 8.817, Trained Tokens 640, Peak mem 6.323 GB
# Iter 50: Train loss 0.147, Learning Rate 2.000e-04, It/sec 0.560, Tokens/sec 8.955, Trained Tokens 800, Peak mem 6.323 GB
# Iter 60: Train loss 0.090, Learning Rate 2.000e-04, It/sec 0.554, Tokens/sec 8.863, Trained Tokens 960, Peak mem 6.323 GB
# Iter 70: Train loss 0.197, Learning Rate 2.000e-04, It/sec 0.548, Tokens/sec 8.764, Trained Tokens 1120, Peak mem 6.323 GB
# Iter 80: Train loss 0.128, Learning Rate 2.000e-04, It/sec 0.554, Tokens/sec 8.863, Trained Tokens 1280, Peak mem 6.323 GB
# Iter 90: Train loss 0.136, Learning Rate 2.000e-04, It/sec 0.540, Tokens/sec 8.635, Trained Tokens 1440, Peak mem 6.323 GB
# Iter 100: Train loss 0.195, Learning Rate 2.000e-04, It/sec 0.540, Tokens/sec 8.644, Trained Tokens 1600, Peak mem 6.323 GB
# Iter 110: Train loss 0.095, Learning Rate 2.000e-04, It/sec 0.552, Tokens/sec 8.829, Trained Tokens 1760, Peak mem 6.323 GB
# Iter 120: Train loss 0.046, Learning Rate 2.000e-04, It/sec 0.546, Tokens/sec 8.741, Trained Tokens 1920, Peak mem 6.323 GB
# Iter 130: Train loss 0.114, Learning Rate 2.000e-04, It/sec 0.546, Tokens/sec 8.741, Trained Tokens 2080, Peak mem 6.323 GB
# Iter 140: Train loss 0.145, Learning Rate 2.000e-04, It/sec 0.556, Tokens/sec 8.896, Trained Tokens 2240, Peak mem 6.323 GB
# Iter 150: Train loss 0.049, Learning Rate 2.000e-04, It/sec 0.557, Tokens/sec 8.912, Trained Tokens 2400, Peak mem 6.323 GB
# Iter 160: Train loss 0.083, Learning Rate 2.000e-04, It/sec 0.572, Tokens/sec 9.159, Trained Tokens 2560, Peak mem 6.323 GB
# Iter 170: Train loss 0.095, Learning Rate 2.000e-04, It/sec 0.541, Tokens/sec 8.659, Trained Tokens 2720, Peak mem 6.323 GB
# Iter 180: Train loss 0.072, Learning Rate 2.000e-04, It/sec 0.540, Tokens/sec 8.641, Trained Tokens 2880, Peak mem 6.323 GB
# Iter 190: Train loss 0.129, Learning Rate 2.000e-04, It/sec 0.550, Tokens/sec 8.799, Trained Tokens 3040, Peak mem 6.323 GB
# Calculating loss...: 100%|██████████████████████| 25/25 [00:23<00:00,  1.06it/s]
# Iter 200: Val loss 0.096, Val took 23.656s
# Iter 200: Train loss 0.098, Learning Rate 2.000e-04, It/sec 0.553, Tokens/sec 8.851, Trained Tokens 3200, Peak mem 6.323 GB
# Iter 210: Train loss 0.052, Learning Rate 2.000e-04, It/sec 0.545, Tokens/sec 8.727, Trained Tokens 3360, Peak mem 6.323 GB
# Iter 220: Train loss 0.174, Learning Rate 2.000e-04, It/sec 0.546, Tokens/sec 8.741, Trained Tokens 3520, Peak mem 6.323 GB
# Iter 230: Train loss 0.092, Learning Rate 2.000e-04, It/sec 0.559, Tokens/sec 8.936, Trained Tokens 3680, Peak mem 6.323 GB
# Iter 240: Train loss 0.066, Learning Rate 2.000e-04, It/sec 0.546, Tokens/sec 8.743, Trained Tokens 3840, Peak mem 6.323 GB
# Iter 250: Train loss 0.149, Learning Rate 2.000e-04, It/sec 0.540, Tokens/sec 8.640, Trained Tokens 4000, Peak mem 6.323 GB
# Iter 260: Train loss 0.082, Learning Rate 2.000e-04, It/sec 0.560, Tokens/sec 8.955, Trained Tokens 4160, Peak mem 6.323 GB
# Iter 270: Train loss 0.071, Learning Rate 2.000e-04, It/sec 0.561, Tokens/sec 8.981, Trained Tokens 4320, Peak mem 6.323 GB
# Iter 280: Train loss 0.109, Learning Rate 2.000e-04, It/sec 0.547, Tokens/sec 8.750, Trained Tokens 4480, Peak mem 6.323 GB
# Iter 290: Train loss 0.104, Learning Rate 2.000e-04, It/sec 0.541, Tokens/sec 8.651, Trained Tokens 4640, Peak mem 6.323 GB
# Iter 300: Train loss 0.060, Learning Rate 2.000e-04, It/sec 0.547, Tokens/sec 8.758, Trained Tokens 4800, Peak mem 6.323 GB
# Iter 310: Train loss 0.044, Learning Rate 2.000e-04, It/sec 0.572, Tokens/sec 9.158, Trained Tokens 4960, Peak mem 6.323 GB
# Iter 320: Train loss 0.082, Learning Rate 2.000e-04, It/sec 0.560, Tokens/sec 8.962, Trained Tokens 5120, Peak mem 6.323 GB
# Iter 330: Train loss 0.091, Learning Rate 2.000e-04, It/sec 0.554, Tokens/sec 8.860, Trained Tokens 5280, Peak mem 6.323 GB
# Iter 340: Train loss 0.044, Learning Rate 2.000e-04, It/sec 0.540, Tokens/sec 8.640, Trained Tokens 5440, Peak mem 6.323 GB
# Iter 350: Train loss 0.048, Learning Rate 2.000e-04, It/sec 0.566, Tokens/sec 9.052, Trained Tokens 5600, Peak mem 6.323 GB
# Iter 360: Train loss 0.065, Learning Rate 2.000e-04, It/sec 0.547, Tokens/sec 8.754, Trained Tokens 5760, Peak mem 6.323 GB
# Iter 370: Train loss 0.044, Learning Rate 2.000e-04, It/sec 0.553, Tokens/sec 8.848, Trained Tokens 5920, Peak mem 6.323 GB
# Iter 380: Train loss 0.042, Learning Rate 2.000e-04, It/sec 0.540, Tokens/sec 8.633, Trained Tokens 6080, Peak mem 6.323 GB
# Iter 390: Train loss 0.022, Learning Rate 2.000e-04, It/sec 0.541, Tokens/sec 8.655, Trained Tokens 6240, Peak mem 6.323 GB
# Calculating loss...: 100%|██████████████████████| 25/25 [00:22<00:00,  1.09it/s]
# Iter 400: Val loss 0.101, Val took 22.892s
# Iter 400: Train loss 0.069, Learning Rate 2.000e-04, It/sec 0.547, Tokens/sec 8.758, Trained Tokens 6400, Peak mem 6.323 GB
# Iter 410: Train loss 0.060, Learning Rate 2.000e-04, It/sec 0.546, Tokens/sec 8.744, Trained Tokens 6560, Peak mem 6.323 GB
# Iter 420: Train loss 0.057, Learning Rate 2.000e-04, It/sec 0.547, Tokens/sec 8.760, Trained Tokens 6720, Peak mem 6.323 GB
# Iter 430: Train loss 0.052, Learning Rate 2.000e-04, It/sec 0.540, Tokens/sec 8.637, Trained Tokens 6880, Peak mem 6.323 GB
# Iter 440: Train loss 0.104, Learning Rate 2.000e-04, It/sec 0.547, Tokens/sec 8.748, Trained Tokens 7040, Peak mem 6.323 GB
# Iter 450: Train loss 0.052, Learning Rate 2.000e-04, It/sec 0.542, Tokens/sec 8.668, Trained Tokens 7200, Peak mem 6.323 GB
# Iter 460: Train loss 0.045, Learning Rate 2.000e-04, It/sec 0.541, Tokens/sec 8.650, Trained Tokens 7360, Peak mem 6.323 GB
# Iter 470: Train loss 0.047, Learning Rate 2.000e-04, It/sec 0.567, Tokens/sec 9.073, Trained Tokens 7520, Peak mem 6.323 GB
# Iter 480: Train loss 0.075, Learning Rate 2.000e-04, It/sec 0.553, Tokens/sec 8.845, Trained Tokens 7680, Peak mem 6.323 GB
# Iter 490: Train loss 0.070, Learning Rate 2.000e-04, It/sec 0.546, Tokens/sec 8.743, Trained Tokens 7840, Peak mem 6.323 GB
# Iter 500: Train loss 0.079, Learning Rate 2.000e-04, It/sec 0.548, Tokens/sec 8.761, Trained Tokens 8000, Peak mem 6.323 GB
# Iter 500: Saved adapter weights to adapters_w2/T2A_demo_only/adapters.safetensors and adapters_w2/T2A_demo_only/0000500_adapters.safetensors.
# Iter 510: Train loss 0.070, Learning Rate 2.000e-04, It/sec 0.546, Tokens/sec 8.744, Trained Tokens 8160, Peak mem 6.365 GB
# Iter 520: Train loss 0.053, Learning Rate 2.000e-04, It/sec 0.547, Tokens/sec 8.749, Trained Tokens 8320, Peak mem 6.365 GB
# Iter 530: Train loss 0.058, Learning Rate 2.000e-04, It/sec 0.553, Tokens/sec 8.841, Trained Tokens 8480, Peak mem 6.365 GB
# Iter 540: Train loss 0.065, Learning Rate 2.000e-04, It/sec 0.560, Tokens/sec 8.952, Trained Tokens 8640, Peak mem 6.365 GB
# Iter 550: Train loss 0.111, Learning Rate 2.000e-04, It/sec 0.547, Tokens/sec 8.759, Trained Tokens 8800, Peak mem 6.365 GB
# Iter 560: Train loss 0.074, Learning Rate 2.000e-04, It/sec 0.559, Tokens/sec 8.952, Trained Tokens 8960, Peak mem 6.365 GB
# Iter 570: Train loss 0.086, Learning Rate 2.000e-04, It/sec 0.547, Tokens/sec 8.755, Trained Tokens 9120, Peak mem 6.365 GB
# Iter 580: Train loss 0.088, Learning Rate 2.000e-04, It/sec 0.546, Tokens/sec 8.739, Trained Tokens 9280, Peak mem 6.365 GB
# Iter 590: Train loss 0.067, Learning Rate 2.000e-04, It/sec 0.546, Tokens/sec 8.736, Trained Tokens 9440, Peak mem 6.365 GB
# Calculating loss...: 100%|██████████████████████| 25/25 [00:23<00:00,  1.06it/s]
# Iter 600: Val loss 0.074, Val took 23.534s
# Iter 600: Train loss 0.068, Learning Rate 2.000e-04, It/sec 0.547, Tokens/sec 8.755, Trained Tokens 9600, Peak mem 6.365 GB
# Iter 610: Train loss 0.059, Learning Rate 2.000e-04, It/sec 0.547, Tokens/sec 8.745, Trained Tokens 9760, Peak mem 6.365 GB
# Iter 620: Train loss 0.094, Learning Rate 2.000e-04, It/sec 0.565, Tokens/sec 9.048, Trained Tokens 9920, Peak mem 6.365 GB
# Iter 630: Train loss 0.072, Learning Rate 2.000e-04, It/sec 0.554, Tokens/sec 8.859, Trained Tokens 10080, Peak mem 6.365 GB
# Iter 640: Train loss 0.091, Learning Rate 2.000e-04, It/sec 0.561, Tokens/sec 8.977, Trained Tokens 10240, Peak mem 6.365 GB
# Iter 650: Train loss 0.133, Learning Rate 2.000e-04, It/sec 0.553, Tokens/sec 8.852, Trained Tokens 10400, Peak mem 6.365 GB
# Iter 660: Train loss 0.058, Learning Rate 2.000e-04, It/sec 0.560, Tokens/sec 8.963, Trained Tokens 10560, Peak mem 6.365 GB
# Iter 670: Train loss 0.062, Learning Rate 2.000e-04, It/sec 0.541, Tokens/sec 8.664, Trained Tokens 10720, Peak mem 6.365 GB
# Iter 680: Train loss 0.073, Learning Rate 2.000e-04, It/sec 0.548, Tokens/sec 8.764, Trained Tokens 10880, Peak mem 6.365 GB
# Iter 690: Train loss 0.053, Learning Rate 2.000e-04, It/sec 0.548, Tokens/sec 8.763, Trained Tokens 11040, Peak mem 6.365 GB
# Iter 700: Train loss 0.093, Learning Rate 2.000e-04, It/sec 0.554, Tokens/sec 8.866, Trained Tokens 11200, Peak mem 6.365 GB
# Iter 710: Train loss 0.051, Learning Rate 2.000e-04, It/sec 0.547, Tokens/sec 8.753, Trained Tokens 11360, Peak mem 6.365 GB
# Iter 720: Train loss 0.061, Learning Rate 2.000e-04, It/sec 0.548, Tokens/sec 8.760, Trained Tokens 11520, Peak mem 6.365 GB
# Iter 730: Train loss 0.078, Learning Rate 2.000e-04, It/sec 0.561, Tokens/sec 8.972, Trained Tokens 11680, Peak mem 6.365 GB
# Iter 740: Train loss 0.044, Learning Rate 2.000e-04, It/sec 0.567, Tokens/sec 9.068, Trained Tokens 11840, Peak mem 6.365 GB
# Iter 750: Train loss 0.051, Learning Rate 2.000e-04, It/sec 0.554, Tokens/sec 8.870, Trained Tokens 12000, Peak mem 6.365 GB
# Iter 760: Train loss 0.102, Learning Rate 2.000e-04, It/sec 0.568, Tokens/sec 9.094, Trained Tokens 12160, Peak mem 6.365 GB
# Iter 770: Train loss 0.050, Learning Rate 2.000e-04, It/sec 0.541, Tokens/sec 8.656, Trained Tokens 12320, Peak mem 6.365 GB
# Iter 780: Train loss 0.074, Learning Rate 2.000e-04, It/sec 0.560, Tokens/sec 8.960, Trained Tokens 12480, Peak mem 6.365 GB
# Iter 790: Train loss 0.027, Learning Rate 2.000e-04, It/sec 0.547, Tokens/sec 8.750, Trained Tokens 12640, Peak mem 6.365 GB
# Calculating loss...: 100%|██████████████████████| 25/25 [00:23<00:00,  1.07it/s]
# Iter 800: Val loss 0.075, Val took 23.430s
# Iter 800: Train loss 0.037, Learning Rate 2.000e-04, It/sec 0.547, Tokens/sec 8.744, Trained Tokens 12800, Peak mem 6.365 GB
# Iter 810: Train loss 0.031, Learning Rate 2.000e-04, It/sec 0.547, Tokens/sec 8.749, Trained Tokens 12960, Peak mem 6.365 GB
# Iter 820: Train loss 0.035, Learning Rate 2.000e-04, It/sec 0.548, Tokens/sec 8.760, Trained Tokens 13120, Peak mem 6.365 GB
# Iter 830: Train loss 0.099, Learning Rate 2.000e-04, It/sec 0.553, Tokens/sec 8.856, Trained Tokens 13280, Peak mem 6.365 GB
# Iter 840: Train loss 0.039, Learning Rate 2.000e-04, It/sec 0.546, Tokens/sec 8.741, Trained Tokens 13440, Peak mem 6.365 GB
# Iter 850: Train loss 0.088, Learning Rate 2.000e-04, It/sec 0.547, Tokens/sec 8.751, Trained Tokens 13600, Peak mem 6.365 GB
# Iter 860: Train loss 0.069, Learning Rate 2.000e-04, It/sec 0.546, Tokens/sec 8.744, Trained Tokens 13760, Peak mem 6.365 GB
# Iter 870: Train loss 0.047, Learning Rate 2.000e-04, It/sec 0.552, Tokens/sec 8.839, Trained Tokens 13920, Peak mem 6.365 GB
# Iter 880: Train loss 0.062, Learning Rate 2.000e-04, It/sec 0.560, Tokens/sec 8.962, Trained Tokens 14080, Peak mem 6.365 GB
# Iter 890: Train loss 0.086, Learning Rate 2.000e-04, It/sec 0.554, Tokens/sec 8.859, Trained Tokens 14240, Peak mem 6.365 GB
# Iter 900: Train loss 0.053, Learning Rate 2.000e-04, It/sec 0.548, Tokens/sec 8.763, Trained Tokens 14400, Peak mem 6.365 GB
# Iter 910: Train loss 0.093, Learning Rate 2.000e-04, It/sec 0.560, Tokens/sec 8.965, Trained Tokens 14560, Peak mem 6.365 GB
# Iter 920: Train loss 0.058, Learning Rate 2.000e-04, It/sec 0.554, Tokens/sec 8.862, Trained Tokens 14720, Peak mem 6.365 GB
# Iter 930: Train loss 0.075, Learning Rate 2.000e-04, It/sec 0.553, Tokens/sec 8.853, Trained Tokens 14880, Peak mem 6.365 GB
# Iter 940: Train loss 0.053, Learning Rate 2.000e-04, It/sec 0.543, Tokens/sec 8.681, Trained Tokens 15040, Peak mem 6.365 GB
# Iter 950: Train loss 0.087, Learning Rate 2.000e-04, It/sec 0.553, Tokens/sec 8.851, Trained Tokens 15200, Peak mem 6.365 GB
# Iter 960: Train loss 0.039, Learning Rate 2.000e-04, It/sec 0.548, Tokens/sec 8.770, Trained Tokens 15360, Peak mem 6.365 GB
# Iter 970: Train loss 0.050, Learning Rate 2.000e-04, It/sec 0.553, Tokens/sec 8.852, Trained Tokens 15520, Peak mem 6.365 GB
# Iter 980: Train loss 0.107, Learning Rate 2.000e-04, It/sec 0.541, Tokens/sec 8.650, Trained Tokens 15680, Peak mem 6.365 GB
# Iter 990: Train loss 0.079, Learning Rate 2.000e-04, It/sec 0.554, Tokens/sec 8.861, Trained Tokens 15840, Peak mem 6.365 GB
# Calculating loss...: 100%|██████████████████████| 25/25 [00:23<00:00,  1.07it/s]
# Iter 1000: Val loss 0.092, Val took 23.436s
# Iter 1000: Train loss 0.041, Learning Rate 2.000e-04, It/sec 0.553, Tokens/sec 8.852, Trained Tokens 16000, Peak mem 6.365 GB
# Iter 1000: Saved adapter weights to adapters_w2/T2A_demo_only/adapters.safetensors and adapters_w2/T2A_demo_only/0001000_adapters.safetensors.
# Iter 1010: Train loss 0.063, Learning Rate 2.000e-04, It/sec 0.541, Tokens/sec 8.651, Trained Tokens 16160, Peak mem 6.365 GB
# Iter 1020: Train loss 0.062, Learning Rate 2.000e-04, It/sec 0.552, Tokens/sec 8.840, Trained Tokens 16320, Peak mem 6.365 GB
# Iter 1030: Train loss 0.093, Learning Rate 2.000e-04, It/sec 0.547, Tokens/sec 8.758, Trained Tokens 16480, Peak mem 6.365 GB
# Iter 1040: Train loss 0.062, Learning Rate 2.000e-04, It/sec 0.589, Tokens/sec 9.425, Trained Tokens 16640, Peak mem 6.365 GB
# Iter 1050: Train loss 0.049, Learning Rate 2.000e-04, It/sec 0.554, Tokens/sec 8.866, Trained Tokens 16800, Peak mem 6.365 GB
# Iter 1060: Train loss 0.059, Learning Rate 2.000e-04, It/sec 0.547, Tokens/sec 8.758, Trained Tokens 16960, Peak mem 6.365 GB
# Iter 1070: Train loss 0.094, Learning Rate 2.000e-04, It/sec 0.546, Tokens/sec 8.742, Trained Tokens 17120, Peak mem 6.365 GB
# Iter 1080: Train loss 0.065, Learning Rate 2.000e-04, It/sec 0.553, Tokens/sec 8.844, Trained Tokens 17280, Peak mem 6.365 GB
# Iter 1090: Train loss 0.093, Learning Rate 2.000e-04, It/sec 0.547, Tokens/sec 8.750, Trained Tokens 17440, Peak mem 6.365 GB
# Iter 1100: Train loss 0.067, Learning Rate 2.000e-04, It/sec 0.541, Tokens/sec 8.661, Trained Tokens 17600, Peak mem 6.365 GB
# Iter 1110: Train loss 0.055, Learning Rate 2.000e-04, It/sec 0.548, Tokens/sec 8.761, Trained Tokens 17760, Peak mem 6.365 GB
# Iter 1120: Train loss 0.012, Learning Rate 2.000e-04, It/sec 0.547, Tokens/sec 8.759, Trained Tokens 17920, Peak mem 6.365 GB
# Iter 1130: Train loss 0.029, Learning Rate 2.000e-04, It/sec 0.567, Tokens/sec 9.077, Trained Tokens 18080, Peak mem 6.365 GB
# Iter 1140: Train loss 0.115, Learning Rate 2.000e-04, It/sec 0.567, Tokens/sec 9.070, Trained Tokens 18240, Peak mem 6.365 GB
# Iter 1150: Train loss 0.149, Learning Rate 2.000e-04, It/sec 0.554, Tokens/sec 8.867, Trained Tokens 18400, Peak mem 6.365 GB
# Iter 1160: Train loss 0.052, Learning Rate 2.000e-04, It/sec 0.554, Tokens/sec 8.867, Trained Tokens 18560, Peak mem 6.365 GB
# Iter 1170: Train loss 0.040, Learning Rate 2.000e-04, It/sec 0.548, Tokens/sec 8.763, Trained Tokens 18720, Peak mem 6.365 GB
# Iter 1180: Train loss 0.057, Learning Rate 2.000e-04, It/sec 0.553, Tokens/sec 8.856, Trained Tokens 18880, Peak mem 6.365 GB
# Iter 1190: Train loss 0.046, Learning Rate 2.000e-04, It/sec 0.560, Tokens/sec 8.962, Trained Tokens 19040, Peak mem 6.365 GB
# Calculating loss...: 100%|██████████████████████| 25/25 [00:23<00:00,  1.06it/s]
# Iter 1200: Val loss 0.083, Val took 23.633s
# Iter 1200: Train loss 0.081, Learning Rate 2.000e-04, It/sec 0.547, Tokens/sec 8.759, Trained Tokens 19200, Peak mem 6.365 GB
# Iter 1210: Train loss 0.078, Learning Rate 2.000e-04, It/sec 0.554, Tokens/sec 8.867, Trained Tokens 19360, Peak mem 6.365 GB
# Iter 1220: Train loss 0.077, Learning Rate 2.000e-04, It/sec 0.548, Tokens/sec 8.764, Trained Tokens 19520, Peak mem 6.365 GB
# Iter 1230: Train loss 0.064, Learning Rate 2.000e-04, It/sec 0.541, Tokens/sec 8.658, Trained Tokens 19680, Peak mem 6.365 GB
# Iter 1240: Train loss 0.051, Learning Rate 2.000e-04, It/sec 0.548, Tokens/sec 8.764, Trained Tokens 19840, Peak mem 6.365 GB
# Iter 1250: Train loss 0.071, Learning Rate 2.000e-04, It/sec 0.547, Tokens/sec 8.744, Trained Tokens 20000, Peak mem 6.365 GB
# Iter 1260: Train loss 0.056, Learning Rate 2.000e-04, It/sec 0.553, Tokens/sec 8.850, Trained Tokens 20160, Peak mem 6.365 GB
# Iter 1270: Train loss 0.085, Learning Rate 2.000e-04, It/sec 0.574, Tokens/sec 9.180, Trained Tokens 20320, Peak mem 6.365 GB
# Iter 1280: Train loss 0.137, Learning Rate 2.000e-04, It/sec 0.553, Tokens/sec 8.854, Trained Tokens 20480, Peak mem 6.365 GB
# Iter 1290: Train loss 0.051, Learning Rate 2.000e-04, It/sec 0.547, Tokens/sec 8.745, Trained Tokens 20640, Peak mem 6.365 GB
# Iter 1300: Train loss 0.046, Learning Rate 2.000e-04, It/sec 0.547, Tokens/sec 8.749, Trained Tokens 20800, Peak mem 6.365 GB
# Iter 1310: Train loss 0.148, Learning Rate 2.000e-04, It/sec 0.553, Tokens/sec 8.851, Trained Tokens 20960, Peak mem 6.365 GB
# Iter 1320: Train loss 0.059, Learning Rate 2.000e-04, It/sec 0.547, Tokens/sec 8.755, Trained Tokens 21120, Peak mem 6.365 GB
# Iter 1330: Train loss 0.082, Learning Rate 2.000e-04, It/sec 0.553, Tokens/sec 8.855, Trained Tokens 21280, Peak mem 6.365 GB
# Iter 1340: Train loss 0.043, Learning Rate 2.000e-04, It/sec 0.567, Tokens/sec 9.072, Trained Tokens 21440, Peak mem 6.365 GB
# Iter 1350: Train loss 0.023, Learning Rate 2.000e-04, It/sec 0.546, Tokens/sec 8.736, Trained Tokens 21600, Peak mem 6.365 GB
# Iter 1360: Train loss 0.079, Learning Rate 2.000e-04, It/sec 0.541, Tokens/sec 8.656, Trained Tokens 21760, Peak mem 6.365 GB
# Iter 1370: Train loss 0.044, Learning Rate 2.000e-04, It/sec 0.559, Tokens/sec 8.948, Trained Tokens 21920, Peak mem 6.365 GB
# Iter 1380: Train loss 0.020, Learning Rate 2.000e-04, It/sec 0.553, Tokens/sec 8.849, Trained Tokens 22080, Peak mem 6.365 GB
# Iter 1390: Train loss 0.058, Learning Rate 2.000e-04, It/sec 0.554, Tokens/sec 8.871, Trained Tokens 22240, Peak mem 6.365 GB
# Calculating loss...: 100%|██████████████████████| 25/25 [00:23<00:00,  1.06it/s]
# Iter 1400: Val loss 0.066, Val took 23.534s
# Iter 1400: Train loss 0.025, Learning Rate 2.000e-04, It/sec 0.541, Tokens/sec 8.659, Trained Tokens 22400, Peak mem 6.365 GB
# Iter 1410: Train loss 0.048, Learning Rate 2.000e-04, It/sec 0.553, Tokens/sec 8.852, Trained Tokens 22560, Peak mem 6.365 GB
# Iter 1420: Train loss 0.111, Learning Rate 2.000e-04, It/sec 0.561, Tokens/sec 8.978, Trained Tokens 22720, Peak mem 6.365 GB
# Iter 1430: Train loss 0.066, Learning Rate 2.000e-04, It/sec 0.573, Tokens/sec 9.175, Trained Tokens 22880, Peak mem 6.365 GB
# Iter 1440: Train loss 0.057, Learning Rate 2.000e-04, It/sec 0.547, Tokens/sec 8.760, Trained Tokens 23040, Peak mem 6.365 GB
# Iter 1450: Train loss 0.072, Learning Rate 2.000e-04, It/sec 0.541, Tokens/sec 8.656, Trained Tokens 23200, Peak mem 6.365 GB
# Iter 1460: Train loss 0.079, Learning Rate 2.000e-04, It/sec 0.561, Tokens/sec 8.973, Trained Tokens 23360, Peak mem 6.365 GB
# Iter 1470: Train loss 0.040, Learning Rate 2.000e-04, It/sec 0.554, Tokens/sec 8.862, Trained Tokens 23520, Peak mem 6.365 GB
# Iter 1480: Train loss 0.051, Learning Rate 2.000e-04, It/sec 0.541, Tokens/sec 8.651, Trained Tokens 23680, Peak mem 6.365 GB
# Iter 1490: Train loss 0.092, Learning Rate 2.000e-04, It/sec 0.568, Tokens/sec 9.082, Trained Tokens 23840, Peak mem 6.365 GB
# Iter 1500: Train loss 0.065, Learning Rate 2.000e-04, It/sec 0.547, Tokens/sec 8.757, Trained Tokens 24000, Peak mem 6.365 GB
# Iter 1500: Saved adapter weights to adapters_w2/T2A_demo_only/adapters.safetensors and adapters_w2/T2A_demo_only/0001500_adapters.safetensors.
# Iter 1510: Train loss 0.089, Learning Rate 2.000e-04, It/sec 0.553, Tokens/sec 8.845, Trained Tokens 24160, Peak mem 6.365 GB
# Iter 1520: Train loss 0.095, Learning Rate 2.000e-04, It/sec 0.567, Tokens/sec 9.071, Trained Tokens 24320, Peak mem 6.365 GB
# Iter 1530: Train loss 0.044, Learning Rate 2.000e-04, It/sec 0.547, Tokens/sec 8.753, Trained Tokens 24480, Peak mem 6.365 GB
# Iter 1540: Train loss 0.046, Learning Rate 2.000e-04, It/sec 0.560, Tokens/sec 8.954, Trained Tokens 24640, Peak mem 6.365 GB
# Iter 1550: Train loss 0.143, Learning Rate 2.000e-04, It/sec 0.554, Tokens/sec 8.859, Trained Tokens 24800, Peak mem 6.365 GB
# Iter 1560: Train loss 0.085, Learning Rate 2.000e-04, It/sec 0.553, Tokens/sec 8.845, Trained Tokens 24960, Peak mem 6.365 GB
# Iter 1570: Train loss 0.089, Learning Rate 2.000e-04, It/sec 0.547, Tokens/sec 8.745, Trained Tokens 25120, Peak mem 6.365 GB
# Iter 1580: Train loss 0.109, Learning Rate 2.000e-04, It/sec 0.560, Tokens/sec 8.962, Trained Tokens 25280, Peak mem 6.365 GB
# Iter 1590: Train loss 0.031, Learning Rate 2.000e-04, It/sec 0.546, Tokens/sec 8.729, Trained Tokens 25440, Peak mem 6.365 GB
# Calculating loss...: 100%|██████████████████████| 25/25 [00:23<00:00,  1.06it/s]
# Iter 1600: Val loss 0.079, Val took 23.531s
# Iter 1600: Train loss 0.100, Learning Rate 2.000e-04, It/sec 0.547, Tokens/sec 8.753, Trained Tokens 25600, Peak mem 6.365 GB
# Iter 1610: Train loss 0.090, Learning Rate 2.000e-04, It/sec 0.553, Tokens/sec 8.849, Trained Tokens 25760, Peak mem 6.365 GB
# Iter 1620: Train loss 0.042, Learning Rate 2.000e-04, It/sec 0.554, Tokens/sec 8.858, Trained Tokens 25920, Peak mem 6.365 GB
# Iter 1630: Train loss 0.053, Learning Rate 2.000e-04, It/sec 0.541, Tokens/sec 8.663, Trained Tokens 26080, Peak mem 6.365 GB
# Iter 1640: Train loss 0.079, Learning Rate 2.000e-04, It/sec 0.561, Tokens/sec 8.970, Trained Tokens 26240, Peak mem 6.365 GB
# Iter 1650: Train loss 0.040, Learning Rate 2.000e-04, It/sec 0.541, Tokens/sec 8.658, Trained Tokens 26400, Peak mem 6.365 GB
# Iter 1660: Train loss 0.039, Learning Rate 2.000e-04, It/sec 0.548, Tokens/sec 8.761, Trained Tokens 26560, Peak mem 6.365 GB
# Iter 1670: Train loss 0.040, Learning Rate 2.000e-04, It/sec 0.562, Tokens/sec 8.989, Trained Tokens 26720, Peak mem 6.365 GB
# Iter 1680: Train loss 0.071, Learning Rate 2.000e-04, It/sec 0.552, Tokens/sec 8.837, Trained Tokens 26880, Peak mem 6.365 GB
# Iter 1690: Train loss 0.046, Learning Rate 2.000e-04, It/sec 0.541, Tokens/sec 8.654, Trained Tokens 27040, Peak mem 6.365 GB
# Iter 1700: Train loss 0.072, Learning Rate 2.000e-04, It/sec 0.541, Tokens/sec 8.655, Trained Tokens 27200, Peak mem 6.365 GB
# Iter 1710: Train loss 0.039, Learning Rate 2.000e-04, It/sec 0.555, Tokens/sec 8.878, Trained Tokens 27360, Peak mem 6.365 GB
# Iter 1720: Train loss 0.094, Learning Rate 2.000e-04, It/sec 0.543, Tokens/sec 8.683, Trained Tokens 27520, Peak mem 6.365 GB
# Iter 1730: Train loss 0.047, Learning Rate 2.000e-04, It/sec 0.541, Tokens/sec 8.653, Trained Tokens 27680, Peak mem 6.365 GB
# Iter 1740: Train loss 0.044, Learning Rate 2.000e-04, It/sec 0.553, Tokens/sec 8.854, Trained Tokens 27840, Peak mem 6.365 GB
# Iter 1750: Train loss 0.023, Learning Rate 2.000e-04, It/sec 0.541, Tokens/sec 8.660, Trained Tokens 28000, Peak mem 6.365 GB
# Iter 1760: Train loss 0.148, Learning Rate 2.000e-04, It/sec 0.548, Tokens/sec 8.763, Trained Tokens 28160, Peak mem 6.365 GB
# Iter 1770: Train loss 0.060, Learning Rate 2.000e-04, It/sec 0.546, Tokens/sec 8.741, Trained Tokens 28320, Peak mem 6.365 GB
# Iter 1780: Train loss 0.055, Learning Rate 2.000e-04, It/sec 0.547, Tokens/sec 8.752, Trained Tokens 28480, Peak mem 6.365 GB
# Iter 1790: Train loss 0.083, Learning Rate 2.000e-04, It/sec 0.548, Tokens/sec 8.768, Trained Tokens 28640, Peak mem 6.365 GB
# Calculating loss...: 100%|██████████████████████| 25/25 [00:23<00:00,  1.07it/s]
# Iter 1800: Val loss 0.045, Val took 23.423s
# Iter 1800: Train loss 0.041, Learning Rate 2.000e-04, It/sec 0.559, Tokens/sec 8.951, Trained Tokens 28800, Peak mem 6.365 GB
# Iter 1810: Train loss 0.132, Learning Rate 2.000e-04, It/sec 0.542, Tokens/sec 8.667, Trained Tokens 28960, Peak mem 6.365 GB
# Iter 1820: Train loss 0.051, Learning Rate 2.000e-04, It/sec 0.547, Tokens/sec 8.757, Trained Tokens 29120, Peak mem 6.365 GB
# Iter 1830: Train loss 0.053, Learning Rate 2.000e-04, It/sec 0.547, Tokens/sec 8.755, Trained Tokens 29280, Peak mem 6.365 GB
# Iter 1840: Train loss 0.070, Learning Rate 2.000e-04, It/sec 0.554, Tokens/sec 8.863, Trained Tokens 29440, Peak mem 6.365 GB
# Iter 1850: Train loss 0.057, Learning Rate 2.000e-04, It/sec 0.547, Tokens/sec 8.748, Trained Tokens 29600, Peak mem 6.365 GB
# Iter 1860: Train loss 0.077, Learning Rate 2.000e-04, It/sec 0.553, Tokens/sec 8.850, Trained Tokens 29760, Peak mem 6.365 GB
# Iter 1870: Train loss 0.025, Learning Rate 2.000e-04, It/sec 0.547, Tokens/sec 8.748, Trained Tokens 29920, Peak mem 6.365 GB
# Iter 1880: Train loss 0.105, Learning Rate 2.000e-04, It/sec 0.547, Tokens/sec 8.750, Trained Tokens 30080, Peak mem 6.365 GB
# Iter 1890: Train loss 0.080, Learning Rate 2.000e-04, It/sec 0.567, Tokens/sec 9.066, Trained Tokens 30240, Peak mem 6.365 GB
# Iter 1900: Train loss 0.096, Learning Rate 2.000e-04, It/sec 0.547, Tokens/sec 8.750, Trained Tokens 30400, Peak mem 6.365 GB
# Iter 1910: Train loss 0.073, Learning Rate 2.000e-04, It/sec 0.540, Tokens/sec 8.643, Trained Tokens 30560, Peak mem 6.365 GB
# Iter 1920: Train loss 0.055, Learning Rate 2.000e-04, It/sec 0.554, Tokens/sec 8.861, Trained Tokens 30720, Peak mem 6.365 GB
# Iter 1930: Train loss 0.055, Learning Rate 2.000e-04, It/sec 0.560, Tokens/sec 8.964, Trained Tokens 30880, Peak mem 6.365 GB
# Iter 1940: Train loss 0.033, Learning Rate 2.000e-04, It/sec 0.561, Tokens/sec 8.970, Trained Tokens 31040, Peak mem 6.365 GB
# Iter 1950: Train loss 0.044, Learning Rate 2.000e-04, It/sec 0.548, Tokens/sec 8.760, Trained Tokens 31200, Peak mem 6.365 GB
# Iter 1960: Train loss 0.006, Learning Rate 2.000e-04, It/sec 0.560, Tokens/sec 8.955, Trained Tokens 31360, Peak mem 6.365 GB
# Iter 1970: Train loss 0.099, Learning Rate 2.000e-04, It/sec 0.554, Tokens/sec 8.867, Trained Tokens 31520, Peak mem 6.365 GB
# Iter 1980: Train loss 0.082, Learning Rate 2.000e-04, It/sec 0.547, Tokens/sec 8.745, Trained Tokens 31680, Peak mem 6.365 GB
# Iter 1990: Train loss 0.031, Learning Rate 2.000e-04, It/sec 0.560, Tokens/sec 8.966, Trained Tokens 31840, Peak mem 6.365 GB
# Calculating loss...: 100%|██████████████████████| 25/25 [00:23<00:00,  1.06it/s]
# Iter 2000: Val loss 0.069, Val took 23.539s
# Iter 2000: Train loss 0.172, Learning Rate 2.000e-04, It/sec 0.560, Tokens/sec 8.964, Trained Tokens 32000, Peak mem 6.365 GB
# Iter 2000: Saved adapter weights to adapters_w2/T2A_demo_only/adapters.safetensors and adapters_w2/T2A_demo_only/0002000_adapters.safetensors.
# Saved final weights to adapters_w2/T2A_demo_only/adapters.safetensors.

# %%
# ── Load model with T2A_demo_only adapter ──────────────────────────────
model_mlx, tok_mlx = load(
    MODEL_ID,
    adapter_path="./adapters_w3/T2A_demo_only",
)

# ── Inference ──────────────────────────────────────────────────────
t0 = time.time()
preds, refs, probs = run_inference_mlx(
    model_mlx, tok_mlx, test_ds_structured_demo, return_probs=True
)

# ── Evaluate ───────────────────────────────────────────────────────
metrics = evaluate_predictions(preds, refs, label_name="T2A_demo_only")

# ── Calibration ────────────────────────────────────────────────────
ece = calibration_analysis(
    probs, refs,
    label_name="T2A_demo_only",
    save_path=os.path.join(OUTPUT_DIR, "calibration_T2A_demo_only.png")
)
metrics["ECE"] = ece
all_metrics.append(metrics)

# ── Save predictions ───────────────────────────────────────────────
out_df = pd.DataFrame({"Predicted_Label": preds, "Ground_Truth": refs, "P_Yes": probs})
out_df.to_csv(os.path.join(OUTPUT_DIR, "predictions_T2A_demo_only.csv"), index=False)

elapsed = round(time.time() - t0, 2)
experiment_times["T2A_demo_only"] = elapsed
print(f"\n  ⏱ T2A_demo_only done in {elapsed:.1f}s")

# ── Clean up ───────────────────────────────────────────────────────
del model_mlx, tok_mlx
# Out:
# Downloading (incomplete total...): 0.00B [00:00, ?B/s]
# Fetching 9 files:   0%|          | 0/9 [00:00<?, ?it/s]
# Generating:   0%|          | 0/8275 [00:00<?, ?it/s]
# ── T2A_demo_only ──
#   Label: T2A_demo_only
#   N_test: 8275
#   Accuracy: 0.8916
#   Recall: 0.3966
#   Precision: 0.5292
#   F1: 0.4534
#   Unknown: 0
#               precision    recall  f1-score   support
#
#           No       0.93      0.95      0.94      7337
#          Yes       0.53      0.40      0.45       938
#
#     accuracy                           0.89      8275
#    macro avg       0.73      0.68      0.70      8275
# weighted avg       0.88      0.89      0.88      8275
#
#   ECE: 0.0684 | Saved → ./results_wave3/calibration_T2A_demo_only.png
#
#   ⏱ T2A_demo_only done in 2732.8s

# %% [markdown]
# ### Training and Inference for T2C_longitudinal_model

# %%
# !mlx_lm.lora \
    --model {MODEL_ID} \
    --train \
    --data ./mlx_data/T2C_longitudinal_model \
    --num-layers 16 \
    --batch-size 4 \
    --grad-accumulation-steps 4 \
    --iters 2000 \
    --learning-rate 2e-4 \
    --mask-prompt \
    --adapter-path ./adapters_w3/T2C_longitudinal_model \
    --save-every 500 \
    -c ./configs/lora_config.yaml
# Out:
# Loading configuration file ./configs/lora_config.yaml
# Loading pretrained model
# Downloading (incomplete total...): 0.00B [00:00, ?B/s]
# Fetching 9 files: 100%|███████████████████████| 9/9 [00:00<00:00, 142987.64it/s]
# Download complete: : 0.00B [00:00, ?B/s]
# Loading datasets
# Training
# Trainable parameters: 0.684% (10.551M/1543.714M)
# Starting training..., iters: 2000
# Calculating loss...: 100%|██████████████████████| 25/25 [00:18<00:00,  1.34it/s]
# Iter 1: Val loss 7.315, Val took 18.656s
# Iter 10: Train loss 3.535, Learning Rate 2.000e-04, It/sec 0.695, Tokens/sec 11.116, Trained Tokens 160, Peak mem 5.275 GB
# Iter 20: Train loss 0.220, Learning Rate 2.000e-04, It/sec 0.702, Tokens/sec 11.234, Trained Tokens 320, Peak mem 5.275 GB
# Iter 30: Train loss 0.027, Learning Rate 2.000e-04, It/sec 0.703, Tokens/sec 11.249, Trained Tokens 480, Peak mem 5.275 GB
# Iter 40: Train loss 0.098, Learning Rate 2.000e-04, It/sec 0.703, Tokens/sec 11.254, Trained Tokens 640, Peak mem 5.275 GB
# Iter 50: Train loss 0.027, Learning Rate 2.000e-04, It/sec 0.701, Tokens/sec 11.220, Trained Tokens 800, Peak mem 5.275 GB
# Iter 60: Train loss 0.089, Learning Rate 2.000e-04, It/sec 0.702, Tokens/sec 11.236, Trained Tokens 960, Peak mem 5.275 GB
# Iter 70: Train loss 0.055, Learning Rate 2.000e-04, It/sec 0.702, Tokens/sec 11.238, Trained Tokens 1120, Peak mem 5.275 GB
# Iter 80: Train loss 0.078, Learning Rate 2.000e-04, It/sec 0.702, Tokens/sec 11.231, Trained Tokens 1280, Peak mem 5.275 GB
# Iter 90: Train loss 0.065, Learning Rate 2.000e-04, It/sec 0.703, Tokens/sec 11.251, Trained Tokens 1440, Peak mem 5.275 GB
# Iter 100: Train loss 0.110, Learning Rate 2.000e-04, It/sec 0.704, Tokens/sec 11.262, Trained Tokens 1600, Peak mem 5.275 GB
# Iter 110: Train loss 0.027, Learning Rate 2.000e-04, It/sec 0.703, Tokens/sec 11.244, Trained Tokens 1760, Peak mem 5.275 GB
# Iter 120: Train loss 0.022, Learning Rate 2.000e-04, It/sec 0.701, Tokens/sec 11.219, Trained Tokens 1920, Peak mem 5.275 GB
# Iter 130: Train loss 0.047, Learning Rate 2.000e-04, It/sec 0.702, Tokens/sec 11.235, Trained Tokens 2080, Peak mem 5.275 GB
# Iter 140: Train loss 0.072, Learning Rate 2.000e-04, It/sec 0.702, Tokens/sec 11.234, Trained Tokens 2240, Peak mem 5.275 GB
# Iter 150: Train loss 0.079, Learning Rate 2.000e-04, It/sec 0.703, Tokens/sec 11.252, Trained Tokens 2400, Peak mem 5.275 GB
# Iter 160: Train loss 0.033, Learning Rate 2.000e-04, It/sec 0.696, Tokens/sec 11.142, Trained Tokens 2560, Peak mem 5.275 GB
# Iter 170: Train loss 0.038, Learning Rate 2.000e-04, It/sec 0.702, Tokens/sec 11.235, Trained Tokens 2720, Peak mem 5.275 GB
# Iter 180: Train loss 0.078, Learning Rate 2.000e-04, It/sec 0.702, Tokens/sec 11.229, Trained Tokens 2880, Peak mem 5.275 GB
# Iter 190: Train loss 0.075, Learning Rate 2.000e-04, It/sec 0.701, Tokens/sec 11.216, Trained Tokens 3040, Peak mem 5.275 GB
# Calculating loss...: 100%|██████████████████████| 25/25 [00:18<00:00,  1.35it/s]
# Iter 200: Val loss 0.039, Val took 18.529s
# Iter 200: Train loss 0.025, Learning Rate 2.000e-04, It/sec 0.703, Tokens/sec 11.243, Trained Tokens 3200, Peak mem 5.275 GB
# Iter 210: Train loss 0.053, Learning Rate 2.000e-04, It/sec 0.703, Tokens/sec 11.242, Trained Tokens 3360, Peak mem 5.275 GB
# Iter 220: Train loss 0.059, Learning Rate 2.000e-04, It/sec 0.702, Tokens/sec 11.237, Trained Tokens 3520, Peak mem 5.275 GB
# Iter 230: Train loss 0.032, Learning Rate 2.000e-04, It/sec 0.703, Tokens/sec 11.254, Trained Tokens 3680, Peak mem 5.275 GB
# Iter 240: Train loss 0.006, Learning Rate 2.000e-04, It/sec 0.702, Tokens/sec 11.234, Trained Tokens 3840, Peak mem 5.275 GB
# Iter 250: Train loss 0.044, Learning Rate 2.000e-04, It/sec 0.703, Tokens/sec 11.247, Trained Tokens 4000, Peak mem 5.275 GB
# Iter 260: Train loss 0.004, Learning Rate 2.000e-04, It/sec 0.703, Tokens/sec 11.250, Trained Tokens 4160, Peak mem 5.275 GB
# Iter 270: Train loss 0.004, Learning Rate 2.000e-04, It/sec 0.704, Tokens/sec 11.264, Trained Tokens 4320, Peak mem 5.275 GB
# Iter 280: Train loss 0.020, Learning Rate 2.000e-04, It/sec 0.704, Tokens/sec 11.261, Trained Tokens 4480, Peak mem 5.275 GB
# Iter 290: Train loss 0.109, Learning Rate 2.000e-04, It/sec 0.702, Tokens/sec 11.235, Trained Tokens 4640, Peak mem 5.275 GB
# Iter 300: Train loss 0.037, Learning Rate 2.000e-04, It/sec 0.703, Tokens/sec 11.245, Trained Tokens 4800, Peak mem 5.275 GB
# Iter 310: Train loss 0.069, Learning Rate 2.000e-04, It/sec 0.702, Tokens/sec 11.239, Trained Tokens 4960, Peak mem 5.275 GB
# Iter 320: Train loss 0.075, Learning Rate 2.000e-04, It/sec 0.701, Tokens/sec 11.222, Trained Tokens 5120, Peak mem 5.275 GB
# Iter 330: Train loss 0.039, Learning Rate 2.000e-04, It/sec 0.702, Tokens/sec 11.224, Trained Tokens 5280, Peak mem 5.275 GB
# Iter 340: Train loss 0.042, Learning Rate 2.000e-04, It/sec 0.702, Tokens/sec 11.235, Trained Tokens 5440, Peak mem 5.275 GB
# Iter 350: Train loss 0.022, Learning Rate 2.000e-04, It/sec 0.703, Tokens/sec 11.246, Trained Tokens 5600, Peak mem 5.275 GB
# Iter 360: Train loss 0.054, Learning Rate 2.000e-04, It/sec 0.703, Tokens/sec 11.241, Trained Tokens 5760, Peak mem 5.275 GB
# Iter 370: Train loss 0.009, Learning Rate 2.000e-04, It/sec 0.703, Tokens/sec 11.248, Trained Tokens 5920, Peak mem 5.275 GB
# Iter 380: Train loss 0.013, Learning Rate 2.000e-04, It/sec 0.703, Tokens/sec 11.255, Trained Tokens 6080, Peak mem 5.275 GB
# Iter 390: Train loss 0.005, Learning Rate 2.000e-04, It/sec 0.703, Tokens/sec 11.246, Trained Tokens 6240, Peak mem 5.275 GB
# Calculating loss...: 100%|██████████████████████| 25/25 [17:43<00:00, 42.56s/it]
# Iter 400: Val loss 0.055, Val took 18.921s
# Iter 400: Train loss 0.019, Learning Rate 2.000e-04, It/sec 0.693, Tokens/sec 11.092, Trained Tokens 6400, Peak mem 5.275 GB
# Iter 410: Train loss 0.014, Learning Rate 2.000e-04, It/sec 0.675, Tokens/sec 10.807, Trained Tokens 6560, Peak mem 5.275 GB
# Iter 420: Train loss 0.033, Learning Rate 2.000e-04, It/sec 0.671, Tokens/sec 10.742, Trained Tokens 6720, Peak mem 5.275 GB
# Iter 430: Train loss 0.004, Learning Rate 2.000e-04, It/sec 0.666, Tokens/sec 10.649, Trained Tokens 6880, Peak mem 5.275 GB
# Iter 440: Train loss 0.103, Learning Rate 2.000e-04, It/sec 0.658, Tokens/sec 10.530, Trained Tokens 7040, Peak mem 5.275 GB
# Iter 450: Train loss 0.027, Learning Rate 2.000e-04, It/sec 0.691, Tokens/sec 11.056, Trained Tokens 7200, Peak mem 5.275 GB
# Iter 460: Train loss 0.046, Learning Rate 2.000e-04, It/sec 0.689, Tokens/sec 11.018, Trained Tokens 7360, Peak mem 5.275 GB
# Iter 470: Train loss 0.017, Learning Rate 2.000e-04, It/sec 0.689, Tokens/sec 11.025, Trained Tokens 7520, Peak mem 5.275 GB
# Iter 480: Train loss 0.023, Learning Rate 2.000e-04, It/sec 0.690, Tokens/sec 11.032, Trained Tokens 7680, Peak mem 5.275 GB
# Iter 490: Train loss 0.003, Learning Rate 2.000e-04, It/sec 0.687, Tokens/sec 10.987, Trained Tokens 7840, Peak mem 5.275 GB
# Iter 500: Train loss 0.022, Learning Rate 2.000e-04, It/sec 0.690, Tokens/sec 11.040, Trained Tokens 8000, Peak mem 5.275 GB
# Iter 500: Saved adapter weights to adapters_w3/T2C_longitudinal_model/adapters.safetensors and adapters_w3/T2C_longitudinal_model/0000500_adapters.safetensors.
# Iter 510: Train loss 0.017, Learning Rate 2.000e-04, It/sec 0.688, Tokens/sec 11.015, Trained Tokens 8160, Peak mem 5.317 GB
# Iter 520: Train loss 0.003, Learning Rate 2.000e-04, It/sec 0.691, Tokens/sec 11.049, Trained Tokens 8320, Peak mem 5.317 GB
# Iter 530: Train loss 0.015, Learning Rate 2.000e-04, It/sec 0.689, Tokens/sec 11.030, Trained Tokens 8480, Peak mem 5.317 GB
# Iter 540: Train loss 0.097, Learning Rate 2.000e-04, It/sec 0.690, Tokens/sec 11.047, Trained Tokens 8640, Peak mem 5.317 GB
# Iter 550: Train loss 0.061, Learning Rate 2.000e-04, It/sec 0.690, Tokens/sec 11.044, Trained Tokens 8800, Peak mem 5.317 GB
# Iter 560: Train loss 0.096, Learning Rate 2.000e-04, It/sec 0.690, Tokens/sec 11.039, Trained Tokens 8960, Peak mem 5.317 GB
# Iter 570: Train loss 0.044, Learning Rate 2.000e-04, It/sec 0.686, Tokens/sec 10.984, Trained Tokens 9120, Peak mem 5.317 GB
# Iter 580: Train loss 0.022, Learning Rate 2.000e-04, It/sec 0.690, Tokens/sec 11.041, Trained Tokens 9280, Peak mem 5.317 GB
# Iter 590: Train loss 0.035, Learning Rate 2.000e-04, It/sec 0.692, Tokens/sec 11.074, Trained Tokens 9440, Peak mem 5.317 GB
# Calculating loss...: 100%|██████████████████████| 25/25 [00:18<00:00,  1.34it/s]
# Iter 600: Val loss 0.036, Val took 18.731s
# Iter 600: Train loss 0.057, Learning Rate 2.000e-04, It/sec 0.688, Tokens/sec 11.005, Trained Tokens 9600, Peak mem 5.317 GB
# Iter 610: Train loss 0.037, Learning Rate 2.000e-04, It/sec 0.687, Tokens/sec 10.993, Trained Tokens 9760, Peak mem 5.317 GB
# Iter 620: Train loss 0.053, Learning Rate 2.000e-04, It/sec 0.688, Tokens/sec 11.007, Trained Tokens 9920, Peak mem 5.317 GB
# Iter 630: Train loss 0.022, Learning Rate 2.000e-04, It/sec 0.688, Tokens/sec 11.007, Trained Tokens 10080, Peak mem 5.317 GB
# Iter 640: Train loss 0.072, Learning Rate 2.000e-04, It/sec 0.690, Tokens/sec 11.045, Trained Tokens 10240, Peak mem 5.317 GB
# Iter 650: Train loss 0.072, Learning Rate 2.000e-04, It/sec 0.689, Tokens/sec 11.020, Trained Tokens 10400, Peak mem 5.317 GB
# Iter 660: Train loss 0.014, Learning Rate 2.000e-04, It/sec 0.689, Tokens/sec 11.018, Trained Tokens 10560, Peak mem 5.317 GB
# Iter 670: Train loss 0.032, Learning Rate 2.000e-04, It/sec 0.687, Tokens/sec 10.995, Trained Tokens 10720, Peak mem 5.317 GB
# Iter 680: Train loss 0.032, Learning Rate 2.000e-04, It/sec 0.689, Tokens/sec 11.021, Trained Tokens 10880, Peak mem 5.317 GB
# Iter 690: Train loss 0.039, Learning Rate 2.000e-04, It/sec 0.690, Tokens/sec 11.046, Trained Tokens 11040, Peak mem 5.317 GB
# Iter 700: Train loss 0.087, Learning Rate 2.000e-04, It/sec 0.689, Tokens/sec 11.029, Trained Tokens 11200, Peak mem 5.317 GB
# Iter 710: Train loss 0.007, Learning Rate 2.000e-04, It/sec 0.689, Tokens/sec 11.029, Trained Tokens 11360, Peak mem 5.317 GB
# Iter 720: Train loss 0.013, Learning Rate 2.000e-04, It/sec 0.688, Tokens/sec 11.014, Trained Tokens 11520, Peak mem 5.317 GB
# Iter 730: Train loss 0.049, Learning Rate 2.000e-04, It/sec 0.690, Tokens/sec 11.043, Trained Tokens 11680, Peak mem 5.317 GB
# Iter 740: Train loss 0.009, Learning Rate 2.000e-04, It/sec 0.688, Tokens/sec 11.011, Trained Tokens 11840, Peak mem 5.317 GB
# Iter 750: Train loss 0.007, Learning Rate 2.000e-04, It/sec 0.689, Tokens/sec 11.017, Trained Tokens 12000, Peak mem 5.317 GB
# Iter 760: Train loss 0.060, Learning Rate 2.000e-04, It/sec 0.686, Tokens/sec 10.977, Trained Tokens 12160, Peak mem 5.317 GB
# Iter 770: Train loss 0.044, Learning Rate 2.000e-04, It/sec 0.688, Tokens/sec 11.015, Trained Tokens 12320, Peak mem 5.317 GB
# Iter 780: Train loss 0.018, Learning Rate 2.000e-04, It/sec 0.689, Tokens/sec 11.029, Trained Tokens 12480, Peak mem 5.317 GB
# Iter 790: Train loss 0.005, Learning Rate 2.000e-04, It/sec 0.686, Tokens/sec 10.973, Trained Tokens 12640, Peak mem 5.317 GB
# Calculating loss...: 100%|██████████████████████| 25/25 [00:18<00:00,  1.33it/s]
# Iter 800: Val loss 0.023, Val took 18.835s
# Iter 800: Train loss 0.061, Learning Rate 2.000e-04, It/sec 0.694, Tokens/sec 11.099, Trained Tokens 12800, Peak mem 5.317 GB
# Iter 810: Train loss 0.030, Learning Rate 2.000e-04, It/sec 0.688, Tokens/sec 11.005, Trained Tokens 12960, Peak mem 5.317 GB
# Iter 820: Train loss 0.016, Learning Rate 2.000e-04, It/sec 0.685, Tokens/sec 10.957, Trained Tokens 13120, Peak mem 5.317 GB
# Iter 830: Train loss 0.047, Learning Rate 2.000e-04, It/sec 0.694, Tokens/sec 11.102, Trained Tokens 13280, Peak mem 5.317 GB
# Iter 840: Train loss 0.045, Learning Rate 2.000e-04, It/sec 0.694, Tokens/sec 11.103, Trained Tokens 13440, Peak mem 5.317 GB
# Iter 850: Train loss 0.022, Learning Rate 2.000e-04, It/sec 0.672, Tokens/sec 10.746, Trained Tokens 13600, Peak mem 5.317 GB
# Iter 860: Train loss 0.057, Learning Rate 2.000e-04, It/sec 0.693, Tokens/sec 11.082, Trained Tokens 13760, Peak mem 5.317 GB
# Iter 870: Train loss 0.034, Learning Rate 2.000e-04, It/sec 0.679, Tokens/sec 10.863, Trained Tokens 13920, Peak mem 5.317 GB
# Iter 880: Train loss 0.023, Learning Rate 2.000e-04, It/sec 0.685, Tokens/sec 10.968, Trained Tokens 14080, Peak mem 5.317 GB
# Iter 890: Train loss 0.031, Learning Rate 2.000e-04, It/sec 0.695, Tokens/sec 11.114, Trained Tokens 14240, Peak mem 5.317 GB
# Iter 900: Train loss 0.078, Learning Rate 2.000e-04, It/sec 0.698, Tokens/sec 11.173, Trained Tokens 14400, Peak mem 5.317 GB
# Iter 910: Train loss 0.043, Learning Rate 2.000e-04, It/sec 0.696, Tokens/sec 11.129, Trained Tokens 14560, Peak mem 5.317 GB
# Iter 920: Train loss 0.011, Learning Rate 2.000e-04, It/sec 0.671, Tokens/sec 10.733, Trained Tokens 14720, Peak mem 5.317 GB
# Iter 930: Train loss 0.046, Learning Rate 2.000e-04, It/sec 0.674, Tokens/sec 10.791, Trained Tokens 14880, Peak mem 5.317 GB
# Iter 940: Train loss 0.032, Learning Rate 2.000e-04, It/sec 0.690, Tokens/sec 11.033, Trained Tokens 15040, Peak mem 5.317 GB
# Iter 950: Train loss 0.065, Learning Rate 2.000e-04, It/sec 0.688, Tokens/sec 11.005, Trained Tokens 15200, Peak mem 5.317 GB
# Iter 960: Train loss 0.024, Learning Rate 2.000e-04, It/sec 0.691, Tokens/sec 11.057, Trained Tokens 15360, Peak mem 5.317 GB
# Iter 970: Train loss 0.009, Learning Rate 2.000e-04, It/sec 0.670, Tokens/sec 10.722, Trained Tokens 15520, Peak mem 5.317 GB
# Iter 980: Train loss 0.040, Learning Rate 2.000e-04, It/sec 0.681, Tokens/sec 10.888, Trained Tokens 15680, Peak mem 5.317 GB
# Iter 990: Train loss 0.068, Learning Rate 2.000e-04, It/sec 0.691, Tokens/sec 11.062, Trained Tokens 15840, Peak mem 5.317 GB
# Calculating loss...: 100%|██████████████████████| 25/25 [00:18<00:00,  1.34it/s]
# Iter 1000: Val loss 0.055, Val took 18.734s
# Iter 1000: Train loss 0.013, Learning Rate 2.000e-04, It/sec 0.690, Tokens/sec 11.036, Trained Tokens 16000, Peak mem 5.317 GB
# Iter 1000: Saved adapter weights to adapters_w3/T2C_longitudinal_model/adapters.safetensors and adapters_w3/T2C_longitudinal_model/0001000_adapters.safetensors.
# Iter 1010: Train loss 0.023, Learning Rate 2.000e-04, It/sec 0.695, Tokens/sec 11.117, Trained Tokens 16160, Peak mem 5.317 GB
# Iter 1020: Train loss 0.021, Learning Rate 2.000e-04, It/sec 0.647, Tokens/sec 10.353, Trained Tokens 16320, Peak mem 5.317 GB
# Iter 1030: Train loss 0.063, Learning Rate 2.000e-04, It/sec 0.692, Tokens/sec 11.066, Trained Tokens 16480, Peak mem 5.317 GB
# Iter 1040: Train loss 0.033, Learning Rate 2.000e-04, It/sec 0.685, Tokens/sec 10.956, Trained Tokens 16640, Peak mem 5.317 GB
# Iter 1050: Train loss 0.038, Learning Rate 2.000e-04, It/sec 0.699, Tokens/sec 11.190, Trained Tokens 16800, Peak mem 5.317 GB
# Iter 1060: Train loss 0.013, Learning Rate 2.000e-04, It/sec 0.694, Tokens/sec 11.097, Trained Tokens 16960, Peak mem 5.317 GB
# Iter 1070: Train loss 0.075, Learning Rate 2.000e-04, It/sec 0.698, Tokens/sec 11.170, Trained Tokens 17120, Peak mem 5.317 GB
# Iter 1080: Train loss 0.062, Learning Rate 2.000e-04, It/sec 0.686, Tokens/sec 10.977, Trained Tokens 17280, Peak mem 5.317 GB
# Iter 1090: Train loss 0.029, Learning Rate 2.000e-04, It/sec 0.692, Tokens/sec 11.069, Trained Tokens 17440, Peak mem 5.317 GB
# Iter 1100: Train loss 0.018, Learning Rate 2.000e-04, It/sec 0.674, Tokens/sec 10.781, Trained Tokens 17600, Peak mem 5.317 GB
# Iter 1110: Train loss 0.012, Learning Rate 2.000e-04, It/sec 0.679, Tokens/sec 10.865, Trained Tokens 17760, Peak mem 5.317 GB
# Iter 1120: Train loss 0.005, Learning Rate 2.000e-04, It/sec 0.686, Tokens/sec 10.982, Trained Tokens 17920, Peak mem 5.317 GB
# Iter 1130: Train loss 0.033, Learning Rate 2.000e-04, It/sec 0.683, Tokens/sec 10.931, Trained Tokens 18080, Peak mem 5.317 GB
# Iter 1140: Train loss 0.066, Learning Rate 2.000e-04, It/sec 0.692, Tokens/sec 11.075, Trained Tokens 18240, Peak mem 5.317 GB
# Iter 1150: Train loss 0.036, Learning Rate 2.000e-04, It/sec 0.691, Tokens/sec 11.059, Trained Tokens 18400, Peak mem 5.317 GB
# Iter 1160: Train loss 0.006, Learning Rate 2.000e-04, It/sec 0.695, Tokens/sec 11.112, Trained Tokens 18560, Peak mem 5.317 GB
# Iter 1170: Train loss 0.005, Learning Rate 2.000e-04, It/sec 0.691, Tokens/sec 11.054, Trained Tokens 18720, Peak mem 5.317 GB
# Iter 1180: Train loss 0.005, Learning Rate 2.000e-04, It/sec 0.690, Tokens/sec 11.038, Trained Tokens 18880, Peak mem 5.317 GB
# Iter 1190: Train loss 0.020, Learning Rate 2.000e-04, It/sec 0.690, Tokens/sec 11.048, Trained Tokens 19040, Peak mem 5.317 GB
# Calculating loss...: 100%|██████████████████████| 25/25 [00:19<00:00,  1.29it/s]
# Iter 1200: Val loss 0.030, Val took 19.395s
# Iter 1200: Train loss 0.061, Learning Rate 2.000e-04, It/sec 0.682, Tokens/sec 10.910, Trained Tokens 19200, Peak mem 5.317 GB
# Iter 1210: Train loss 0.053, Learning Rate 2.000e-04, It/sec 0.681, Tokens/sec 10.893, Trained Tokens 19360, Peak mem 5.317 GB
# Iter 1220: Train loss 0.071, Learning Rate 2.000e-04, It/sec 0.688, Tokens/sec 11.001, Trained Tokens 19520, Peak mem 5.317 GB
# Iter 1230: Train loss 0.031, Learning Rate 2.000e-04, It/sec 0.687, Tokens/sec 10.989, Trained Tokens 19680, Peak mem 5.317 GB
# Iter 1240: Train loss 0.023, Learning Rate 2.000e-04, It/sec 0.660, Tokens/sec 10.562, Trained Tokens 19840, Peak mem 5.317 GB
# Iter 1250: Train loss 0.081, Learning Rate 2.000e-04, It/sec 0.688, Tokens/sec 11.001, Trained Tokens 20000, Peak mem 5.317 GB
# Iter 1260: Train loss 0.009, Learning Rate 2.000e-04, It/sec 0.686, Tokens/sec 10.979, Trained Tokens 20160, Peak mem 5.317 GB
# Iter 1270: Train loss 0.012, Learning Rate 2.000e-04, It/sec 0.688, Tokens/sec 11.004, Trained Tokens 20320, Peak mem 5.317 GB
# Iter 1280: Train loss 0.048, Learning Rate 2.000e-04, It/sec 0.687, Tokens/sec 10.993, Trained Tokens 20480, Peak mem 5.317 GB
# Iter 1290: Train loss 0.012, Learning Rate 2.000e-04, It/sec 0.688, Tokens/sec 11.013, Trained Tokens 20640, Peak mem 5.317 GB
# Iter 1300: Train loss 0.046, Learning Rate 2.000e-04, It/sec 0.689, Tokens/sec 11.031, Trained Tokens 20800, Peak mem 5.317 GB
# Iter 1310: Train loss 0.062, Learning Rate 2.000e-04, It/sec 0.665, Tokens/sec 10.646, Trained Tokens 20960, Peak mem 5.317 GB
# Iter 1320: Train loss 0.033, Learning Rate 2.000e-04, It/sec 0.681, Tokens/sec 10.891, Trained Tokens 21120, Peak mem 5.317 GB
# Iter 1330: Train loss 0.007, Learning Rate 2.000e-04, It/sec 0.680, Tokens/sec 10.874, Trained Tokens 21280, Peak mem 5.317 GB
# Iter 1340: Train loss 0.034, Learning Rate 2.000e-04, It/sec 0.687, Tokens/sec 10.997, Trained Tokens 21440, Peak mem 5.317 GB
# Iter 1350: Train loss 0.006, Learning Rate 2.000e-04, It/sec 0.682, Tokens/sec 10.913, Trained Tokens 21600, Peak mem 5.317 GB
# Iter 1360: Train loss 0.009, Learning Rate 2.000e-04, It/sec 0.669, Tokens/sec 10.704, Trained Tokens 21760, Peak mem 5.317 GB
# Iter 1370: Train loss 0.027, Learning Rate 2.000e-04, It/sec 0.668, Tokens/sec 10.690, Trained Tokens 21920, Peak mem 5.317 GB
# Iter 1380: Train loss 0.013, Learning Rate 2.000e-04, It/sec 0.678, Tokens/sec 10.844, Trained Tokens 22080, Peak mem 5.317 GB
# Iter 1390: Train loss 0.065, Learning Rate 2.000e-04, It/sec 0.671, Tokens/sec 10.740, Trained Tokens 22240, Peak mem 5.317 GB
# Calculating loss...: 100%|██████████████████████| 25/25 [00:19<00:00,  1.27it/s]
# Iter 1400: Val loss 0.020, Val took 19.761s
# Iter 1400: Train loss 0.005, Learning Rate 2.000e-04, It/sec 0.673, Tokens/sec 10.774, Trained Tokens 22400, Peak mem 5.317 GB
# Iter 1410: Train loss 0.022, Learning Rate 2.000e-04, It/sec 0.679, Tokens/sec 10.858, Trained Tokens 22560, Peak mem 5.317 GB
# Iter 1420: Train loss 0.092, Learning Rate 2.000e-04, It/sec 0.682, Tokens/sec 10.908, Trained Tokens 22720, Peak mem 5.317 GB
# Iter 1430: Train loss 0.020, Learning Rate 2.000e-04, It/sec 0.682, Tokens/sec 10.911, Trained Tokens 22880, Peak mem 5.317 GB
# Iter 1440: Train loss 0.033, Learning Rate 2.000e-04, It/sec 0.683, Tokens/sec 10.933, Trained Tokens 23040, Peak mem 5.317 GB
# Iter 1450: Train loss 0.013, Learning Rate 2.000e-04, It/sec 0.683, Tokens/sec 10.921, Trained Tokens 23200, Peak mem 5.317 GB
# Iter 1460: Train loss 0.023, Learning Rate 2.000e-04, It/sec 0.666, Tokens/sec 10.651, Trained Tokens 23360, Peak mem 5.317 GB
# Iter 1470: Train loss 0.020, Learning Rate 2.000e-04, It/sec 0.676, Tokens/sec 10.821, Trained Tokens 23520, Peak mem 5.317 GB
# Iter 1480: Train loss 0.045, Learning Rate 2.000e-04, It/sec 0.672, Tokens/sec 10.749, Trained Tokens 23680, Peak mem 5.317 GB
# Iter 1490: Train loss 0.124, Learning Rate 2.000e-04, It/sec 0.672, Tokens/sec 10.758, Trained Tokens 23840, Peak mem 5.317 GB
# Iter 1500: Train loss 0.038, Learning Rate 2.000e-04, It/sec 0.592, Tokens/sec 9.478, Trained Tokens 24000, Peak mem 5.317 GB
# Iter 1500: Saved adapter weights to adapters_w3/T2C_longitudinal_model/adapters.safetensors and adapters_w3/T2C_longitudinal_model/0001500_adapters.safetensors.
# Iter 1510: Train loss 0.026, Learning Rate 2.000e-04, It/sec 0.695, Tokens/sec 11.125, Trained Tokens 24160, Peak mem 5.317 GB
# Iter 1520: Train loss 0.054, Learning Rate 2.000e-04, It/sec 0.696, Tokens/sec 11.134, Trained Tokens 24320, Peak mem 5.317 GB
# Iter 1530: Train loss 0.019, Learning Rate 2.000e-04, It/sec 0.692, Tokens/sec 11.076, Trained Tokens 24480, Peak mem 5.317 GB
# Iter 1540: Train loss 0.008, Learning Rate 2.000e-04, It/sec 0.693, Tokens/sec 11.083, Trained Tokens 24640, Peak mem 5.317 GB
# Iter 1550: Train loss 0.028, Learning Rate 2.000e-04, It/sec 0.698, Tokens/sec 11.162, Trained Tokens 24800, Peak mem 5.317 GB
# Iter 1560: Train loss 0.118, Learning Rate 2.000e-04, It/sec 0.694, Tokens/sec 11.103, Trained Tokens 24960, Peak mem 5.317 GB
# Iter 1570: Train loss 0.071, Learning Rate 2.000e-04, It/sec 0.691, Tokens/sec 11.054, Trained Tokens 25120, Peak mem 5.317 GB
# Iter 1580: Train loss 0.033, Learning Rate 2.000e-04, It/sec 0.703, Tokens/sec 11.248, Trained Tokens 25280, Peak mem 5.317 GB
# Iter 1590: Train loss 0.031, Learning Rate 2.000e-04, It/sec 0.691, Tokens/sec 11.055, Trained Tokens 25440, Peak mem 5.317 GB
# Calculating loss...: 100%|██████████████████████| 25/25 [00:18<00:00,  1.34it/s]
# Iter 1600: Val loss 0.035, Val took 18.731s
# Iter 1600: Train loss 0.015, Learning Rate 2.000e-04, It/sec 0.684, Tokens/sec 10.949, Trained Tokens 25600, Peak mem 5.317 GB
# Iter 1610: Train loss 0.083, Learning Rate 2.000e-04, It/sec 0.701, Tokens/sec 11.221, Trained Tokens 25760, Peak mem 5.317 GB
# Iter 1620: Train loss 0.018, Learning Rate 2.000e-04, It/sec 0.702, Tokens/sec 11.233, Trained Tokens 25920, Peak mem 5.317 GB
# Iter 1630: Train loss 0.076, Learning Rate 2.000e-04, It/sec 0.680, Tokens/sec 10.884, Trained Tokens 26080, Peak mem 5.317 GB
# Iter 1640: Train loss 0.039, Learning Rate 2.000e-04, It/sec 0.690, Tokens/sec 11.036, Trained Tokens 26240, Peak mem 5.317 GB
# Iter 1650: Train loss 0.013, Learning Rate 2.000e-04, It/sec 0.686, Tokens/sec 10.982, Trained Tokens 26400, Peak mem 5.317 GB
# Iter 1660: Train loss 0.012, Learning Rate 2.000e-04, It/sec 0.690, Tokens/sec 11.042, Trained Tokens 26560, Peak mem 5.317 GB
# Iter 1670: Train loss 0.043, Learning Rate 2.000e-04, It/sec 0.694, Tokens/sec 11.110, Trained Tokens 26720, Peak mem 5.317 GB
# Iter 1680: Train loss 0.011, Learning Rate 2.000e-04, It/sec 0.692, Tokens/sec 11.076, Trained Tokens 26880, Peak mem 5.317 GB
# Iter 1690: Train loss 0.023, Learning Rate 2.000e-04, It/sec 0.692, Tokens/sec 11.067, Trained Tokens 27040, Peak mem 5.317 GB
# Iter 1700: Train loss 0.022, Learning Rate 2.000e-04, It/sec 0.680, Tokens/sec 10.872, Trained Tokens 27200, Peak mem 5.317 GB
# Iter 1710: Train loss 0.032, Learning Rate 2.000e-04, It/sec 0.684, Tokens/sec 10.945, Trained Tokens 27360, Peak mem 5.317 GB
# Iter 1720: Train loss 0.114, Learning Rate 2.000e-04, It/sec 0.689, Tokens/sec 11.027, Trained Tokens 27520, Peak mem 5.317 GB
# Iter 1730: Train loss 0.007, Learning Rate 2.000e-04, It/sec 0.690, Tokens/sec 11.037, Trained Tokens 27680, Peak mem 5.317 GB
# Iter 1740: Train loss 0.016, Learning Rate 2.000e-04, It/sec 0.679, Tokens/sec 10.871, Trained Tokens 27840, Peak mem 5.317 GB
# Iter 1750: Train loss 0.013, Learning Rate 2.000e-04, It/sec 0.683, Tokens/sec 10.934, Trained Tokens 28000, Peak mem 5.317 GB
# Iter 1760: Train loss 0.130, Learning Rate 2.000e-04, It/sec 0.674, Tokens/sec 10.781, Trained Tokens 28160, Peak mem 5.317 GB
# Iter 1770: Train loss 1.143, Learning Rate 2.000e-04, It/sec 0.675, Tokens/sec 10.800, Trained Tokens 28320, Peak mem 5.317 GB
# Iter 1780: Train loss 2.272, Learning Rate 2.000e-04, It/sec 0.688, Tokens/sec 11.011, Trained Tokens 28480, Peak mem 5.317 GB
# Iter 1790: Train loss 0.306, Learning Rate 2.000e-04, It/sec 0.688, Tokens/sec 11.003, Trained Tokens 28640, Peak mem 5.317 GB
# Calculating loss...: 100%|██████████████████████| 25/25 [00:18<00:00,  1.33it/s]
# Iter 1800: Val loss 0.056, Val took 18.857s
# Iter 1800: Train loss 0.263, Learning Rate 2.000e-04, It/sec 0.687, Tokens/sec 10.991, Trained Tokens 28800, Peak mem 5.317 GB
# Iter 1810: Train loss 0.170, Learning Rate 2.000e-04, It/sec 0.693, Tokens/sec 11.092, Trained Tokens 28960, Peak mem 5.317 GB
# Iter 1820: Train loss 0.013, Learning Rate 2.000e-04, It/sec 0.687, Tokens/sec 10.998, Trained Tokens 29120, Peak mem 5.317 GB
# Iter 1830: Train loss 0.008, Learning Rate 2.000e-04, It/sec 0.695, Tokens/sec 11.114, Trained Tokens 29280, Peak mem 5.317 GB
# Iter 1840: Train loss 0.017, Learning Rate 2.000e-04, It/sec 0.695, Tokens/sec 11.122, Trained Tokens 29440, Peak mem 5.317 GB
# Iter 1850: Train loss 0.043, Learning Rate 2.000e-04, It/sec 0.686, Tokens/sec 10.973, Trained Tokens 29600, Peak mem 5.317 GB
# Iter 1860: Train loss 0.118, Learning Rate 2.000e-04, It/sec 0.692, Tokens/sec 11.077, Trained Tokens 29760, Peak mem 5.317 GB
# Iter 1870: Train loss 0.006, Learning Rate 2.000e-04, It/sec 0.700, Tokens/sec 11.197, Trained Tokens 29920, Peak mem 5.317 GB
# Iter 1880: Train loss 0.114, Learning Rate 2.000e-04, It/sec 0.701, Tokens/sec 11.223, Trained Tokens 30080, Peak mem 5.317 GB
# Iter 1890: Train loss 0.046, Learning Rate 2.000e-04, It/sec 0.703, Tokens/sec 11.247, Trained Tokens 30240, Peak mem 5.317 GB
# Iter 1900: Train loss 0.057, Learning Rate 2.000e-04, It/sec 0.694, Tokens/sec 11.107, Trained Tokens 30400, Peak mem 5.317 GB
# Iter 1910: Train loss 0.033, Learning Rate 2.000e-04, It/sec 0.681, Tokens/sec 10.888, Trained Tokens 30560, Peak mem 5.317 GB
# Iter 1920: Train loss 0.043, Learning Rate 2.000e-04, It/sec 0.666, Tokens/sec 10.654, Trained Tokens 30720, Peak mem 5.317 GB
# Iter 1930: Train loss 0.022, Learning Rate 2.000e-04, It/sec 0.684, Tokens/sec 10.950, Trained Tokens 30880, Peak mem 5.317 GB
# Iter 1940: Train loss 0.010, Learning Rate 2.000e-04, It/sec 0.686, Tokens/sec 10.976, Trained Tokens 31040, Peak mem 5.317 GB
# Iter 1950: Train loss 0.053, Learning Rate 2.000e-04, It/sec 0.686, Tokens/sec 10.982, Trained Tokens 31200, Peak mem 5.317 GB
# Iter 1960: Train loss 0.021, Learning Rate 2.000e-04, It/sec 0.686, Tokens/sec 10.978, Trained Tokens 31360, Peak mem 5.317 GB
# Iter 1970: Train loss 0.041, Learning Rate 2.000e-04, It/sec 0.700, Tokens/sec 11.207, Trained Tokens 31520, Peak mem 5.317 GB
# Iter 1980: Train loss 0.023, Learning Rate 2.000e-04, It/sec 0.675, Tokens/sec 10.797, Trained Tokens 31680, Peak mem 5.317 GB
# Iter 1990: Train loss 0.018, Learning Rate 2.000e-04, It/sec 0.638, Tokens/sec 10.203, Trained Tokens 31840, Peak mem 5.317 GB
# Calculating loss...: 100%|██████████████████████| 25/25 [00:18<00:00,  1.33it/s]
# Iter 2000: Val loss 0.017, Val took 18.827s
# Iter 2000: Train loss 0.053, Learning Rate 2.000e-04, It/sec 0.651, Tokens/sec 10.413, Trained Tokens 32000, Peak mem 5.317 GB
# Iter 2000: Saved adapter weights to adapters_w3/T2C_longitudinal_model/adapters.safetensors and adapters_w3/T2C_longitudinal_model/0002000_adapters.safetensors.
# Saved final weights to adapters_w3/T2C_longitudinal_model/adapters.safetensors.

# %%
# ── Load model with T2C_longitudinal_model adapter ──────────────────────────────
model_mlx, tok_mlx = load(
    MODEL_ID,
    adapter_path="./adapters_w3/T2C_longitudinal_model",
)

# ── Inference ──────────────────────────────────────────────────────
t0 = time.time()
preds, refs, probs = run_inference_mlx(
    model_mlx, tok_mlx, test_ds_structured_longitudinal, return_probs=True
)

# ── Evaluate ───────────────────────────────────────────────────────
metrics = evaluate_predictions(preds, refs, label_name="T2C_longitudinal_model")

# ── Calibration ────────────────────────────────────────────────────
ece = calibration_analysis(
    probs, refs,
    label_name="T2C_longitudinal_model",
    save_path=os.path.join(OUTPUT_DIR, "calibration_T2C_longitudinal_model.png")
)
metrics["ECE"] = ece
all_metrics.append(metrics)

# ── Save predictions ───────────────────────────────────────────────
out_df = pd.DataFrame({"Predicted_Label": preds, "Ground_Truth": refs, "P_Yes": probs})
out_df.to_csv(os.path.join(OUTPUT_DIR, "predictions_T2C_longitudinal_model.csv"), index=False)

elapsed = round(time.time() - t0, 2)
experiment_times["T2C_longitudinal_model"] = elapsed
print(f"\n  ⏱ T2C_longitudinal_model done in {elapsed:.1f}s")

# ── Clean up ───────────────────────────────────────────────────────
del model_mlx, tok_mlx
# Out:
# Downloading (incomplete total...): 0.00B [00:00, ?B/s]
# Fetching 9 files:   0%|          | 0/9 [00:00<?, ?it/s]
# Generating:   0%|          | 0/8275 [00:00<?, ?it/s]
# ── T2C_longitudinal_model ──
#   Label: T2C_longitudinal_model
#   N_test: 8275
#   Accuracy: 0.9601
#   Recall: 0.8412
#   Precision: 0.8134
#   F1: 0.827
#   Unknown: 0
#               precision    recall  f1-score   support
#
#           No       0.98      0.98      0.98      7337
#          Yes       0.81      0.84      0.83       938
#
#     accuracy                           0.96      8275
#    macro avg       0.90      0.91      0.90      8275
# weighted avg       0.96      0.96      0.96      8275
#
#   ECE: 0.0180 | Saved → ./results_wave3/calibration_T2C_longitudinal_model.png
#
#   ⏱ T2C_longitudinal_model done in 2494.8s

# %% [markdown]
# ### Inference for zero shot

# %%
## Inference for zero shot
t0 = time.time()

model_mlx, tok_mlx = load(
    MODEL_ID,
    # no adapter_path — base model only
)

preds, refs, probs = run_inference_mlx(
    model_mlx, tok_mlx, test_ds_structured_full, return_probs=True
)

metrics = evaluate_predictions(preds, refs, label_name="T3A_zeroshot")

ece = calibration_analysis(
    probs, refs,
    label_name="T3A_zeroshot",
    save_path=os.path.join(OUTPUT_DIR, "calibration_T3A_zeroshot.png")
)
metrics["ECE"] = ece
all_metrics.append(metrics)

out_df = pd.DataFrame({"Predicted_Label": preds, "Ground_Truth": refs, "P_Yes": probs})
out_df.to_csv(os.path.join(OUTPUT_DIR, "predictions_T3A_zeroshot.csv"), index=False)

elapsed = round(time.time() - t0, 2)
experiment_times["T3A_zeroshot"] = elapsed
print(f"\n  ⏱ T3A_zeroshot done in {elapsed:.1f}s")

del model_mlx, tok_mlx
# Out:
# Downloading (incomplete total...): 0.00B [00:00, ?B/s]
# Fetching 9 files:   0%|          | 0/9 [00:00<?, ?it/s]
# Generating:   0%|          | 0/8275 [00:00<?, ?it/s]
# ── T3A_zeroshot ──
#   Label: T3A_zeroshot
#   N_test: 8275
#   Accuracy: 0.4214
#   Recall: 0.9392
#   Precision: 0.157
#   F1: 0.269
#   Unknown: 0
#               precision    recall  f1-score   support
#
#           No       0.98      0.36      0.52      7337
#          Yes       0.16      0.94      0.27       938
#
#     accuracy                           0.42      8275
#    macro avg       0.57      0.65      0.40      8275
# weighted avg       0.89      0.42      0.49      8275
#
#   ECE: 0.0069 | Saved → ./results_wave3/calibration_T3A_zeroshot.png
#
#   ⏱ T3A_zeroshot done in 2469.3s

# %% [markdown]
# ### Training and Inference for T3A_narrative

# %%
# !mlx_lm.lora \
    --model {MODEL_ID} \
    --train \
    --data ./mlx_data/T3A_narrative \
    --num-layers 16 \
    --batch-size 4 \
    --grad-accumulation-steps 4 \
    --iters 2000 \
    --learning-rate 2e-4 \
    --mask-prompt \
    --adapter-path ./adapters_w3/T3A_narrative \
    --save-every 500 \
    -c ./configs/lora_config.yaml
# Out:
# Loading configuration file ./configs/lora_config.yaml
# Loading pretrained model
# Downloading (incomplete total...): 0.00B [00:00, ?B/s]
# Fetching 9 files: 100%|████████████████████████| 9/9 [00:00<00:00, 43690.67it/s]
# Download complete: : 0.00B [00:00, ?B/s]
# Loading datasets
# Training
# Trainable parameters: 0.684% (10.551M/1543.714M)
# Starting training..., iters: 2000
# Calculating loss...: 100%|██████████████████████| 25/25 [00:21<00:00,  1.17it/s]
# Iter 1: Val loss 7.450, Val took 21.438s
# Iter 10: Train loss 3.703, Learning Rate 2.000e-04, It/sec 0.607, Tokens/sec 9.714, Trained Tokens 160, Peak mem 5.730 GB
# Iter 20: Train loss 0.154, Learning Rate 2.000e-04, It/sec 0.614, Tokens/sec 9.828, Trained Tokens 320, Peak mem 5.730 GB
# Iter 30: Train loss 0.050, Learning Rate 2.000e-04, It/sec 0.614, Tokens/sec 9.820, Trained Tokens 480, Peak mem 5.730 GB
# Iter 40: Train loss 0.102, Learning Rate 2.000e-04, It/sec 0.613, Tokens/sec 9.813, Trained Tokens 640, Peak mem 5.730 GB
# Iter 50: Train loss 0.052, Learning Rate 2.000e-04, It/sec 0.612, Tokens/sec 9.795, Trained Tokens 800, Peak mem 5.730 GB
# Iter 60: Train loss 0.147, Learning Rate 2.000e-04, It/sec 0.614, Tokens/sec 9.831, Trained Tokens 960, Peak mem 5.730 GB
# Iter 70: Train loss 0.053, Learning Rate 2.000e-04, It/sec 0.614, Tokens/sec 9.825, Trained Tokens 1120, Peak mem 5.730 GB
# Iter 80: Train loss 0.056, Learning Rate 2.000e-04, It/sec 0.613, Tokens/sec 9.809, Trained Tokens 1280, Peak mem 5.730 GB
# Iter 90: Train loss 0.083, Learning Rate 2.000e-04, It/sec 0.614, Tokens/sec 9.823, Trained Tokens 1440, Peak mem 5.730 GB
# Iter 100: Train loss 0.116, Learning Rate 2.000e-04, It/sec 0.615, Tokens/sec 9.841, Trained Tokens 1600, Peak mem 5.730 GB
# Iter 110: Train loss 0.017, Learning Rate 2.000e-04, It/sec 0.614, Tokens/sec 9.824, Trained Tokens 1760, Peak mem 5.730 GB
# Iter 120: Train loss 0.017, Learning Rate 2.000e-04, It/sec 0.615, Tokens/sec 9.836, Trained Tokens 1920, Peak mem 5.730 GB
# Iter 130: Train loss 0.035, Learning Rate 2.000e-04, It/sec 0.612, Tokens/sec 9.794, Trained Tokens 2080, Peak mem 5.730 GB
# Iter 140: Train loss 0.073, Learning Rate 2.000e-04, It/sec 0.614, Tokens/sec 9.820, Trained Tokens 2240, Peak mem 5.730 GB
# Iter 150: Train loss 0.082, Learning Rate 2.000e-04, It/sec 0.614, Tokens/sec 9.823, Trained Tokens 2400, Peak mem 5.730 GB
# Iter 160: Train loss 0.037, Learning Rate 2.000e-04, It/sec 0.610, Tokens/sec 9.760, Trained Tokens 2560, Peak mem 5.730 GB
# Iter 170: Train loss 0.051, Learning Rate 2.000e-04, It/sec 0.614, Tokens/sec 9.824, Trained Tokens 2720, Peak mem 5.730 GB
# Iter 180: Train loss 0.072, Learning Rate 2.000e-04, It/sec 0.613, Tokens/sec 9.815, Trained Tokens 2880, Peak mem 5.730 GB
# Iter 190: Train loss 0.061, Learning Rate 2.000e-04, It/sec 0.613, Tokens/sec 9.813, Trained Tokens 3040, Peak mem 5.730 GB
# Calculating loss...: 100%|██████████████████████| 25/25 [00:21<00:00,  1.18it/s]
# Iter 200: Val loss 0.049, Val took 21.187s
# Iter 200: Train loss 0.034, Learning Rate 2.000e-04, It/sec 0.613, Tokens/sec 9.813, Trained Tokens 3200, Peak mem 5.730 GB
# Iter 210: Train loss 0.048, Learning Rate 2.000e-04, It/sec 0.612, Tokens/sec 9.795, Trained Tokens 3360, Peak mem 5.730 GB
# Iter 220: Train loss 0.072, Learning Rate 2.000e-04, It/sec 0.612, Tokens/sec 9.791, Trained Tokens 3520, Peak mem 5.730 GB
# Iter 230: Train loss 0.036, Learning Rate 2.000e-04, It/sec 0.613, Tokens/sec 9.803, Trained Tokens 3680, Peak mem 5.730 GB
# Iter 240: Train loss 0.006, Learning Rate 2.000e-04, It/sec 0.612, Tokens/sec 9.799, Trained Tokens 3840, Peak mem 5.730 GB
# Iter 250: Train loss 0.035, Learning Rate 2.000e-04, It/sec 0.614, Tokens/sec 9.816, Trained Tokens 4000, Peak mem 5.730 GB
# Iter 260: Train loss 0.006, Learning Rate 2.000e-04, It/sec 0.614, Tokens/sec 9.819, Trained Tokens 4160, Peak mem 5.730 GB
# Iter 270: Train loss 0.007, Learning Rate 2.000e-04, It/sec 0.613, Tokens/sec 9.812, Trained Tokens 4320, Peak mem 5.730 GB
# Iter 280: Train loss 0.034, Learning Rate 2.000e-04, It/sec 0.614, Tokens/sec 9.827, Trained Tokens 4480, Peak mem 5.730 GB
# Iter 290: Train loss 0.101, Learning Rate 2.000e-04, It/sec 0.614, Tokens/sec 9.817, Trained Tokens 4640, Peak mem 5.730 GB
# Iter 300: Train loss 0.037, Learning Rate 2.000e-04, It/sec 0.611, Tokens/sec 9.776, Trained Tokens 4800, Peak mem 5.730 GB
# Iter 310: Train loss 0.083, Learning Rate 2.000e-04, It/sec 0.614, Tokens/sec 9.829, Trained Tokens 4960, Peak mem 5.730 GB
# Iter 320: Train loss 0.058, Learning Rate 2.000e-04, It/sec 0.614, Tokens/sec 9.820, Trained Tokens 5120, Peak mem 5.730 GB
# Iter 330: Train loss 0.035, Learning Rate 2.000e-04, It/sec 0.613, Tokens/sec 9.811, Trained Tokens 5280, Peak mem 5.730 GB
# Iter 340: Train loss 0.028, Learning Rate 2.000e-04, It/sec 0.614, Tokens/sec 9.826, Trained Tokens 5440, Peak mem 5.730 GB
# Iter 350: Train loss 0.021, Learning Rate 2.000e-04, It/sec 0.614, Tokens/sec 9.824, Trained Tokens 5600, Peak mem 5.730 GB
# Iter 360: Train loss 0.051, Learning Rate 2.000e-04, It/sec 0.613, Tokens/sec 9.803, Trained Tokens 5760, Peak mem 5.730 GB
# Iter 370: Train loss 0.010, Learning Rate 2.000e-04, It/sec 0.614, Tokens/sec 9.822, Trained Tokens 5920, Peak mem 5.730 GB
# Iter 380: Train loss 0.012, Learning Rate 2.000e-04, It/sec 0.613, Tokens/sec 9.813, Trained Tokens 6080, Peak mem 5.730 GB
# Iter 390: Train loss 0.008, Learning Rate 2.000e-04, It/sec 0.613, Tokens/sec 9.813, Trained Tokens 6240, Peak mem 5.730 GB
# Calculating loss...: 100%|██████████████████████| 25/25 [00:21<00:00,  1.18it/s]
# Iter 400: Val loss 0.053, Val took 21.173s
# Iter 400: Train loss 0.020, Learning Rate 2.000e-04, It/sec 0.613, Tokens/sec 9.814, Trained Tokens 6400, Peak mem 5.730 GB
# Iter 410: Train loss 0.017, Learning Rate 2.000e-04, It/sec 0.614, Tokens/sec 9.828, Trained Tokens 6560, Peak mem 5.730 GB
# Iter 420: Train loss 0.031, Learning Rate 2.000e-04, It/sec 0.614, Tokens/sec 9.821, Trained Tokens 6720, Peak mem 5.730 GB
# Iter 430: Train loss 0.005, Learning Rate 2.000e-04, It/sec 0.614, Tokens/sec 9.822, Trained Tokens 6880, Peak mem 5.730 GB
# Iter 440: Train loss 0.120, Learning Rate 2.000e-04, It/sec 0.614, Tokens/sec 9.832, Trained Tokens 7040, Peak mem 5.730 GB
# Iter 450: Train loss 0.026, Learning Rate 2.000e-04, It/sec 0.613, Tokens/sec 9.812, Trained Tokens 7200, Peak mem 5.730 GB
# Iter 460: Train loss 0.046, Learning Rate 2.000e-04, It/sec 0.614, Tokens/sec 9.822, Trained Tokens 7360, Peak mem 5.730 GB
# Iter 470: Train loss 0.022, Learning Rate 2.000e-04, It/sec 0.614, Tokens/sec 9.821, Trained Tokens 7520, Peak mem 5.730 GB
# Iter 480: Train loss 0.030, Learning Rate 2.000e-04, It/sec 0.614, Tokens/sec 9.829, Trained Tokens 7680, Peak mem 5.730 GB
# Iter 490: Train loss 0.006, Learning Rate 2.000e-04, It/sec 0.615, Tokens/sec 9.837, Trained Tokens 7840, Peak mem 5.730 GB
# Iter 500: Train loss 0.026, Learning Rate 2.000e-04, It/sec 0.614, Tokens/sec 9.822, Trained Tokens 8000, Peak mem 5.730 GB
# Iter 500: Saved adapter weights to adapters_w3/T3A_narrative/adapters.safetensors and adapters_w3/T3A_narrative/0000500_adapters.safetensors.
# Iter 510: Train loss 0.013, Learning Rate 2.000e-04, It/sec 0.614, Tokens/sec 9.826, Trained Tokens 8160, Peak mem 5.772 GB
# Iter 520: Train loss 0.003, Learning Rate 2.000e-04, It/sec 0.614, Tokens/sec 9.822, Trained Tokens 8320, Peak mem 5.772 GB
# Iter 530: Train loss 0.013, Learning Rate 2.000e-04, It/sec 0.615, Tokens/sec 9.837, Trained Tokens 8480, Peak mem 5.772 GB
# Iter 540: Train loss 0.084, Learning Rate 2.000e-04, It/sec 0.614, Tokens/sec 9.817, Trained Tokens 8640, Peak mem 5.772 GB
# Iter 550: Train loss 0.055, Learning Rate 2.000e-04, It/sec 0.613, Tokens/sec 9.812, Trained Tokens 8800, Peak mem 5.772 GB
# Iter 560: Train loss 0.093, Learning Rate 2.000e-04, It/sec 0.615, Tokens/sec 9.833, Trained Tokens 8960, Peak mem 5.772 GB
# Iter 570: Train loss 0.043, Learning Rate 2.000e-04, It/sec 0.614, Tokens/sec 9.822, Trained Tokens 9120, Peak mem 5.772 GB
# Iter 580: Train loss 0.016, Learning Rate 2.000e-04, It/sec 0.613, Tokens/sec 9.814, Trained Tokens 9280, Peak mem 5.772 GB
# Iter 590: Train loss 0.032, Learning Rate 2.000e-04, It/sec 0.614, Tokens/sec 9.823, Trained Tokens 9440, Peak mem 5.772 GB
# Calculating loss...: 100%|██████████████████████| 25/25 [00:21<00:00,  1.18it/s]
# Iter 600: Val loss 0.037, Val took 21.176s
# Iter 600: Train loss 0.062, Learning Rate 2.000e-04, It/sec 0.614, Tokens/sec 9.821, Trained Tokens 9600, Peak mem 5.772 GB
# Iter 610: Train loss 0.034, Learning Rate 2.000e-04, It/sec 0.614, Tokens/sec 9.824, Trained Tokens 9760, Peak mem 5.772 GB
# Iter 620: Train loss 0.050, Learning Rate 2.000e-04, It/sec 0.614, Tokens/sec 9.825, Trained Tokens 9920, Peak mem 5.772 GB
# Iter 630: Train loss 0.020, Learning Rate 2.000e-04, It/sec 0.614, Tokens/sec 9.817, Trained Tokens 10080, Peak mem 5.772 GB
# Iter 640: Train loss 0.071, Learning Rate 2.000e-04, It/sec 0.612, Tokens/sec 9.798, Trained Tokens 10240, Peak mem 5.772 GB
# Iter 650: Train loss 0.077, Learning Rate 2.000e-04, It/sec 0.615, Tokens/sec 9.837, Trained Tokens 10400, Peak mem 5.772 GB
# Iter 660: Train loss 0.012, Learning Rate 2.000e-04, It/sec 0.614, Tokens/sec 9.826, Trained Tokens 10560, Peak mem 5.772 GB
# Iter 670: Train loss 0.032, Learning Rate 2.000e-04, It/sec 0.614, Tokens/sec 9.822, Trained Tokens 10720, Peak mem 5.772 GB
# Iter 680: Train loss 0.032, Learning Rate 2.000e-04, It/sec 0.614, Tokens/sec 9.828, Trained Tokens 10880, Peak mem 5.772 GB
# Iter 690: Train loss 0.039, Learning Rate 2.000e-04, It/sec 0.614, Tokens/sec 9.817, Trained Tokens 11040, Peak mem 5.772 GB
# Iter 700: Train loss 0.084, Learning Rate 2.000e-04, It/sec 0.614, Tokens/sec 9.822, Trained Tokens 11200, Peak mem 5.772 GB
# Iter 710: Train loss 0.007, Learning Rate 2.000e-04, It/sec 0.614, Tokens/sec 9.827, Trained Tokens 11360, Peak mem 5.772 GB
# Iter 720: Train loss 0.011, Learning Rate 2.000e-04, It/sec 0.614, Tokens/sec 9.826, Trained Tokens 11520, Peak mem 5.772 GB
# Iter 730: Train loss 0.047, Learning Rate 2.000e-04, It/sec 0.614, Tokens/sec 9.829, Trained Tokens 11680, Peak mem 5.772 GB
# Iter 740: Train loss 0.006, Learning Rate 2.000e-04, It/sec 0.614, Tokens/sec 9.821, Trained Tokens 11840, Peak mem 5.772 GB
# Iter 750: Train loss 0.003, Learning Rate 2.000e-04, It/sec 0.614, Tokens/sec 9.819, Trained Tokens 12000, Peak mem 5.772 GB
# Iter 760: Train loss 0.060, Learning Rate 2.000e-04, It/sec 0.613, Tokens/sec 9.807, Trained Tokens 12160, Peak mem 5.772 GB
# Iter 770: Train loss 0.044, Learning Rate 2.000e-04, It/sec 0.614, Tokens/sec 9.820, Trained Tokens 12320, Peak mem 5.772 GB
# Iter 780: Train loss 0.020, Learning Rate 2.000e-04, It/sec 0.615, Tokens/sec 9.836, Trained Tokens 12480, Peak mem 5.772 GB
# Iter 790: Train loss 0.005, Learning Rate 2.000e-04, It/sec 0.614, Tokens/sec 9.819, Trained Tokens 12640, Peak mem 5.772 GB
# Calculating loss...: 100%|██████████████████████| 25/25 [00:21<00:00,  1.18it/s]
# Iter 800: Val loss 0.023, Val took 21.180s
# Iter 800: Train loss 0.054, Learning Rate 2.000e-04, It/sec 0.614, Tokens/sec 9.817, Trained Tokens 12800, Peak mem 5.772 GB
# Iter 810: Train loss 0.022, Learning Rate 2.000e-04, It/sec 0.614, Tokens/sec 9.827, Trained Tokens 12960, Peak mem 5.772 GB
# Iter 820: Train loss 0.011, Learning Rate 2.000e-04, It/sec 0.614, Tokens/sec 9.817, Trained Tokens 13120, Peak mem 5.772 GB
# Iter 830: Train loss 0.056, Learning Rate 2.000e-04, It/sec 0.614, Tokens/sec 9.828, Trained Tokens 13280, Peak mem 5.772 GB
# Iter 840: Train loss 0.040, Learning Rate 2.000e-04, It/sec 0.614, Tokens/sec 9.818, Trained Tokens 13440, Peak mem 5.772 GB
# Iter 850: Train loss 0.021, Learning Rate 2.000e-04, It/sec 0.614, Tokens/sec 9.828, Trained Tokens 13600, Peak mem 5.772 GB
# Iter 860: Train loss 0.061, Learning Rate 2.000e-04, It/sec 0.614, Tokens/sec 9.825, Trained Tokens 13760, Peak mem 5.772 GB
# Iter 870: Train loss 0.030, Learning Rate 2.000e-04, It/sec 0.614, Tokens/sec 9.827, Trained Tokens 13920, Peak mem 5.772 GB
# Iter 880: Train loss 0.024, Learning Rate 2.000e-04, It/sec 0.614, Tokens/sec 9.822, Trained Tokens 14080, Peak mem 5.772 GB
# Iter 890: Train loss 0.032, Learning Rate 2.000e-04, It/sec 0.614, Tokens/sec 9.821, Trained Tokens 14240, Peak mem 5.772 GB
# Iter 900: Train loss 0.070, Learning Rate 2.000e-04, It/sec 0.615, Tokens/sec 9.832, Trained Tokens 14400, Peak mem 5.772 GB
# Iter 910: Train loss 0.037, Learning Rate 2.000e-04, It/sec 0.614, Tokens/sec 9.820, Trained Tokens 14560, Peak mem 5.772 GB
# Iter 920: Train loss 0.011, Learning Rate 2.000e-04, It/sec 0.614, Tokens/sec 9.817, Trained Tokens 14720, Peak mem 5.772 GB
# Iter 930: Train loss 0.045, Learning Rate 2.000e-04, It/sec 0.609, Tokens/sec 9.743, Trained Tokens 14880, Peak mem 5.772 GB
# Iter 940: Train loss 0.030, Learning Rate 2.000e-04, It/sec 0.614, Tokens/sec 9.828, Trained Tokens 15040, Peak mem 5.772 GB
# Iter 950: Train loss 0.068, Learning Rate 2.000e-04, It/sec 0.614, Tokens/sec 9.827, Trained Tokens 15200, Peak mem 5.772 GB
# Iter 960: Train loss 0.021, Learning Rate 2.000e-04, It/sec 0.614, Tokens/sec 9.817, Trained Tokens 15360, Peak mem 5.772 GB
# Iter 970: Train loss 0.007, Learning Rate 2.000e-04, It/sec 0.615, Tokens/sec 9.835, Trained Tokens 15520, Peak mem 5.772 GB
# Iter 980: Train loss 0.039, Learning Rate 2.000e-04, It/sec 0.613, Tokens/sec 9.812, Trained Tokens 15680, Peak mem 5.772 GB
# Iter 990: Train loss 0.077, Learning Rate 2.000e-04, It/sec 0.614, Tokens/sec 9.827, Trained Tokens 15840, Peak mem 5.772 GB
# Calculating loss...: 100%|██████████████████████| 25/25 [00:21<00:00,  1.18it/s]
# Iter 1000: Val loss 0.055, Val took 21.192s
# Iter 1000: Train loss 0.013, Learning Rate 2.000e-04, It/sec 0.602, Tokens/sec 9.635, Trained Tokens 16000, Peak mem 6.323 GB
# Iter 1000: Saved adapter weights to adapters_w3/T3A_narrative/adapters.safetensors and adapters_w3/T3A_narrative/0001000_adapters.safetensors.
# Iter 1010: Train loss 0.023, Learning Rate 2.000e-04, It/sec 0.613, Tokens/sec 9.801, Trained Tokens 16160, Peak mem 6.323 GB
# Iter 1020: Train loss 0.023, Learning Rate 2.000e-04, It/sec 0.612, Tokens/sec 9.797, Trained Tokens 16320, Peak mem 6.323 GB
# Iter 1030: Train loss 0.061, Learning Rate 2.000e-04, It/sec 0.615, Tokens/sec 9.844, Trained Tokens 16480, Peak mem 6.323 GB
# Iter 1040: Train loss 0.031, Learning Rate 2.000e-04, It/sec 0.613, Tokens/sec 9.814, Trained Tokens 16640, Peak mem 6.323 GB
# Iter 1050: Train loss 0.037, Learning Rate 2.000e-04, It/sec 0.614, Tokens/sec 9.824, Trained Tokens 16800, Peak mem 6.323 GB
# Iter 1060: Train loss 0.015, Learning Rate 2.000e-04, It/sec 0.614, Tokens/sec 9.825, Trained Tokens 16960, Peak mem 6.323 GB
# Iter 1070: Train loss 0.075, Learning Rate 2.000e-04, It/sec 0.613, Tokens/sec 9.808, Trained Tokens 17120, Peak mem 6.323 GB
# Iter 1080: Train loss 0.061, Learning Rate 2.000e-04, It/sec 0.614, Tokens/sec 9.820, Trained Tokens 17280, Peak mem 6.323 GB
# Iter 1090: Train loss 0.031, Learning Rate 2.000e-04, It/sec 0.615, Tokens/sec 9.835, Trained Tokens 17440, Peak mem 6.323 GB
# Iter 1100: Train loss 0.017, Learning Rate 2.000e-04, It/sec 0.614, Tokens/sec 9.824, Trained Tokens 17600, Peak mem 6.323 GB
# Iter 1110: Train loss 0.013, Learning Rate 2.000e-04, It/sec 0.614, Tokens/sec 9.818, Trained Tokens 17760, Peak mem 6.323 GB
# Iter 1120: Train loss 0.004, Learning Rate 2.000e-04, It/sec 0.614, Tokens/sec 9.819, Trained Tokens 17920, Peak mem 6.323 GB
# Iter 1130: Train loss 0.030, Learning Rate 2.000e-04, It/sec 0.614, Tokens/sec 9.830, Trained Tokens 18080, Peak mem 6.323 GB
# Iter 1140: Train loss 0.070, Learning Rate 2.000e-04, It/sec 0.613, Tokens/sec 9.814, Trained Tokens 18240, Peak mem 6.323 GB
# Iter 1150: Train loss 0.037, Learning Rate 2.000e-04, It/sec 0.614, Tokens/sec 9.828, Trained Tokens 18400, Peak mem 6.323 GB
# Iter 1160: Train loss 0.005, Learning Rate 2.000e-04, It/sec 0.614, Tokens/sec 9.817, Trained Tokens 18560, Peak mem 6.323 GB
# Iter 1170: Train loss 0.006, Learning Rate 2.000e-04, It/sec 0.615, Tokens/sec 9.832, Trained Tokens 18720, Peak mem 6.323 GB
# Iter 1180: Train loss 0.006, Learning Rate 2.000e-04, It/sec 0.614, Tokens/sec 9.821, Trained Tokens 18880, Peak mem 6.323 GB
# Iter 1190: Train loss 0.016, Learning Rate 2.000e-04, It/sec 0.615, Tokens/sec 9.834, Trained Tokens 19040, Peak mem 6.323 GB
# Calculating loss...: 100%|██████████████████████| 25/25 [00:21<00:00,  1.18it/s]
# Iter 1200: Val loss 0.030, Val took 21.187s
# Iter 1200: Train loss 0.054, Learning Rate 2.000e-04, It/sec 0.614, Tokens/sec 9.831, Trained Tokens 19200, Peak mem 6.323 GB
# Iter 1210: Train loss 0.047, Learning Rate 2.000e-04, It/sec 0.613, Tokens/sec 9.803, Trained Tokens 19360, Peak mem 6.323 GB
# Iter 1220: Train loss 0.089, Learning Rate 2.000e-04, It/sec 0.613, Tokens/sec 9.809, Trained Tokens 19520, Peak mem 6.323 GB
# Iter 1230: Train loss 0.033, Learning Rate 2.000e-04, It/sec 0.614, Tokens/sec 9.830, Trained Tokens 19680, Peak mem 6.323 GB
# Iter 1240: Train loss 0.019, Learning Rate 2.000e-04, It/sec 0.604, Tokens/sec 9.664, Trained Tokens 19840, Peak mem 6.323 GB
# Iter 1250: Train loss 0.093, Learning Rate 2.000e-04, It/sec 0.615, Tokens/sec 9.836, Trained Tokens 20000, Peak mem 6.323 GB
# Iter 1260: Train loss 0.013, Learning Rate 2.000e-04, It/sec 0.613, Tokens/sec 9.810, Trained Tokens 20160, Peak mem 6.323 GB
# Iter 1270: Train loss 0.021, Learning Rate 2.000e-04, It/sec 0.614, Tokens/sec 9.817, Trained Tokens 20320, Peak mem 6.323 GB
# Iter 1280: Train loss 0.049, Learning Rate 2.000e-04, It/sec 0.612, Tokens/sec 9.797, Trained Tokens 20480, Peak mem 6.323 GB
# Iter 1290: Train loss 0.016, Learning Rate 2.000e-04, It/sec 0.614, Tokens/sec 9.830, Trained Tokens 20640, Peak mem 6.323 GB
# Iter 1300: Train loss 0.039, Learning Rate 2.000e-04, It/sec 0.614, Tokens/sec 9.827, Trained Tokens 20800, Peak mem 6.323 GB
# Iter 1310: Train loss 0.065, Learning Rate 2.000e-04, It/sec 0.613, Tokens/sec 9.811, Trained Tokens 20960, Peak mem 6.323 GB
# Iter 1320: Train loss 0.026, Learning Rate 2.000e-04, It/sec 0.613, Tokens/sec 9.813, Trained Tokens 21120, Peak mem 6.323 GB
# Iter 1330: Train loss 0.005, Learning Rate 2.000e-04, It/sec 0.614, Tokens/sec 9.823, Trained Tokens 21280, Peak mem 6.323 GB
# Iter 1340: Train loss 0.033, Learning Rate 2.000e-04, It/sec 0.614, Tokens/sec 9.824, Trained Tokens 21440, Peak mem 6.323 GB
# Iter 1350: Train loss 0.004, Learning Rate 2.000e-04, It/sec 0.613, Tokens/sec 9.815, Trained Tokens 21600, Peak mem 6.323 GB
# Iter 1360: Train loss 0.006, Learning Rate 2.000e-04, It/sec 0.613, Tokens/sec 9.804, Trained Tokens 21760, Peak mem 6.323 GB
# Iter 1370: Train loss 0.030, Learning Rate 2.000e-04, It/sec 0.614, Tokens/sec 9.820, Trained Tokens 21920, Peak mem 6.323 GB
# Iter 1380: Train loss 0.010, Learning Rate 2.000e-04, It/sec 0.613, Tokens/sec 9.815, Trained Tokens 22080, Peak mem 6.323 GB
# Iter 1390: Train loss 0.060, Learning Rate 2.000e-04, It/sec 0.614, Tokens/sec 9.819, Trained Tokens 22240, Peak mem 6.323 GB
# Calculating loss...: 100%|██████████████████████| 25/25 [00:21<00:00,  1.18it/s]
# Iter 1400: Val loss 0.026, Val took 21.180s
# Iter 1400: Train loss 0.003, Learning Rate 2.000e-04, It/sec 0.613, Tokens/sec 9.811, Trained Tokens 22400, Peak mem 6.323 GB
# Iter 1410: Train loss 0.028, Learning Rate 2.000e-04, It/sec 0.613, Tokens/sec 9.814, Trained Tokens 22560, Peak mem 6.323 GB
# Iter 1420: Train loss 0.096, Learning Rate 2.000e-04, It/sec 0.614, Tokens/sec 9.823, Trained Tokens 22720, Peak mem 6.323 GB
# Iter 1430: Train loss 0.033, Learning Rate 2.000e-04, It/sec 0.614, Tokens/sec 9.828, Trained Tokens 22880, Peak mem 6.323 GB
# Iter 1440: Train loss 0.033, Learning Rate 2.000e-04, It/sec 0.614, Tokens/sec 9.828, Trained Tokens 23040, Peak mem 6.323 GB
# Iter 1450: Train loss 0.015, Learning Rate 2.000e-04, It/sec 0.614, Tokens/sec 9.823, Trained Tokens 23200, Peak mem 6.323 GB
# Iter 1460: Train loss 0.017, Learning Rate 2.000e-04, It/sec 0.613, Tokens/sec 9.806, Trained Tokens 23360, Peak mem 6.323 GB
# Iter 1470: Train loss 0.013, Learning Rate 2.000e-04, It/sec 0.615, Tokens/sec 9.833, Trained Tokens 23520, Peak mem 6.323 GB
# Iter 1480: Train loss 0.024, Learning Rate 2.000e-04, It/sec 0.614, Tokens/sec 9.820, Trained Tokens 23680, Peak mem 6.323 GB
# Iter 1490: Train loss 0.130, Learning Rate 2.000e-04, It/sec 0.614, Tokens/sec 9.824, Trained Tokens 23840, Peak mem 6.323 GB
# Iter 1500: Train loss 0.021, Learning Rate 2.000e-04, It/sec 0.614, Tokens/sec 9.831, Trained Tokens 24000, Peak mem 6.323 GB
# Iter 1500: Saved adapter weights to adapters_w3/T3A_narrative/adapters.safetensors and adapters_w3/T3A_narrative/0001500_adapters.safetensors.
# Iter 1510: Train loss 0.035, Learning Rate 2.000e-04, It/sec 0.614, Tokens/sec 9.828, Trained Tokens 24160, Peak mem 6.323 GB
# Iter 1520: Train loss 0.053, Learning Rate 2.000e-04, It/sec 0.614, Tokens/sec 9.824, Trained Tokens 24320, Peak mem 6.323 GB
# Iter 1530: Train loss 0.017, Learning Rate 2.000e-04, It/sec 0.614, Tokens/sec 9.827, Trained Tokens 24480, Peak mem 6.323 GB
# Iter 1540: Train loss 0.005, Learning Rate 2.000e-04, It/sec 0.613, Tokens/sec 9.815, Trained Tokens 24640, Peak mem 6.323 GB
# Iter 1550: Train loss 0.028, Learning Rate 2.000e-04, It/sec 0.614, Tokens/sec 9.830, Trained Tokens 24800, Peak mem 6.323 GB
# Iter 1560: Train loss 0.103, Learning Rate 2.000e-04, It/sec 0.613, Tokens/sec 9.814, Trained Tokens 24960, Peak mem 6.323 GB
# Iter 1570: Train loss 0.069, Learning Rate 2.000e-04, It/sec 0.613, Tokens/sec 9.814, Trained Tokens 25120, Peak mem 6.323 GB
# Iter 1580: Train loss 0.040, Learning Rate 2.000e-04, It/sec 0.614, Tokens/sec 9.829, Trained Tokens 25280, Peak mem 6.323 GB
# Iter 1590: Train loss 0.028, Learning Rate 2.000e-04, It/sec 0.614, Tokens/sec 9.820, Trained Tokens 25440, Peak mem 6.323 GB
# Calculating loss...: 100%|██████████████████████| 25/25 [00:21<00:00,  1.18it/s]
# Iter 1600: Val loss 0.031, Val took 21.185s
# Iter 1600: Train loss 0.017, Learning Rate 2.000e-04, It/sec 0.613, Tokens/sec 9.815, Trained Tokens 25600, Peak mem 6.323 GB
# Iter 1610: Train loss 0.093, Learning Rate 2.000e-04, It/sec 0.614, Tokens/sec 9.827, Trained Tokens 25760, Peak mem 6.323 GB
# Iter 1620: Train loss 0.017, Learning Rate 2.000e-04, It/sec 0.605, Tokens/sec 9.682, Trained Tokens 25920, Peak mem 6.323 GB
# Iter 1630: Train loss 0.073, Learning Rate 2.000e-04, It/sec 0.614, Tokens/sec 9.828, Trained Tokens 26080, Peak mem 6.323 GB
# Iter 1640: Train loss 0.035, Learning Rate 2.000e-04, It/sec 0.614, Tokens/sec 9.819, Trained Tokens 26240, Peak mem 6.323 GB
# Iter 1650: Train loss 0.011, Learning Rate 2.000e-04, It/sec 0.606, Tokens/sec 9.697, Trained Tokens 26400, Peak mem 6.323 GB
# Iter 1660: Train loss 0.009, Learning Rate 2.000e-04, It/sec 0.613, Tokens/sec 9.809, Trained Tokens 26560, Peak mem 6.323 GB
# Iter 1670: Train loss 0.041, Learning Rate 2.000e-04, It/sec 0.613, Tokens/sec 9.814, Trained Tokens 26720, Peak mem 6.323 GB
# Iter 1680: Train loss 0.008, Learning Rate 2.000e-04, It/sec 0.614, Tokens/sec 9.825, Trained Tokens 26880, Peak mem 6.323 GB
# Iter 1690: Train loss 0.023, Learning Rate 2.000e-04, It/sec 0.614, Tokens/sec 9.823, Trained Tokens 27040, Peak mem 6.323 GB
# Iter 1700: Train loss 0.029, Learning Rate 2.000e-04, It/sec 0.613, Tokens/sec 9.803, Trained Tokens 27200, Peak mem 6.323 GB
# Iter 1710: Train loss 0.030, Learning Rate 2.000e-04, It/sec 0.607, Tokens/sec 9.718, Trained Tokens 27360, Peak mem 6.323 GB
# Iter 1720: Train loss 0.105, Learning Rate 2.000e-04, It/sec 0.613, Tokens/sec 9.806, Trained Tokens 27520, Peak mem 6.323 GB
# Iter 1730: Train loss 0.007, Learning Rate 2.000e-04, It/sec 0.607, Tokens/sec 9.713, Trained Tokens 27680, Peak mem 6.323 GB
# Iter 1740: Train loss 0.018, Learning Rate 2.000e-04, It/sec 0.614, Tokens/sec 9.818, Trained Tokens 27840, Peak mem 6.323 GB
# Iter 1750: Train loss 0.010, Learning Rate 2.000e-04, It/sec 0.614, Tokens/sec 9.828, Trained Tokens 28000, Peak mem 6.323 GB
# Iter 1760: Train loss 0.140, Learning Rate 2.000e-04, It/sec 0.614, Tokens/sec 9.831, Trained Tokens 28160, Peak mem 6.323 GB
# Iter 1770: Train loss 0.077, Learning Rate 2.000e-04, It/sec 0.606, Tokens/sec 9.699, Trained Tokens 28320, Peak mem 6.323 GB
# Iter 1780: Train loss 0.044, Learning Rate 2.000e-04, It/sec 0.614, Tokens/sec 9.830, Trained Tokens 28480, Peak mem 6.323 GB
# Iter 1790: Train loss 0.029, Learning Rate 2.000e-04, It/sec 0.614, Tokens/sec 9.826, Trained Tokens 28640, Peak mem 6.323 GB
# Calculating loss...: 100%|██████████████████████| 25/25 [00:21<00:00,  1.18it/s]
# Iter 1800: Val loss 0.046, Val took 21.202s
# Iter 1800: Train loss 0.013, Learning Rate 2.000e-04, It/sec 0.614, Tokens/sec 9.817, Trained Tokens 28800, Peak mem 6.323 GB
# Iter 1810: Train loss 0.120, Learning Rate 2.000e-04, It/sec 0.614, Tokens/sec 9.828, Trained Tokens 28960, Peak mem 6.323 GB
# Iter 1820: Train loss 0.015, Learning Rate 2.000e-04, It/sec 0.613, Tokens/sec 9.810, Trained Tokens 29120, Peak mem 6.323 GB
# Iter 1830: Train loss 0.004, Learning Rate 2.000e-04, It/sec 0.614, Tokens/sec 9.828, Trained Tokens 29280, Peak mem 6.323 GB
# Iter 1840: Train loss 0.024, Learning Rate 2.000e-04, It/sec 0.614, Tokens/sec 9.822, Trained Tokens 29440, Peak mem 6.323 GB
# Iter 1850: Train loss 0.054, Learning Rate 2.000e-04, It/sec 0.614, Tokens/sec 9.818, Trained Tokens 29600, Peak mem 6.323 GB
# Iter 1860: Train loss 0.096, Learning Rate 2.000e-04, It/sec 0.614, Tokens/sec 9.819, Trained Tokens 29760, Peak mem 6.323 GB
# Iter 1870: Train loss 0.002, Learning Rate 2.000e-04, It/sec 0.606, Tokens/sec 9.694, Trained Tokens 29920, Peak mem 6.323 GB
# Iter 1880: Train loss 0.130, Learning Rate 2.000e-04, It/sec 0.613, Tokens/sec 9.810, Trained Tokens 30080, Peak mem 6.323 GB
# Iter 1890: Train loss 0.024, Learning Rate 2.000e-04, It/sec 0.614, Tokens/sec 9.819, Trained Tokens 30240, Peak mem 6.323 GB
# Iter 1900: Train loss 0.046, Learning Rate 2.000e-04, It/sec 0.614, Tokens/sec 9.820, Trained Tokens 30400, Peak mem 6.323 GB
# Iter 1910: Train loss 0.048, Learning Rate 2.000e-04, It/sec 0.613, Tokens/sec 9.812, Trained Tokens 30560, Peak mem 6.323 GB
# Iter 1920: Train loss 0.038, Learning Rate 2.000e-04, It/sec 0.614, Tokens/sec 9.832, Trained Tokens 30720, Peak mem 6.323 GB
# Iter 1930: Train loss 0.024, Learning Rate 2.000e-04, It/sec 0.614, Tokens/sec 9.823, Trained Tokens 30880, Peak mem 6.323 GB
# Iter 1940: Train loss 0.008, Learning Rate 2.000e-04, It/sec 0.614, Tokens/sec 9.827, Trained Tokens 31040, Peak mem 6.323 GB
# Iter 1950: Train loss 0.039, Learning Rate 2.000e-04, It/sec 0.614, Tokens/sec 9.821, Trained Tokens 31200, Peak mem 6.323 GB
# Iter 1960: Train loss 0.014, Learning Rate 2.000e-04, It/sec 0.614, Tokens/sec 9.823, Trained Tokens 31360, Peak mem 6.323 GB
# Iter 1970: Train loss 0.035, Learning Rate 2.000e-04, It/sec 0.613, Tokens/sec 9.812, Trained Tokens 31520, Peak mem 6.323 GB
# Iter 1980: Train loss 0.011, Learning Rate 2.000e-04, It/sec 0.614, Tokens/sec 9.829, Trained Tokens 31680, Peak mem 6.323 GB
# Iter 1990: Train loss 0.005, Learning Rate 2.000e-04, It/sec 0.613, Tokens/sec 9.814, Trained Tokens 31840, Peak mem 6.323 GB
# Calculating loss...: 100%|██████████████████████| 25/25 [00:21<00:00,  1.18it/s]
# Iter 2000: Val loss 0.016, Val took 21.195s
# Iter 2000: Train loss 0.070, Learning Rate 2.000e-04, It/sec 0.613, Tokens/sec 9.807, Trained Tokens 32000, Peak mem 6.323 GB
# Iter 2000: Saved adapter weights to adapters_w3/T3A_narrative/adapters.safetensors and adapters_w3/T3A_narrative/0002000_adapters.safetensors.
# Saved final weights to adapters_w3/T3A_narrative/adapters.safetensors.

# %%
# ── Load model with T3A_narrative adapter ──────────────────────────────
model_mlx, tok_mlx = load(
    MODEL_ID,
    adapter_path="./adapters_w3/T3A_narrative",
)

# ── Inference ──────────────────────────────────────────────────────
t0 = time.time()
preds, refs, probs = run_inference_mlx(
    model_mlx, tok_mlx, test_ds_narrative_full, return_probs=True
)

# ── Evaluate ───────────────────────────────────────────────────────
metrics = evaluate_predictions(preds, refs, label_name="T3A_narrative")

# ── Calibration ────────────────────────────────────────────────────
ece = calibration_analysis(
    probs, refs,
    label_name="T3A_narrative",
    save_path=os.path.join(OUTPUT_DIR, "calibration_T3A_narrative.png")
)
metrics["ECE"] = ece
all_metrics.append(metrics)

# ── Save predictions ───────────────────────────────────────────────
out_df = pd.DataFrame({"Predicted_Label": preds, "Ground_Truth": refs, "P_Yes": probs})
out_df.to_csv(os.path.join(OUTPUT_DIR, "predictions_T3A_narrative.csv"), index=False)

elapsed = round(time.time() - t0, 2)
experiment_times["T3A_narrative"] = elapsed
print(f"\n  ⏱ T3A_narrative done in {elapsed:.1f}s")

# ── Clean up ───────────────────────────────────────────────────────
del model_mlx, tok_mlx
# Out:
# Downloading (incomplete total...): 0.00B [00:00, ?B/s]
# Fetching 9 files:   0%|          | 0/9 [00:00<?, ?it/s]
# Generating:   0%|          | 0/8275 [00:00<?, ?it/s]
# ── T3A_narrative ──
#   Label: T3A_narrative
#   N_test: 8275
#   Accuracy: 0.9601
#   Recall: 0.8412
#   Precision: 0.8134
#   F1: 0.827
#   Unknown: 0
#               precision    recall  f1-score   support
#
#           No       0.98      0.98      0.98      7337
#          Yes       0.81      0.84      0.83       938
#
#     accuracy                           0.96      8275
#    macro avg       0.90      0.91      0.90      8275
# weighted avg       0.96      0.96      0.96      8275
#
#   ECE: 0.0180 | Saved → ./results_wave3/calibration_T3A_narrative.png
#
#   ⏱ T3A_narrative done in 2685.2s

# %% [markdown]
# ### Training and Inference for T3B_minimal

# %%
# !mlx_lm.lora \
    --model {MODEL_ID} \
    --train \
    --data ./mlx_data/T3B_minimal \
    --num-layers 16 \
    --batch-size 4 \
    --grad-accumulation-steps 4 \
    --iters 2000 \
    --learning-rate 2e-4 \
    --mask-prompt \
    --adapter-path ./adapters_w3/T3B_minimal \
    --save-every 500 \
    -c ./configs/lora_config.yaml
# Out:
# Loading configuration file ./configs/lora_config.yaml
# Loading pretrained model
# Downloading (incomplete total...): 0.00B [00:00, ?B/s]
# Fetching 9 files: 100%|████████████████████████| 9/9 [00:00<00:00, 50805.84it/s]
# Download complete: : 0.00B [00:00, ?B/s]
# Loading datasets
# Training
# Trainable parameters: 0.684% (10.551M/1543.714M)
# Starting training..., iters: 2000
# Calculating loss...: 100%|██████████████████████| 25/25 [00:21<00:00,  1.17it/s]
# Iter 1: Val loss 7.455, Val took 21.318s
# Iter 10: Train loss 3.648, Learning Rate 2.000e-04, It/sec 0.602, Tokens/sec 9.639, Trained Tokens 160, Peak mem 5.730 GB
# Iter 20: Train loss 0.192, Learning Rate 2.000e-04, It/sec 0.607, Tokens/sec 9.714, Trained Tokens 320, Peak mem 5.730 GB
# Iter 30: Train loss 0.035, Learning Rate 2.000e-04, It/sec 0.610, Tokens/sec 9.757, Trained Tokens 480, Peak mem 5.730 GB
# Iter 40: Train loss 0.060, Learning Rate 2.000e-04, It/sec 0.610, Tokens/sec 9.761, Trained Tokens 640, Peak mem 5.730 GB
# Iter 50: Train loss 0.027, Learning Rate 2.000e-04, It/sec 0.609, Tokens/sec 9.742, Trained Tokens 800, Peak mem 5.730 GB
# Iter 60: Train loss 0.072, Learning Rate 2.000e-04, It/sec 0.610, Tokens/sec 9.755, Trained Tokens 960, Peak mem 5.730 GB
# Iter 70: Train loss 0.053, Learning Rate 2.000e-04, It/sec 0.610, Tokens/sec 9.758, Trained Tokens 1120, Peak mem 5.730 GB
# Iter 80: Train loss 0.050, Learning Rate 2.000e-04, It/sec 0.611, Tokens/sec 9.776, Trained Tokens 1280, Peak mem 5.730 GB
# Iter 90: Train loss 0.088, Learning Rate 2.000e-04, It/sec 0.610, Tokens/sec 9.755, Trained Tokens 1440, Peak mem 5.730 GB
# Iter 100: Train loss 0.074, Learning Rate 2.000e-04, It/sec 0.611, Tokens/sec 9.773, Trained Tokens 1600, Peak mem 5.730 GB
# Iter 110: Train loss 0.036, Learning Rate 2.000e-04, It/sec 0.610, Tokens/sec 9.761, Trained Tokens 1760, Peak mem 5.730 GB
# Iter 120: Train loss 0.031, Learning Rate 2.000e-04, It/sec 0.609, Tokens/sec 9.747, Trained Tokens 1920, Peak mem 5.730 GB
# Iter 130: Train loss 0.072, Learning Rate 2.000e-04, It/sec 0.610, Tokens/sec 9.758, Trained Tokens 2080, Peak mem 5.730 GB
# Iter 140: Train loss 0.072, Learning Rate 2.000e-04, It/sec 0.610, Tokens/sec 9.760, Trained Tokens 2240, Peak mem 5.730 GB
# Iter 150: Train loss 0.083, Learning Rate 2.000e-04, It/sec 0.611, Tokens/sec 9.775, Trained Tokens 2400, Peak mem 5.730 GB
# Iter 160: Train loss 0.033, Learning Rate 2.000e-04, It/sec 0.605, Tokens/sec 9.679, Trained Tokens 2560, Peak mem 5.730 GB
# Iter 170: Train loss 0.048, Learning Rate 2.000e-04, It/sec 0.610, Tokens/sec 9.758, Trained Tokens 2720, Peak mem 5.730 GB
# Iter 180: Train loss 0.070, Learning Rate 2.000e-04, It/sec 0.609, Tokens/sec 9.746, Trained Tokens 2880, Peak mem 5.730 GB
# Iter 190: Train loss 0.064, Learning Rate 2.000e-04, It/sec 0.609, Tokens/sec 9.748, Trained Tokens 3040, Peak mem 5.730 GB
# Calculating loss...: 100%|██████████████████████| 25/25 [00:21<00:00,  1.18it/s]
# Iter 200: Val loss 0.037, Val took 21.244s
# Iter 200: Train loss 0.023, Learning Rate 2.000e-04, It/sec 0.610, Tokens/sec 9.756, Trained Tokens 3200, Peak mem 5.730 GB
# Iter 210: Train loss 0.048, Learning Rate 2.000e-04, It/sec 0.610, Tokens/sec 9.756, Trained Tokens 3360, Peak mem 5.730 GB
# Iter 220: Train loss 0.067, Learning Rate 2.000e-04, It/sec 0.611, Tokens/sec 9.780, Trained Tokens 3520, Peak mem 5.730 GB
# Iter 230: Train loss 0.034, Learning Rate 2.000e-04, It/sec 0.610, Tokens/sec 9.760, Trained Tokens 3680, Peak mem 5.730 GB
# Iter 240: Train loss 0.013, Learning Rate 2.000e-04, It/sec 0.611, Tokens/sec 9.769, Trained Tokens 3840, Peak mem 5.730 GB
# Iter 250: Train loss 0.036, Learning Rate 2.000e-04, It/sec 0.609, Tokens/sec 9.743, Trained Tokens 4000, Peak mem 5.730 GB
# Iter 260: Train loss 0.004, Learning Rate 2.000e-04, It/sec 0.610, Tokens/sec 9.759, Trained Tokens 4160, Peak mem 5.730 GB
# Iter 270: Train loss 0.003, Learning Rate 2.000e-04, It/sec 0.609, Tokens/sec 9.752, Trained Tokens 4320, Peak mem 5.730 GB
# Iter 280: Train loss 0.013, Learning Rate 2.000e-04, It/sec 0.609, Tokens/sec 9.749, Trained Tokens 4480, Peak mem 5.730 GB
# Iter 290: Train loss 0.115, Learning Rate 2.000e-04, It/sec 0.609, Tokens/sec 9.746, Trained Tokens 4640, Peak mem 5.730 GB
# Iter 300: Train loss 0.048, Learning Rate 2.000e-04, It/sec 0.609, Tokens/sec 9.751, Trained Tokens 4800, Peak mem 5.730 GB
# Iter 310: Train loss 0.074, Learning Rate 2.000e-04, It/sec 0.610, Tokens/sec 9.762, Trained Tokens 4960, Peak mem 5.730 GB
# Iter 320: Train loss 0.063, Learning Rate 2.000e-04, It/sec 0.609, Tokens/sec 9.742, Trained Tokens 5120, Peak mem 5.730 GB
# Iter 330: Train loss 0.031, Learning Rate 2.000e-04, It/sec 0.609, Tokens/sec 9.740, Trained Tokens 5280, Peak mem 5.730 GB
# Iter 340: Train loss 0.044, Learning Rate 2.000e-04, It/sec 0.609, Tokens/sec 9.739, Trained Tokens 5440, Peak mem 5.730 GB
# Iter 350: Train loss 0.024, Learning Rate 2.000e-04, It/sec 0.609, Tokens/sec 9.749, Trained Tokens 5600, Peak mem 5.730 GB
# Iter 360: Train loss 0.056, Learning Rate 2.000e-04, It/sec 0.609, Tokens/sec 9.752, Trained Tokens 5760, Peak mem 5.730 GB
# Iter 370: Train loss 0.015, Learning Rate 2.000e-04, It/sec 0.609, Tokens/sec 9.739, Trained Tokens 5920, Peak mem 5.730 GB
# Iter 380: Train loss 0.015, Learning Rate 2.000e-04, It/sec 0.610, Tokens/sec 9.759, Trained Tokens 6080, Peak mem 5.730 GB
# Iter 390: Train loss 0.008, Learning Rate 2.000e-04, It/sec 0.609, Tokens/sec 9.751, Trained Tokens 6240, Peak mem 5.730 GB
# Calculating loss...: 100%|██████████████████████| 25/25 [00:21<00:00,  1.18it/s]
# Iter 400: Val loss 0.053, Val took 21.221s
# Iter 400: Train loss 0.013, Learning Rate 2.000e-04, It/sec 0.611, Tokens/sec 9.774, Trained Tokens 6400, Peak mem 5.730 GB
# Iter 410: Train loss 0.022, Learning Rate 2.000e-04, It/sec 0.611, Tokens/sec 9.769, Trained Tokens 6560, Peak mem 5.730 GB
# Iter 420: Train loss 0.031, Learning Rate 2.000e-04, It/sec 0.610, Tokens/sec 9.753, Trained Tokens 6720, Peak mem 5.730 GB
# Iter 430: Train loss 0.003, Learning Rate 2.000e-04, It/sec 0.610, Tokens/sec 9.764, Trained Tokens 6880, Peak mem 5.730 GB
# Iter 440: Train loss 0.120, Learning Rate 2.000e-04, It/sec 0.610, Tokens/sec 9.760, Trained Tokens 7040, Peak mem 5.730 GB
# Iter 450: Train loss 0.020, Learning Rate 2.000e-04, It/sec 0.610, Tokens/sec 9.768, Trained Tokens 7200, Peak mem 5.730 GB
# Iter 460: Train loss 0.043, Learning Rate 2.000e-04, It/sec 0.611, Tokens/sec 9.773, Trained Tokens 7360, Peak mem 5.730 GB
# Iter 470: Train loss 0.022, Learning Rate 2.000e-04, It/sec 0.610, Tokens/sec 9.755, Trained Tokens 7520, Peak mem 5.730 GB
# Iter 480: Train loss 0.035, Learning Rate 2.000e-04, It/sec 0.611, Tokens/sec 9.773, Trained Tokens 7680, Peak mem 5.730 GB
# Iter 490: Train loss 0.007, Learning Rate 2.000e-04, It/sec 0.611, Tokens/sec 9.768, Trained Tokens 7840, Peak mem 5.730 GB
# Iter 500: Train loss 0.026, Learning Rate 2.000e-04, It/sec 0.611, Tokens/sec 9.772, Trained Tokens 8000, Peak mem 5.730 GB
# Iter 500: Saved adapter weights to adapters_w3/T3B_minimal/adapters.safetensors and adapters_w3/T3B_minimal/0000500_adapters.safetensors.
# Iter 510: Train loss 0.019, Learning Rate 2.000e-04, It/sec 0.610, Tokens/sec 9.762, Trained Tokens 8160, Peak mem 5.772 GB
# Iter 520: Train loss 0.004, Learning Rate 2.000e-04, It/sec 0.610, Tokens/sec 9.760, Trained Tokens 8320, Peak mem 5.772 GB
# Iter 530: Train loss 0.013, Learning Rate 2.000e-04, It/sec 0.610, Tokens/sec 9.757, Trained Tokens 8480, Peak mem 5.772 GB
# Iter 540: Train loss 0.085, Learning Rate 2.000e-04, It/sec 0.611, Tokens/sec 9.776, Trained Tokens 8640, Peak mem 5.772 GB
# Iter 550: Train loss 0.046, Learning Rate 2.000e-04, It/sec 0.610, Tokens/sec 9.764, Trained Tokens 8800, Peak mem 5.772 GB
# Iter 560: Train loss 0.088, Learning Rate 2.000e-04, It/sec 0.610, Tokens/sec 9.757, Trained Tokens 8960, Peak mem 5.772 GB
# Iter 570: Train loss 0.043, Learning Rate 2.000e-04, It/sec 0.610, Tokens/sec 9.768, Trained Tokens 9120, Peak mem 5.772 GB
# Iter 580: Train loss 0.017, Learning Rate 2.000e-04, It/sec 0.610, Tokens/sec 9.755, Trained Tokens 9280, Peak mem 5.772 GB
# Iter 590: Train loss 0.033, Learning Rate 2.000e-04, It/sec 0.610, Tokens/sec 9.763, Trained Tokens 9440, Peak mem 5.772 GB
# Calculating loss...: 100%|██████████████████████| 25/25 [00:21<00:00,  1.18it/s]
# Iter 600: Val loss 0.036, Val took 21.222s
# Iter 600: Train loss 0.059, Learning Rate 2.000e-04, It/sec 0.609, Tokens/sec 9.748, Trained Tokens 9600, Peak mem 5.772 GB
# Iter 610: Train loss 0.033, Learning Rate 2.000e-04, It/sec 0.609, Tokens/sec 9.736, Trained Tokens 9760, Peak mem 5.772 GB
# Iter 620: Train loss 0.049, Learning Rate 2.000e-04, It/sec 0.611, Tokens/sec 9.768, Trained Tokens 9920, Peak mem 5.772 GB
# Iter 630: Train loss 0.020, Learning Rate 2.000e-04, It/sec 0.611, Tokens/sec 9.775, Trained Tokens 10080, Peak mem 5.772 GB
# Iter 640: Train loss 0.072, Learning Rate 2.000e-04, It/sec 0.610, Tokens/sec 9.761, Trained Tokens 10240, Peak mem 5.772 GB
# Iter 650: Train loss 0.075, Learning Rate 2.000e-04, It/sec 0.610, Tokens/sec 9.764, Trained Tokens 10400, Peak mem 5.772 GB
# Iter 660: Train loss 0.013, Learning Rate 2.000e-04, It/sec 0.610, Tokens/sec 9.759, Trained Tokens 10560, Peak mem 5.772 GB
# Iter 670: Train loss 0.033, Learning Rate 2.000e-04, It/sec 0.610, Tokens/sec 9.764, Trained Tokens 10720, Peak mem 5.772 GB
# Iter 680: Train loss 0.032, Learning Rate 2.000e-04, It/sec 0.610, Tokens/sec 9.756, Trained Tokens 10880, Peak mem 5.772 GB
# Iter 690: Train loss 0.033, Learning Rate 2.000e-04, It/sec 0.611, Tokens/sec 9.772, Trained Tokens 11040, Peak mem 5.772 GB
# Iter 700: Train loss 0.084, Learning Rate 2.000e-04, It/sec 0.609, Tokens/sec 9.746, Trained Tokens 11200, Peak mem 5.772 GB
# Iter 710: Train loss 0.007, Learning Rate 2.000e-04, It/sec 0.609, Tokens/sec 9.751, Trained Tokens 11360, Peak mem 5.772 GB
# Iter 720: Train loss 0.010, Learning Rate 2.000e-04, It/sec 0.610, Tokens/sec 9.765, Trained Tokens 11520, Peak mem 5.772 GB
# Iter 730: Train loss 0.046, Learning Rate 2.000e-04, It/sec 0.611, Tokens/sec 9.772, Trained Tokens 11680, Peak mem 5.772 GB
# Iter 740: Train loss 0.005, Learning Rate 2.000e-04, It/sec 0.610, Tokens/sec 9.762, Trained Tokens 11840, Peak mem 5.772 GB
# Iter 750: Train loss 0.003, Learning Rate 2.000e-04, It/sec 0.611, Tokens/sec 9.770, Trained Tokens 12000, Peak mem 5.772 GB
# Iter 760: Train loss 0.061, Learning Rate 2.000e-04, It/sec 0.610, Tokens/sec 9.758, Trained Tokens 12160, Peak mem 5.772 GB
# Iter 770: Train loss 0.043, Learning Rate 2.000e-04, It/sec 0.609, Tokens/sec 9.747, Trained Tokens 12320, Peak mem 5.772 GB
# Iter 780: Train loss 0.021, Learning Rate 2.000e-04, It/sec 0.607, Tokens/sec 9.708, Trained Tokens 12480, Peak mem 5.772 GB
# Iter 790: Train loss 0.006, Learning Rate 2.000e-04, It/sec 0.611, Tokens/sec 9.770, Trained Tokens 12640, Peak mem 5.772 GB
# Calculating loss...: 100%|██████████████████████| 25/25 [00:21<00:00,  1.18it/s]
# Iter 800: Val loss 0.022, Val took 21.225s
# Iter 800: Train loss 0.051, Learning Rate 2.000e-04, It/sec 0.610, Tokens/sec 9.757, Trained Tokens 12800, Peak mem 5.772 GB
# Iter 810: Train loss 0.022, Learning Rate 2.000e-04, It/sec 0.610, Tokens/sec 9.766, Trained Tokens 12960, Peak mem 5.772 GB
# Iter 820: Train loss 0.012, Learning Rate 2.000e-04, It/sec 0.610, Tokens/sec 9.758, Trained Tokens 13120, Peak mem 5.772 GB
# Iter 830: Train loss 0.051, Learning Rate 2.000e-04, It/sec 0.610, Tokens/sec 9.760, Trained Tokens 13280, Peak mem 5.772 GB
# Iter 840: Train loss 0.041, Learning Rate 2.000e-04, It/sec 0.611, Tokens/sec 9.773, Trained Tokens 13440, Peak mem 5.772 GB
# Iter 850: Train loss 0.021, Learning Rate 2.000e-04, It/sec 0.611, Tokens/sec 9.769, Trained Tokens 13600, Peak mem 5.772 GB
# Iter 860: Train loss 0.060, Learning Rate 2.000e-04, It/sec 0.611, Tokens/sec 9.777, Trained Tokens 13760, Peak mem 5.772 GB
# Iter 870: Train loss 0.032, Learning Rate 2.000e-04, It/sec 0.609, Tokens/sec 9.748, Trained Tokens 13920, Peak mem 5.772 GB
# Iter 880: Train loss 0.023, Learning Rate 2.000e-04, It/sec 0.610, Tokens/sec 9.756, Trained Tokens 14080, Peak mem 5.772 GB
# Iter 890: Train loss 0.031, Learning Rate 2.000e-04, It/sec 0.612, Tokens/sec 9.793, Trained Tokens 14240, Peak mem 5.772 GB
# Iter 900: Train loss 0.068, Learning Rate 2.000e-04, It/sec 0.610, Tokens/sec 9.763, Trained Tokens 14400, Peak mem 5.772 GB
# Iter 910: Train loss 0.037, Learning Rate 2.000e-04, It/sec 0.610, Tokens/sec 9.753, Trained Tokens 14560, Peak mem 5.772 GB
# Iter 920: Train loss 0.012, Learning Rate 2.000e-04, It/sec 0.610, Tokens/sec 9.766, Trained Tokens 14720, Peak mem 5.772 GB
# Iter 930: Train loss 0.042, Learning Rate 2.000e-04, It/sec 0.605, Tokens/sec 9.682, Trained Tokens 14880, Peak mem 5.772 GB
# Iter 940: Train loss 0.031, Learning Rate 2.000e-04, It/sec 0.609, Tokens/sec 9.748, Trained Tokens 15040, Peak mem 5.772 GB
# Iter 950: Train loss 0.070, Learning Rate 2.000e-04, It/sec 0.611, Tokens/sec 9.772, Trained Tokens 15200, Peak mem 5.772 GB
# Iter 960: Train loss 0.022, Learning Rate 2.000e-04, It/sec 0.610, Tokens/sec 9.760, Trained Tokens 15360, Peak mem 5.772 GB
# Iter 970: Train loss 0.007, Learning Rate 2.000e-04, It/sec 0.609, Tokens/sec 9.749, Trained Tokens 15520, Peak mem 5.772 GB
# Iter 980: Train loss 0.040, Learning Rate 2.000e-04, It/sec 0.609, Tokens/sec 9.744, Trained Tokens 15680, Peak mem 5.772 GB
# Iter 990: Train loss 0.075, Learning Rate 2.000e-04, It/sec 0.610, Tokens/sec 9.766, Trained Tokens 15840, Peak mem 5.772 GB
# Calculating loss...: 100%|██████████████████████| 25/25 [00:21<00:00,  1.18it/s]
# Iter 1000: Val loss 0.055, Val took 21.216s
# Iter 1000: Train loss 0.013, Learning Rate 2.000e-04, It/sec 0.611, Tokens/sec 9.777, Trained Tokens 16000, Peak mem 5.772 GB
# Iter 1000: Saved adapter weights to adapters_w3/T3B_minimal/adapters.safetensors and adapters_w3/T3B_minimal/0001000_adapters.safetensors.
# Iter 1010: Train loss 0.025, Learning Rate 2.000e-04, It/sec 0.610, Tokens/sec 9.758, Trained Tokens 16160, Peak mem 5.772 GB
# Iter 1020: Train loss 0.023, Learning Rate 2.000e-04, It/sec 0.610, Tokens/sec 9.755, Trained Tokens 16320, Peak mem 5.772 GB
# Iter 1030: Train loss 0.062, Learning Rate 2.000e-04, It/sec 0.611, Tokens/sec 9.780, Trained Tokens 16480, Peak mem 5.772 GB
# Iter 1040: Train loss 0.030, Learning Rate 2.000e-04, It/sec 0.610, Tokens/sec 9.767, Trained Tokens 16640, Peak mem 5.772 GB
# Iter 1050: Train loss 0.035, Learning Rate 2.000e-04, It/sec 0.610, Tokens/sec 9.762, Trained Tokens 16800, Peak mem 5.772 GB
# Iter 1060: Train loss 0.016, Learning Rate 2.000e-04, It/sec 0.611, Tokens/sec 9.770, Trained Tokens 16960, Peak mem 5.772 GB
# Iter 1070: Train loss 0.074, Learning Rate 2.000e-04, It/sec 0.610, Tokens/sec 9.756, Trained Tokens 17120, Peak mem 5.772 GB
# Iter 1080: Train loss 0.059, Learning Rate 2.000e-04, It/sec 0.610, Tokens/sec 9.760, Trained Tokens 17280, Peak mem 5.772 GB
# Iter 1090: Train loss 0.032, Learning Rate 2.000e-04, It/sec 0.611, Tokens/sec 9.777, Trained Tokens 17440, Peak mem 5.772 GB
# Iter 1100: Train loss 0.018, Learning Rate 2.000e-04, It/sec 0.610, Tokens/sec 9.754, Trained Tokens 17600, Peak mem 5.772 GB
# Iter 1110: Train loss 0.011, Learning Rate 2.000e-04, It/sec 0.610, Tokens/sec 9.759, Trained Tokens 17760, Peak mem 5.772 GB
# Iter 1120: Train loss 0.003, Learning Rate 2.000e-04, It/sec 0.610, Tokens/sec 9.766, Trained Tokens 17920, Peak mem 5.772 GB
# Iter 1130: Train loss 0.032, Learning Rate 2.000e-04, It/sec 0.611, Tokens/sec 9.770, Trained Tokens 18080, Peak mem 5.772 GB
# Iter 1140: Train loss 0.072, Learning Rate 2.000e-04, It/sec 0.612, Tokens/sec 9.789, Trained Tokens 18240, Peak mem 5.772 GB
# Iter 1150: Train loss 0.038, Learning Rate 2.000e-04, It/sec 0.611, Tokens/sec 9.769, Trained Tokens 18400, Peak mem 5.772 GB
# Iter 1160: Train loss 0.007, Learning Rate 2.000e-04, It/sec 0.610, Tokens/sec 9.766, Trained Tokens 18560, Peak mem 5.772 GB
# Iter 1170: Train loss 0.010, Learning Rate 2.000e-04, It/sec 0.611, Tokens/sec 9.778, Trained Tokens 18720, Peak mem 5.772 GB
# Iter 1180: Train loss 0.007, Learning Rate 2.000e-04, It/sec 0.610, Tokens/sec 9.755, Trained Tokens 18880, Peak mem 5.772 GB
# Iter 1190: Train loss 0.015, Learning Rate 2.000e-04, It/sec 0.610, Tokens/sec 9.765, Trained Tokens 19040, Peak mem 5.772 GB
# Calculating loss...: 100%|██████████████████████| 25/25 [00:21<00:00,  1.18it/s]
# Iter 1200: Val loss 0.025, Val took 21.219s
# Iter 1200: Train loss 0.059, Learning Rate 2.000e-04, It/sec 0.610, Tokens/sec 9.767, Trained Tokens 19200, Peak mem 5.772 GB
# Iter 1210: Train loss 0.046, Learning Rate 2.000e-04, It/sec 0.610, Tokens/sec 9.753, Trained Tokens 19360, Peak mem 5.772 GB
# Iter 1220: Train loss 0.077, Learning Rate 2.000e-04, It/sec 0.610, Tokens/sec 9.766, Trained Tokens 19520, Peak mem 5.772 GB
# Iter 1230: Train loss 0.034, Learning Rate 2.000e-04, It/sec 0.610, Tokens/sec 9.764, Trained Tokens 19680, Peak mem 5.772 GB
# Iter 1240: Train loss 0.021, Learning Rate 2.000e-04, It/sec 0.610, Tokens/sec 9.762, Trained Tokens 19840, Peak mem 5.772 GB
# Iter 1250: Train loss 0.084, Learning Rate 2.000e-04, It/sec 0.610, Tokens/sec 9.763, Trained Tokens 20000, Peak mem 5.772 GB
# Iter 1260: Train loss 0.012, Learning Rate 2.000e-04, It/sec 0.610, Tokens/sec 9.761, Trained Tokens 20160, Peak mem 5.772 GB
# Iter 1270: Train loss 0.018, Learning Rate 2.000e-04, It/sec 0.610, Tokens/sec 9.752, Trained Tokens 20320, Peak mem 5.772 GB
# Iter 1280: Train loss 0.047, Learning Rate 2.000e-04, It/sec 0.610, Tokens/sec 9.753, Trained Tokens 20480, Peak mem 5.772 GB
# Iter 1290: Train loss 0.015, Learning Rate 2.000e-04, It/sec 0.610, Tokens/sec 9.761, Trained Tokens 20640, Peak mem 5.772 GB
# Iter 1300: Train loss 0.036, Learning Rate 2.000e-04, It/sec 0.610, Tokens/sec 9.768, Trained Tokens 20800, Peak mem 5.772 GB
# Iter 1310: Train loss 0.066, Learning Rate 2.000e-04, It/sec 0.610, Tokens/sec 9.757, Trained Tokens 20960, Peak mem 5.772 GB
# Iter 1320: Train loss 0.026, Learning Rate 2.000e-04, It/sec 0.610, Tokens/sec 9.763, Trained Tokens 21120, Peak mem 5.772 GB
# Iter 1330: Train loss 0.007, Learning Rate 2.000e-04, It/sec 0.609, Tokens/sec 9.747, Trained Tokens 21280, Peak mem 5.772 GB
# Iter 1340: Train loss 0.035, Learning Rate 2.000e-04, It/sec 0.610, Tokens/sec 9.752, Trained Tokens 21440, Peak mem 5.772 GB
# Iter 1350: Train loss 0.004, Learning Rate 2.000e-04, It/sec 0.610, Tokens/sec 9.766, Trained Tokens 21600, Peak mem 5.772 GB
# Iter 1360: Train loss 0.006, Learning Rate 2.000e-04, It/sec 0.609, Tokens/sec 9.739, Trained Tokens 21760, Peak mem 5.772 GB
# Iter 1370: Train loss 0.029, Learning Rate 2.000e-04, It/sec 0.610, Tokens/sec 9.752, Trained Tokens 21920, Peak mem 5.772 GB
# Iter 1380: Train loss 0.010, Learning Rate 2.000e-04, It/sec 0.609, Tokens/sec 9.751, Trained Tokens 22080, Peak mem 5.772 GB
# Iter 1390: Train loss 0.059, Learning Rate 2.000e-04, It/sec 0.609, Tokens/sec 9.751, Trained Tokens 22240, Peak mem 5.772 GB
# Calculating loss...: 100%|██████████████████████| 25/25 [00:21<00:00,  1.18it/s]
# Iter 1400: Val loss 0.022, Val took 21.220s
# Iter 1400: Train loss 0.003, Learning Rate 2.000e-04, It/sec 0.610, Tokens/sec 9.756, Trained Tokens 22400, Peak mem 5.772 GB
# Iter 1410: Train loss 0.021, Learning Rate 2.000e-04, It/sec 0.609, Tokens/sec 9.748, Trained Tokens 22560, Peak mem 5.772 GB
# Iter 1420: Train loss 0.093, Learning Rate 2.000e-04, It/sec 0.610, Tokens/sec 9.756, Trained Tokens 22720, Peak mem 5.772 GB
# Iter 1430: Train loss 0.028, Learning Rate 2.000e-04, It/sec 0.610, Tokens/sec 9.761, Trained Tokens 22880, Peak mem 5.772 GB
# Iter 1440: Train loss 0.032, Learning Rate 2.000e-04, It/sec 0.609, Tokens/sec 9.742, Trained Tokens 23040, Peak mem 5.772 GB
# Iter 1450: Train loss 0.018, Learning Rate 2.000e-04, It/sec 0.611, Tokens/sec 9.781, Trained Tokens 23200, Peak mem 5.772 GB
# Iter 1460: Train loss 0.019, Learning Rate 2.000e-04, It/sec 0.611, Tokens/sec 9.771, Trained Tokens 23360, Peak mem 5.772 GB
# Iter 1470: Train loss 0.017, Learning Rate 2.000e-04, It/sec 0.610, Tokens/sec 9.759, Trained Tokens 23520, Peak mem 5.772 GB
# Iter 1480: Train loss 0.033, Learning Rate 2.000e-04, It/sec 0.610, Tokens/sec 9.753, Trained Tokens 23680, Peak mem 5.772 GB
# Iter 1490: Train loss 0.121, Learning Rate 2.000e-04, It/sec 0.610, Tokens/sec 9.767, Trained Tokens 23840, Peak mem 5.772 GB
# Iter 1500: Train loss 0.028, Learning Rate 2.000e-04, It/sec 0.610, Tokens/sec 9.758, Trained Tokens 24000, Peak mem 5.772 GB
# Iter 1500: Saved adapter weights to adapters_w3/T3B_minimal/adapters.safetensors and adapters_w3/T3B_minimal/0001500_adapters.safetensors.
# Iter 1510: Train loss 0.026, Learning Rate 2.000e-04, It/sec 0.610, Tokens/sec 9.766, Trained Tokens 24160, Peak mem 5.772 GB
# Iter 1520: Train loss 0.057, Learning Rate 2.000e-04, It/sec 0.610, Tokens/sec 9.766, Trained Tokens 24320, Peak mem 5.772 GB
# Iter 1530: Train loss 0.016, Learning Rate 2.000e-04, It/sec 0.610, Tokens/sec 9.766, Trained Tokens 24480, Peak mem 5.772 GB
# Iter 1540: Train loss 0.006, Learning Rate 2.000e-04, It/sec 0.609, Tokens/sec 9.737, Trained Tokens 24640, Peak mem 5.772 GB
# Iter 1550: Train loss 0.027, Learning Rate 2.000e-04, It/sec 0.611, Tokens/sec 9.773, Trained Tokens 24800, Peak mem 5.772 GB
# Iter 1560: Train loss 0.100, Learning Rate 2.000e-04, It/sec 0.610, Tokens/sec 9.753, Trained Tokens 24960, Peak mem 5.772 GB
# Iter 1570: Train loss 0.072, Learning Rate 2.000e-04, It/sec 0.610, Tokens/sec 9.757, Trained Tokens 25120, Peak mem 5.772 GB
# Iter 1580: Train loss 0.036, Learning Rate 2.000e-04, It/sec 0.609, Tokens/sec 9.752, Trained Tokens 25280, Peak mem 5.772 GB
# Iter 1590: Train loss 0.026, Learning Rate 2.000e-04, It/sec 0.610, Tokens/sec 9.761, Trained Tokens 25440, Peak mem 5.772 GB
# Calculating loss...: 100%|██████████████████████| 25/25 [00:21<00:00,  1.18it/s]
# Iter 1600: Val loss 0.031, Val took 21.225s
# Iter 1600: Train loss 0.015, Learning Rate 2.000e-04, It/sec 0.610, Tokens/sec 9.761, Trained Tokens 25600, Peak mem 5.772 GB
# Iter 1610: Train loss 0.094, Learning Rate 2.000e-04, It/sec 0.610, Tokens/sec 9.765, Trained Tokens 25760, Peak mem 5.772 GB
# Iter 1620: Train loss 0.018, Learning Rate 2.000e-04, It/sec 0.609, Tokens/sec 9.752, Trained Tokens 25920, Peak mem 5.772 GB
# Iter 1630: Train loss 0.073, Learning Rate 2.000e-04, It/sec 0.609, Tokens/sec 9.743, Trained Tokens 26080, Peak mem 5.772 GB
# Iter 1640: Train loss 0.034, Learning Rate 2.000e-04, It/sec 0.610, Tokens/sec 9.765, Trained Tokens 26240, Peak mem 5.772 GB
# Iter 1650: Train loss 0.014, Learning Rate 2.000e-04, It/sec 0.610, Tokens/sec 9.758, Trained Tokens 26400, Peak mem 5.772 GB
# Iter 1660: Train loss 0.012, Learning Rate 2.000e-04, It/sec 0.608, Tokens/sec 9.723, Trained Tokens 26560, Peak mem 5.772 GB
# Iter 1670: Train loss 0.044, Learning Rate 2.000e-04, It/sec 0.610, Tokens/sec 9.752, Trained Tokens 26720, Peak mem 5.772 GB
# Iter 1680: Train loss 0.010, Learning Rate 2.000e-04, It/sec 0.610, Tokens/sec 9.764, Trained Tokens 26880, Peak mem 5.772 GB
# Iter 1690: Train loss 0.022, Learning Rate 2.000e-04, It/sec 0.610, Tokens/sec 9.764, Trained Tokens 27040, Peak mem 5.772 GB
# Iter 1700: Train loss 0.020, Learning Rate 2.000e-04, It/sec 0.610, Tokens/sec 9.759, Trained Tokens 27200, Peak mem 5.772 GB
# Iter 1710: Train loss 0.033, Learning Rate 2.000e-04, It/sec 0.611, Tokens/sec 9.776, Trained Tokens 27360, Peak mem 5.772 GB
# Iter 1720: Train loss 0.101, Learning Rate 2.000e-04, It/sec 0.610, Tokens/sec 9.762, Trained Tokens 27520, Peak mem 5.772 GB
# Iter 1730: Train loss 0.009, Learning Rate 2.000e-04, It/sec 0.613, Tokens/sec 9.807, Trained Tokens 27680, Peak mem 5.772 GB
# Iter 1740: Train loss 0.017, Learning Rate 2.000e-04, It/sec 0.609, Tokens/sec 9.741, Trained Tokens 27840, Peak mem 5.772 GB
# Iter 1750: Train loss 0.008, Learning Rate 2.000e-04, It/sec 0.610, Tokens/sec 9.755, Trained Tokens 28000, Peak mem 5.772 GB
# Iter 1760: Train loss 0.132, Learning Rate 2.000e-04, It/sec 0.604, Tokens/sec 9.661, Trained Tokens 28160, Peak mem 5.772 GB
# Iter 1770: Train loss 0.076, Learning Rate 2.000e-04, It/sec 0.610, Tokens/sec 9.763, Trained Tokens 28320, Peak mem 5.772 GB
# Iter 1780: Train loss 0.040, Learning Rate 2.000e-04, It/sec 0.610, Tokens/sec 9.766, Trained Tokens 28480, Peak mem 5.772 GB
# Iter 1790: Train loss 0.033, Learning Rate 2.000e-04, It/sec 0.611, Tokens/sec 9.773, Trained Tokens 28640, Peak mem 5.772 GB
# Calculating loss...: 100%|██████████████████████| 25/25 [00:21<00:00,  1.18it/s]
# Iter 1800: Val loss 0.047, Val took 21.210s
# Iter 1800: Train loss 0.014, Learning Rate 2.000e-04, It/sec 0.610, Tokens/sec 9.768, Trained Tokens 28800, Peak mem 5.772 GB
# Iter 1810: Train loss 0.112, Learning Rate 2.000e-04, It/sec 0.609, Tokens/sec 9.749, Trained Tokens 28960, Peak mem 5.772 GB
# Iter 1820: Train loss 0.014, Learning Rate 2.000e-04, It/sec 0.609, Tokens/sec 9.751, Trained Tokens 29120, Peak mem 5.772 GB
# Iter 1830: Train loss 0.006, Learning Rate 2.000e-04, It/sec 0.610, Tokens/sec 9.762, Trained Tokens 29280, Peak mem 5.772 GB
# Iter 1840: Train loss 0.020, Learning Rate 2.000e-04, It/sec 0.609, Tokens/sec 9.748, Trained Tokens 29440, Peak mem 5.772 GB
# Iter 1850: Train loss 0.044, Learning Rate 2.000e-04, It/sec 0.609, Tokens/sec 9.750, Trained Tokens 29600, Peak mem 5.772 GB
# Iter 1860: Train loss 0.092, Learning Rate 2.000e-04, It/sec 0.610, Tokens/sec 9.756, Trained Tokens 29760, Peak mem 5.772 GB
# Iter 1870: Train loss 0.004, Learning Rate 2.000e-04, It/sec 0.610, Tokens/sec 9.753, Trained Tokens 29920, Peak mem 5.772 GB
# Iter 1880: Train loss 0.111, Learning Rate 2.000e-04, It/sec 0.609, Tokens/sec 9.746, Trained Tokens 30080, Peak mem 5.772 GB
# Iter 1890: Train loss 0.028, Learning Rate 2.000e-04, It/sec 0.611, Tokens/sec 9.777, Trained Tokens 30240, Peak mem 5.772 GB
# Iter 1900: Train loss 0.047, Learning Rate 2.000e-04, It/sec 0.610, Tokens/sec 9.757, Trained Tokens 30400, Peak mem 5.772 GB
# Iter 1910: Train loss 0.043, Learning Rate 2.000e-04, It/sec 0.610, Tokens/sec 9.756, Trained Tokens 30560, Peak mem 5.772 GB
# Iter 1920: Train loss 0.036, Learning Rate 2.000e-04, It/sec 0.609, Tokens/sec 9.752, Trained Tokens 30720, Peak mem 5.772 GB
# Iter 1930: Train loss 0.020, Learning Rate 2.000e-04, It/sec 0.610, Tokens/sec 9.757, Trained Tokens 30880, Peak mem 5.772 GB
# Iter 1940: Train loss 0.007, Learning Rate 2.000e-04, It/sec 0.609, Tokens/sec 9.749, Trained Tokens 31040, Peak mem 5.772 GB
# Iter 1950: Train loss 0.040, Learning Rate 2.000e-04, It/sec 0.610, Tokens/sec 9.760, Trained Tokens 31200, Peak mem 5.772 GB
# Iter 1960: Train loss 0.014, Learning Rate 2.000e-04, It/sec 0.610, Tokens/sec 9.767, Trained Tokens 31360, Peak mem 5.772 GB
# Iter 1970: Train loss 0.036, Learning Rate 2.000e-04, It/sec 0.610, Tokens/sec 9.760, Trained Tokens 31520, Peak mem 5.772 GB
# Iter 1980: Train loss 0.009, Learning Rate 2.000e-04, It/sec 0.610, Tokens/sec 9.758, Trained Tokens 31680, Peak mem 5.772 GB
# Iter 1990: Train loss 0.005, Learning Rate 2.000e-04, It/sec 0.610, Tokens/sec 9.759, Trained Tokens 31840, Peak mem 5.772 GB
# Calculating loss...: 100%|██████████████████████| 25/25 [00:21<00:00,  1.18it/s]
# Iter 2000: Val loss 0.017, Val took 21.223s
# Iter 2000: Train loss 0.067, Learning Rate 2.000e-04, It/sec 0.610, Tokens/sec 9.756, Trained Tokens 32000, Peak mem 5.772 GB
# Iter 2000: Saved adapter weights to adapters_w3/T3B_minimal/adapters.safetensors and adapters_w3/T3B_minimal/0002000_adapters.safetensors.
# Saved final weights to adapters_w3/T3B_minimal/adapters.safetensors.

# %%
# ── Load model with T3B_minimal adapter ──────────────────────────────
model_mlx, tok_mlx = load(
    MODEL_ID,
    adapter_path="./adapters_w3/T3B_minimal",
)

# ── Inference ──────────────────────────────────────────────────────
t0 = time.time()
preds, refs, probs = run_inference_mlx(
    model_mlx, tok_mlx, test_ds_structured_minimal, return_probs=True
)

# ── Evaluate ───────────────────────────────────────────────────────
metrics = evaluate_predictions(preds, refs, label_name="T3B_minimal")

# ── Calibration ────────────────────────────────────────────────────
ece = calibration_analysis(
    probs, refs,
    label_name="T3B_minimal",
    save_path=os.path.join(OUTPUT_DIR, "calibration_T3B_minimal.png")
)
metrics["ECE"] = ece
all_metrics.append(metrics)

# ── Save predictions ───────────────────────────────────────────────
out_df = pd.DataFrame({"Predicted_Label": preds, "Ground_Truth": refs, "P_Yes": probs})
out_df.to_csv(os.path.join(OUTPUT_DIR, "predictions_T3B_minimal.csv"), index=False)

elapsed = round(time.time() - t0, 2)
experiment_times["T3B_minimal"] = elapsed
print(f"\n  ⏱ T3B_minimal done in {elapsed:.1f}s")

# ── Clean up ───────────────────────────────────────────────────────
del model_mlx, tok_mlx
# Out:
# Downloading (incomplete total...): 0.00B [00:00, ?B/s]
# Fetching 9 files:   0%|          | 0/9 [00:00<?, ?it/s]
# Generating:   0%|          | 0/8275 [00:00<?, ?it/s]
# ── T3B_minimal ──
#   Label: T3B_minimal
#   N_test: 8275
#   Accuracy: 0.96
#   Recall: 0.8401
#   Precision: 0.8132
#   F1: 0.8264
#   Unknown: 0
#               precision    recall  f1-score   support
#
#           No       0.98      0.98      0.98      7337
#          Yes       0.81      0.84      0.83       938
#
#     accuracy                           0.96      8275
#    macro avg       0.90      0.91      0.90      8275
# weighted avg       0.96      0.96      0.96      8275
#
#   ECE: 0.0181 | Saved → ./results_wave3/calibration_T3B_minimal.png
#
#   ⏱ T3B_minimal done in 2710.7s

# %% [markdown]
# ### Save Results Summary

# %%
results_df = pd.DataFrame(all_metrics)
results_csv = os.path.join(OUTPUT_DIR, "results_wave3_summary.csv")
results_df.to_csv(results_csv, index=False)
print("\n── Final Results (Wave 3) ──")
print(results_df.to_string(index=False))
print(f"\nSaved → {results_csv}")

print("\n── Experiment Runtimes ──")
for exp, t in experiment_times.items():
    print(f"  {exp}: {t:.1f}s")
# Out:
# ── Final Results (Wave 3) ──
#                  Label  N_test  Accuracy  Recall  Precision     F1  Unknown    ECE
#         T1A_imbalanced    8275    0.9601  0.8412     0.8134 0.8270        0 0.0180
#        T1B_oversampled    8275    0.9473  0.8923     0.7142 0.7934        0 0.0122
#          T2A_demo_only    8275    0.8916  0.3966     0.5292 0.4534        0 0.0684
# T2C_longitudinal_model    8275    0.9601  0.8412     0.8134 0.8270        0 0.0180
#           T3A_zeroshot    8275    0.4214  0.9392     0.1570 0.2690        0 0.0069
#          T3A_narrative    8275    0.9601  0.8412     0.8134 0.8270        0 0.0180
#            T3B_minimal    8275    0.9600  0.8401     0.8132 0.8264        0 0.0181
#
# Saved → ./results_wave3/results_wave3_summary.csv
#
# ── Experiment Runtimes ──
#   T1A_imbalanced: 2913.0s
#   T1B_oversampled: 2915.5s
#   T2A_demo_only: 2732.8s
#   T2C_longitudinal_model: 2494.8s
#   T3A_zeroshot: 2469.3s
#   T3A_narrative: 2685.2s
#   T3B_minimal: 2710.7s
